# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ##### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle, class_weight

import keras
from keras.layers import Input, Conv2D, Add, Activation, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, LeakyReLU, Flatten, ZeroPadding2D
from keras import layers
from tensorflow.keras.applications import ResNet50V2, EfficientNetB4
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.layers.merge import add
from keras.activations import relu, softmax
from keras.models import Sequential
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import Adam
from keras.layers.experimental.preprocessing import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom

import os, shutil, random, cv2
from shutil import copyfile
from distutils.dir_util import copy_tree
from tqdm import tqdm

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *Chest X-Ray Images (Pneumonia)*
# [Kaggle](https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia)
# [Paper](http://www.cell.com/cell/fulltext/S0092-8674(18)30154-5)
# [Data](https://data.mendeley.com/datasets/rscbjbr9sj/2)

# %%
# problem: also 'small' part of the normal images in the used covid dataset
if not os.path.exists('chest_xray'):
    # !wget https://data.mendeley.com/public-files/datasets/rscbjbr9sj/files/f12eaf6d-6023-432f-acc9-80c9d7393433/file_downloaded -O ChestXRay2017.zip
    # !unzip -q ChestXRay2017.zip
    # !rm ChestXRay2017.zip
    # !rm -r __MACOSX
    # !rm chest_xray/train/PNEUMONIA/.DS_Store
# Out:
# --2021-06-07 14:28:40--  https://data.mendeley.com/public-files/datasets/rscbjbr9sj/files/f12eaf6d-6023-432f-acc9-80c9d7393433/file_downloaded
# Resolving data.mendeley.com (data.mendeley.com)... 162.159.130.86, 162.159.133.86
# Connecting to data.mendeley.com (data.mendeley.com)|162.159.130.86|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com/31ab5ede-ed34-46d4-b1bf-c63d70411497 [following]
# --2021-06-07 14:28:41--  https://md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com/31ab5ede-ed34-46d4-b1bf-c63d70411497
# Resolving md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com (md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com)... 52.218.92.112
# Connecting to md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com (md-datasets-public-files-prod.s3.eu-west-1.amazonaws.com)|52.218.92.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1235512464 (1.2G) [application/zip]
# Saving to: ‘ChestXRay2017.zip’
#
# ChestXRay2017.zip   100%[===================>]   1.15G  39.6MB/s    in 29s
#
# 2021-06-07 14:29:10 (41.1 MB/s) - ‘ChestXRay2017.zip’ saved [1235512464/1235512464]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Set fixed random seed
seed = 42
np.random.seed(seed)
random.seed(seed)
random_state = 42

# Data parameters
SPLIT = 0.15
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SIZE = [256, 256] # dataset image size is 299x299
EPOCHS = 20

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/paultimothymooney/chest-xray-pneumonia

# path to normal 
normal_imgpaths = ['chest_xray/train/NORMAL', 'chest_xray/test/NORMAL']

# path to pneumonia 
pneumonia_imgpaths = ['chest_xray/train/PNEUMONIA', 'chest_xray/test/PNEUMONIA']

# %%
# stats
normal_cnt = sum([len([name for name in os.listdir(path) if os.path.isfile(os.path.join(path, name))]) for path in normal_imgpaths])
pneumonia_cnt = sum([len([name for name in os.listdir(path) if os.path.isfile(os.path.join(path, name))]) for path in pneumonia_imgpaths])

class_count = {'normal': normal_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 1583, 'pneumonia': 4273}
# Total images:  5856

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpaths, pneumonia_imgpaths = paths
    filenames = []
    y_labels = []

    # nomal
    nomal_images = []
    for nomal_imgpath in normal_imgpaths:
        nomal_images.extend([nomal_imgpath + '/' + name for name in os.listdir(nomal_imgpath) if os.path.isfile(os.path.join(nomal_imgpath, name))])
    random.shuffle(nomal_images)
    nomal_images = nomal_images[:int(len(nomal_images))]
    filenames.extend(nomal_images)
    y_labels.extend([label_encoding.index('normal') for img in nomal_images])

    # pneumonia
    pneumonia_images = []
    for pneumonia_imgpath in pneumonia_imgpaths:
        pneumonia_images.extend([pneumonia_imgpath + '/' + name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])
    random.shuffle(pneumonia_images)
    pneumonia_images = pneumonia_images[:int(IMBALANCE_RATIO*len(nomal_images))]
    filenames.extend(pneumonia_images)
    y_labels.extend([label_encoding.index('pneumonia') for img in pneumonia_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = [normal_imgpaths, pneumonia_imgpaths]
label_encoding = ['normal', 'pneumonia'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-val-test split
x_train, x_val, y_train, y_val = train_test_split(files, labels, test_size=2*SPLIT, random_state=random_state)
x_val, x_test, y_val, y_test = train_test_split(x_val, y_val, test_size=0.5, random_state=random_state)

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'pneumonia': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set:   ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 1093, 'pneumonia': 1676}
# val set:    {'normal': 256, 'pneumonia': 338}
# test set:   {'normal': 234, 'pneumonia': 360}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    file_path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_ds).numpy()
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_ds).numpy()
TEST_IMG_COUNT = tf.data.experimental.cardinality(test_ds).numpy()
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 2769, Val: 594, Test: 594

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
resize_and_rescale = tf.keras.Sequential([
  Resizing(IMG_SIZE[0], IMG_SIZE[1]),
  Rescaling(1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for quick overview
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range=(0.85, 1.15), # randomly zoom image 
        brightness_range=(0.9, 1.1), # randomly shift brightness
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False,    # randomly flip images
        fill_mode='constant',   # constant filling of points outside boundaries of input
        cval=0.,)   # fill with zeros, see fill_mode

# %%
class RandomBrightness(layers.Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = tf.keras.Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_training(ds, shuffle=False, repeat=False, augment=False, cache=True, shuffle_buffer_size=1000):
    # Resize and rescale all datasets
    ds = ds.map(lambda x, y: (resize_and_rescale(x), y),
                num_parallel_calls=AUTOTUNE)

    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    # repeat training set forever
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)

    # batch all datasets
    ds = ds.batch(BATCH_SIZE)

    # use data augmentation only on the training set
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    # fetches batches in the background while training the model
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %%
train_batched = prepare_training(train_ds, shuffle=True, repeat=True, augment=True, cache='cache')
val_batched = prepare_training(val_ds)
test_batched = prepare_training(test_ds)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("PNEUMONIA")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)

class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())
print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for pneumonia: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	1.27
# Weight for pneumonia: 	0.83

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ### Early stopping

# %%
# checkpoint = ModelCheckpoint("x-covid.h5", monitor=monitor='val_loss', save_best_only=True)
# early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# ## DP-Net - CNN Archecture for DP-SGD
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# [[Paper 2](https://openreview.net/forum?id=rJg851rYwH)]
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_builder():
    # create DP-Net
    dpnet = Sequential([
        Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='relu'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ])
    return dpnet

# %%
dpnet = dpnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet.compile(
    optimizer=Adam(lr=1e-3), # default: 1e-3
    loss='binary_crossentropy',
    metrics=METRICS
)
# Out:
# WARNING:tensorflow:Please add `keras.layers.InputLayer` instead of `keras.Input` to Sequential model. `keras.Input` is intended to be used by Functional model.
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
dpnet.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization (BatchNo (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                230432
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet = dpnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# 86/86 [==============================] - 86s 553ms/step - loss: 0.4631 - accuracy: 0.7694 - precision: 0.8692 - recall: 0.7207 - val_loss: 1.4509 - val_accuracy: 0.5712 - val_precision: 0.5712 - val_recall: 1.0000
# Epoch 2/20
# 86/86 [==============================] - 37s 438ms/step - loss: 0.3141 - accuracy: 0.8701 - precision: 0.9157 - recall: 0.8659 - val_loss: 1.6816 - val_accuracy: 0.5712 - val_precision: 0.5712 - val_recall: 1.0000
# Epoch 3/20
# 86/86 [==============================] - 37s 436ms/step - loss: 0.2703 - accuracy: 0.8873 - precision: 0.9346 - recall: 0.8680 - val_loss: 1.3086 - val_accuracy: 0.5799 - val_precision: 0.5764 - val_recall: 0.9970
# Epoch 4/20
# 86/86 [==============================] - 38s 446ms/step - loss: 0.2741 - accuracy: 0.8758 - precision: 0.9377 - recall: 0.8573 - val_loss: 0.3983 - val_accuracy: 0.8056 - val_precision: 0.7506 - val_recall: 0.9878
# Epoch 5/20
# 86/86 [==============================] - 35s 410ms/step - loss: 0.2708 - accuracy: 0.8894 - precision: 0.9417 - recall: 0.8712 - val_loss: 3.8077 - val_accuracy: 0.4288 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 86/86 [==============================] - 35s 414ms/step - loss: 0.2750 - accuracy: 0.8909 - precision: 0.9357 - recall: 0.8774 - val_loss: 4.2324 - val_accuracy: 0.5660 - val_precision: 0.5689 - val_recall: 0.9909
# Epoch 7/20
# 86/86 [==============================] - 21s 242ms/step - loss: 0.2298 - accuracy: 0.8985 - precision: 0.9457 - recall: 0.8841 - val_loss: 1.5410 - val_accuracy: 0.6250 - val_precision: 0.6044 - val_recall: 0.9939
# Epoch 8/20
# 86/86 [==============================] - 31s 360ms/step - loss: 0.2341 - accuracy: 0.8994 - precision: 0.9490 - recall: 0.8808 - val_loss: 0.2179 - val_accuracy: 0.9288 - val_precision: 0.9091 - val_recall: 0.9726
# Epoch 9/20
# 86/86 [==============================] - 31s 361ms/step - loss: 0.2466 - accuracy: 0.9004 - precision: 0.9493 - recall: 0.8884 - val_loss: 0.1799 - val_accuracy: 0.9340 - val_precision: 0.9450 - val_recall: 0.9392
# Epoch 10/20
# 86/86 [==============================] - 31s 367ms/step - loss: 0.2387 - accuracy: 0.9062 - precision: 0.9573 - recall: 0.8897 - val_loss: 0.2427 - val_accuracy: 0.9184 - val_precision: 0.8917 - val_recall: 0.9757
# Epoch 11/20
# 86/86 [==============================] - 32s 377ms/step - loss: 0.2246 - accuracy: 0.9053 - precision: 0.9463 - recall: 0.8973 - val_loss: 0.4339 - val_accuracy: 0.8299 - val_precision: 0.9833 - val_recall: 0.7143
# Epoch 12/20
# 86/86 [==============================] - 30s 355ms/step - loss: 0.2227 - accuracy: 0.9080 - precision: 0.9418 - recall: 0.9039 - val_loss: 0.2414 - val_accuracy: 0.9080 - val_precision: 0.9694 - val_recall: 0.8663
# Epoch 13/20
# 86/86 [==============================] - 31s 362ms/step - loss: 0.2253 - accuracy: 0.9128 - precision: 0.9496 - recall: 0.9027 - val_loss: 0.2162 - val_accuracy: 0.9184 - val_precision: 0.9638 - val_recall: 0.8906
# Epoch 14/20
# 86/86 [==============================] - 31s 362ms/step - loss: 0.2185 - accuracy: 0.9111 - precision: 0.9533 - recall: 0.8966 - val_loss: 0.2067 - val_accuracy: 0.9184 - val_precision: 0.9578 - val_recall: 0.8967
# Epoch 15/20
# 86/86 [==============================] - 31s 361ms/step - loss: 0.2099 - accuracy: 0.9281 - precision: 0.9644 - recall: 0.9149 - val_loss: 0.2057 - val_accuracy: 0.9201 - val_precision: 0.9579 - val_recall: 0.8997
# Epoch 16/20
# 86/86 [==============================] - 32s 371ms/step - loss: 0.2218 - accuracy: 0.9126 - precision: 0.9526 - recall: 0.9013 - val_loss: 0.2098 - val_accuracy: 0.9184 - val_precision: 0.9578 - val_recall: 0.8967
# Epoch 17/20
# 86/86 [==============================] - 32s 368ms/step - loss: 0.2006 - accuracy: 0.9250 - precision: 0.9612 - recall: 0.9137 - val_loss: 0.2054 - val_accuracy: 0.9201 - val_precision: 0.9579 - val_recall: 0.8997
# Epoch 18/20
# 86/86 [==============================] - 30s 355ms/step - loss: 0.2053 - accuracy: 0.9236 - precision: 0.9452 - recall: 0.9242 - val_loss: 0.2035 - val_accuracy: 0.9201 - val_precision: 0.9579 - val_recall: 0.8997
# Epoch 19/20
# 86/86 [==============================] - 32s 366ms/step - loss: 0.2320 - accuracy: 0.9032 - precision: 0.9553 - recall: 0.8828 - val_loss: 0.1997 - val_accuracy: 0.9201 - val_precision: 0.9579 - val_recall: 0.8997
# Epoch 20/20
# 86/86 [==============================] - 31s 365ms/step - loss: 0.2334 - accuracy: 0.9038 - precision: 0.9485 - recall: 0.8914 - val_loss: 0.2033 - val_accuracy: 0.9201 - val_precision: 0.9579 - val_recall: 0.8997

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet.history[met])
    ax[i].plot(history_dpnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 19/19 [==============================] - 4s 209ms/step - loss: 0.2685 - accuracy: 0.9007 - precision: 0.9659 - recall: 0.8667
# Loss of the model is -  0.2684589922428131
# Accuracy of the model is -  90.06733894348145 %
# Precision of the model is -  0.9659442901611328
# Recall of the model is -  0.8666666746139526

# %% [markdown]
# ###### Save for transfer learning

# %%
# save model
# attach the preprocessing layers!
#resnet18.save("resnet18_public.h5")
# load model
#resnet18 = keras.models.load_model("resnet18_public.h5")

# save weights
dpnet.save_weights('dpnet_relu_public_weights.h5')
# load weights
#resnet18.load_weights('resnet18_tanh_public_weights.h5') #, by_name=True)
