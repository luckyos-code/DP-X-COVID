# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install git+https://github.com/tensorflow/privacy
# Out:
#      |████████████████████████████████| 4.0 MB 10.4 MB/s
#   Building wheel for tensorflow-privacy (setup.py) ... done

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from tensorflow.keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SingleAttackResult
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 100% 780M/780M [00:04<00:00, 181MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SHAPE = [224, 224, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-val-test split with 80-5-15
x_train, x_rest, y_train, y_rest = train_test_split(files, labels, test_size=VAL_SPLIT+TEST_SPLIT, random_state=random_state)
x_test, x_val, y_test, y_val = train_test_split(x_rest, y_rest, test_size=VAL_SPLIT/(VAL_SPLIT+TEST_SPLIT), random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7232, Val: 452, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4339, 'COVID-19': 2893}
# val set:  {'normal': 272, 'COVID-19': 180}
# test set:   {'normal': 813, 'COVID-19': 543}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# set for attack on train set
train_attack_data = prepare_dataset(train_ds,
                                    pre=True,
                                    shuffle=False,
                                    repeat=False,
                                    batch=1,
                                    augment=False,
                                    cache=False)

# set for attack on test set
test_attack_data = prepare_dataset(test_ds,
                                   pre=True,
                                   shuffle=False,
                                   repeat=False,
                                   batch=1,
                                   augment=False,
                                   cache=False)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## Shallow Network
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def shallow_builder(weights=False, dropout=False, bn=False, activation='relu', name='ShallowNetwork'):

    seq = [InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]), name='Input'),]
    seq.append(Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation=activation, name='Conv1'))
    if bn:
        seq.append(BatchNormalization(name='BN1'))
    seq.append(MaxPooling2D(pool_size=(2,2), name='Pool1'))
    seq.append(Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation=activation, name='Conv2'))
    if bn:
        seq.append(BatchNormalization(name='BN2'))
    seq.append(MaxPooling2D(pool_size=(2,2), name='Pool2'))
    seq.append(Flatten(name='Flatten'))
    seq.append(Dense(units=32, activation=activation, name='Dense'))
    if bn:
        seq.append(BatchNormalization(name='BN3'))
    if dropout:
        seq.append(Dropout(rate=dropout, name='Dropout'))
    seq.append(Dense(units=1, activation='sigmoid', name='Output'))

    model = Sequential(seq, name=name)

    # load weights from pneumonia pretraining
    if weights == 'pneumonia' and activation == 'relu':
        model.load_weights(weights_path+'shallow_relu_public_weights.h5', by_name=True)
    if weights == 'pneumonia' and activation == 'tanh':
        model.load_weights(weights_path+'shallow_tanh_public_weights.h5', by_name=True)
    
    return model

# %%
shallow = shallow_builder(name='ShallowNetwork')
shallow_dropout = shallow_builder(dropout=0.2, name='ShallowNetwork-dropout')
shallow_bn = shallow_builder(bn=True, name='ShallowNetwork-bn')
shallow_pneumonia_bn = shallow_builder(weights='pneumonia', bn=True, name='ShallowNetwork-pneumonia-bn')

#shallow_tanh = shallow_builder(activation='tanh', name='ShallowNetwork-tanh')
#shallow_tanh_bn = shallow_builder(activation='tanh', bn=True, name='ShallowNetwork-tanh-bn')
#shallow_tanh_dropout_bn = shallow_builder(activation='tanh', dropout=0.2, bn=True, name='ShallowNetwork-tanh-dropout-bn')
#shallow_tanh_pneumonia_bn = shallow_builder(activation='tanh', weights='pneumonia', bn=True, name='ShallowNetwork-tanh-pneumonia-bn')

models = [
    shallow,
    shallow_dropout,
    shallow_bn,
    shallow_pneumonia_bn,
    #shallow_tanh,
    #shallow_tanh_bn,
    #shallow_tanh_dropout_bn,
    #shallow_tanh_pneumonia_bn,
]

METRICS = [
    'accuracy',
    Precision(name='precision'),
    Recall(name='recall')
]

for model in models:
    model.compile(
        optimizer=Adam(learning_rate=1e-3),
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
models[0].summary()
# Out:
# Model: "ShallowNetwork"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv1 (Conv2D)               (None, 109, 109, 16)      3088
# _________________________________________________________________
# Pool1 (MaxPooling2D)         (None, 54, 54, 16)        0
# _________________________________________________________________
# Conv2 (Conv2D)               (None, 26, 26, 32)        8224
# _________________________________________________________________
# Pool2 (MaxPooling2D)         (None, 13, 13, 32)        0
# _________________________________________________________________
# Flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# Dense (Dense)                (None, 32)                173088
# _________________________________________________________________
# Output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 184,433
# Trainable params: 184,433
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
for model in models:
    print("Training %s ..." % (model.name))
    history = model.fit(
        train_batched,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_batched,
        validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
        class_weight=class_weight_dict,
        callbacks = [learning_rate_decay],
    )
    print('\n')
# Out:
# Training ShallowNetwork ...
# Epoch 1/20
# 226/226 [==============================] - 111s 401ms/step - loss: 0.6662 - accuracy: 0.5801 - precision: 0.4793 - recall: 0.5752 - val_loss: 0.5713 - val_accuracy: 0.6719 - val_precision: 0.5820 - val_recall: 0.6180
# Epoch 2/20
# 226/226 [==============================] - 78s 348ms/step - loss: 0.5950 - accuracy: 0.6726 - precision: 0.5750 - recall: 0.6955 - val_loss: 0.5940 - val_accuracy: 0.6763 - val_precision: 0.5657 - val_recall: 0.7978
# Epoch 3/20
# 226/226 [==============================] - 79s 350ms/step - loss: 0.5793 - accuracy: 0.6820 - precision: 0.5826 - recall: 0.7228 - val_loss: 0.5467 - val_accuracy: 0.7076 - val_precision: 0.6667 - val_recall: 0.5281
# Epoch 4/20
# 226/226 [==============================] - 79s 350ms/step - loss: 0.5690 - accuracy: 0.6896 - precision: 0.5895 - recall: 0.7380 - val_loss: 0.5335 - val_accuracy: 0.6987 - val_precision: 0.6188 - val_recall: 0.6292
# Epoch 5/20
# 226/226 [==============================] - 79s 350ms/step - loss: 0.5442 - accuracy: 0.7040 - precision: 0.6019 - recall: 0.7677 - val_loss: 0.5375 - val_accuracy: 0.7188 - val_precision: 0.6781 - val_recall: 0.5562
# Epoch 6/20
# 226/226 [==============================] - 79s 349ms/step - loss: 0.5308 - accuracy: 0.7188 - precision: 0.6146 - recall: 0.7961 - val_loss: 0.5138 - val_accuracy: 0.7254 - val_precision: 0.6471 - val_recall: 0.6798
# Epoch 7/20
# 226/226 [==============================] - 79s 349ms/step - loss: 0.5207 - accuracy: 0.7222 - precision: 0.6171 - recall: 0.8050 - val_loss: 0.5056 - val_accuracy: 0.7388 - val_precision: 0.6502 - val_recall: 0.7416
# Epoch 8/20
# 226/226 [==============================] - 78s 348ms/step - loss: 0.5114 - accuracy: 0.7223 - precision: 0.6158 - recall: 0.8133 - val_loss: 0.5039 - val_accuracy: 0.7165 - val_precision: 0.6123 - val_recall: 0.7809
# Epoch 9/20
# 226/226 [==============================] - 79s 349ms/step - loss: 0.5002 - accuracy: 0.7275 - precision: 0.6229 - recall: 0.8075 - val_loss: 0.4964 - val_accuracy: 0.7344 - val_precision: 0.6667 - val_recall: 0.6629
# Epoch 10/20
# 226/226 [==============================] - 78s 346ms/step - loss: 0.5077 - accuracy: 0.7329 - precision: 0.6286 - recall: 0.8120 - val_loss: 0.5051 - val_accuracy: 0.7299 - val_precision: 0.6707 - val_recall: 0.6292
# Epoch 11/20
# 226/226 [==============================] - 78s 348ms/step - loss: 0.4880 - accuracy: 0.7407 - precision: 0.6354 - recall: 0.8254 - val_loss: 0.4982 - val_accuracy: 0.7478 - val_precision: 0.6946 - val_recall: 0.6517
# Epoch 12/20
# 226/226 [==============================] - 78s 348ms/step - loss: 0.4622 - accuracy: 0.7478 - precision: 0.6420 - recall: 0.8351 - val_loss: 0.4739 - val_accuracy: 0.7433 - val_precision: 0.6615 - val_recall: 0.7247
# Epoch 13/20
# 226/226 [==============================] - 77s 344ms/step - loss: 0.4655 - accuracy: 0.7467 - precision: 0.6407 - recall: 0.8351 - val_loss: 0.4694 - val_accuracy: 0.7433 - val_precision: 0.6425 - val_recall: 0.7978
# Epoch 14/20
# 226/226 [==============================] - 78s 344ms/step - loss: 0.4616 - accuracy: 0.7511 - precision: 0.6442 - recall: 0.8438 - val_loss: 0.4648 - val_accuracy: 0.7567 - val_precision: 0.6845 - val_recall: 0.7191
# Epoch 15/20
# 226/226 [==============================] - 77s 342ms/step - loss: 0.4563 - accuracy: 0.7565 - precision: 0.6503 - recall: 0.8465 - val_loss: 0.4651 - val_accuracy: 0.7522 - val_precision: 0.6791 - val_recall: 0.7135
# Epoch 16/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.4582 - accuracy: 0.7562 - precision: 0.6502 - recall: 0.8455 - val_loss: 0.4642 - val_accuracy: 0.7500 - val_precision: 0.6719 - val_recall: 0.7247
# Epoch 17/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.4552 - accuracy: 0.7576 - precision: 0.6528 - recall: 0.8417 - val_loss: 0.4564 - val_accuracy: 0.7455 - val_precision: 0.6495 - val_recall: 0.7809
# Epoch 18/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.4505 - accuracy: 0.7627 - precision: 0.6572 - recall: 0.8503 - val_loss: 0.4589 - val_accuracy: 0.7612 - val_precision: 0.6919 - val_recall: 0.7191
# Epoch 19/20
# 226/226 [==============================] - 76s 339ms/step - loss: 0.4487 - accuracy: 0.7619 - precision: 0.6588 - recall: 0.8396 - val_loss: 0.4534 - val_accuracy: 0.7545 - val_precision: 0.6667 - val_recall: 0.7640
# Epoch 20/20
# 226/226 [==============================] - 77s 340ms/step - loss: 0.4446 - accuracy: 0.7677 - precision: 0.6625 - recall: 0.8548 - val_loss: 0.4543 - val_accuracy: 0.7589 - val_precision: 0.6733 - val_recall: 0.7640
#
#
# Training ShallowNetwork-dropout ...
# Epoch 1/20
# 226/226 [==============================] - 80s 345ms/step - loss: 0.6948 - accuracy: 0.4845 - precision: 0.4161 - recall: 0.6177 - val_loss: 0.6937 - val_accuracy: 0.3973 - val_precision: 0.3973 - val_recall: 1.0000
# Epoch 2/20
# 226/226 [==============================] - 77s 342ms/step - loss: 0.6932 - accuracy: 0.4397 - precision: 0.4060 - recall: 0.8648 - val_loss: 0.6921 - val_accuracy: 0.6004 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.6931 - accuracy: 0.5796 - precision: 0.4330 - recall: 0.1642 - val_loss: 0.6960 - val_accuracy: 0.3951 - val_precision: 0.3906 - val_recall: 0.9326
# Epoch 4/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.6921 - accuracy: 0.5326 - precision: 0.4265 - recall: 0.4888 - val_loss: 0.6995 - val_accuracy: 0.4174 - val_precision: 0.3422 - val_recall: 0.5056
# Epoch 5/20
# 226/226 [==============================] - 76s 339ms/step - loss: 0.6865 - accuracy: 0.5701 - precision: 0.4703 - recall: 0.5918 - val_loss: 0.6846 - val_accuracy: 0.6228 - val_precision: 0.5338 - val_recall: 0.3989
# Epoch 6/20
# 226/226 [==============================] - 77s 339ms/step - loss: 0.6575 - accuracy: 0.6326 - precision: 0.5388 - recall: 0.5658 - val_loss: 0.6372 - val_accuracy: 0.6362 - val_precision: 0.5949 - val_recall: 0.2640
# Epoch 7/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.6317 - accuracy: 0.6507 - precision: 0.5588 - recall: 0.6025 - val_loss: 0.6071 - val_accuracy: 0.6696 - val_precision: 0.6786 - val_recall: 0.3202
# Epoch 8/20
# 226/226 [==============================] - 77s 342ms/step - loss: 0.6216 - accuracy: 0.6643 - precision: 0.5698 - recall: 0.6564 - val_loss: 0.5904 - val_accuracy: 0.6875 - val_precision: 0.6727 - val_recall: 0.4157
# Epoch 9/20
# 226/226 [==============================] - 77s 342ms/step - loss: 0.6052 - accuracy: 0.6746 - precision: 0.5784 - recall: 0.6889 - val_loss: 0.5762 - val_accuracy: 0.6830 - val_precision: 0.6837 - val_recall: 0.3764
# Epoch 10/20
# 226/226 [==============================] - 76s 339ms/step - loss: 0.5937 - accuracy: 0.6839 - precision: 0.5865 - recall: 0.7114 - val_loss: 0.5813 - val_accuracy: 0.6674 - val_precision: 0.6933 - val_recall: 0.2921
# Epoch 11/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.5865 - accuracy: 0.6919 - precision: 0.5940 - recall: 0.7262 - val_loss: 0.5588 - val_accuracy: 0.7254 - val_precision: 0.6455 - val_recall: 0.6854
# Epoch 12/20
# 226/226 [==============================] - 78s 344ms/step - loss: 0.5853 - accuracy: 0.6897 - precision: 0.5909 - recall: 0.7290 - val_loss: 0.5451 - val_accuracy: 0.7121 - val_precision: 0.6738 - val_recall: 0.5337
# Epoch 13/20
# 226/226 [==============================] - 77s 342ms/step - loss: 0.5794 - accuracy: 0.6959 - precision: 0.5971 - recall: 0.7373 - val_loss: 0.5436 - val_accuracy: 0.7143 - val_precision: 0.7193 - val_recall: 0.4607
# Epoch 14/20
# 226/226 [==============================] - 77s 344ms/step - loss: 0.5669 - accuracy: 0.7041 - precision: 0.6056 - recall: 0.7463 - val_loss: 0.5324 - val_accuracy: 0.7388 - val_precision: 0.6805 - val_recall: 0.6461
# Epoch 15/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.5649 - accuracy: 0.6999 - precision: 0.6006 - recall: 0.7459 - val_loss: 0.5420 - val_accuracy: 0.7210 - val_precision: 0.7304 - val_recall: 0.4719
# Epoch 16/20
# 226/226 [==============================] - 78s 346ms/step - loss: 0.5647 - accuracy: 0.7040 - precision: 0.6023 - recall: 0.7653 - val_loss: 0.5244 - val_accuracy: 0.7455 - val_precision: 0.7222 - val_recall: 0.5843
# Epoch 17/20
# 226/226 [==============================] - 77s 342ms/step - loss: 0.5627 - accuracy: 0.7073 - precision: 0.6069 - recall: 0.7615 - val_loss: 0.5230 - val_accuracy: 0.7455 - val_precision: 0.7500 - val_recall: 0.5393
# Epoch 18/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.5556 - accuracy: 0.7163 - precision: 0.6184 - recall: 0.7591 - val_loss: 0.5139 - val_accuracy: 0.7656 - val_precision: 0.7355 - val_recall: 0.6404
# Epoch 19/20
# 226/226 [==============================] - 76s 338ms/step - loss: 0.5510 - accuracy: 0.7181 - precision: 0.6194 - recall: 0.7656 - val_loss: 0.5162 - val_accuracy: 0.7589 - val_precision: 0.6823 - val_recall: 0.7360
# Epoch 20/20
# 226/226 [==============================] - 77s 340ms/step - loss: 0.5476 - accuracy: 0.7251 - precision: 0.6266 - recall: 0.7743 - val_loss: 0.5125 - val_accuracy: 0.7634 - val_precision: 0.6978 - val_recall: 0.7135
#
#
# Training ShallowNetwork-bn ...
# Epoch 1/20
# 226/226 [==============================] - 81s 346ms/step - loss: 0.5872 - accuracy: 0.6885 - precision: 0.5950 - recall: 0.7258 - val_loss: 0.6294 - val_accuracy: 0.6964 - val_precision: 0.6944 - val_recall: 0.4213
# Epoch 2/20
# 226/226 [==============================] - 77s 340ms/step - loss: 0.5203 - accuracy: 0.7367 - precision: 0.6433 - recall: 0.7674 - val_loss: 1.9508 - val_accuracy: 0.6049 - val_precision: 1.0000 - val_recall: 0.0056
# Epoch 3/20
# 226/226 [==============================] - 77s 344ms/step - loss: 0.4936 - accuracy: 0.7540 - precision: 0.6663 - recall: 0.7715 - val_loss: 0.6651 - val_accuracy: 0.6719 - val_precision: 0.5498 - val_recall: 0.9607
# Epoch 4/20
# 226/226 [==============================] - 78s 345ms/step - loss: 0.4723 - accuracy: 0.7665 - precision: 0.6805 - recall: 0.7847 - val_loss: 0.4477 - val_accuracy: 0.7879 - val_precision: 0.8673 - val_recall: 0.5506
# Epoch 5/20
# 226/226 [==============================] - 78s 347ms/step - loss: 0.4441 - accuracy: 0.7875 - precision: 0.7043 - recall: 0.8078 - val_loss: 0.4258 - val_accuracy: 0.7991 - val_precision: 0.7785 - val_recall: 0.6910
# Epoch 6/20
# 226/226 [==============================] - 78s 346ms/step - loss: 0.4274 - accuracy: 0.7989 - precision: 0.7177 - recall: 0.8199 - val_loss: 0.4074 - val_accuracy: 0.8214 - val_precision: 0.8224 - val_recall: 0.7022
# Epoch 7/20
# 226/226 [==============================] - 79s 348ms/step - loss: 0.4208 - accuracy: 0.8045 - precision: 0.7254 - recall: 0.8227 - val_loss: 0.3980 - val_accuracy: 0.8170 - val_precision: 0.7927 - val_recall: 0.7303
# Epoch 8/20
# 226/226 [==============================] - 78s 347ms/step - loss: 0.4126 - accuracy: 0.8038 - precision: 0.7241 - recall: 0.8230 - val_loss: 0.4172 - val_accuracy: 0.8080 - val_precision: 0.8382 - val_recall: 0.6404
# Epoch 9/20
# 226/226 [==============================] - 78s 347ms/step - loss: 0.4047 - accuracy: 0.8111 - precision: 0.7312 - recall: 0.8348 - val_loss: 0.3912 - val_accuracy: 0.8281 - val_precision: 0.8483 - val_recall: 0.6910
# Epoch 10/20
# 226/226 [==============================] - 77s 344ms/step - loss: 0.3992 - accuracy: 0.8143 - precision: 0.7393 - recall: 0.8275 - val_loss: 0.3930 - val_accuracy: 0.8103 - val_precision: 0.7719 - val_recall: 0.7416
# Epoch 11/20
# 226/226 [==============================] - 78s 346ms/step - loss: 0.3988 - accuracy: 0.8147 - precision: 0.7384 - recall: 0.8313 - val_loss: 0.3987 - val_accuracy: 0.8080 - val_precision: 0.8286 - val_recall: 0.6517
# Epoch 12/20
# 226/226 [==============================] - 78s 346ms/step - loss: 0.3856 - accuracy: 0.8254 - precision: 0.7508 - recall: 0.8434 - val_loss: 0.3863 - val_accuracy: 0.8192 - val_precision: 0.8212 - val_recall: 0.6966
# Epoch 13/20
# 226/226 [==============================] - 78s 347ms/step - loss: 0.3930 - accuracy: 0.8193 - precision: 0.7448 - recall: 0.8341 - val_loss: 0.3867 - val_accuracy: 0.8147 - val_precision: 0.8025 - val_recall: 0.7079
# Epoch 14/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.3873 - accuracy: 0.8240 - precision: 0.7492 - recall: 0.8417 - val_loss: 0.4010 - val_accuracy: 0.8170 - val_precision: 0.8478 - val_recall: 0.6573
# Epoch 15/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.3918 - accuracy: 0.8189 - precision: 0.7421 - recall: 0.8386 - val_loss: 0.3915 - val_accuracy: 0.8192 - val_precision: 0.8299 - val_recall: 0.6854
# Epoch 16/20
# 226/226 [==============================] - 77s 344ms/step - loss: 0.3835 - accuracy: 0.8272 - precision: 0.7541 - recall: 0.8427 - val_loss: 0.3881 - val_accuracy: 0.8192 - val_precision: 0.8170 - val_recall: 0.7022
# Epoch 17/20
# 226/226 [==============================] - 78s 344ms/step - loss: 0.3850 - accuracy: 0.8218 - precision: 0.7444 - recall: 0.8445 - val_loss: 0.3909 - val_accuracy: 0.8170 - val_precision: 0.8200 - val_recall: 0.6910
# Epoch 18/20
# 226/226 [==============================] - 78s 345ms/step - loss: 0.3825 - accuracy: 0.8251 - precision: 0.7511 - recall: 0.8417 - val_loss: 0.3898 - val_accuracy: 0.8147 - val_precision: 0.8146 - val_recall: 0.6910
# Epoch 19/20
# 226/226 [==============================] - 78s 345ms/step - loss: 0.3840 - accuracy: 0.8252 - precision: 0.7505 - recall: 0.8434 - val_loss: 0.3910 - val_accuracy: 0.8147 - val_precision: 0.8146 - val_recall: 0.6910
# Epoch 20/20
# 226/226 [==============================] - 78s 346ms/step - loss: 0.3820 - accuracy: 0.8273 - precision: 0.7546 - recall: 0.8420 - val_loss: 0.3893 - val_accuracy: 0.8192 - val_precision: 0.8212 - val_recall: 0.6966
#
#
# Training ShallowNetwork-pneumonia-bn ...
# Epoch 1/20
# 226/226 [==============================] - 81s 349ms/step - loss: 0.5803 - accuracy: 0.6993 - precision: 0.6033 - recall: 0.7750 - val_loss: 0.9024 - val_accuracy: 0.6875 - val_precision: 0.7159 - val_recall: 0.3539
# Epoch 2/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.5298 - accuracy: 0.7317 - precision: 0.6374 - recall: 0.7639 - val_loss: 2.2657 - val_accuracy: 0.6049 - val_precision: 1.0000 - val_recall: 0.0056
# Epoch 3/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.5088 - accuracy: 0.7459 - precision: 0.6576 - recall: 0.7608 - val_loss: 1.3599 - val_accuracy: 0.3973 - val_precision: 0.3973 - val_recall: 1.0000
# Epoch 4/20
# 226/226 [==============================] - 78s 346ms/step - loss: 0.4853 - accuracy: 0.7612 - precision: 0.6739 - recall: 0.7809 - val_loss: 0.5315 - val_accuracy: 0.7500 - val_precision: 0.7661 - val_recall: 0.5337
# Epoch 5/20
# 226/226 [==============================] - 77s 342ms/step - loss: 0.4664 - accuracy: 0.7763 - precision: 0.6913 - recall: 0.7964 - val_loss: 0.5162 - val_accuracy: 0.7634 - val_precision: 0.6935 - val_recall: 0.7247
# Epoch 6/20
# 226/226 [==============================] - 76s 338ms/step - loss: 0.4636 - accuracy: 0.7761 - precision: 0.6907 - recall: 0.7974 - val_loss: 0.5504 - val_accuracy: 0.7254 - val_precision: 0.8235 - val_recall: 0.3933
# Epoch 7/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.4556 - accuracy: 0.7815 - precision: 0.6996 - recall: 0.7954 - val_loss: 0.4682 - val_accuracy: 0.7723 - val_precision: 0.8167 - val_recall: 0.5506
# Epoch 8/20
# 226/226 [==============================] - 77s 340ms/step - loss: 0.4420 - accuracy: 0.7927 - precision: 0.7113 - recall: 0.8109 - val_loss: 0.4274 - val_accuracy: 0.7902 - val_precision: 0.7308 - val_recall: 0.7472
# Epoch 9/20
# 226/226 [==============================] - 78s 345ms/step - loss: 0.4429 - accuracy: 0.7900 - precision: 0.7072 - recall: 0.8106 - val_loss: 0.4513 - val_accuracy: 0.7924 - val_precision: 0.8571 - val_recall: 0.5730
# Epoch 10/20
# 226/226 [==============================] - 79s 350ms/step - loss: 0.4315 - accuracy: 0.7937 - precision: 0.7130 - recall: 0.8106 - val_loss: 0.4125 - val_accuracy: 0.8080 - val_precision: 0.7840 - val_recall: 0.7135
# Epoch 11/20
# 226/226 [==============================] - 79s 351ms/step - loss: 0.4282 - accuracy: 0.7978 - precision: 0.7187 - recall: 0.8127 - val_loss: 0.4302 - val_accuracy: 0.7902 - val_precision: 0.8750 - val_recall: 0.5506
# Epoch 12/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.4129 - accuracy: 0.8095 - precision: 0.7340 - recall: 0.8213 - val_loss: 0.4812 - val_accuracy: 0.7589 - val_precision: 0.8365 - val_recall: 0.4888
# Epoch 13/20
# 226/226 [==============================] - 78s 347ms/step - loss: 0.4001 - accuracy: 0.8208 - precision: 0.7471 - recall: 0.8344 - val_loss: 0.3761 - val_accuracy: 0.8326 - val_precision: 0.8199 - val_recall: 0.7416
# Epoch 14/20
# 226/226 [==============================] - 78s 349ms/step - loss: 0.4097 - accuracy: 0.8086 - precision: 0.7284 - recall: 0.8317 - val_loss: 0.4113 - val_accuracy: 0.8058 - val_precision: 0.8760 - val_recall: 0.5955
# Epoch 15/20
# 226/226 [==============================] - 79s 351ms/step - loss: 0.3975 - accuracy: 0.8193 - precision: 0.7460 - recall: 0.8313 - val_loss: 0.3767 - val_accuracy: 0.8304 - val_precision: 0.8355 - val_recall: 0.7135
# Epoch 16/20
# 226/226 [==============================] - 79s 350ms/step - loss: 0.4012 - accuracy: 0.8143 - precision: 0.7390 - recall: 0.8282 - val_loss: 0.3716 - val_accuracy: 0.8371 - val_precision: 0.8182 - val_recall: 0.7584
# Epoch 17/20
# 226/226 [==============================] - 80s 354ms/step - loss: 0.3984 - accuracy: 0.8194 - precision: 0.7451 - recall: 0.8337 - val_loss: 0.3725 - val_accuracy: 0.8326 - val_precision: 0.8012 - val_recall: 0.7697
# Epoch 18/20
# 226/226 [==============================] - 79s 350ms/step - loss: 0.4027 - accuracy: 0.8132 - precision: 0.7381 - recall: 0.8261 - val_loss: 0.3713 - val_accuracy: 0.8326 - val_precision: 0.8012 - val_recall: 0.7697
# Epoch 19/20
# 226/226 [==============================] - 79s 351ms/step - loss: 0.3978 - accuracy: 0.8172 - precision: 0.7430 - recall: 0.8303 - val_loss: 0.3718 - val_accuracy: 0.8371 - val_precision: 0.8261 - val_recall: 0.7472
# Epoch 20/20
# 226/226 [==============================] - 79s 351ms/step - loss: 0.3999 - accuracy: 0.8155 - precision: 0.7408 - recall: 0.8289 - val_loss: 0.3716 - val_accuracy: 0.8348 - val_precision: 0.8210 - val_recall: 0.7472

# %% [markdown]
# ## Evaluation

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating ShallowNetwork ...
# 43/43 [==============================] - 4s 92ms/step - loss: 0.4132 - accuracy: 0.7928 - precision: 0.7183 - recall: 0.7937
#
#
# Evaluating ShallowNetwork-dropout ...
# 43/43 [==============================] - 1s 29ms/step - loss: 0.4994 - accuracy: 0.7574 - precision: 0.6871 - recall: 0.7238
#
#
# Evaluating ShallowNetwork-bn ...
# 43/43 [==============================] - 1s 29ms/step - loss: 0.3129 - accuracy: 0.8599 - precision: 0.8914 - recall: 0.7403
#
#
# Evaluating ShallowNetwork-pneumonia-bn ...
# 43/43 [==============================] - 1s 30ms/step - loss: 0.3267 - accuracy: 0.8636 - precision: 0.8623 - recall: 0.7845

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# no noise added here
NOISE_MULTIPLIER = 0.0

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = inf

# %% [markdown]
# #### Membership Inference Attack

# %%
def compute_attack_inputs(attack_data):
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant
    # get labels
    labels = []
    for x, y in attack_data.as_numpy_iterator():
        labels.append(y[0])
    # predict
    probs = model.predict(attack_data)
    # compute loss
    losses = np.array([x[0] for x in bc(constant([[y] for y in labels]), constant(probs), from_logits=False).numpy()])
    
    return (np.array(probs), np.array(losses), np.array(labels))

# run membership inference attack
def run_mia(model, train_attack_input, test_attack_input):
    # prepare attacks
    probs_train, loss_train, labels_train = train_attack_input
    probs_test, loss_test, labels_test = test_attack_input

    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = labels_train,
        labels_test = labels_test
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
        by_classification_correctness = True
    )

    attack_types = [
        #AttackType.THRESHOLD_ATTACK, # logistic was always better, so no threshold to save time
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    #plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    #plt.show()

    # print a user-friendly summary of the attacks
    #print(attacks_result.summary(by_slices=False))

    max_auc = attacks_result.get_result_with_max_auc().get_auc()
    max_adv = attacks_result.get_result_with_max_attacker_advantage().get_attacker_advantage()

    return max_auc, max_adv

# epsilon estimation based on attack, metric adapted for AUC from https://paperswithcode.com/paper/antipodes-of-label-differential-privacy-pate
def empirical_eps(auc):
    if auc <= 0.5:
        return 0
    if auc == 1:
        return np.inf
    return np.log(auc / (1 - auc))

from contextlib import contextmanager
import sys
@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout

# %%
import scipy.stats as st

for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    SAMPLE_NB = 100
    
    train_attack_input = compute_attack_inputs(train_attack_data)
    test_attack_input = compute_attack_inputs(test_attack_data)

    aucs = []
    advs = []
    emp_eps = []
    for i in range(SAMPLE_NB):
        with suppress_stdout():
            max_auc, max_adv = run_mia(model, train_attack_input, test_attack_input)
        aucs.append(max_auc)
        advs.append(max_adv)
        emp_eps.append(empirical_eps(max_auc))

    auc_low, auc_high = st.t.interval(0.95, len(aucs)-1, loc=np.mean(aucs), scale=st.sem(aucs))
    adv_low, adv_high = st.t.interval(0.95, len(advs)-1, loc=np.mean(advs), scale=st.sem(advs))
    eps_low, eps_high = st.t.interval(0.95, len(emp_eps)-1, loc=np.mean(emp_eps), scale=st.sem(emp_eps))

    print('95%%-CI based on %i attack samples'%(SAMPLE_NB))
    print('AUC: %0.2f-%0.2f'%(auc_low, auc_high))
    print('Attacker advantage: %0.2f-%0.2f'%(adv_low, adv_high))
    print('Empirical epsilon bounds from AUC: %0.2f-%0.2f\n'%(eps_low, eps_high))
# Out:
# Membership Inference Attack on ShallowNetwork...
# 95%-CI based on 100 attack samples
# AUC: 0.52-0.53
# Attacker advantage: 0.11-0.12
# Empirical epsilon bounds from AUC: 0.09-0.12
#
# Membership Inference Attack on ShallowNetwork-dropout...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.13-0.14
# Empirical epsilon bounds from AUC: 0.12-0.16
#
# Membership Inference Attack on ShallowNetwork-bn...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.13-0.16
#
# Membership Inference Attack on ShallowNetwork-pneumonia-bn...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.13-0.15
