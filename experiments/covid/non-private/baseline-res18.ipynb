# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install git+https://github.com/tensorflow/privacy
# Out:
#      |████████████████████████████████| 4.0 MB 12.8 MB/s
#   Building wheel for tensorflow-privacy (setup.py) ... done

# %%
# !pip -q install git+https://github.com/qubvel/classification_models.git
# Out:
#      |████████████████████████████████| 50 kB 5.2 MB/s
#   Building wheel for image-classifiers (setup.py) ... done

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from classification_models.tfkeras import Classifiers

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from tensorflow.keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SingleAttackResult
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

# %%
ResNet18, _ = Classifiers.get('resnet18')

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 100% 780M/780M [00:07<00:00, 111MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SHAPE = [224, 224, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-val-test split with 80-5-15
x_train, x_rest, y_train, y_rest = train_test_split(files, labels, test_size=VAL_SPLIT+TEST_SPLIT, random_state=random_state)
x_test, x_val, y_test, y_val = train_test_split(x_rest, y_rest, test_size=VAL_SPLIT/(VAL_SPLIT+TEST_SPLIT), random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7232, Val: 452, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4339, 'COVID-19': 2893}
# val set:  {'normal': 272, 'COVID-19': 180}
# test set:   {'normal': 813, 'COVID-19': 543}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# set for attack on train set
train_attack_data = prepare_dataset(train_ds,
                                    pre=True,
                                    shuffle=False,
                                    repeat=False,
                                    batch=1,
                                    augment=False,
                                    cache=False)

# set for attack on test set
test_attack_data = prepare_dataset(test_ds,
                                   pre=True,
                                   shuffle=False,
                                   repeat=False,
                                   batch=1,
                                   augment=False,
                                   cache=False)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## ResNet18
# [Paper](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('tanh', name=name + '_preact_tanh')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride, name=name + 'pool_pool')(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('tanh', name=name + '_1_tanh')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('tanh', name=name + '_2_tanh')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    # bottom
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    # body
    x = stack_fn(x)
    # no top added
    # Create model
    model = tf.keras.models.Model(input, x, name=model_name)
    return model
    
def ResNet18_tanh(input):
    def stack_fn(x):
        x = resnet_stack(x, 64, 2, name='conv2')
        x = resnet_stack(x, 128, 2, name='conv3')
        x = resnet_stack(x, 256, 2, name='conv4')
        x = resnet_stack(x, 512, 2, stride1=1, name='conv5')
        x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
        x = Activation('tanh', name='post_tanh')(x)
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_builder(weights=False, dropout=False, activation='relu', name='ResNet18'):
    # ResNet18 without head
    if activation == 'tanh':
        resnet18 = ResNet18_tanh(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    elif activation == 'relu':
        _weights = False if weights == 'pneumonia' else weights
        resnet18 = ResNet18(include_top = False,
                            weights = _weights,
                            input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]))
    
    resnet18.trainable = True # make layers trainable

    seq = [
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]), name='Input'),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ]

    if dropout:
        seq.insert(3, Dropout(rate=dropout, name='Dropout')) # add dropout (inspired by inception-resnet-v2))

    model = Sequential(seq, name=name)

    # load weights from pneumonia pretraining
    if weights == 'pneumonia' and activation == 'relu':
        model.load_weights(weights_path+'resnet18_relu_public_weights.h5', by_name=True)
    if weights == 'pneumonia' and activation == 'tanh':
        model.load_weights(weights_path+'resnet18_tanh_public_weights.h5', by_name=True)
    
    return model

# %%
resnet18 = resnet18_builder(name='ResNet18')
resnet18_dropout = resnet18_builder(dropout=0.2, name='ResNet18-dropout')
resnet18_imagenet = resnet18_builder(weights='imagenet', name='ResNet18-imagenet')
resnet18_pneumonia = resnet18_builder(weights='pneumonia', name='ResNet18-pneumonia')

resnet18_tanh = resnet18_builder(activation='tanh', name='ResNet18-tanh')
#resnet18_tanh_dropout = resnet18_builder(activation='tanh', dropout=0.2, name='ResNet18-tanh-dropout')
#resnet18_tanh_pneumonia = resnet18_builder(activation='tanh', weights='pneumonia', name='ResNet18-tanh-pneumonia')

models = [
    resnet18,
    resnet18_dropout,
    resnet18_imagenet,
    resnet18_pneumonia,
    resnet18_tanh,
    #resnet18_tanh_dropout,
    #resnet18_tanh_pneumonia,
]

METRICS = [
    'accuracy',
    Precision(name='precision'),
    Recall(name='recall')
]

for model in models:
    model.compile(
        optimizer=Adam(learning_rate=1e-3),
        loss='binary_crossentropy',
        metrics=METRICS
    )
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet18_imagenet_1000_no_top.h5
# 44924928/44920640 [==============================] - 1s 0us/step
# 44933120/44920640 [==============================] - 1s 0us/step

# %%
models[0].summary()
# Out:
# Model: "ResNet18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 7, 7, 512)         11186889
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 11,187,402
# Trainable params: 11,179,460
# Non-trainable params: 7,942
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
for model in models:
    print("Training %s ..." % (model.name))
    history = model.fit(
        train_batched,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_batched,
        validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
        class_weight=class_weight_dict,
        callbacks = [learning_rate_decay],
    )
    print('\n')
# Out:
# Training ResNet18 ...
# Epoch 1/20
# 226/226 [==============================] - 113s 401ms/step - loss: 0.5309 - accuracy: 0.7370 - precision: 0.6468 - recall: 0.7546 - val_loss: 2.6706 - val_accuracy: 0.3973 - val_precision: 0.3973 - val_recall: 1.0000
# Epoch 2/20
# 226/226 [==============================] - 79s 352ms/step - loss: 0.4457 - accuracy: 0.7880 - precision: 0.6978 - recall: 0.8292 - val_loss: 0.5949 - val_accuracy: 0.6942 - val_precision: 0.5936 - val_recall: 0.7303
# Epoch 3/20
# 226/226 [==============================] - 79s 351ms/step - loss: 0.4017 - accuracy: 0.8126 - precision: 0.7263 - recall: 0.8531 - val_loss: 0.4728 - val_accuracy: 0.7388 - val_precision: 0.6533 - val_recall: 0.7303
# Epoch 4/20
# 226/226 [==============================] - 79s 352ms/step - loss: 0.3835 - accuracy: 0.8161 - precision: 0.7279 - recall: 0.8628 - val_loss: 4.1644 - val_accuracy: 0.4866 - val_precision: 0.4316 - val_recall: 0.9213
# Epoch 5/20
# 226/226 [==============================] - 80s 355ms/step - loss: 0.3425 - accuracy: 0.8408 - precision: 0.7651 - recall: 0.8690 - val_loss: 1.0159 - val_accuracy: 0.7165 - val_precision: 0.6209 - val_recall: 0.7360
# Epoch 6/20
# 226/226 [==============================] - 81s 357ms/step - loss: 0.2925 - accuracy: 0.8693 - precision: 0.8078 - recall: 0.8835 - val_loss: 0.3011 - val_accuracy: 0.8661 - val_precision: 0.8352 - val_recall: 0.8258
# Epoch 7/20
# 226/226 [==============================] - 80s 356ms/step - loss: 0.2749 - accuracy: 0.8798 - precision: 0.8192 - recall: 0.8977 - val_loss: 0.2735 - val_accuracy: 0.8929 - val_precision: 0.8571 - val_recall: 0.8764
# Epoch 8/20
# 226/226 [==============================] - 81s 358ms/step - loss: 0.2668 - accuracy: 0.8856 - precision: 0.8296 - recall: 0.8987 - val_loss: 0.3240 - val_accuracy: 0.8683 - val_precision: 0.7793 - val_recall: 0.9326
# Epoch 9/20
# 226/226 [==============================] - 81s 359ms/step - loss: 0.2638 - accuracy: 0.8877 - precision: 0.8358 - recall: 0.8953 - val_loss: 0.2556 - val_accuracy: 0.8996 - val_precision: 0.8410 - val_recall: 0.9213
# Epoch 10/20
# 226/226 [==============================] - 81s 362ms/step - loss: 0.2503 - accuracy: 0.8927 - precision: 0.8405 - recall: 0.9032 - val_loss: 0.2713 - val_accuracy: 0.8906 - val_precision: 0.8413 - val_recall: 0.8933
# Epoch 11/20
# 226/226 [==============================] - 82s 363ms/step - loss: 0.2494 - accuracy: 0.8941 - precision: 0.8461 - recall: 0.8987 - val_loss: 0.2434 - val_accuracy: 0.8996 - val_precision: 0.8556 - val_recall: 0.8989
# Epoch 12/20
# 226/226 [==============================] - 82s 363ms/step - loss: 0.2327 - accuracy: 0.9020 - precision: 0.8541 - recall: 0.9105 - val_loss: 0.2054 - val_accuracy: 0.9152 - val_precision: 0.8977 - val_recall: 0.8876
# Epoch 13/20
# 226/226 [==============================] - 82s 362ms/step - loss: 0.2278 - accuracy: 0.9061 - precision: 0.8632 - recall: 0.9094 - val_loss: 0.2237 - val_accuracy: 0.9018 - val_precision: 0.8490 - val_recall: 0.9157
# Epoch 14/20
# 226/226 [==============================] - 82s 363ms/step - loss: 0.2252 - accuracy: 0.9071 - precision: 0.8609 - recall: 0.9157 - val_loss: 0.2051 - val_accuracy: 0.9330 - val_precision: 0.9458 - val_recall: 0.8820
# Epoch 15/20
# 226/226 [==============================] - 82s 364ms/step - loss: 0.2272 - accuracy: 0.9080 - precision: 0.8662 - recall: 0.9108 - val_loss: 0.3285 - val_accuracy: 0.8750 - val_precision: 0.7723 - val_recall: 0.9719
# Epoch 16/20
# 226/226 [==============================] - 82s 365ms/step - loss: 0.2238 - accuracy: 0.9082 - precision: 0.8643 - recall: 0.9139 - val_loss: 0.2236 - val_accuracy: 0.9152 - val_precision: 0.8608 - val_recall: 0.9382
# Epoch 17/20
# 226/226 [==============================] - 82s 365ms/step - loss: 0.1971 - accuracy: 0.9239 - precision: 0.8938 - recall: 0.9191 - val_loss: 0.1830 - val_accuracy: 0.9353 - val_precision: 0.9116 - val_recall: 0.9270
# Epoch 18/20
# 226/226 [==============================] - 81s 362ms/step - loss: 0.2015 - accuracy: 0.9181 - precision: 0.8834 - recall: 0.9163 - val_loss: 0.1826 - val_accuracy: 0.9420 - val_precision: 0.9222 - val_recall: 0.9326
# Epoch 19/20
# 226/226 [==============================] - 82s 363ms/step - loss: 0.1908 - accuracy: 0.9204 - precision: 0.8825 - recall: 0.9240 - val_loss: 0.1858 - val_accuracy: 0.9241 - val_precision: 0.8789 - val_recall: 0.9382
# Epoch 20/20
# 226/226 [==============================] - 81s 361ms/step - loss: 0.1940 - accuracy: 0.9209 - precision: 0.8834 - recall: 0.9243 - val_loss: 0.1870 - val_accuracy: 0.9397 - val_precision: 0.9171 - val_recall: 0.9326
#
#
# Training ResNet18-dropout ...
# Epoch 1/20
# 226/226 [==============================] - 86s 361ms/step - loss: 0.5126 - accuracy: 0.7443 - precision: 0.6631 - recall: 0.7909 - val_loss: 2.8629 - val_accuracy: 0.4531 - val_precision: 0.4197 - val_recall: 0.9831
# Epoch 2/20
# 226/226 [==============================] - 79s 352ms/step - loss: 0.4488 - accuracy: 0.7814 - precision: 0.6873 - recall: 0.8320 - val_loss: 9.8593 - val_accuracy: 0.4174 - val_precision: 0.4050 - val_recall: 0.9944
# Epoch 3/20
# 226/226 [==============================] - 79s 351ms/step - loss: 0.4123 - accuracy: 0.7998 - precision: 0.7101 - recall: 0.8441 - val_loss: 2.1832 - val_accuracy: 0.6339 - val_precision: 0.5243 - val_recall: 0.8483
# Epoch 4/20
# 226/226 [==============================] - 79s 351ms/step - loss: 0
20
# 226/226 [==============================] - 79s 351ms/step - loss: 0.0522 - accuracy: 0.9813 - precision: 0.9765 - recall: 0.9768 - val_loss: 0.1319 - val_accuracy: 0.9464 - val_precision: 0.9936 - val_recall: 0.8708
# Epoch 14/20
# 226/226 [==============================] - 79s 352ms/step - loss: 0.0480 - accuracy: 0.9824 - precision: 0.9753 - recall: 0.9810 - val_loss: 0.1438 - val_accuracy: 0.9397 - val_precision: 0.9935 - val_recall: 0.8539
# Epoch 15/20
# 226/226 [==============================] - 80s 356ms/step - loss: 0.0473 - accuracy: 0.9831 - precision: 0.9779 - recall: 0.9800 - val_loss: 0.1401 - val_accuracy: 0.9464 - val_precision: 0.9936 - val_recall: 0.8708
# Epoch 16/20
# 226/226 [==============================] - 80s 356ms/step - loss: 0.0492 - accuracy: 0.9842 - precision: 0.9823 - recall: 0.9782 - val_loss: 0.1417 - val_accuracy: 0.9442 - val_precision: 0.9935 - val_recall: 0.8652
# Epoch 17/20
# 226/226 [==============================] - 80s 356ms/step - loss: 0.0465 - accuracy: 0.9826 - precision: 0.9772 - recall: 0.9793 - val_loss: 0.1379 - val_accuracy: 0.9464 - val_precision: 0.9936 - val_recall: 0.8708
# Epoch 18/20
# 226/226 [==============================] - 80s 357ms/step - loss: 0.0476 - accuracy: 0.9831 - precision: 0.9783 - recall: 0.9796 - val_loss: 0.1358 - val_accuracy: 0.9464 - val_precision: 0.9936 - val_recall: 0.8708
# Epoch 19/20
# 226/226 [==============================] - 80s 355ms/step - loss: 0.0446 - accuracy: 0.9840 - precision: 0.9800 - recall: 0.9800 - val_loss: 0.1422 - val_accuracy: 0.9442 - val_precision: 0.9935 - val_recall: 0.8652
# Epoch 20/20
# 226/226 [==============================] - 80s 355ms/step - loss: 0.0482 - accuracy: 0.9826 - precision: 0.9799 - recall: 0.9765 - val_loss: 0.1385 - val_accuracy: 0.9442 - val_precision: 0.9935 - val_recall: 0.8652
#
#
# Training ResNet18-pneumonia ...
# Epoch 1/20
# 226/226 [==============================] - 86s 362ms/step - loss: 0.5743 - accuracy: 0.7009 - precision: 0.6142 - recall: 0.7730 - val_loss: 1.8003 - val_accuracy: 0.6317 - val_precision: 0.5783 - val_recall: 0.2697
# Epoch 2/20
# 226/226 [==============================] - 80s 356ms/step - loss: 0.4830 - accuracy: 0.7692 - precision: 0.6780 - recall: 0.8057 - val_loss: 0.4685 - val_accuracy: 0.8058 - val_precision: 0.8473 - val_recall: 0.6236
# Epoch 3/20
# 226/226 [==============================] - 80s 355ms/step - loss: 0.4250 - accuracy: 0.8027 - precision: 0.7161 - recall: 0.8396 - val_loss: 0.5783 - val_accuracy: 0.8036 - val_precision: 0.8125 - val_recall: 0.6573
# Epoch 4/20
# 226/226 [==============================] - 81s 359ms/step - loss: 0.3996 - accuracy: 0.8222 - precision: 0.7392 - recall: 0.8583 - val_loss: 1.1568 - val_accuracy: 0.6920 - val_precision: 0.5769 - val_recall: 0.8427
# Epoch 5/20
# Epoch 19/20
# 226/226 [==============================] - 78s 347ms/step - loss: 0.2773 - accuracy: 0.8791 - precision: 0.8206 - recall: 0.8932 - val_loss: 0.2394 - val_accuracy: 0.8884 - val_precision: 0.8168 - val_recall: 0.9270
# Epoch 20/20
# 226/226 [==============================] - 78s 346ms/step - loss: 0.2794 - accuracy: 0.8782 - precision: 0.8204 - recall: 0.8904 - val_loss: 0.2411 - val_accuracy: 0.8951 - val_precision: 0.8291 - val_recall: 0.9270
#
#
# Training ResNet18-tanh ...
# Epoch 1/20
# 226/226 [==============================] - 85s 349ms/step - loss: 0.6265 - accuracy: 0.6851 - precision: 0.6040 - recall: 0.7063 - val_loss: 1.5361 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 226/226 [==============================] - 79s 349ms/step - loss: 0.5738 - accuracy: 0.7139 - precision: 0.6183 - recall: 0.7446 - val_loss: 0.8050 - val_accuracy: 0.6808 - val_precision: 0.6061 - val_recall: 0.5618
# Epoch 3/20
# 226/226 [==============================] - 80s 353ms/step - loss: 0.5616 - accuracy: 0.7217 - precision: 0.6281 - recall: 0.7456 - val_loss: 0.8588 - val_accuracy: 0.6295 - val_precision: 0.5229 - val_recall: 0.7697
# Epoch 4/20
# 226/226 [==============================] - 79s 351ms/step - loss: 0.5435 - accuracy: 0.7382 - precision: 0.6466 - recall: 0.7622 - val_loss: 0.5176 - val_accuracy: 0.7612 - val_precision: 0.6550 - val_recall: 0.8427
# Epoch 5/20
# 226/226 [==============================] - 78s 347ms/step - loss: 0.5369 - accuracy: 0.7399 - precision: 0.6462 - recall: 0.7729 - val_loss: 0.8372 - val_accuracy: 0.6696 - val_precision: 0.6230 - val_recall: 0.4270
# Epoch 6/20
# 226/226 [==============================] - 80s 355ms/step - loss: 0.5179 - accuracy: 0.7464 - precision: 0.6543 - recall: 0.7760 - val_loss: 0.9861 - val_accuracy: 0.6429 - val_precision: 0.5324 - val_recall: 0.8315
# Epoch 7/20
# 226/226 [==============================] - 80s 354ms/step - loss: 0.4650 - accuracy: 0.7830 - precision: 0.6955 - recall: 0.8140 - val_loss: 0.9100 - val_accuracy: 0.6518 - val_precision: 0.5342 - val_recall: 0.9663
# Epoch 8/20
# 226/226 [==============================] - 80s 356ms/step - loss: 0.4363 - accuracy: 0.7952 - precision: 0.7141 - recall: 0.8140 - val_loss: 0.8943 - val_accuracy: 0.6696 - val_precision: 0.9688 - val_recall: 0.1742
# Epoch 9/20
# 226/226 [==============================] - 80s 357ms/step - loss: 0.4153 - accuracy: 0.8110 - precision: 0.7383 - recall: 0.8171 - val_loss: 0.4022 - val_accuracy: 0.8214 - val_precision: 0.7168 - val_recall: 0.9101
# Epoch 10/20
# 226/226 [==============================] - 80s 356ms/step - loss: 0.4062 - accuracy: 0.8129 - precision: 0.7350 - recall: 0.8324 - val_loss: 0.3880 - val_accuracy: 0.8348 - val_precision: 0.7342 - val_recall: 0.9157
# Epoch 11/20
# 226/226 [==============================] - 80s 354ms/step - loss: 0.3959 - accuracy: 0.8146 - precision: 0.7353 - recall: 0.8382 - val_loss: 0.4526 - val_accuracy: 0.7991 - val_precision: 0.6803 - val_recall: 0.9326
# Epoch 12/20
# 226/226 [==============================] - 80s 353ms/step - loss: 0.3901 - accuracy: 0.8220 - precision: 0.7433 - recall: 0.8479 - val_loss: 0.3684 - val_accuracy: 0.8415 - val_precision: 0.7536 - val_recall: 0.8933
# Epoch 13/20
# 226/226 [==============================] - 80s 355ms/step - loss: 0.3964 - accuracy: 0.8164 - precision: 0.7385 - recall: 0.8375 - val_loss: 0.4511 - val_accuracy: 0.7991 - val_precision: 0.6774 - val_recall: 0.9438
# Epoch 14/20
# 226/226 [==============================] - 79s 351ms/step - loss: 0.3878 - accuracy: 0.8225 - precision: 0.7437 - recall: 0.8486 - val_loss: 0.3513 - val_accuracy: 0.8549 - val_precision: 0.7729 - val_recall: 0.8989
# Epoch 15/20
# 226/226 [==============================] - 78s 348ms/step - loss: 0.3778 - accuracy: 0.8258 - precision: 0.7480 - recall: 0.8514 - val_loss: 0.4504 - val_accuracy: 0.7991 - val_precision: 0.6774 - val_recall: 0.9438
# Epoch 16/20
# 226/226 [==============================] - 78s 347ms/step - loss: 0.3829 - accuracy: 0.8223 - precision: 0.7442 - recall: 0.8469 - val_loss: 0.3331 - val_accuracy: 0.8594 - val_precision: 0.8249 - val_recall: 0.8202
# Epoch 17/20
# 226/226 [==============================] - 78s 347ms/step - loss: 0.3757 - accuracy: 0.8285 - precision: 0.7547 - recall: 0.8465 - val_loss: 0.4076 - val_accuracy: 0.8326 - val_precision: 0.7229 - val_recall: 0.9382
# Epoch 18/20
# 226/226 [==============================] - 78s 348ms/step - loss: 0.3786 - accuracy: 0.8302 - precision: 0.7585 - recall: 0.8445 - val_loss: 0.3648 - val_accuracy: 0.8371 - val_precision: 0.7419 - val_recall: 0.9045
# Epoch 19/20
# 226/226 [==============================] - 78s 345ms/step - loss: 0.3752 - accuracy: 0.8335 - precision: 0.7609 - recall: 0.8514 - val_loss: 0.3804 - val_accuracy: 0.8527 - val_precision: 0.7500 - val_recall: 0.9438
# Epoch 20/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.3744 - accuracy: 0.8290 - precision: 0.7571 - recall: 0.8427 - val_loss: 0.4029 - val_accuracy: 0.8281 - val_precision: 0.7149 - val_recall: 0.9438

# %% [markdown]
# ## Evaluation

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating ResNet18 ...
# 43/43 [==============================] - 4s 100ms/step - loss: 0.2226 - accuracy: 0.9137 - precision: 0.8685 - recall: 0.9245
#
#
# Evaluating ResNet18-dropout ...
# 43/43 [==============================] - 1s 32ms/step - loss: 0.2361 - accuracy: 0.9071 - precision: 0.8589 - recall: 0.9190
#
#
# Evaluating ResNet18-imagenet ...
# 43/43 [==============================] - 1s 31ms/step - loss: 0.1571 - accuracy: 0.9403 - precision: 0.9915 - recall: 0.8582
#
#
# Evaluating ResNet18-pneumonia ...
# 43/43 [==============================] - 1s 33ms/step - loss: 0.3245 - accuracy: 0.8621 - precision: 0.7773 - recall: 0.9190
#
#
# Evaluating ResNet18-tanh ...
# 43/43 [==============================] - 2s 38ms/step - loss: 0.4705 - accuracy: 0.7935 - precision: 0.6779 - recall: 0.9227

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# no noise added here
NOISE_MULTIPLIER = 0.0

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = inf

# %% [markdown]
# #### Membership Inference Attack

# %%
def compute_attack_inputs(model, attack_data):
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant
    # get labels
    labels = []
    for x, y in attack_data.as_numpy_iterator():
        labels.append(y[0])
    # predict
    probs = model.predict(attack_data)
    # compute loss
    losses = np.array([x[0] for x in bc(constant([[y] for y in labels]), constant(probs), from_logits=False).numpy()])
    
    return (np.array(probs), np.array(losses), np.array(labels))

# run membership inference attack
def run_mia(model, train_attack_input, test_attack_input):
    # prepare attacks
    probs_train, loss_train, labels_train = train_attack_input
    probs_test, loss_test, labels_test = test_attack_input

    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = labels_train,
        labels_test = labels_test
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
        by_classification_correctness = True
    )

    attack_types = [
        #AttackType.THRESHOLD_ATTACK, # logistic was always better, so no threshold to save time
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    #plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    #plt.show()

    # print a user-friendly summary of the attacks
    #print(attacks_result.summary(by_slices=False))

    max_auc = attacks_result.get_result_with_max_auc().get_auc()
    max_adv = attacks_result.get_result_with_max_attacker_advantage().get_attacker_advantage()

    return max_auc, max_adv

# epsilon estimation based on attack, metric adapted for AUC from https://paperswithcode.com/paper/antipodes-of-label-differential-privacy-pate
def empirical_eps(auc):
    if auc <= 0.5:
        return 0
    if auc == 1:
        return np.inf
    return np.log(auc / (1 - auc))

from contextlib import contextmanager
import sys
@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout

# %%
import scipy.stats as st

for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    SAMPLE_NB = 100
    
    train_attack_input = compute_attack_inputs(model, train_attack_data)
    test_attack_input = compute_attack_inputs(model, test_attack_data)

    aucs = []
    advs = []
    emp_eps = []
    for i in range(SAMPLE_NB):
        with suppress_stdout():
            max_auc, max_adv = run_mia(model, train_attack_input, test_attack_input)
        aucs.append(max_auc)
        advs.append(max_adv)
        emp_eps.append(empirical_eps(max_auc))

    auc_low, auc_high = st.t.interval(0.95, len(aucs)-1, loc=np.mean(aucs), scale=st.sem(aucs))
    adv_low, adv_high = st.t.interval(0.95, len(advs)-1, loc=np.mean(advs), scale=st.sem(advs))
    eps_low, eps_high = st.t.interval(0.95, len(emp_eps)-1, loc=np.mean(emp_eps), scale=st.sem(emp_eps))

    print('95%%-CI based on %i attack samples'%(SAMPLE_NB))
    print('AUC: %0.2f-%0.2f'%(auc_low, auc_high))
    print('Attacker advantage: %0.2f-%0.2f'%(adv_low, adv_high))
    print('Empirical epsilon bounds from AUC: %0.2f-%0.2f\n'%(eps_low, eps_high))
# Out:
# Membership Inference Attack on ResNet18...
# 95%-CI based on 100 attack samples
# AUC: 0.55-0.56
# Attacker advantage: 0.13-0.14
# Empirical epsilon bounds from AUC: 0.21-0.24
#
# Membership Inference Attack on ResNet18-dropout...
# 95%-CI based on 100 attack samples
# AUC: 0.56-0.56
# Attacker advantage: 0.15-0.16
# Empirical epsilon bounds from AUC: 0.22-0.26
#
# Membership Inference Attack on ResNet18-imagenet...
# 95%-CI based on 100 attack samples
# AUC: 0.54-0.55
# Attacker advantage: 0.13-0.14
# Empirical epsilon bounds from AUC: 0.17-0.21
#
# Membership Inference Attack on ResNet18-pneumonia...
# 95%-CI based on 100 attack samples
# AUC: 0.55-0.56
# Attacker advantage: 0.13-0.14
# Empirical epsilon bounds from AUC: 0.19-0.23
#
# Membership Inference Attack on ResNet18-tanh...
# 95%-CI based on 100 attack samples
# AUC: 0.54-0.55
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.17-0.20
