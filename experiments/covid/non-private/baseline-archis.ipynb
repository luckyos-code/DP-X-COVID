# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install git+https://github.com/tensorflow/privacy

# %%
# !pip -q install git+https://github.com/qubvel/classification_models.git

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from classification_models.tfkeras import Classifiers

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.applications import EfficientNetB4
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from tensorflow.keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten, LeakyReLU

import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SingleAttackResult
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

# %%
ResNet18, _ = Classifiers.get('resnet18')
ResNet50, _ = Classifiers.get('resnet50')

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SHAPE = [224, 224, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-val-test split with 80-5-15
x_train, x_rest, y_train, y_rest = train_test_split(files, labels, test_size=VAL_SPLIT+TEST_SPLIT, random_state=random_state)
x_test, x_val, y_test, y_val = train_test_split(x_rest, y_rest, test_size=VAL_SPLIT/(VAL_SPLIT+TEST_SPLIT), random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7232, Val: 452, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4339, 'COVID-19': 2893}
# val set:  {'normal': 272, 'COVID-19': 180}
# test set:   {'normal': 813, 'COVID-19': 543}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# set for attack on train set
train_attack_data = prepare_dataset(train_ds,
                                    pre=True,
                                    shuffle=False,
                                    repeat=False,
                                    batch=1,
                                    augment=False,
                                    cache=False)

# set for attack on test set
test_attack_data = prepare_dataset(test_ds,
                                   pre=True,
                                   shuffle=False,
                                   repeat=False,
                                   batch=1,
                                   augment=False,
                                   cache=False)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight(class_weight='balanced',
                                                 classes=np.unique(y_train),
                                                 y=y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## ResNet18
# [Paper](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet18_builder(weights=False, dropout=False, activation='relu', name='ResNet18'):
    # ResNet18 without head
    if activation == 'tanh':
        resnet18 = ResNet18_tanh(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    elif activation == 'relu':
        _weights = False if weights == 'pneumonia' else weights
        resnet18 = ResNet18(include_top = False,
                            weights = _weights,
                            input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]))
    
    resnet18.trainable = True # make layers trainable

    seq = [
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]), name='Input'),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ]

    if dropout:
        seq.insert(3, Dropout(rate=dropout, name='Dropout')) # add dropout (inspired by inception-resnet-v2))

    model = Sequential(seq, name=name)

    # load weights from pneumonia pretraining
    if weights == 'pneumonia' and activation == 'relu':
        model.load_weights(weights_path+'resnet18_relu_public_weights.h5', by_name=True)
    if weights == 'pneumonia' and activation == 'tanh':
        model.load_weights(weights_path+'resnet18_tanh_public_weights.h5', by_name=True)
    
    return model

# %%
def resnet50_builder(weights=False, dropout=False, activation='relu', name='ResNet50'):
    # ResNet50 without head
    if activation == 'tanh':
        resnet50 = ResNet50_tanh(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    elif activation == 'relu':
        _weights = False if weights == 'pneumonia' else weights
        resnet50 = ResNet50(include_top = False,
                            weights = _weights,
                            input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]))
    
    resnet50.trainable = True # make layers trainable

    seq = [
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]), name='Input'),
        resnet50, # add resnet50 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ]

    if dropout:
        seq.insert(3, Dropout(rate=dropout, name='Dropout')) # add dropout (inspired by inception-resnet-v2))

    model = Sequential(seq, name=name)

    # load weights from pneumonia pretraining
    if weights == 'pneumonia' and activation == 'relu':
        model.load_weights(weights_path+'resnet50_relu_public_weights.h5', by_name=True)
    if weights == 'pneumonia' and activation == 'tanh':
        model.load_weights(weights_path+'resnet50_tanh_public_weights.h5', by_name=True)
    
    return model

# %%
DENSE_KERNEL_INITIALIZER = {
    'class_name': 'VarianceScaling',
    'config': {
        'scale': 1. / 3.,
        'mode': 'fan_out',
        'distribution': 'uniform'
    }
}

def efficientnetb4_builder(name='EfficientNetB4'):
    effnet = EfficientNetB4(include_top = False,
                       #weights = 'imagenet',
                       input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]),)
    
    effnet.trainable = True

    seq = [
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]), name='Input'),
        effnet, # add resnet50 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', kernel_initializer=DENSE_KERNEL_INITIALIZER, name='Output'), # add classification layer for normal/COVID-19
    ]

    model = Sequential(seq, name=name)
    
    return model

# %%
def darknet_block(filters, kernel_size=3, strides=1):
    block = Sequential([
        ZeroPadding2D(padding=(1, 1)),
        Conv2D(filters=filters, kernel_size=kernel_size, strides=strides, padding='valid', use_bias=False),
        BatchNormalization(),
        LeakyReLU(alpha=0.1),
    ])
    return block

def triple_conv(prev, filters):
    return Sequential([
        darknet_block(filters),
        darknet_block(prev, kernel_size=1),  
        darknet_block(filters)
    ])

def darkcovidnet_builder(name='DarkCovidNet'):
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]), name='Input'),
        darknet_block(8),
        MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'),
        darknet_block(16),
        MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'),
        triple_conv(16, 32),
        MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'),
        triple_conv(32, 64),
        MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'),
        triple_conv(64, 128),
        MaxPooling2D(pool_size=(2, 2), strides=2, padding='valid'),
        triple_conv(128, 256),
        darknet_block(128, kernel_size=1),
        darknet_block(256),
        darknet_block(3),
        Flatten(),
        Dense(units=1, activation='sigmoid')
    ], name=name)
    
    return model

# %%
resnet18 = resnet18_builder(name='ResNet18')
resnet50 = resnet50_builder(name='ResNet50')
efficientnetb4 = efficientnetb4_builder(name='EfficientNetB4')
darkcovidnet = darkcovidnet_builder(name='DarkCovidNet')

models = [
    efficientnetb4,
    darkcovidnet,
    resnet50,
    resnet18,
]

METRICS = [
    'accuracy',
    Precision(name='precision'),
    Recall(name='recall')
]

for model in models:
    model.compile(
        optimizer=Adam(learning_rate=1e-3),
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
models[0].summary()
# Out:
# Model: "EfficientNetB4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  efficientnetb4 (Functional)  (None, 7, 7, 1792)       17673823
#
#  AvgPool (GlobalAveragePooli  (None, 1792)             0
#  ng2D)
#
#  Output (Dense)              (None, 1)                 1793
#
# =================================================================
# Total params: 17,675,616
# Trainable params: 17,550,409
# Non-trainable params: 125,207
# _________________________________________________________________

# %%
models[1].summary()
# Out:
# Model: "DarkCovidNet"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential_48 (Sequential)  (None, 500, 500, 8)       248
#
#  max_pooling2d_10 (MaxPoolin  (None, 250, 250, 8)      0
#  g2D)
#
#  sequential_49 (Sequential)  (None, 250, 250, 16)      1216
#
#  max_pooling2d_11 (MaxPoolin  (None, 125, 125, 16)     0
#  g2D)
#
#  sequential_53 (Sequential)  (None, 127, 127, 32)      10048
#
#  max_pooling2d_12 (MaxPoolin  (None, 63, 63, 32)       0
#  g2D)
#
#  sequential_57 (Sequential)  (None, 65, 65, 64)        39552
#
#  max_pooling2d_13 (MaxPoolin  (None, 32, 32, 64)       0
#  g2D)
#
#  sequential_61 (Sequential)  (None, 34, 34, 128)       156928
#
#  max_pooling2d_14 (MaxPoolin  (None, 17, 17, 128)      0
#  g2D)
#
#  sequential_65 (Sequential)  (None, 19, 19, 256)       625152
#
#  sequential_66 (Sequential)  (None, 21, 21, 128)       33280
#
#  sequential_67 (Sequential)  (None, 21, 21, 256)       295936
#
#  sequential_68 (Sequential)  (None, 21, 21, 3)         6924
#
#  flatten_2 (Flatten)         (None, 1323)              0
#
#  dense_2 (Dense)             (None, 1)                 1324
#
# =================================================================
# Total params: 1,170,608
# Trainable params: 1,167,386
# Non-trainable params: 3,222
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
for model in models:
    print("Training %s ..." % (model.name))
    history = model.fit(
        train_batched,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_batched,
        validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
        class_weight=class_weight_dict,
        callbacks = [learning_rate_decay],
    )
    print('\n')
# Out:
# Training EfficientNetB4 ...
# Epoch 1/20
# 226/226 [==============================] - 159s 580ms/step - loss: 0.9391 - accuracy: 0.7947 - precision: 0.7264 - recall: 0.7809 - val_loss: 5.6942 - val_accuracy: 0.3973 - val_precision: 0.3973 - val_recall: 1.0000 - lr: 0.0010
# Epoch 2/20
# 226/226 [==============================] - 127s 563ms/step - loss: 0.2423 - accuracy: 0.9039 - precision: 0.8738 - recall: 0.8880 - val_loss: 2.7556 - val_accuracy: 0.4308 - val_precision: 0.4111 - val_recall: 1.0000 - lr: 0.0010
# Epoch 3/20
# 226/226 [==============================] - 126s 556ms/step - loss: 0.1728 - accuracy: 0.9346 - precision: 0.9113 - recall: 0.9267 - val_loss: 0.9574 - val_accuracy: 0.6317 - val_precision: 0.5201 - val_recall: 0.9438 - lr: 0.0010
# Epoch 4/20
# 226/226 [==============================] - 126s 557ms/step - loss: 0.1385 - accuracy: 0.9459 - precision: 0.9206 - recall: 0.9464 - val_loss: 3.7891 - val_accuracy: 0.3973 - val_precision: 0.3973 - val_recall: 1.0000 - lr: 0.0010
# Epoch 5/20
# 226/226 [==============================] - 127s 563ms/step - loss: 0.1206 - accuracy: 0.9523 - precision: 0.9292 - recall: 0.9533 - val_loss: 3.5459 - val_accuracy: 0.3973 - val_precision: 0.3973 - val_recall: 1.0000 - lr: 0.0010
# Epoch 6/20
# 226/226 [==============================] - 127s 562ms/step - loss: 0.0766 - accuracy: 0.9729 - precision: 0.9610 - recall: 0.9717 - val_loss: 1.4939 - val_accuracy: 0.4665 - val_precision: 0.4269 - val_recall: 1.0000 - lr: 1.0000e-04
# Epoch 7/20
# 226/226 [==============================] - 126s 557ms/step - loss: 0.0600 - accuracy: 0.9802 - precision: 0.9709 - recall: 0.9800 - val_loss: 0.1909 - val_accuracy: 0.9375 - val_precision: 0.9747 - val_recall: 0.8652 - lr: 1.0000e-04
# Epoch 8/20
# 226/226 [==============================] - 126s 558ms/step - loss: 0.0569 - accuracy: 0.9793 - precision: 0.9686 - recall: 0.9800 - val_loss: 0.2058 - val_accuracy: 0.9040 - val_precision: 0.8462 - val_recall: 0.9270 - lr: 1.0000e-04
# Epoch 9/20
# 226/226 [==============================] - 126s 558ms/step - loss: 0.0521 - accuracy: 0.9813 - precision: 0.9736 - recall: 0.9800 - val_loss: 0.2805 - val_accuracy: 0.8951 - val_precision: 0.9396 - val_recall: 0.7865 - lr: 1.0000e-04
# Epoch 10/20
# 226/226 [==============================] - 126s 559ms/step - loss: 0.0476 - accuracy: 0.9829 - precision: 0.9782 - recall: 0.9789 - val_loss: 0.1308 - val_accuracy: 0.9531 - val_precision: 0.9337 - val_recall: 0.9494 - lr: 1.0000e-05
# Epoch 11/20
# 226/226 [==============================] - 126s 559ms/step - loss: 0.0502 - accuracy: 0.9824 - precision: 0.9749 - recall: 0.9813 - val_loss: 0.1401 - val_accuracy: 0.9531 - val_precision: 0.9435 - val_recall: 0.9382 - lr: 1.0000e-05
# Epoch 12/20
# 226/226 [==============================] - 126s 560ms/step - loss: 0.0367 - accuracy: 0.9869 - precision: 0.9791 - recall: 0.9882 - val_loss: 0.1551 - val_accuracy: 0.9442 - val_precision: 0.9005 - val_recall: 0.9663 - lr: 1.0000e-05
# Epoch 13/20
# 226/226 [==============================] - 125s 555ms/step - loss: 0.0395 - accuracy: 0.9860 - precision: 0.9791 - recall: 0.9862 - val_loss: 0.1386 - val_accuracy: 0.9487 - val_precision: 0.9235 - val_recall: 0.9494 - lr: 1.0000e-06
# Epoch 14/20
# 226/226 [==============================] - 126s 558ms/step - loss: 0.0456 - accuracy: 0.9833 - precision: 0.9756 - recall: 0.9827 - val_loss: 0.1504 - val_accuracy: 0.9487 - val_precision: 0.9235 - val_recall: 0.9494 - lr: 1.0000e-06
# Epoch 15/20
# 226/226 [==============================] - 126s 559ms/step - loss: 0.0442 - accuracy: 0.9835 - precision: 0.9753 - recall: 0.9838 - val_loss: 0.1530 - val_accuracy: 0.9375 - val_precision: 0.8989 - val_recall: 0.9494 - lr: 1.0000e-06
# Epoch 16/20
# 226/226 [==============================] - 126s 559ms/step - loss: 0.0399 - accuracy: 0.9858 - precision: 0.9797 - recall: 0.9848 - val_loss: 0.1563 - val_accuracy: 0.9353 - val_precision: 0.8942 - val_recall: 0.9494 - lr: 1.0000e-06
# Epoch 17/20
# 226/226 [==============================] - 127s 562ms/step - loss: 0.0360 - accuracy: 0.9878 - precision: 0.9831 - recall: 0.9865 - val_loss: 0.1381 - val_accuracy: 0.9531 - val_precision: 0.9337 - val_recall: 0.9494 - lr: 1.0000e-06
# Epoch 18/20
# 226/226 [==============================] - 126s 558ms/step - loss: 0.0384 - accuracy: 0.9853 - precision: 0.9748 - recall: 0.9889 - val_loss: 0.1529 - val_accuracy: 0.9442 - val_precision: 0.9135 - val_recall: 0.9494 - lr: 1.0000e-06
# Epoch 19/20
# 226/226 [==============================] - 126s 556ms/step - loss: 0.0423 - accuracy: 0.9855 - precision: 0.9804 - recall: 0.9834 - val_loss: 0.1387 - val_accuracy: 0.9464 - val_precision: 0.9185 - val_recall: 0.9494 - lr: 1.0000e-06
# Epoch 20/20
# 226/226 [==============================] - 127s 560ms/step - loss: 0.0408 - accuracy: 0.9847 - precision: 0.9751 - recall: 0.9869 - val_loss: 0.1381 - val_accuracy: 0.9442 - val_precision: 0.9135 - val_recall: 0.9494 - lr: 1.0000e-06
#
#
# Training DarkCovidNet ...
# Epoch 1/20
# 226/226 [==============================] - 71s 299ms/step - loss: 0.5793 - accuracy: 0.6717 - precision: 0.5834 - recall: 0.7655 - val_loss: 1.3359 - val_accuracy: 0.3973 - val_precision: 0.3973 - val_recall: 1.0000 - lr: 0.0010
# Epoch 2/20
# 226/226 [==============================] - 66s 293ms/step - loss: 0.4553 - accuracy: 0.7680 - precision: 0.6643 - recall: 0.8489 - val_loss: 0.5167 - val_accuracy: 0.7634 - val_precision: 0.6731 - val_recall: 0.7865 - lr: 0.0010
# Epoch 3/20
# 226/226 [==============================] - 66s 294ms/step - loss: 0.3984 - accuracy: 0.7976 - precision: 0.6955 - recall: 0.8787 - val_loss: 4.8948 - val_accuracy: 0.3951 - val_precision: 0.3960 - val_recall: 0.9944 - lr: 0.0010
# Epoch 4/20
# 226/226 [==============================] - 66s 295ms/step - loss: 0.3654 - accuracy: 0.8166 - precision: 0.7226 - recall: 0.8790 - val_loss: 1.1431 - val_accuracy: 0.6205 - val_precision: 0.5126 - val_recall: 0.9157 - lr: 0.0010
# Epoch 5/20
# 226/226 [==============================] - 67s 295ms/step - loss: 0.2962 - accuracy: 0.8599 - precision: 0.7828 - recall: 0.8994 - val_loss: 0.3672 - val_accuracy: 0.8326 - val_precision: 0.7269 - val_recall: 0.9270 - lr: 1.0000e-04
# Epoch 6/20
# 226/226 [==============================] - 66s 292ms/step - loss: 0.2633 - accuracy: 0.8803 - precision: 0.8170 - recall: 0.9029 - val_loss: 0.2768 - val_accuracy: 0.8862 - val_precision: 0.8223 - val_recall: 0.9101 - lr: 1.0000e-04
# Epoch 7/20
# 226/226 [==============================] - 67s 295ms/step - loss: 0.2441 - accuracy: 0.8986 - precision: 0.8500 - recall: 0.9067 - val_loss: 0.1955 - val_accuracy: 0.9107 - val_precision: 0.8632 - val_recall: 0.9213 - lr: 1.0000e-04
# Epoch 8/20
# 226/226 [==============================] - 66s 292ms/step - loss: 0.2343 - accuracy: 0.9004 - precision: 0.8568 - recall: 0.9018 - val_loss: 0.4125 - val_accuracy: 0.8326 - val_precision: 0.7137 - val_recall: 0.9663 - lr: 1.0000e-04
# Epoch 9/20
# 226/226 [==============================] - 66s 294ms/step - loss: 0.2243 - accuracy: 0.9074 - precision: 0.8626 - recall: 0.9139 - val_loss: 0.3949 - val_accuracy: 0.8371 - val_precision: 0.7273 - val_recall: 0.9438 - lr: 1.0000e-04
# Epoch 10/20
# 226/226 [==============================] - 66s 292ms/step - loss: 0.1974 - accuracy: 0.9209 - precision: 0.8922 - recall: 0.9125 - val_loss: 0.2591 - val_accuracy: 0.8929 - val_precision: 0.8283 - val_recall: 0.9213 - lr: 1.0000e-05
# Epoch 11/20
# 226/226 [==============================] - 66s 295ms/step - loss: 0.1954 - accuracy: 0.9212 - precision: 0.8858 - recall: 0.9219 - val_loss: 0.2269 - val_accuracy: 0.9018 - val_precision: 0.8641 - val_recall: 0.8933 - lr: 1.0000e-05
# Epoch 12/20
# 226/226 [==============================] - 66s 294ms/step - loss: 0.1934 - accuracy: 0.9216 - precision: 0.8877 - recall: 0.9205 - val_loss: 0.2383 - val_accuracy: 0.9040 - val_precision: 0.8571 - val_recall: 0.9101 - lr: 1.0000e-06
# Epoch 13/20
# 226/226 [==============================] - 66s 295ms/step - loss: 0.1879 - accuracy: 0.9219 - precision: 0.8837 - recall: 0.9267 - val_loss: 0.2367 - val_accuracy: 0.9107 - val_precision: 0.8632 - val_recall: 0.9213 - lr: 1.0000e-06
# Epoch 14/20
# 226/226 [==============================] - 66s 294ms/step - loss: 0.1910 - accuracy: 0.9274 - precision: 0.8968 - recall: 0.9250 - val_loss: 0.2396 - val_accuracy: 0.9129 - val_precision: 0.8601 - val_recall: 0.9326 - lr: 1.0000e-06
# Epoch 15/20
# 226/226 [==============================] - 66s 294ms/step - loss: 0.1967 - accuracy: 0.9222 - precision: 0.8899 - recall: 0.9191 - val_loss: 0.2399 - val_accuracy: 0.9085 - val_precision: 0.8586 - val_recall: 0.9213 - lr: 1.0000e-06
# Epoch 16/20
# 226/226 [==============================] - 66s 294ms/step - loss: 0.1869 - accuracy: 0.9287 - precision: 0.8960 - recall: 0.9295 - val_loss: 0.2393 - val_accuracy: 0.9085 - val_precision: 0.8586 - val_recall: 0.9213 - lr: 1.0000e-06
# Epoch 17/20
# 226/226 [==============================] - 66s 294ms/step - loss: 0.1876 - accuracy: 0.9237 - precision: 0.8929 - recall: 0.9195 - val_loss: 0.2459 - val_accuracy: 0.9152 - val_precision: 0.8608 - val_recall: 0.9382 - lr: 1.0000e-06
# Epoch 18/20
# 226/226 [==============================] - 66s 294ms/step - loss: 0.1919 - accuracy: 0.9206 - precision: 0.8853 - recall: 0.9208 - val_loss: 0.2513 - val_accuracy: 0.9062 - val_precision: 0.8505 - val_recall: 0.9270 - lr: 1.0000e-06
# Epoch 19/20
# 226/226 [==============================] - 67s 297ms/step - loss: 0.1940 - accuracy: 0.9228 - precision: 0.8901 - recall: 0.9208 - val_loss: 0.2561 - val_accuracy: 0.9040 - val_precision: 0.8426 - val_recall: 0.9326 - lr: 1.0000e-06
# Epoch 20/20
# 226/226 [==============================] - 67s 299ms/step - loss: 0.1839 - accuracy: 0.9284 - precision: 0.8973 - recall: 0.9271 - val_loss: 0.2627 - val_accuracy: 0.9085 - val_precision: 0.8442 - val_recall: 0.9438 - lr: 1.0000e-06
#
#
# Training ResNet50 ...
# Epoch 1/20
# 226/226 [==============================] - 84s 343ms/step - loss: 0.5366 - accuracy: 0.7286 - precision: 0.6431 - recall: 0.7805 - val_loss: 2.4847 - val_accuracy: 0.6607 - val_precision: 1.0000 - val_recall: 0.1461 - lr: 0.0010
# Epoch 2/20
# 226/226 [==============================] - 77s 340ms/step - loss: 0.4532 - accuracy: 0.7788 - precision: 0.6871 - recall: 0.8206 - val_loss: 1.0195 - val_accuracy: 0.5268 - val_precision: 0.4351 - val_recall: 0.6404 - lr: 0.0010
# Epoch 3/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.4274 - accuracy: 0.7897 - precision: 0.6984 - recall: 0.8348 - val_loss: 1.6480 - val_accuracy: 0.4933 - val_precision: 0.4181 - val_recall: 0.7022 - lr: 0.0010
# Epoch 4/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.3999 - accuracy: 0.8111 - precision: 0.7269 - recall: 0.8455 - val_loss: 1.6503 - val_accuracy: 0.5938 - val_precision: 0.4944 - val_recall: 0.9831 - lr: 0.0010
# Epoch 5/20
# 226/226 [==============================] - 77s 340ms/step - loss: 0.3384 - accuracy: 0.8396 - precision: 0.7586 - recall: 0.8787 - val_loss: 0.2635 - val_accuracy: 0.8638 - val_precision: 0.8421 - val_recall: 0.8090 - lr: 1.0000e-04
# Epoch 6/20
# 226/226 [==============================] - 77s 340ms/step - loss: 0.2950 - accuracy: 0.8614 - precision: 0.7939 - recall: 0.8828 - val_loss: 0.2637 - val_accuracy: 0.8795 - val_precision: 0.7818 - val_recall: 0.9663 - lr: 1.0000e-04
# Epoch 7/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.2832 - accuracy: 0.8764 - precision: 0.8160 - recall: 0.8922 - val_loss: 0.2659 - val_accuracy: 0.9018 - val_precision: 0.8221 - val_recall: 0.9607 - lr: 1.0000e-04
# Epoch 8/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.2623 - accuracy: 0.8850 - precision: 0.8262 - recall: 0.9022 - val_loss: 0.2650 - val_accuracy: 0.8750 - val_precision: 0.7798 - val_recall: 0.9551 - lr: 1.0000e-05
# Epoch 9/20
# 226/226 [==============================] - 77s 340ms/step - loss: 0.2529 - accuracy: 0.8894 - precision: 0.8334 - recall: 0.9043 - val_loss: 0.2434 - val_accuracy: 0.8884 - val_precision: 0.8137 - val_recall: 0.9326 - lr: 1.0000e-05
# Epoch 10/20
# 226/226 [==============================] - 77s 340ms/step - loss: 0.2536 - accuracy: 0.8890 - precision: 0.8332 - recall: 0.9032 - val_loss: 0.2648 - val_accuracy: 0.8839 - val_precision: 0.8029 - val_recall: 0.9382 - lr: 1.0000e-05
# Epoch 11/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.2579 - accuracy: 0.8872 - precision: 0.8313 - recall: 0.9008 - val_loss: 0.2459 - val_accuracy: 0.8929 - val_precision: 0.8283 - val_recall: 0.9213 - lr: 1.0000e-05
# Epoch 12/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.2467 - accuracy: 0.8934 - precision: 0.8405 - recall: 0.9053 - val_loss: 0.2527 - val_accuracy: 0.8884 - val_precision: 0.8200 - val_recall: 0.9213 - lr: 1.0000e-06
# Epoch 13/20
# 226/226 [==============================] - 77s 340ms/step - loss: 0.2437 - accuracy: 0.8942 - precision: 0.8406 - recall: 0.9077 - val_loss: 0.2450 - val_accuracy: 0.8906 - val_precision: 0.8209 - val_recall: 0.9270 - lr: 1.0000e-06
# Epoch 14/20
# 226/226 [==============================] - 77s 342ms/step - loss: 0.2487 - accuracy: 0.8912 - precision: 0.8382 - recall: 0.9022 - val_loss: 0.2543 - val_accuracy: 0.8884 - val_precision: 0.8200 - val_recall: 0.9213 - lr: 1.0000e-06
# Epoch 15/20
# 226/226 [==============================] - 77s 341ms/step - loss: 0.2508 - accuracy: 0.8917 - precision: 0.8381 - recall: 0.9039 - val_loss: 0.2499 - val_accuracy: 0.8884 - val_precision: 0.8137 - val_recall: 0.9326 - lr: 1.0000e-06
# Epoch 16/20
# 226/226 [==============================] - 76s 339ms/step - loss: 0.2468 - accuracy: 0.8933 - precision: 0.8383 - recall: 0.9084 - val_loss: 0.2419 - val_accuracy: 0.8973 - val_precision: 0.8300 - val_recall: 0.9326 - lr: 1.0000e-06
# Epoch 17/20
# 226/226 [==============================] - 77s 343ms/step - loss: 0.2458 - accuracy: 0.8931 - precision: 0.8404 - recall: 0.9046 - val_loss: 0.2507 - val_accuracy: 0.8929 - val_precision: 0.8250 - val_recall: 0.9270 - lr: 1.0000e-06
# Epoch 18/20
# 226/226 [==============================] - 77s 342ms/step - loss: 0.2411 - accuracy: 0.8966 - precision: 0.8430 - recall: 0.9112 - val_loss: 0.2492 - val_accuracy: 0.8951 - val_precision: 0.8259 - val_recall: 0.9326 - lr: 1.0000e-06
# Epoch 19/20
# 226/226 [==============================] - 77s 342ms/step - loss: 0.2491 - accuracy: 0.8894 - precision: 0.8340 - recall: 0.9032 - val_loss: 0.2416 - val_accuracy: 0.8973 - val_precision: 0.8300 - val_recall: 0.9326 - lr: 1.0000e-06
# Epoch 20/20
# 226/226 [==============================] - 76s 339ms/step - loss: 0.2400 - accuracy: 0.8927 - precision: 0.8379 - recall: 0.9074 - val_loss: 0.2513 - val_accuracy: 0.8884 - val_precision: 0.8168 - val_recall: 0.9270 - lr: 1.0000e-06
#
#
# Training ResNet18 ...
# Epoch 1/20
# 226/226 [==============================] - 72s 306ms/step - loss: 0.5384 - accuracy: 0.7293 - precision: 0.6375 - recall: 0.8023 - val_loss: 8.4765 - val_accuracy: 0.4196 - val_precision: 0.3566 - val_recall: 0.5730 - lr: 0.0010
# Epoch 2/20
# 226/226 [==============================] - 69s 307ms/step - loss: 0.4626 - accuracy: 0.7723 - precision: 0.6744 - recall: 0.8327 - val_loss: 6.5322 - val_accuracy: 0.4598 - val_precision: 0.4059 - val_recall: 0.7753 - lr: 0.0010
# Epoch 3/20
# 226/226 [==============================] - 68s 302ms/step - loss: 0.4424 - accuracy: 0.7873 - precision: 0.6934 - recall: 0.8396 - val_loss: 6.1922 - val_accuracy: 0.4487 - val_precision: 0.4127 - val_recall: 0.9157 - lr: 0.0010
# Epoch 4/20
# 226/226 [==============================] - 68s 302ms/step - loss: 0.4055 - accuracy: 0.8071 - precision: 0.7209 - recall: 0.8448 - val_loss: 0.4418 - val_accuracy: 0.7924 - val_precision: 0.6906 - val_recall: 0.8652 - lr: 0.0010
# Epoch 5/20
# 226/226 [==============================] - 68s 301ms/step - loss: 0.3823 - accuracy: 0.8183 - precision: 0.7335 - recall: 0.8572 - val_loss: 0.4260 - val_accuracy: 0.8304 - val_precision: 0.7713 - val_recall: 0.8146 - lr: 0.0010
# Epoch 6/20
# 226/226 [==============================] - 67s 300ms/step - loss: 0.3533 - accuracy: 0.8402 - precision: 0.7645 - recall: 0.8676 - val_loss: 1.3505 - val_accuracy: 0.6362 - val_precision: 0.5355 - val_recall: 0.6348 - lr: 0.0010
# Epoch 7/20
# 226/226 [==============================] - 68s 300ms/step - loss: 0.3537 - accuracy: 0.8363 - precision: 0.7614 - recall: 0.8604 - val_loss: 3.7254 - val_accuracy: 0.5134 - val_precision: 0.4471 - val_recall: 0.9494 - lr: 0.0010
# Epoch 8/20
# 226/226 [==============================] - 68s 300ms/step - loss: 0.2813 - accuracy: 0.8775 - precision: 0.8177 - recall: 0.8928 - val_loss: 0.2634 - val_accuracy: 0.8817 - val_precision: 0.8834 - val_recall: 0.8090 - lr: 1.0000e-04
# Epoch 9/20
# 226/226 [==============================] - 68s 300ms/step - loss: 0.2670 - accuracy: 0.8840 - precision: 0.8302 - recall: 0.8925 - val_loss: 0.2442 - val_accuracy: 0.8817 - val_precision: 0.8415 - val_recall: 0.8652 - lr: 1.0000e-04
# Epoch 10/20
# 226/226 [==============================] - 68s 302ms/step - loss: 0.2650 - accuracy: 0.8859 - precision: 0.8344 - recall: 0.8918 - val_loss: 0.2981 - val_accuracy: 0.8772 - val_precision: 0.8254 - val_recall: 0.8764 - lr: 1.0000e-04
# Epoch 11/20
# 226/226 [==============================] - 68s 304ms/step - loss: 0.2613 - accuracy: 0.8898 - precision: 0.8392 - recall: 0.8963 - val_loss: 0.3071 - val_accuracy: 0.8705 - val_precision: 0.8158 - val_recall: 0.8708 - lr: 1.0000e-04
# Epoch 12/20
# 226/226 [==============================] - 68s 301ms/step - loss: 0.2473 - accuracy: 0.8924 - precision: 0.8452 - recall: 0.8949 - val_loss: 0.2490 - val_accuracy: 0.8795 - val_precision: 0.8069 - val_recall: 0.9157 - lr: 1.0000e-05
# Epoch 13/20
# 226/226 [==============================] - 68s 302ms/step - loss: 0.2368 - accuracy: 0.8985 - precision: 0.8488 - recall: 0.9081 - val_loss: 0.2383 - val_accuracy: 0.8884 - val_precision: 0.8333 - val_recall: 0.8989 - lr: 1.0000e-05
# Epoch 14/20
# 226/226 [==============================] - 68s 301ms/step - loss: 0.2406 - accuracy: 0.8942 - precision: 0.8452 - recall: 0.9004 - val_loss: 0.2467 - val_accuracy: 0.8862 - val_precision: 0.8191 - val_recall: 0.9157 - lr: 1.0000e-05
# Epoch 15/20
# 226/226 [==============================] - 68s 301ms/step - loss: 0.2283 - accuracy: 0.9038 - precision: 0.8605 - recall: 0.9063 - val_loss: 0.2347 - val_accuracy: 0.8906 - val_precision: 0.8342 - val_recall: 0.9045 - lr: 1.0000e-05
# Epoch 16/20
# 226/226 [==============================] - 67s 299ms/step - loss: 0.2350 - accuracy: 0.9038 - precision: 0.8634 - recall: 0.9022 - val_loss: 0.2378 - val_accuracy: 0.8839 - val_precision: 0.8247 - val_recall: 0.8989 - lr: 1.0000e-05
# Epoch 17/20
# 226/226 [==============================] - 68s 301ms/step - loss: 0.2376 - accuracy: 0.8974 - precision: 0.8539 - recall: 0.8970 - val_loss: 0.2444 - val_accuracy: 0.8906 - val_precision: 0.8308 - val_recall: 0.9101 - lr: 1.0000e-05
# Epoch 18/20
# 226/226 [==============================] - 67s 299ms/step - loss: 0.2379 - accuracy: 0.8995 - precision: 0.8558 - recall: 0.9004 - val_loss: 0.2363 - val_accuracy: 0.8906 - val_precision: 0.8274 - val_recall: 0.9157 - lr: 1.0000e-06
# Epoch 19/20
# 226/226 [==============================] - 68s 300ms/step - loss: 0.2335 - accuracy: 0.9039 - precision: 0.8587 - recall: 0.9094 - val_loss: 0.2316 - val_accuracy: 0.8906 - val_precision: 0.8274 - val_recall: 0.9157 - lr: 1.0000e-06
# Epoch 20/20
# 226/226 [==============================] - 67s 299ms/step - loss: 0.2263 - accuracy: 0.9028 - precision: 0.8560 - recall: 0.9101 - val_loss: 0.2425 - val_accuracy: 0.8884 - val_precision: 0.8232 - val_recall: 0.9157 - lr: 1.0000e-06

# %% [markdown]
# ## Evaluation

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating EfficientNetB4 ...
# 43/43 [==============================] - 5s 110ms/step - loss: 0.0889 - accuracy: 0.9661 - precision: 0.9526 - recall: 0.9632
#
#
# Evaluating DarkCovidNet ...
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2255 - accuracy: 0.9189 - precision: 0.8579 - recall: 0.9558
#
#
# Evaluating ResNet50 ...
# 43/43 [==============================] - 3s 61ms/step - loss: 0.2324 - accuracy: 0.9063 - precision: 0.8478 - recall: 0.9337
#
#
# Evaluating ResNet18 ...
# 43/43 [==============================] - 1s 27ms/step - loss: 0.2470 - accuracy: 0.9049 - precision: 0.8557 - recall: 0.9171

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# no noise added here
NOISE_MULTIPLIER = 0.0

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = inf

# %% [markdown]
# #### Membership Inference Attack

# %%
def compute_attack_inputs(model, attack_data):
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant
    # get labels
    labels = []
    for x, y in attack_data.as_numpy_iterator():
        labels.append(y[0])
    # predict
    probs = model.predict(attack_data)
    # compute loss
    losses = np.array([x[0] for x in bc(constant([[y] for y in labels]), constant(probs), from_logits=False).numpy()])
    
    return (np.array(probs), np.array(losses), np.array(labels))

# run membership inference attack
def run_mia(model, train_attack_input, test_attack_input):
    # prepare attacks
    probs_train, loss_train, labels_train = train_attack_input
    probs_test, loss_test, labels_test = test_attack_input

    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = labels_train,
        labels_test = labels_test
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
        by_classification_correctness = True
    )

    attack_types = [
        #AttackType.THRESHOLD_ATTACK, # logistic was always better, so no threshold to save time
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    #plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    #plt.show()

    # print a user-friendly summary of the attacks
    #print(attacks_result.summary(by_slices=False))

    max_auc = attacks_result.get_result_with_max_auc().get_auc()
    max_adv = attacks_result.get_result_with_max_attacker_advantage().get_attacker_advantage()

    return max_auc, max_adv

# epsilon estimation based on attack, metric adapted for AUC from https://paperswithcode.com/paper/antipodes-of-label-differential-privacy-pate
def empirical_eps(auc):
    if auc <= 0.5:
        return 0
    if auc == 1:
        return np.inf
    return np.log(auc / (1 - auc))

from contextlib import contextmanager
import sys
@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout

# %%
import scipy.stats as st

for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    SAMPLE_NB = 100
    
    train_attack_input = compute_attack_inputs(model, train_attack_data)
    test_attack_input = compute_attack_inputs(model, test_attack_data)

    aucs = []
    advs = []
    emp_eps = []
    for i in range(SAMPLE_NB):
        with suppress_stdout():
            max_auc, max_adv = run_mia(model, train_attack_input, test_attack_input)
        aucs.append(max_auc)
        advs.append(max_adv)
        emp_eps.append(empirical_eps(max_auc))

    auc_low, auc_high = st.t.interval(0.95, len(aucs)-1, loc=np.mean(aucs), scale=st.sem(aucs))
    adv_low, adv_high = st.t.interval(0.95, len(advs)-1, loc=np.mean(advs), scale=st.sem(advs))
    eps_low, eps_high = st.t.interval(0.95, len(emp_eps)-1, loc=np.mean(emp_eps), scale=st.sem(emp_eps))

    print('95%%-CI based on %i attack samples'%(SAMPLE_NB))
    print('AUC: %0.2f-%0.2f'%(auc_low, auc_high))
    print('Attacker advantage: %0.2f-%0.2f'%(adv_low, adv_high))
    print('Empirical epsilon bounds from AUC: %0.2f-%0.2f\n'%(eps_low, eps_high))
# Out:
# Membership Inference Attack on EfficientNetB4...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.14-0.16
#
# Membership Inference Attack on DarkCovidNet...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.14
# Empirical epsilon bounds from AUC: 0.11-0.14
#
# Membership Inference Attack on ResNet50...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.13-0.15
# Empirical epsilon bounds from AUC: 0.12-0.15
#
# Membership Inference Attack on ResNet18...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.53
# Attacker advantage: 0.13-0.14
# Empirical epsilon bounds from AUC: 0.10-0.14
