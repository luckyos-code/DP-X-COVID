# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install git+https://github.com/tensorflow/privacy
# Out:
#      |████████████████████████████████| 4.0 MB 6.9 MB/s
#   Building wheel for tensorflow-privacy (setup.py) ... done

# %%
# !pip -q install git+https://github.com/qubvel/classification_models.git
# Out:
#      |████████████████████████████████| 50 kB 4.1 MB/s
#   Building wheel for image-classifiers (setup.py) ... done

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from classification_models.tfkeras import Classifiers

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from tensorflow.keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SingleAttackResult
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

# %%
ResNet18, _ = Classifiers.get('resnet18')

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 100% 780M/780M [00:03<00:00, 229MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 16
IMG_SHAPE = [224, 224, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 1.023
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-val-test split with 80-5-15
x_train, x_rest, y_train, y_rest = train_test_split(files, labels, test_size=VAL_SPLIT+TEST_SPLIT, random_state=random_state)
x_test, x_val, y_test, y_val = train_test_split(x_rest, y_rest, test_size=VAL_SPLIT/(VAL_SPLIT+TEST_SPLIT), random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7232, Val: 452, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4339, 'COVID-19': 2893}
# val set:  {'normal': 272, 'COVID-19': 180}
# test set:   {'normal': 813, 'COVID-19': 543}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# set for attack on train set
train_attack_data = prepare_dataset(train_ds,
                                    pre=True,
                                    shuffle=False,
                                    repeat=False,
                                    batch=1,
                                    augment=False,
                                    cache=False)

# set for attack on test set
test_attack_data = prepare_dataset(test_ds,
                                   pre=True,
                                   shuffle=False,
                                   repeat=False,
                                   batch=1,
                                   augment=False,
                                   cache=False)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## ResNet18
# [Paper](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('tanh', name=name + '_preact_tanh')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride, name=name + 'pool_pool')(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('tanh', name=name + '_1_tanh')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('tanh', name=name + '_2_tanh')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    # bottom
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    # body
    x = stack_fn(x)
    # no top added
    # Create model
    model = tf.keras.models.Model(input, x, name=model_name)
    return model
    
def ResNet18_tanh(input):
    def stack_fn(x):
        x = resnet_stack(x, 64, 2, name='conv2')
        x = resnet_stack(x, 128, 2, name='conv3')
        x = resnet_stack(x, 256, 2, name='conv4')
        x = resnet_stack(x, 512, 2, stride1=1, name='conv5')
        x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
        x = Activation('tanh', name='post_tanh')(x)
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_builder(weights=False, dropout=False, activation='relu', name='ResNet18'):
    # ResNet18 without head
    if activation == 'tanh':
        resnet18 = ResNet18_tanh(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    elif activation == 'relu':
        _weights = False if weights == 'pneumonia' else weights
        resnet18 = ResNet18(include_top = False,
                            weights = _weights,
                            input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]))
    
    resnet18.trainable = True # make layers trainable

    seq = [
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]), name='Input'),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ]

    if dropout:
        seq.insert(3, Dropout(rate=dropout, name='Dropout')) # add dropout (inspired by inception-resnet-v2))

    model = Sequential(seq, name=name)

    # load weights from pneumonia pretraining
    if weights == 'pneumonia' and activation == 'relu':
        model.load_weights(weights_path+'resnet18_relu_public_weights.h5', by_name=True)
    if weights == 'pneumonia' and activation == 'tanh':
        model.load_weights(weights_path+'resnet18_tanh_public_weights.h5', by_name=True)
    
    return model

# %%
resnet18 = resnet18_builder(name='ResNet18') # NA
resnet18_dropout = resnet18_builder(dropout=0.2, name='ResNet18-dropout') # NA
resnet18_imagenet = resnet18_builder(weights='imagenet', name='ResNet18-imagenet') # NA
resnet18_pneumonia = resnet18_builder(weights='pneumonia', name='ResNet18-pneumonia')

resnet18_tanh = resnet18_builder(activation='tanh', name='ResNet18-tanh')
resnet18_tanh_dropout = resnet18_builder(activation='tanh', dropout=0.2, name='ResNet18-tanh-dropout')
resnet18_tanh_pneumonia = resnet18_builder(activation='tanh', weights='pneumonia', name='ResNet18-tanh-pneumonia')

models = [
    resnet18,
    resnet18_dropout,
    resnet18_imagenet,
    resnet18_pneumonia,
    resnet18_tanh,
    resnet18_tanh_dropout,
    resnet18_tanh_pneumonia,
]

METRICS = [
    'accuracy',
    Precision(name='precision'),
    Recall(name='recall')
]

for model in models:
    model.compile(
        optimizer=VectorizedDPKerasAdamOptimizer(
            l2_norm_clip=L2_NORM_CLIP,
            noise_multiplier=NOISE_MULTIPLIER,
            num_microbatches=MICROBATCHES,
            learning_rate=1e-3
        ),
        loss=BinaryCrossentropy(
            from_logits=True,
            reduction=tf.compat.v1.losses.Reduction.NONE
            # reduction is set to NONE to get loss in a vector form
        ),
        metrics=METRICS
    )
# Out:
# Downloading data from https://github.com/qubvel/classification_models/releases/download/0.0.1/resnet18_imagenet_1000_no_top.h5
# 44924928/44920640 [==============================] - 1s 0us/step
# 44933120/44920640 [==============================] - 1s 0us/step

# %%
models[0].summary()
# Out:
# Model: "ResNet18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Functional)           (None, 7, 7, 512)         11186889
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 11,187,402
# Trainable params: 11,179,460
# Non-trainable params: 7,942
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
for model in models:
    print("Training %s ..." % (model.name))
    history = model.fit(
        train_batched,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_batched,
        validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
        class_weight=class_weight_dict,
        callbacks = [learning_rate_decay],
    )
    print('\n')
# Out:
# Training ResNet18 ...
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4994: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 452/452 [==============================] - 309s 609ms/step - loss: 1.3466 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.5141 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.6917 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2715 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.6579 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3448 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.6556 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3261 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.6277 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0907 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.6211 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0888 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5861 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0885 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5750 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0467 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5489 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0524 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 452/452 [==============================] - 274s 605ms/step - loss: 1.5462 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0561 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.5440 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0528 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5400 - accuracy: 0.6001 - precision: 1.0000 - recall: 3.4566e-04 - val_loss: 1.0458 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5335 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0460 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5271 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0467 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5314 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0404 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5186 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0465 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5307 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0435 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5262 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0449 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5253 - accuracy: 0.5998 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0407 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.5292 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0448 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
#
# Training ResNet18-dropout ...
# Epoch 1/20
# 452/452 [==============================] - 291s 609ms/step - loss: 0.8819 - accuracy: 0.5625 - precision: 0.4329 - recall: 0.2846 - val_loss: 0.9781 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.5791 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3443 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7736 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4247 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.7843 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2151 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7760 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2138 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 452/452 [==============================] - 275s 607ms/step - loss: 1.7626 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2047 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7698 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2076 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7657 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2088 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7665 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2053 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7657 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2047 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.7623 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2032 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7638 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2094 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7657 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2060 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.7678 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2119 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7513 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2096 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7594 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2081 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7720 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2079 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7548 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2069 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7617 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2031 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.7575 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2004 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
#
# Training ResNet18-imagenet ...
# Epoch 1/20
# 452/452 [==============================] - 290s 608ms/step - loss: 0.8647 - accuracy: 0.6164 - precision: 0.5699 - recall: 0.1579 - val_loss: 1.2575 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.6832 - accuracy: 0.6001 - precision: 1.0000 - recall: 3.4566e-04 - val_loss: 1.4248 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.9023 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.9279 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.9394 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.7225 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.9597 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6298 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 452/452 [==============================] - 275s 608ms/step - loss: 1.9541 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6385 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 452/452 [==============================] - 275s 609ms/step - loss: 1.9463 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6400 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 452/452 [==============================] - 275s 609ms/step - loss: 1.9254 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6411 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.9421 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6438 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.9311 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6463 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.9398 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6361 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.9353 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6379 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.9311 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6426 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.9315 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6338 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.9403 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6406 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.9372 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6394 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 452/452 [==============================] - 274s 606ms/step - loss: 1.9294 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6402 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.9354 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6279 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.9343 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6451 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 452/452 [==============================] - 274s 607ms/step - loss: 1.9321 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.6430 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
#
#
# Training ResNet18-pneumonia ...
# Epoch 1/20
# 452/452 [==============================] - 290s 608ms/step - loss: 0.8668 - accuracy: 0.7178 - precision: 0.6216 - recall: 0.7089 - val_loss: 1.3790 - val_accuracy: 0.6920 - val_precision: 0.7000 - val_recall: 0.3933
# Epoch 2/20
# 452/452 [==============================] - 275s 607ms/step - loss: 0.8930 - accuracy: 0.7294 - precision: 0.6513 - recall: 0.6965 - val_loss: 1.0113 - val_accuracy: 0.7277 - val_precision: 0.6728 - val_recall: 0.6124
# Epoch 3/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.9124 - accuracy: 0.7320 - precision: 0.6529 - recall: 0.7048 - val_loss: 1.3700 - val_accuracy: 0.7165 - val_precision: 0.7073 - val_recall: 0.4888
# Epoch 4/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.8942 - accuracy: 0.7344 - precision: 0.6579 - recall: 0.7000 - val_loss: 0.9821 - val_accuracy: 0.7545 - val_precision: 0.7000 - val_recall: 0.6685
# Epoch 5/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.9204 - accuracy: 0.7359 - precision: 0.6623 - recall: 0.6934 - val_loss: 1.1859 - val_accuracy: 0.7455 - val_precision: 0.7353 - val_recall: 0.5618
# Epoch 6/20
# 452/452 [==============================] - 275s 608ms/step - loss: 0.9287 - accuracy: 0.7373 - precision: 0.6643 - recall: 0.6937 - val_loss: 1.1586 - val_accuracy: 0.7522 - val_precision: 0.7376 - val_recall: 0.5843
# Epoch 7/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.8802 - accuracy: 0.7475 - precision: 0.6767 - recall: 0.7062 - val_loss: 1.2771 - val_accuracy: 0.7522 - val_precision: 0.7481 - val_recall: 0.5674
# Epoch 8/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.8987 - accuracy: 0.7461 - precision: 0.6741 - recall: 0.7072 - val_loss: 1.2439 - val_accuracy: 0.7500 - val_precision: 0.7357 - val_recall: 0.5787
# Epoch 9/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.8886 - accuracy: 0.7490 - precision: 0.6771 - recall: 0.7124 - val_loss: 1.2400 - val_accuracy: 0.7545 - val_precision: 0.7500 - val_recall: 0.5730
# Epoch 10/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.8929 - accuracy: 0.7541 - precision: 0.6827 - recall: 0.7200 - val_loss: 1.2594 - val_accuracy: 0.7522 - val_precision: 0.7481 - val_recall: 0.5674
# Epoch 11/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.9119 - accuracy: 0.7424 - precision: 0.6691 - recall: 0.7045 - val_loss: 1.2191 - val_accuracy: 0.7522 - val_precision: 0.7445 - val_recall: 0.5730
# Epoch 12/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.9080 - accuracy: 0.7474 - precision: 0.6743 - recall: 0.7128 - val_loss: 1.2514 - val_accuracy: 0.7522 - val_precision: 0.7481 - val_recall: 0.5674
# Epoch 13/20
# 452/452 [==============================] - 275s 608ms/step - loss: 0.9295 - accuracy: 0.7464 - precision: 0.6748 - recall: 0.7065 - val_loss: 1.2182 - val_accuracy: 0.7522 - val_precision: 0.7445 - val_recall: 0.5730
# Epoch 14/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.9155 - accuracy: 0.7470 - precision: 0.6752 - recall: 0.7079 - val_loss: 1.2477 - val_accuracy: 0.7545 - val_precision: 0.7500 - val_recall: 0.5730
# Epoch 15/20
# 452/452 [==============================] - 275s 608ms/step - loss: 0.9023 - accuracy: 0.7460 - precision: 0.6727 - recall: 0.7110 - val_loss: 1.2183 - val_accuracy: 0.7522 - val_precision: 0.7445 - val_recall: 0.5730
# Epoch 16/20
# 452/452 [==============================] - 275s 607ms/step - loss: 0.8893 - accuracy: 0.7497 - precision: 0.6762 - recall: 0.7183 - val_loss: 1.2370 - val_accuracy: 0.7522 - val_precision: 0.7481 - val_recall: 0.5674
# Epoch 17/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.8956 - accuracy: 0.7449 - precision: 0.6695 - recall: 0.7155 - val_loss: 1.2462 - val_accuracy: 0.7522 - val_precision: 0.7481 - val_recall: 0.5674
# Epoch 18/20
# 452/452 [==============================] - 275s 608ms/step - loss: 0.9101 - accuracy: 0.7457 - precision: 0.6722 - recall: 0.7110 - val_loss: 1.2225 - val_accuracy: 0.7522 - val_precision: 0.7445 - val_recall: 0.5730
# Epoch 19/20
# 452/452 [==============================] - 274s 607ms/step - loss: 0.9049 - accuracy: 0.7438 - precision: 0.6705 - recall: 0.7069 - val_loss: 1.2258 - val_accuracy: 0.7522 - val_precision: 0.7481 - val_recall: 0.5674
# Epoch 20/20
# 452/452 [==============================] - 275s 607ms/step - loss: 0.8942 - accuracy: 0.7471 - precision: 0.6732 - recall: 0.7148 - val_loss: 1.2080 - val_accuracy: 0.7500 - val_precision: 0.7426 - val_recall: 0.5674
#
#
# Training ResNet18-tanh ...
# Epoch 1/20
# 452/452 [==============================] - 404s 845ms/step - loss: 0.6659 - accuracy: 0.6473 - precision: 0.5589 - recall: 0.6304 - val_loss: 0.9336 - val_accuracy: 0.6384 - val_precision: 0.5296 - val_recall: 0.8034
# Epoch 2/20
# 452/452 [==============================] - 380s 842ms/step - loss: 0.8423 - accuracy: 0.6626 - precision: 0.5688 - recall: 0.6474 - val_loss: 0.8361 - val_accuracy: 0.6629 - val_precision: 0.5894 - val_recall: 0.5000
# Epoch 3/20
# 452/452 [==============================] - 380s 842ms/step - loss: 0.9400 - accuracy: 0.6753 - precision: 0.5853 - recall: 0.6464 - val_loss: 0.8612 - val_accuracy: 0.6652 - val_precision: 0.6061 - val_recall: 0.4494
# Epoch 4/20
# 452/452 [==============================] - 380s 841ms/step - loss: 0.9841 - accuracy: 0.6850 - precision: 0.5987 - recall: 0.6447 - val_loss: 0.8668 - val_accuracy: 0.6473 - val_precision: 0.6042 - val_recall: 0.3258
# Epoch 5/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.0062 - accuracy: 0.6865 - precision: 0.6016 - recall: 0.6409 - val_loss: 0.9915 - val_accuracy: 0.6920 - val_precision: 0.6316 - val_recall: 0.5393
# Epoch 6/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.0360 - accuracy: 0.6881 - precision: 0.6028 - recall: 0.6454 - val_loss: 1.1642 - val_accuracy: 0.6897 - val_precision: 0.6696 - val_recall: 0.4326
# Epoch 7/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.0653 - accuracy: 0.6892 - precision: 0.6047 - recall: 0.6440 - val_loss: 1.0530 - val_accuracy: 0.7031 - val_precision: 0.6271 - val_recall: 0.6236
# Epoch 8/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.0550 - accuracy: 0.6932 - precision: 0.6105 - recall: 0.6436 - val_loss: 1.0557 - val_accuracy: 0.7076 - val_precision: 0.6478 - val_recall: 0.5787
# Epoch 9/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.0435 - accuracy: 0.6912 - precision: 0.6071 - recall: 0.6464 - val_loss: 1.0553 - val_accuracy: 0.7076 - val_precision: 0.6442 - val_recall: 0.5899
# Epoch 10/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.0690 - accuracy: 0.6856 - precision: 0.6022 - recall: 0.6305 - val_loss: 1.0550 - val_accuracy: 0.7076 - val_precision: 0.6478 - val_recall: 0.5787
# Epoch 11/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.0758 - accuracy: 0.6905 - precision: 0.6073 - recall: 0.6409 - val_loss: 1.0537 - val_accuracy: 0.7076 - val_precision: 0.6460 - val_recall: 0.5843
# Epoch 12/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.0623 - accuracy: 0.6897 - precision: 0.6055 - recall: 0.6436 - val_loss: 1.0554 - val_accuracy: 0.7054 - val_precision: 0.6438 - val_recall: 0.5787
# Epoch 13/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.0721 - accuracy: 0.6897 - precision: 0.6057 - recall: 0.6429 - val_loss: 1.0529 - val_accuracy: 0.7054 - val_precision: 0.6438 - val_recall: 0.5787
# Epoch 14/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.0487 - accuracy: 0.6914 - precision: 0.6089 - recall: 0.6388 - val_loss: 1.0536 - val_accuracy: 0.7054 - val_precision: 0.6438 - val_recall: 0.5787
# Epoch 15/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.0490 - accuracy: 0.6911 - precision: 0.6074 - recall: 0.6443 - val_loss: 1.0558 - val_accuracy: 0.7076 - val_precision: 0.6460 - val_recall: 0.5843
# Epoch 16/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.0668 - accuracy: 0.6910 - precision: 0.6072 - recall: 0.6443 - val_loss: 1.0573 - val_accuracy: 0.7076 - val_precision: 0.6442 - val_recall: 0.5899
# Epoch 17/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.0529 - accuracy: 0.6892 - precision: 0.6035 - recall: 0.6498 - val_loss: 1.0607 - val_accuracy: 0.7031 - val_precision: 0.6364 - val_recall: 0.5899
# Epoch 18/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.0633 - accuracy: 0.6883 - precision: 0.6051 - recall: 0.6357 - val_loss: 1.0587 - val_accuracy: 0.7076 - val_precision: 0.6442 - val_recall: 0.5899
# Epoch 19/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.0752 - accuracy: 0.6876 - precision: 0.6025 - recall: 0.6440 - val_loss: 1.0593 - val_accuracy: 0.7076 - val_precision: 0.6442 - val_recall: 0.5899
# Epoch 20/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.0699 - accuracy: 0.6869 - precision: 0.6019 - recall: 0.6419 - val_loss: 1.0582 - val_accuracy: 0.7054 - val_precision: 0.6438 - val_recall: 0.5787
#
#
# Training ResNet18-tanh-dropout ...
# Epoch 1/20
# 452/452 [==============================] - 402s 843ms/step - loss: 0.6480 - accuracy: 0.6478 - precision: 0.5556 - recall: 0.6376 - val_loss: 0.9213 - val_accuracy: 0.6004 - val_precision: 0.4839 - val_recall: 0.0843
# Epoch 2/20
# 452/452 [==============================] - 381s 843ms/step - loss: 0.7989 - accuracy: 0.6676 - precision: 0.5733 - recall: 0.6609 - val_loss: 1.9196 - val_accuracy: 0.6049 - val_precision: 1.0000 - val_recall: 0.0056
# Epoch 3/20
# 452/452 [==============================] - 381s 842ms/step - loss: 0.9402 - accuracy: 0.6767 - precision: 0.5859 - recall: 0.6540 - val_loss: 1.2706 - val_accuracy: 0.6161 - val_precision: 0.8000 - val_recall: 0.0449
# Epoch 4/20
# 452/452 [==============================] - 380s 842ms/step - loss: 0.9517 - accuracy: 0.6811 - precision: 0.5923 - recall: 0.6512 - val_loss: 1.0278 - val_accuracy: 0.6875 - val_precision: 0.5913 - val_recall: 0.6910
# Epoch 5/20
# 452/452 [==============================] - 381s 843ms/step - loss: 1.0079 - accuracy: 0.6831 - precision: 0.5949 - recall: 0.6512 - val_loss: 1.0121 - val_accuracy: 0.6987 - val_precision: 0.6229 - val_recall: 0.6124
# Epoch 6/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.0189 - accuracy: 0.6836 - precision: 0.5955 - recall: 0.6519 - val_loss: 1.0213 - val_accuracy: 0.7031 - val_precision: 0.6316 - val_recall: 0.6067
# Epoch 7/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.0052 - accuracy: 0.6853 - precision: 0.5959 - recall: 0.6626 - val_loss: 1.0179 - val_accuracy: 0.7009 - val_precision: 0.6341 - val_recall: 0.5843
# Epoch 8/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.0303 - accuracy: 0.6832 - precision: 0.5947 - recall: 0.6533 - val_loss: 1.0180 - val_accuracy: 0.6987 - val_precision: 0.6319 - val_recall: 0.5787
# Epoch 9/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.0116 - accuracy: 0.6799 - precision: 0.5903 - recall: 0.6530 - val_loss: 1.0183 - val_accuracy: 0.7009 - val_precision: 0.6341 - val_recall: 0.5843
# Epoch 10/20
# 452/452 [==============================] - 381s 842ms/step - loss: 0.9920 - accuracy: 0.6910 - precision: 0.6024 - recall: 0.6692 - val_loss: 1.0201 - val_accuracy: 0.7009 - val_precision: 0.6341 - val_recall: 0.5843
# Epoch 11/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.0208 - accuracy: 0.6846 - precision: 0.5958 - recall: 0.6578 - val_loss: 1.0189 - val_accuracy: 0.6987 - val_precision: 0.6319 - val_recall: 0.5787
# Epoch 12/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.0000 - accuracy: 0.6887 - precision: 0.6000 - recall: 0.6657 - val_loss: 1.0223 - val_accuracy: 0.6987 - val_precision: 0.6303 - val_recall: 0.5843
# Epoch 13/20
# 452/452 [==============================] - 381s 843ms/step - loss: 1.0062 - accuracy: 0.6885 - precision: 0.6001 - recall: 0.6633 - val_loss: 1.0224 - val_accuracy: 0.7009 - val_precision: 0.6341 - val_recall: 0.5843
# Epoch 14/20
# 452/452 [==============================] - 381s 843ms/step - loss: 1.0119 - accuracy: 0.6846 - precision: 0.5952 - recall: 0.6613 - val_loss: 1.0215 - val_accuracy: 0.6987 - val_precision: 0.6319 - val_recall: 0.5787
# Epoch 15/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.0305 - accuracy: 0.6857 - precision: 0.5972 - recall: 0.6581 - val_loss: 1.0231 - val_accuracy: 0.7031 - val_precision: 0.6364 - val_recall: 0.5899
# Epoch 16/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.0279 - accuracy: 0.6836 - precision: 0.5940 - recall: 0.6609 - val_loss: 1.0205 - val_accuracy: 0.6987 - val_precision: 0.6319 - val_recall: 0.5787
# Epoch 17/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.0081 - accuracy: 0.6836 - precision: 0.5930 - recall: 0.6668 - val_loss: 1.0236 - val_accuracy: 0.7009 - val_precision: 0.6341 - val_recall: 0.5843
# Epoch 18/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.0173 - accuracy: 0.6838 - precision: 0.5939 - recall: 0.6626 - val_loss: 1.0227 - val_accuracy: 0.6987 - val_precision: 0.6319 - val_recall: 0.5787
# Epoch 19/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.0272 - accuracy: 0.6810 - precision: 0.5914 - recall: 0.6554 - val_loss: 1.0241 - val_accuracy: 0.6987 - val_precision: 0.6319 - val_recall: 0.5787
# Epoch 20/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.0251 - accuracy: 0.6843 - precision: 0.5961 - recall: 0.6540 - val_loss: 1.0235 - val_accuracy: 0.7009 - val_precision: 0.6341 - val_recall: 0.5843
#
#
# Training ResNet18-tanh-pneumonia ...
# Epoch 1/20
# 452/452 [==============================] - 402s 843ms/step - loss: 1.0087 - accuracy: 0.6868 - precision: 0.5855 - recall: 0.7496 - val_loss: 1.4891 - val_accuracy: 0.6138 - val_precision: 0.5090 - val_recall: 0.7978
# Epoch 2/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.1879 - accuracy: 0.7041 - precision: 0.6094 - recall: 0.7252 - val_loss: 2.3305 - val_accuracy: 0.5446 - val_precision: 0.4645 - val_recall: 0.9551
# Epoch 3/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.1810 - accuracy: 0.7114 - precision: 0.6198 - recall: 0.7207 - val_loss: 1.3319 - val_accuracy: 0.7188 - val_precision: 0.6140 - val_recall: 0.7865
# Epoch 4/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.2555 - accuracy: 0.7147 - precision: 0.6236 - recall: 0.7238 - val_loss: 8.7492 - val_accuracy: 0.3973 - val_precision: 0.3973 - val_recall: 1.0000
# Epoch 5/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.2391 - accuracy: 0.7140 - precision: 0.6213 - recall: 0.7304 - val_loss: 1.8625 - val_accuracy: 0.6808 - val_precision: 0.5623 - val_recall: 0.8876
# Epoch 6/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.2283 - accuracy: 0.7176 - precision: 0.6276 - recall: 0.7235 - val_loss: 1.3635 - val_accuracy: 0.7321 - val_precision: 0.6151 - val_recall: 0.8708
# Epoch 7/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.2135 - accuracy: 0.7193 - precision: 0.6298 - recall: 0.7238 - val_loss: 1.1937 - val_accuracy: 0.7321 - val_precision: 0.7164 - val_recall: 0.5393
# Epoch 8/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.2192 - accuracy: 0.7203 - precision: 0.6312 - recall: 0.7235 - val_loss: 2.6451 - val_accuracy: 0.5603 - val_precision: 0.4729 - val_recall: 0.9326
# Epoch 9/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.2338 - accuracy: 0.7250 - precision: 0.6371 - recall: 0.7259 - val_loss: 1.8470 - val_accuracy: 0.6540 - val_precision: 0.5380 - val_recall: 0.9157
# Epoch 10/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.2110 - accuracy: 0.7243 - precision: 0.6345 - recall: 0.7328 - val_loss: 1.1183 - val_accuracy: 0.7545 - val_precision: 0.7000 - val_recall: 0.6685
# Epoch 11/20
# 452/452 [==============================] - 381s 843ms/step - loss: 1.2317 - accuracy: 0.7232 - precision: 0.6338 - recall: 0.7293 - val_loss: 1.1157 - val_accuracy: 0.7567 - val_precision: 0.6769 - val_recall: 0.7416
# Epoch 12/20
# 452/452 [==============================] - 381s 843ms/step - loss: 1.2028 - accuracy: 0.7262 - precision: 0.6374 - recall: 0.7321 - val_loss: 1.1319 - val_accuracy: 0.7634 - val_precision: 0.6875 - val_recall: 0.7416
# Epoch 13/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.2219 - accuracy: 0.7261 - precision: 0.6359 - recall: 0.7376 - val_loss: 1.1121 - val_accuracy: 0.7589 - val_precision: 0.7059 - val_recall: 0.6742
# Epoch 14/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.2368 - accuracy: 0.7237 - precision: 0.6349 - recall: 0.7280 - val_loss: 1.1608 - val_accuracy: 0.7500 - val_precision: 0.6587 - val_recall: 0.7697
# Epoch 15/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.2275 - accuracy: 0.7272 - precision: 0.6386 - recall: 0.7328 - val_loss: 1.1850 - val_accuracy: 0.7522 - val_precision: 0.6588 - val_recall: 0.7809
# Epoch 16/20
# 452/452 [==============================] - 381s 842ms/step - loss: 1.2392 - accuracy: 0.7208 - precision: 0.6305 - recall: 0.7297 - val_loss: 1.1582 - val_accuracy: 0.7500 - val_precision: 0.6587 - val_recall: 0.7697
# Epoch 17/20
# 452/452 [==============================] - 381s 843ms/step - loss: 1.2250 - accuracy: 0.7258 - precision: 0.6376 - recall: 0.7287 - val_loss: 1.1639 - val_accuracy: 0.7500 - val_precision: 0.6587 - val_recall: 0.7697
# Epoch 18/20
# 452/452 [==============================] - 380s 842ms/step - loss: 1.2000 - accuracy: 0.7280 - precision: 0.6393 - recall: 0.7345 - val_loss: 1.1314 - val_accuracy: 0.7567 - val_precision: 0.6700 - val_recall: 0.7640
# Epoch 19/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.2076 - accuracy: 0.7259 - precision: 0.6367 - recall: 0.7331 - val_loss: 1.1319 - val_accuracy: 0.7567 - val_precision: 0.6700 - val_recall: 0.7640
# Epoch 20/20
# 452/452 [==============================] - 380s 841ms/step - loss: 1.2254 - accuracy: 0.7255 - precision: 0.6359 - recall: 0.7342 - val_loss: 1.1357 - val_accuracy: 0.7522 - val_precision: 0.6634 - val_recall: 0.7640

# %% [markdown]
# ## Evaluation

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating ResNet18 ...
# 85/85 [==============================] - 7s 84ms/step - loss: 1.0520 - accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating ResNet18-dropout ...
# 85/85 [==============================] - 3s 32ms/step - loss: 1.2110 - accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating ResNet18-imagenet ...
# 85/85 [==============================] - 3s 30ms/step - loss: 1.6076 - accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating ResNet18-pneumonia ...
# 85/85 [==============================] - 3s 31ms/step - loss: 1.3925 - accuracy: 0.7124 - precision: 0.6927 - recall: 0.5064
#
#
# Evaluating ResNet18-tanh ...
# 85/85 [==============================] - 3s 34ms/step - loss: 1.0548 - accuracy: 0.7072 - precision: 0.6342 - recall: 0.6354
#
#
# Evaluating ResNet18-tanh-dropout ...
# 85/85 [==============================] - 3s 33ms/step - loss: 1.0002 - accuracy: 0.7198 - precision: 0.6552 - recall: 0.6335
#
#
# Evaluating ResNet18-tanh-pneumonia ...
# 85/85 [==============================] - 3s 32ms/step - loss: 1.2312 - accuracy: 0.7412 - precision: 0.6472 - recall: 0.7772

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 1.000

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 1.0
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.221% and noise_multiplier = 1.020921289099455 iterated over 9040 steps satisfies differential privacy with eps = 1 and delta = 0.0001.
# 1.020921289099455

# %% [markdown]
# #### Membership Inference Attack

# %%
def compute_attack_inputs(model, attack_data):
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant
    # get labels
    labels = []
    for x, y in attack_data.as_numpy_iterator():
        labels.append(y[0])
    # predict
    probs = model.predict(attack_data)
    # compute loss
    losses = np.array([x[0] for x in bc(constant([[y] for y in labels]), constant(probs), from_logits=False).numpy()])
    
    return (np.array(probs), np.array(losses), np.array(labels))

# run membership inference attack
def run_mia(model, train_attack_input, test_attack_input):
    # prepare attacks
    probs_train, loss_train, labels_train = train_attack_input
    probs_test, loss_test, labels_test = test_attack_input

    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = labels_train,
        labels_test = labels_test
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
        by_classification_correctness = True
    )

    attack_types = [
        #AttackType.THRESHOLD_ATTACK, # logistic was always better, so no threshold to save time
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    #plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    #plt.show()

    # print a user-friendly summary of the attacks
    #print(attacks_result.summary(by_slices=False))

    max_auc = attacks_result.get_result_with_max_auc().get_auc()
    max_adv = attacks_result.get_result_with_max_attacker_advantage().get_attacker_advantage()

    return max_auc, max_adv

# epsilon estimation based on attack, metric adapted for AUC from https://paperswithcode.com/paper/antipodes-of-label-differential-privacy-pate
def empirical_eps(auc):
    if auc <= 0.5:
        return 0
    if auc == 1:
        return np.inf
    return np.log(auc / (1 - auc))

from contextlib import contextmanager
import sys
@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout

# %%
import scipy.stats as st

for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    SAMPLE_NB = 100
    
    train_attack_input = compute_attack_inputs(model, train_attack_data)
    test_attack_input = compute_attack_inputs(model, test_attack_data)

    aucs = []
    advs = []
    emp_eps = []
    for i in range(SAMPLE_NB):
        with suppress_stdout():
            max_auc, max_adv = run_mia(model, train_attack_input, test_attack_input)
        aucs.append(max_auc)
        advs.append(max_adv)
        emp_eps.append(empirical_eps(max_auc))

    auc_low, auc_high = st.t.interval(0.95, len(aucs)-1, loc=np.mean(aucs), scale=st.sem(aucs))
    adv_low, adv_high = st.t.interval(0.95, len(advs)-1, loc=np.mean(advs), scale=st.sem(advs))
    eps_low, eps_high = st.t.interval(0.95, len(emp_eps)-1, loc=np.mean(emp_eps), scale=st.sem(emp_eps))

    print('95%%-CI based on %i attack samples'%(SAMPLE_NB))
    print('AUC: %0.2f-%0.2f'%(auc_low, auc_high))
    print('Attacker advantage: %0.2f-%0.2f'%(adv_low, adv_high))
    print('Empirical epsilon bounds from AUC: %0.2f-%0.2f\n'%(eps_low, eps_high))
# Out:
# Membership Inference Attack on ResNet18...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.11-0.15
#
# Membership Inference Attack on ResNet18-dropout...
# 95%-CI based on 100 attack samples
# AUC: 0.52-0.53
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.10-0.13
#
# Membership Inference Attack on ResNet18-imagenet...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.53
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.11-0.14
#
# Membership Inference Attack on ResNet18-pneumonia...
# 95%-CI based on 100 attack samples
# AUC: 0.54-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.14-0.18
#
# Membership Inference Attack on ResNet18-tanh...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.14-0.17
#
# Membership Inference Attack on ResNet18-tanh-dropout...
# 95%-CI based on 100 attack samples
# AUC: 0.54-0.55
# Attacker advantage: 0.13-0.14
# Empirical epsilon bounds from AUC: 0.15-0.18
#
# Membership Inference Attack on ResNet18-tanh-pneumonia...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.14-0.17
