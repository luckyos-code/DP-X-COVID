# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install git+https://github.com/tensorflow/privacy
# Out:
#      |████████████████████████████████| 4.0 MB 10.9 MB/s
#   Building wheel for tensorflow-privacy (setup.py) ... done

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.losses import BinaryCrossentropy
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from tensorflow.keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SingleAttackResult
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 100% 780M/780M [00:13<00:00, 57.6MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SHAPE = [224, 224, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 1.267
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-val-test split with 80-5-15
x_train, x_rest, y_train, y_rest = train_test_split(files, labels, test_size=VAL_SPLIT+TEST_SPLIT, random_state=random_state)
x_test, x_val, y_test, y_val = train_test_split(x_rest, y_rest, test_size=VAL_SPLIT/(VAL_SPLIT+TEST_SPLIT), random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7232, Val: 452, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4339, 'COVID-19': 2893}
# val set:  {'normal': 272, 'COVID-19': 180}
# test set:   {'normal': 813, 'COVID-19': 543}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# set for attack on train set
train_attack_data = prepare_dataset(train_ds,
                                    pre=True,
                                    shuffle=False,
                                    repeat=False,
                                    batch=1,
                                    augment=False,
                                    cache=False)

# set for attack on test set
test_attack_data = prepare_dataset(test_ds,
                                   pre=True,
                                   shuffle=False,
                                   repeat=False,
                                   batch=1,
                                   augment=False,
                                   cache=False)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## Shallow Network
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def shallow_builder(weights=False, dropout=False, bn=False, activation='relu', name='ShallowNetwork'):

    seq = [InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]), name='Input'),]
    seq.append(Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation=activation, name='Conv1'))
    if bn:
        seq.append(BatchNormalization(name='BN1'))
    seq.append(MaxPooling2D(pool_size=(2,2), name='Pool1'))
    seq.append(Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation=activation, name='Conv2'))
    if bn:
        seq.append(BatchNormalization(name='BN2'))
    seq.append(MaxPooling2D(pool_size=(2,2), name='Pool2'))
    seq.append(Flatten(name='Flatten'))
    seq.append(Dense(units=32, activation=activation, name='Dense'))
    if bn:
        seq.append(BatchNormalization(name='BN3'))
    if dropout:
        seq.append(Dropout(rate=dropout, name='Dropout'))
    seq.append(Dense(units=1, activation='sigmoid', name='Output'))

    model = Sequential(seq, name=name)

    # load weights from pneumonia pretraining
    if weights == 'pneumonia' and activation == 'relu':
        model.load_weights(weights_path+'shallow_relu_public_weights.h5', by_name=True)
    if weights == 'pneumonia' and activation == 'tanh':
        model.load_weights(weights_path+'shallow_tanh_public_weights.h5', by_name=True)
    
    return model

# %%
shallow_bn = shallow_builder(bn=True, name='ShallowNetwork-bn')
shallow_dropout_bn = shallow_builder(dropout=0.2, bn=True, name='ShallowNetwork-dropout-bn')
shallow_pneumonia_bn = shallow_builder(weights='pneumonia', bn=True, name='ShallowNetwork-pneumonia-bn')

shallow_tanh = shallow_builder(activation='tanh', name='ShallowNetwork-tanh')
shallow_tanh_bn = shallow_builder(activation='tanh', bn=True, name='ShallowNetwork-tanh-bn')
shallow_tanh_dropout_bn = shallow_builder(activation='tanh', dropout=0.2, bn=True, name='ShallowNetwork-tanh-dropout-bn')
shallow_tanh_pneumonia_bn = shallow_builder(activation='tanh', weights='pneumonia', bn=True, name='ShallowNetwork-tanh-pneumonia-bn')

models = [
    shallow_bn,
    shallow_dropout_bn,
    shallow_pneumonia_bn,
    shallow_tanh,
    shallow_tanh_bn,
    shallow_tanh_dropout_bn,
    shallow_tanh_pneumonia_bn,
]

METRICS = [
    'accuracy',
    Precision(name='precision'),
    Recall(name='recall')
]

for model in models:
    model.compile(
        optimizer=VectorizedDPKerasAdamOptimizer(
            l2_norm_clip=L2_NORM_CLIP,
            noise_multiplier=NOISE_MULTIPLIER,
            num_microbatches=MICROBATCHES,
            learning_rate=1e-3
        ),
        loss=BinaryCrossentropy(
            from_logits=True,
            reduction=tf.compat.v1.losses.Reduction.NONE
            # reduction is set to NONE to get loss in a vector form
        ),
        metrics=METRICS
    )

# %%
models[0].summary()
# Out:
# Model: "ShallowNetwork-bn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# Conv1 (Conv2D)               (None, 109, 109, 16)      3088
# _________________________________________________________________
# BN1 (BatchNormalization)     (None, 109, 109, 16)      64
# _________________________________________________________________
# Pool1 (MaxPooling2D)         (None, 54, 54, 16)        0
# _________________________________________________________________
# Conv2 (Conv2D)               (None, 26, 26, 32)        8224
# _________________________________________________________________
# BN2 (BatchNormalization)     (None, 26, 26, 32)        128
# _________________________________________________________________
# Pool2 (MaxPooling2D)         (None, 13, 13, 32)        0
# _________________________________________________________________
# Flatten (Flatten)            (None, 5408)              0
# _________________________________________________________________
# Dense (Dense)                (None, 32)                173088
# _________________________________________________________________
# BN3 (BatchNormalization)     (None, 32)                128
# _________________________________________________________________
# Output (Dense)               (None, 1)                 33
# =================================================================
# Total params: 184,753
# Trainable params: 184,593
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
for model in models:
    print("Training %s ..." % (model.name))
    history = model.fit(
        train_batched,
        steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
        epochs=EPOCHS,
        validation_data=val_batched,
        validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
        class_weight=class_weight_dict,
        callbacks = [learning_rate_decay],
    )
    print('\n')
# Out:
# Training ShallowNetwork-bn ...
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4994: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 226/226 [==============================] - 126s 441ms/step - loss: 0.7883 - accuracy: 0.5579 - precision: 0.4575 - recall: 0.5658 - val_loss: 0.8346 - val_accuracy: 0.3996 - val_precision: 0.3982 - val_recall: 1.0000
# Epoch 2/20
# 226/226 [==============================] - 90s 398ms/step - loss: 0.7692 - accuracy: 0.6218 - precision: 0.5228 - recall: 0.6253 - val_loss: 1.0449 - val_accuracy: 0.5424 - val_precision: 0.4611 - val_recall: 0.8989
# Epoch 3/20
# 226/226 [==============================] - 90s 399ms/step - loss: 0.8095 - accuracy: 0.6390 - precision: 0.5417 - recall: 0.6329 - val_loss: 0.8016 - val_accuracy: 0.6674 - val_precision: 0.5924 - val_recall: 0.5225
# Epoch 4/20
# 226/226 [==============================] - 89s 396ms/step - loss: 0.8529 - accuracy: 0.6550 - precision: 0.5596 - recall: 0.6460 - val_loss: 0.9423 - val_accuracy: 0.6830 - val_precision: 0.5826 - val_recall: 0.7135
# Epoch 5/20
# 226/226 [==============================] - 88s 391ms/step - loss: 0.8669 - accuracy: 0.6662 - precision: 0.5715 - recall: 0.6616 - val_loss: 0.9939 - val_accuracy: 0.6808 - val_precision: 0.5837 - val_recall: 0.6854
# Epoch 6/20
# 226/226 [==============================] - 89s 396ms/step - loss: 0.8798 - accuracy: 0.6679 - precision: 0.5721 - recall: 0.6730 - val_loss: 0.9278 - val_accuracy: 0.6853 - val_precision: 0.5885 - val_recall: 0.6910
# Epoch 7/20
# 226/226 [==============================] - 88s 388ms/step - loss: 0.8739 - accuracy: 0.6686 - precision: 0.5739 - recall: 0.6654 - val_loss: 0.9510 - val_accuracy: 0.6897 - val_precision: 0.5915 - val_recall: 0.7079
# Epoch 8/20
# 226/226 [==============================] - 87s 384ms/step - loss: 0.8854 - accuracy: 0.6681 - precision: 0.5730 - recall: 0.6685 - val_loss: 0.9293 - val_accuracy: 0.6808 - val_precision: 0.5854 - val_recall: 0.6742
# Epoch 9/20
# 226/226 [==============================] - 87s 386ms/step - loss: 0.8863 - accuracy: 0.6733 - precision: 0.5788 - recall: 0.6730 - val_loss: 0.9339 - val_accuracy: 0.6830 - val_precision: 0.5857 - val_recall: 0.6910
# Epoch 10/20
# 226/226 [==============================] - 88s 389ms/step - loss: 0.8693 - accuracy: 0.6766 - precision: 0.5825 - recall: 0.6758 - val_loss: 0.9350 - val_accuracy: 0.6897 - val_precision: 0.5915 - val_recall: 0.7079
# Epoch 11/20
# 226/226 [==============================] - 87s 388ms/step - loss: 0.8816 - accuracy: 0.6763 - precision: 0.5829 - recall: 0.6709 - val_loss: 0.9426 - val_accuracy: 0.6942 - val_precision: 0.5953 - val_recall: 0.7191
# Epoch 12/20
# 226/226 [==============================] - 88s 390ms/step - loss: 0.8771 - accuracy: 0.6733 - precision: 0.5795 - recall: 0.6678 - val_loss: 0.9488 - val_accuracy: 0.6897 - val_precision: 0.5899 - val_recall: 0.7191
# Epoch 13/20
# 226/226 [==============================] - 89s 393ms/step - loss: 0.8918 - accuracy: 0.6742 - precision: 0.5811 - recall: 0.6651 - val_loss: 0.9354 - val_accuracy: 0.6897 - val_precision: 0.5915 - val_recall: 0.7079
# Epoch 14/20
# 226/226 [==============================] - 88s 389ms/step - loss: 0.8783 - accuracy: 0.6774 - precision: 0.5843 - recall: 0.6706 - val_loss: 0.9493 - val_accuracy: 0.6942 - val_precision: 0.5953 - val_recall: 0.7191
# Epoch 15/20
# 226/226 [==============================] - 88s 391ms/step - loss: 0.9072 - accuracy: 0.6661 - precision: 0.5708 - recall: 0.6661 - val_loss: 0.9410 - val_accuracy: 0.6920 - val_precision: 0.5935 - val_recall: 0.7135
# Epoch 16/20
# 226/226 [==============================] - 87s 387ms/step - loss: 0.8907 - accuracy: 0.6691 - precision: 0.5747 - recall: 0.6647 - val_loss: 0.9374 - val_accuracy: 0.6897 - val_precision: 0.5915 - val_recall: 0.7079
# Epoch 17/20
# 226/226 [==============================] - 88s 391ms/step - loss: 0.8746 - accuracy: 0.6710 - precision: 0.5763 - recall: 0.6709 - val_loss: 0.9508 - val_accuracy: 0.6920 - val_precision: 0.5926 - val_recall: 0.7191
# Epoch 18/20
# 226/226 [==============================] - 88s 388ms/step - loss: 0.8959 - accuracy: 0.6657 - precision: 0.5711 - recall: 0.6595 - val_loss: 0.9444 - val_accuracy: 0.6942 - val_precision: 0.5953 - val_recall: 0.7191
# Epoch 19/20
# 226/226 [==============================] - 88s 390ms/step - loss: 0.8868 - accuracy: 0.6730 - precision: 0.5786 - recall: 0.6720 - val_loss: 0.9466 - val_accuracy: 0.6942 - val_precision: 0.5953 - val_recall: 0.7191
# Epoch 20/20
# 226/226 [==============================] - 88s 391ms/step - loss: 0.8961 - accuracy: 0.6724 - precision: 0.5784 - recall: 0.6678 - val_loss: 0.9623 - val_accuracy: 0.6920 - val_precision: 0.5909 - val_recall: 0.7303
#
#
# Training ShallowNetwork-dropout ...
# Epoch 1/20
# 226/226 [==============================] - 88s 390ms/step - loss: 1.0994 - accuracy: 0.6662 - precision: 0.5735 - recall: 0.6457 - val_loss: 1.6069 - val_accuracy: 0.6272 - val_precision: 0.5188 - val_recall: 0.8539
# Epoch 4/20
# 226/226 [==============================] - 87s 387ms/step - loss: 1.0936 - accuracy: 0.6787 - precision: 0.5867 - recall: 0.6657 - val_loss: 1.2640 - val_accuracy: 0.6696 - val_precision: 0.5670 - val_recall: 0.7135
# Epoch 5/20
# 226/226 [==============================] - 88s 392ms/step - loss: 1.1187 - accuracy: 0.6733 - precision: 0.5823 - recall: 0.6481 - val_loss: 1.2862 - val_accuracy: 0.6652 - val_precision: 0.5614 - val_recall: 0.7191
# Epoch 6/20
# 226/226 [==============================] - 87s 385ms/step - loss: 1.1260 - accuracy: 0.6724 - precision: 0.5805 - recall: 0.6533 - val_loss: 1.1544 - val_accuracy: 0.6674 - val_precision: 0.5714 - val_recall: 0.6517
# Epoch 7/20
# 226/226 [==============================] - 88s 390ms/step - loss: 1.1148 - accuracy: 0.6738 - precision: 0.5822 - recall: 0.6536 - val_loss: 1.2079 - val_accuracy: 0.6674 - val_precision: 0.5681 - val_recall: 0.6798
# Epoch 8/20
# 226/226 [==============================] - 87s 388ms/step - loss: 1.1203 - accuracy: 0.6770 - precision: 0.5861 - recall: 0.6554 - val_loss: 1.1239 - val_accuracy: 0.6540 - val_precision: 0.5615 - val_recall: 0.5899
# Epoch 9/20
# 226/226 [==============================] - 87s 387ms/step - loss: 1.1111 - accuracy: 0.6727 - precision: 0.5804 - recall: 0.6561 - val_loss: 1.1304 - val_accuracy: 0.6674 - val_precision: 0.5736 - val_recall: 0.6348
# Epoch 10/20
# 226/226 [==============================] - 87s 385ms/step - loss: 1.1214 - accuracy: 0.6829 - precision: 0.5927 - recall: 0.6630 - val_loss: 1.0960 - val_accuracy: 0.6540 - val_precision: 0.5615 - val_recall: 0.5899
# Epoch 11/20
# 226/226 [==============================] - 87s 387ms/step - loss: 1.1248 - accuracy: 0.6809 - precision: 0.5904 - recall: 0.6606 - val_loss: 1.2718 - val_accuracy: 0.6696 - val_precision: 0.5647 - val_recall: 0.7360
# Epoch 12/20
# 226/226 [==============================] - 86s 381ms/step - loss: 1.1260 - accuracy: 0.6774 - precision: 0.5855 - recall: 0.6626 - val_loss: 1.1132 - val_accuracy: 0.6652 - val_precision: 0.5714 - val_recall: 0.6292
# Epoch 13/20
# 226/226 [==============================] - 87s 386ms/step - loss: 1.1285 - accuracy: 0.6766 - precision: 0.5849 - recall: 0.6595 - val_loss: 1.1203 - val_accuracy: 0.6696 - val_precision: 0.5758 - val_recall: 0.6404
# Epoch 14/20
# 226/226 [==============================] - 88s 388ms/step - loss: 1.0989 - accuracy: 0.6803 - precision: 0.5890 - recall: 0.6644 - val_loss: 1.1442 - val_accuracy: 0.6696 - val_precision: 0.5728 - val_recall: 0.6629
# Epoch 15/20
# 226/226 [==============================] - 86s 383ms/step - loss: 1.1064 - accuracy: 0.6782 - precision: 0.5867 - recall: 0.6623 - val_loss: 1.1418 - val_accuracy: 0.6696 - val_precision: 0.5735 - val_recall: 0.6573
# Epoch 16/20
# 226/226 [==============================] - 87s 384ms/step - loss: 1.0980 - accuracy: 0.6864 - precision: 0.5963 - recall: 0.6689 - val_loss: 1.1414 - val_accuracy: 0.6696 - val_precision: 0.5735 - val_recall: 0.6573
# Epoch 17/20
# 226/226 [==============================] - 87s 384ms/step - loss: 1.1105 - accuracy: 0.6771 - precision: 0.5854 - recall: 0.6609 - val_loss: 1.1531 - val_accuracy: 0.6696 - val_precision: 0.5708 - val_recall: 0.6798
# Epoch 18/20
# 226/226 [==============================] - 88s 390ms/step - loss: 1.1213 - accuracy: 0.6735 - precision: 0.5816 - recall: 0.6554 - val_loss: 1.1423 - val_accuracy: 0.6696 - val_precision: 0.5735 - val_recall: 0.6573
# Epoch 19/20
# 226/226 [==============================] - 87s 384ms/step - loss: 1.1107 - accuracy: 0.6733 - precision: 0.5808 - recall: 0.6585 - val_loss: 1.1387 - val_accuracy: 0.6696 - val_precision: 0.5735 - val_recall: 0.6573
# Epoch 20/20
# 226/226 [==============================] - 88s 388ms/step - loss: 1.0948 - accuracy: 0.6858 - precision: 0.5954 - recall: 0.6699 - val_loss: 1.1533 - val_accuracy: 0.6696 - val_precision: 0.5708 - val_recall: 0.6798
#
#
# Training ShallowNetwork-tanh-dropout-bn ...
# Epoch 1/20
# 226/226 [==============================] - 96s 395ms/step - loss: 0.9178 - accuracy: 0.6274 - precision: 0.5305 - recall: 0.6454 - val_loss: 1.4761 - val_accuracy: 0.5201 - val_precision: 0.4488 - val_recall: 0.9101
# Epoch 2/20
# 226/226 [==============================] - 86s 382ms/step - loss: 1.1166 - accuracy: 0.6545 - precision: 0.5585 - recall: 0.6498 - val_loss: 1.1191 - val_accuracy: 0.6496 - val_precision: 0.5528 - val_recall: 0.6180
# Epoch 3/20
# 226/226 [==============================] - 87s 387ms/step - loss: 1.1336 - accuracy: 0.6580 - precision: 0.5634 - recall: 0.6447 - val_loss: 1.3022 - val_accuracy: 0.6339 - val_precision: 0.5267 - val_recall: 0.7753
# Epoch 4/20
# 226/226 [==============================] - 87s 388ms/step - loss: 1.1396 - accuracy: 0.6679 - precision: 0.5738 - recall: 0.6595 - val_loss: 1.8907 - val_accuracy: 0.5156 - val_precision: 0.4460 - val_recall: 0.9045
# Epoch 5/20
# 226/226 [==============================] - 88s 387ms/step - loss: 1.1784 - accuracy: 0.6675 - precision: 0.5720 - recall: 0.6699 - val_loss: 1.1957 - val_accuracy: 0.6540 - val_precision: 0.5596 - val_recall: 0.6067
# Epoch 6/20
# 226/226 [==============================] - 87s 386ms/step - loss: 1.1566 - accuracy: 0.6713 - precision: 0.5768 - recall: 0.6699 - val_loss: 1.2010 - val_accuracy: 0.6607 - val_precision: 0.5644 - val_recall: 0.6404
# Epoch 7/20
# 226/226 [==============================] - 87s 388ms/step - loss: 1.1731 - accuracy: 0.6673 - precision: 0.5728 - recall: 0.6626 - val_loss: 1.2195 - val_accuracy: 0.6585 - val_precision: 0.5604 - val_recall: 0.6517
# Epoch 8/20
# 226/226 [==============================] - 88s 388ms/step - loss: 1.1487 - accuracy: 0.6737 - precision: 0.5795 - recall: 0.6716 - val_loss: 1.2161 - val_accuracy: 0.6607 - val_precision: 0.5670 - val_recall: 0.6180
# Epoch 9/20
# 226/226 [==============================] - 88s 390ms/step - loss: 1.1690 - accuracy: 0.6697 - precision: 0.5757 - recall: 0.6626 - val_loss: 1.2190 - val_accuracy: 0.6607 - val_precision: 0.5637 - val_recall: 0.6461
# Epoch 10/20
# 226/226 [==============================] - 89s 395ms/step - loss: 1.1855 - accuracy: 0.6683 - precision: 0.5740 - recall: 0.6623 - val_loss: 1.2222 - val_accuracy: 0.6607 - val_precision: 0.5625 - val_recall: 0.6573
# Epoch 11/20
# 226/226 [==============================] - 87s 385ms/step - loss: 1.1606 - accuracy: 0.6702 - precision: 0.5762 - recall: 0.6640 - val_loss: 1.2266 - val_accuracy: 0.6607 - val_precision: 0.5613 - val_recall: 0.6685
# Epoch 12/20
# 226/226 [==============================] - 86s 383ms/step - loss: 1.1695 - accuracy: 0.6702 - precision: 0.5758 - recall: 0.6668 - val_loss: 1.2318 - val_accuracy: 0.6629 - val_precision: 0.5628 - val_recall: 0.6798
# Epoch 13/20
# 226/226 [==============================] - 86s 384ms/step - loss: 1.1726 - accuracy: 0.6655 - precision: 0.5711 - recall: 0.6578 - val_loss: 1.2241 - val_accuracy: 0.6607 - val_precision: 0.5619 - val_recall: 0.6629
# Epoch 14/20
# 226/226 [==============================] - 86s 383ms/step - loss: 1.1718 - accuracy: 0.6690 - precision: 0.5745 - recall: 0.6651 - val_loss: 1.2265 - val_accuracy: 0.6629 - val_precision: 0.5628 - val_recall: 0.6798
# Epoch 15/20
# 226/226 [==============================] - 86s 380ms/step - loss: 1.1611 - accuracy: 0.6680 - precision: 0.5740 - recall: 0.6599 - val_loss: 1.2241 - val_accuracy: 0.6607 - val_precision: 0.5625 - val_recall: 0.6573
# Epoch 16/20
# 226/226 [==============================] - 86s 382ms/step - loss: 1.1587 - accuracy: 0.6657 - precision: 0.5707 - recall: 0.6623 - val_loss: 1.2218 - val_accuracy: 0.6629 - val_precision: 0.5646 - val_recall: 0.6629
# Epoch 17/20
# 226/226 [==============================] - 87s 385ms/step - loss: 1.1829 - accuracy: 0.6658 - precision: 0.5722 - recall: 0.6523 - val_loss: 1.2265 - val_accuracy: 0.6629 - val_precision: 0.5628 - val_recall: 0.6798
# Epoch 18/20
# 226/226 [==============================] - 88s 388ms/step - loss: 1.1565 - accuracy: 0.6712 - precision: 0.5769 - recall: 0.6675 - val_loss: 1.2243 - val_accuracy: 0.6607 - val_precision: 0.5613 - val_recall: 0.6685
# Epoch 19/20
# 226/226 [==============================] - 88s 391ms/step - loss: 1.1814 - accuracy: 0.6691 - precision: 0.5757 - recall: 0.6571 - val_loss: 1.2254 - val_accuracy: 0.6629 - val_precision: 0.5634 - val_recall: 0.6742
# Epoch 20/20
# 226/226 [==============================] - 88s 392ms/step - loss: 1.1702 - accuracy: 0.6728 - precision: 0.5794 - recall: 0.6647 - val_loss: 1.2330 - val_accuracy: 0.6652 - val_precision: 0.5642 - val_recall: 0.6910
#
#
# Training ShallowNetwork-tanh-pneumonia-bn ...
# Epoch 1/20
# 226/226 [==============================] - 95s 389ms/step - loss: 0.9948 - accuracy: 0.6755 - precision: 0.5740 - recall: 0.7248 - val_loss: 3.6455 - val_accuracy: 0.4754 - val_precision: 0.4286 - val_recall: 0.9607
# Epoch 2/20
# 226/226 [==============================] - 87s 387ms/step - loss: 1.1614 - accuracy: 0.6778 - precision: 0.5776 - recall: 0.7245 - val_loss: 1.9238 - val_accuracy: 0.6272 - val_precision: 0.5190 - val_recall: 0.8427
# Epoch 3/20
# 226/226 [==============================] - 88s 390ms/step - loss: 1.1748 - accuracy: 0.6809 - precision: 0.5820 - recall: 0.7179 - val_loss: 3.1145 - val_accuracy: 0.4888 - val_precision: 0.4344 - val_recall: 0.9494
# Epoch 4/20
# 226/226 [==============================] - 87s 387ms/step - loss: 1.1678 - accuracy: 0.6936 - precision: 0.5958 - recall: 0.7276 - val_loss: 1.6214 - val_accuracy: 0.7143 - val_precision: 0.7016 - val_recall: 0.4888
# Epoch 5/20
# 226/226 [==============================] - 88s 389ms/step - loss: 1.1504 - accuracy: 0.6905 - precision: 0.5904 - recall: 0.7394 - val_loss: 1.3825 - val_accuracy: 0.6674 - val_precision: 0.6495 - val_recall: 0.3539
# Epoch 6/20
# 226/226 [==============================] - 87s 386ms/step - loss: 1.1684 - accuracy: 0.6928 - precision: 0.5929 - recall: 0.7401 - val_loss: 2.3944 - val_accuracy: 0.6496 - val_precision: 0.8889 - val_recall: 0.1348
# Epoch 7/20
# 226/226 [==============================] - 88s 389ms/step - loss: 1.1775 - accuracy: 0.6968 - precision: 0.5973 - recall: 0.7428 - val_loss: 3.0312 - val_accuracy: 0.5871 - val_precision: 0.4897 - val_recall: 0.9382
# Epoch 8/20
# 226/226 [==============================] - 88s 389ms/step - loss: 1.1923 - accuracy: 0.7051 - precision: 0.6089 - recall: 0.7342 - val_loss: 1.4952 - val_accuracy: 0.7143 - val_precision: 0.6250 - val_recall: 0.7022
# Epoch 9/20
# 226/226 [==============================] - 87s 386ms/step - loss: 1.1838 - accuracy: 0.6986 - precision: 0.6008 - recall: 0.7345 - val_loss: 1.3964 - val_accuracy: 0.7143 - val_precision: 0.6420 - val_recall: 0.6348
# Epoch 10/20
# 226/226 [==============================] - 88s 388ms/step - loss: 1.1737 - accuracy: 0.7062 - precision: 0.6080 - recall: 0.7470 - val_loss: 1.4357 - val_accuracy: 0.7254 - val_precision: 0.6708 - val_recall: 0.6067
# Epoch 11/20
# 226/226 [==============================] - 87s 387ms/step - loss: 1.1795 - accuracy: 0.7038 - precision: 0.6062 - recall: 0.7411 - val_loss: 1.4432 - val_accuracy: 0.7254 - val_precision: 0.6730 - val_recall: 0.6011
# Epoch 12/20
# 226/226 [==============================] - 88s 388ms/step - loss: 1.1811 - accuracy: 0.7006 - precision: 0.6020 - recall: 0.7428 - val_loss: 1.4282 - val_accuracy: 0.7277 - val_precision: 0.6750 - val_recall: 0.6067
# Epoch 13/20
# 226/226 [==============================] - 88s 389ms/step - loss: 1.1638 - accuracy: 0.7052 - precision: 0.6064 - recall: 0.7494 - val_loss: 1.4374 - val_accuracy: 0.7232 - val_precision: 0.6687 - val_recall: 0.6011
# Epoch 14/20
# 226/226 [==============================] - 87s 387ms/step - loss: 1.1693 - accuracy: 0.7011 - precision: 0.6012 - recall: 0.7508 - val_loss: 1.4463 - val_accuracy: 0.7277 - val_precision: 0.6750 - val_recall: 0.6067
# Epoch 15/20
# 226/226 [==============================] - 86s 381ms/step - loss: 1.1538 - accuracy: 0.7022 - precision: 0.6028 - recall: 0.7490 - val_loss: 1.4452 - val_accuracy: 0.7232 - val_precision: 0.6687 - val_recall: 0.6011
# Epoch 16/20
# 226/226 [==============================] - 86s 381ms/step - loss: 1.1700 - accuracy: 0.7042 - precision: 0.6061 - recall: 0.7446 - val_loss: 1.4380 - val_accuracy: 0.7277 - val_precision: 0.6728 - val_recall: 0.6124
# Epoch 17/20
# 226/226 [==============================] - 85s 378ms/step - loss: 1.1538 - accuracy: 0.7085 - precision: 0.6100 - recall: 0.7525 - val_loss: 1.4545 - val_accuracy: 0.7321 - val_precision: 0.6790 - val_recall: 0.6180
# Epoch 18/20
# 226/226 [==============================] - 86s 382ms/step - loss: 1.1730 - accuracy: 0.6995 - precision: 0.6007 - recall: 0.7425 - val_loss: 1.4560 - val_accuracy: 0.7277 - val_precision: 0.6750 - val_recall: 0.6067
# Epoch 19/20
# 226/226 [==============================] - 87s 384ms/step - loss: 1.1856 - accuracy: 0.6998 - precision: 0.5994 - recall: 0.7525 - val_loss: 1.4426 - val_accuracy: 0.7254 - val_precision: 0.6730 - val_recall: 0.6011
# Epoch 20/20
# 226/226 [==============================] - 85s 377ms/step - loss: 1.1871 - accuracy: 0.7001 - precision: 0.6015 - recall: 0.7414 - val_loss: 1.4295 - val_accuracy: 0.7299 - val_precision: 0.6748 - val_recall: 0.6180

# %% [markdown]
# ## Evaluation

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating ShallowNetwork-bn ...
# 43/43 [==============================] - 4s 92ms/step - loss: 0.8706 - accuracy: 0.7212 - precision: 0.6279 - recall: 0.7459
#
#
# Evaluating ShallowNetwork-dropout ...
# 43/43 [==============================] - 1s 28ms/step - loss: 0.8266 - accuracy: 0.6969 - precision: 0.6012 - recall: 0.7219
#
#
# Evaluating ShallowNetwork-pneumonia-bn ...
# 43/43 [==============================] - 1s 27ms/step - loss: 0.8872 - accuracy: 0.7220 - precision: 0.6554 - recall: 0.6446
#
#
# Evaluating ShallowNetwork-tanh ...
# 43/43 [==============================] - 1s 28ms/step - loss: 1.4011 - accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating ShallowNetwork-tanh-bn ...
# 43/43 [==============================] - 1s 27ms/step - loss: 1.0960 - accuracy: 0.7094 - precision: 0.6223 - recall: 0.6980
#
#
# Evaluating ShallowNetwork-tanh-dropout-bn ...
# 43/43 [==============================] - 1s 29ms/step - loss: 1.0931 - accuracy: 0.6984 - precision: 0.6044 - recall: 0.7145
#
#
# Evaluating ShallowNetwork-tanh-pneumonia-bn ...
# 43/43 [==============================] - 1s 30ms/step - loss: 1.3210 - accuracy: 0.7242 - precision: 0.6693 - recall: 0.6151

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 1.000

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 1.0
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.442% and noise_multiplier = 1.2673231247985364 iterated over 4520 steps satisfies differential privacy with eps = 1 and delta = 0.0001.
# 1.2673231247985364

# %% [markdown]
# #### Membership Inference Attack

# %%
def compute_attack_inputs(attack_data):
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant
    # get labels
    labels = []
    for x, y in attack_data.as_numpy_iterator():
        labels.append(y[0])
    # predict
    probs = model.predict(attack_data)
    # compute loss
    losses = np.array([x[0] for x in bc(constant([[y] for y in labels]), constant(probs), from_logits=False).numpy()])
    
    return (np.array(probs), np.array(losses), np.array(labels))

# run membership inference attack
def run_mia(model, train_attack_input, test_attack_input):
    # prepare attacks
    probs_train, loss_train, labels_train = train_attack_input
    probs_test, loss_test, labels_test = test_attack_input

    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = labels_train,
        labels_test = labels_test
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
        by_classification_correctness = True
    )

    attack_types = [
        #AttackType.THRESHOLD_ATTACK, # logistic was always better, so no threshold to save time
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    #plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    #plt.show()

    # print a user-friendly summary of the attacks
    #print(attacks_result.summary(by_slices=False))

    max_auc = attacks_result.get_result_with_max_auc().get_auc()
    max_adv = attacks_result.get_result_with_max_attacker_advantage().get_attacker_advantage()

    return max_auc, max_adv

# epsilon estimation based on attack, metric adapted for AUC from https://paperswithcode.com/paper/antipodes-of-label-differential-privacy-pate
def empirical_eps(auc):
    if auc <= 0.5:
        return 0
    if auc == 1:
        return np.inf
    return np.log(auc / (1 - auc))

from contextlib import contextmanager
import sys
@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout

# %%
import scipy.stats as st

for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    SAMPLE_NB = 100
    
    train_attack_input = compute_attack_inputs(train_attack_data)
    test_attack_input = compute_attack_inputs(test_attack_data)

    aucs = []
    advs = []
    emp_eps = []
    for i in range(SAMPLE_NB):
        with suppress_stdout():
            max_auc, max_adv = run_mia(model, train_attack_input, test_attack_input)
        aucs.append(max_auc)
        advs.append(max_adv)
        emp_eps.append(empirical_eps(max_auc))

    auc_low, auc_high = st.t.interval(0.95, len(aucs)-1, loc=np.mean(aucs), scale=st.sem(aucs))
    adv_low, adv_high = st.t.interval(0.95, len(advs)-1, loc=np.mean(advs), scale=st.sem(advs))
    eps_low, eps_high = st.t.interval(0.95, len(emp_eps)-1, loc=np.mean(emp_eps), scale=st.sem(emp_eps))

    print('95%%-CI based on %i attack samples'%(SAMPLE_NB))
    print('AUC: %0.2f-%0.2f'%(auc_low, auc_high))
    print('Attacker advantage: %0.2f-%0.2f'%(adv_low, adv_high))
    print('Empirical epsilon bounds from AUC: %0.2f-%0.2f\n'%(eps_low, eps_high))
# Out:
# Membership Inference Attack on ShallowNetwork-bn...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.14
# Empirical epsilon bounds from AUC: 0.14-0.17
#
# Membership Inference Attack on ShallowNetwork-dropout...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.13-0.14
# Empirical epsilon bounds from AUC: 0.13-0.16
#
# Membership Inference Attack on ShallowNetwork-pneumonia-bn...
# 95%-CI based on 100 attack samples
# AUC: 0.52-0.53
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.10-0.13
#
# Membership Inference Attack on ShallowNetwork-tanh...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.53
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.11-0.14
#
# Membership Inference Attack on ShallowNetwork-tanh-bn...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.13-0.17
#
# Membership Inference Attack on ShallowNetwork-tanh-dropout-bn...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.13-0.16
#
# Membership Inference Attack on ShallowNetwork-tanh-pneumonia-bn...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.12-0.15
