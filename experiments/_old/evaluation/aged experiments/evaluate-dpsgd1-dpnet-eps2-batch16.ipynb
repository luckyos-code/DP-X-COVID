# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install 'tensorflow-privacy==0.5.2'
#!pip -q install git+https://github.com/tensorflow/privacy #TODO fix this
# Out:
#      |████████████████████████████████| 194kB 14.9MB/s

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.experimental.preprocessing import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

#import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 780MB [00:09, 83.2MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.1
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 16
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 0.75
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-test split
x_train, x_test, y_train, y_test = train_test_split(files, labels, test_size=TEST_SPLIT, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(files, labels, test_size=VAL_SPLIT, random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 8136, Val: 904, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4883, 'COVID-19': 3253}
# val set:  {'normal': 541, 'COVID-19': 363}
# test set:   {'normal': 817, 'COVID-19': 539}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# seperate train labels and images for attacks
train_unbatched= prepare_dataset(train_ds,
                                 pre=True,
                                 shuffle=True,
                                 repeat=False,
                                 batch=False,
                                 augment=False,
                                 cache=False)
x_train_attack = prepare_dataset(train_unbatched,
                                 pre=False,
                                 shuffle=False,
                                 repeat=False,
                                 batch=1,
                                 augment=False)
y_train_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(train_unbatched):
    y_train_attack.append(y)

# seperate test labels and images for attacks
test_unbatched = prepare_dataset(test_ds,
                                 pre=True,
                                 shuffle=False,
                                 repeat=False,
                                 batch=False,
                                 augment=False,
                                 cache=False)
x_test_attack = prepare_dataset(test_unbatched,
                                pre=False,
                                shuffle=False,
                                repeat=False,
                                batch=1,
                                augment=False)

y_test_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(test_unbatched):
    y_test_attack.append(y)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## DP-Net - relu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_relu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='relu'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-relu')
    return dpnet

# %%
dpnet_relu = dpnet_relu_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_relu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_relu.summary()
# Out:
# Model: "DP-Net-relu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization (BatchNo (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                230432
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_relu = dpnet_relu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 151s 230ms/step - loss: 0.8868 - accuracy: 0.5559 - precision: 0.4583 - recall: 0.5528 - val_loss: 0.8608 - val_accuracy: 0.6083 - val_precision: 0.5641 - val_recall: 0.1219
# Epoch 2/20
# 508/508 [==============================] - 104s 205ms/step - loss: 0.9436 - accuracy: 0.6037 - precision: 0.5071 - recall: 0.5867 - val_loss: 1.0707 - val_accuracy: 0.6272 - val_precision: 0.5251 - val_recall: 0.7812
# Epoch 3/20
# 508/508 [==============================] - 104s 206ms/step - loss: 0.9243 - accuracy: 0.6286 - precision: 0.5346 - recall: 0.6037 - val_loss: 0.9580 - val_accuracy: 0.6663 - val_precision: 0.5833 - val_recall: 0.6011
# Epoch 4/20
# 508/508 [==============================] - 104s 204ms/step - loss: 0.9842 - accuracy: 0.6393 - precision: 0.5443 - recall: 0.6253 - val_loss: 0.9956 - val_accuracy: 0.6674 - val_precision: 0.5822 - val_recall: 0.6177
# Epoch 5/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.0030 - accuracy: 0.6416 - precision: 0.5496 - recall: 0.6266 - val_loss: 1.0651 - val_accuracy: 0.6719 - val_precision: 0.5861 - val_recall: 0.6316
# Epoch 6/20
# 508/508 [==============================] - 104s 205ms/step - loss: 0.9923 - accuracy: 0.6444 - precision: 0.5507 - recall: 0.6309 - val_loss: 1.0216 - val_accuracy: 0.6719 - val_precision: 0.5908 - val_recall: 0.6039
# Epoch 7/20
# 508/508 [==============================] - 105s 208ms/step - loss: 0.9927 - accuracy: 0.6438 - precision: 0.5540 - recall: 0.6274 - val_loss: 1.0110 - val_accuracy: 0.6685 - val_precision: 0.5914 - val_recall: 0.5734
# Epoch 8/20
# 508/508 [==============================] - 105s 206ms/step - loss: 1.0015 - accuracy: 0.6466 - precision: 0.5549 - recall: 0.6323 - val_loss: 1.0155 - val_accuracy: 0.6730 - val_precision: 0.5939 - val_recall: 0.5956
# Epoch 9/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0120 - accuracy: 0.6401 - precision: 0.5470 - recall: 0.6171 - val_loss: 1.0209 - val_accuracy: 0.6741 - val_precision: 0.5940 - val_recall: 0.6039
# Epoch 10/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.0179 - accuracy: 0.6428 - precision: 0.5478 - recall: 0.6291 - val_loss: 1.0154 - val_accuracy: 0.6685 - val_precision: 0.5914 - val_recall: 0.5734
# Epoch 11/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0096 - accuracy: 0.6469 - precision: 0.5528 - recall: 0.6279 - val_loss: 1.0312 - val_accuracy: 0.6708 - val_precision: 0.5882 - val_recall: 0.6094
# Epoch 12/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.0272 - accuracy: 0.6492 - precision: 0.5480 - recall: 0.6341 - val_loss: 1.0310 - val_accuracy: 0.6696 - val_precision: 0.5871 - val_recall: 0.6066
# Epoch 13/20
# 508/508 [==============================] - 104s 205ms/step - loss: 0.9946 - accuracy: 0.6457 - precision: 0.5554 - recall: 0.6215 - val_loss: 1.0212 - val_accuracy: 0.6730 - val_precision: 0.5929 - val_recall: 0.6011
# Epoch 14/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.0132 - accuracy: 0.6438 - precision: 0.5496 - recall: 0.6214 - val_loss: 1.0223 - val_accuracy: 0.6719 - val_precision: 0.5928 - val_recall: 0.5928
# Epoch 15/20
# 508/508 [==============================] - 104s 204ms/step - loss: 0.9909 - accuracy: 0.6529 - precision: 0.5609 - recall: 0.6377 - val_loss: 1.0117 - val_accuracy: 0.6696 - val_precision: 0.5915 - val_recall: 0.5817
# Epoch 16/20
# 508/508 [==============================] - 103s 203ms/step - loss: 1.0166 - accuracy: 0.6418 - precision: 0.5475 - recall: 0.6160 - val_loss: 1.0174 - val_accuracy: 0.6719 - val_precision: 0.5938 - val_recall: 0.5873
# Epoch 17/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0344 - accuracy: 0.6314 - precision: 0.5381 - recall: 0.6103 - val_loss: 1.0241 - val_accuracy: 0.6730 - val_precision: 0.5919 - val_recall: 0.6066
# Epoch 18/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0218 - accuracy: 0.6433 - precision: 0.5478 - recall: 0.6186 - val_loss: 1.0175 - val_accuracy: 0.6730 - val_precision: 0.5950 - val_recall: 0.5900
# Epoch 19/20
# 508/508 [==============================] - 103s 204ms/step - loss: 0.9918 - accuracy: 0.6464 - precision: 0.5516 - recall: 0.6231 - val_loss: 1.0190 - val_accuracy: 0.6741 - val_precision: 0.5950 - val_recall: 0.5983
# Epoch 20/20
# 508/508 [==============================] - 104s 204ms/step - loss: 0.9974 - accuracy: 0.6463 - precision: 0.5546 - recall: 0.6264 - val_loss: 1.0146 - val_accuracy: 0.6730 - val_precision: 0.5939 - val_recall: 0.5956

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_relu.history[met])
    ax[i].plot(history_dpnet_relu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_relu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 3s 36ms/step - loss: 0.9779 - accuracy: 0.6770 - precision: 0.5933 - recall: 0.5955
# Loss of the model is -  0.9779495596885681
# Accuracy of the model is -  67.69911646842957 %
# Precision of the model is -  0.5933456420898438
# Recall of the model is -  0.5955473184585571

# %% [markdown]
# ## DP-Net - CNN Architecture for DP-SGD
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net')
    return dpnet

# %%
dpnet = dpnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet.summary()
# Out:
# Model: "DP-Net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet = dpnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 111s 206ms/step - loss: 0.9718 - accuracy: 0.5754 - precision: 0.4785 - recall: 0.6021 - val_loss: 1.3936 - val_accuracy: 0.6406 - val_precision: 0.5343 - val_recall: 0.8421
# Epoch 2/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.1868 - accuracy: 0.6547 - precision: 0.5638 - recall: 0.6396 - val_loss: 0.8410 - val_accuracy: 0.6719 - val_precision: 0.5803 - val_recall: 0.6704
# Epoch 3/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1441 - accuracy: 0.6528 - precision: 0.5608 - recall: 0.6470 - val_loss: 1.2273 - val_accuracy: 0.6719 - val_precision: 0.5677 - val_recall: 0.7784
# Epoch 4/20
# 508/508 [==============================] - 104s 206ms/step - loss: 1.1439 - accuracy: 0.6699 - precision: 0.5794 - recall: 0.6550 - val_loss: 1.2242 - val_accuracy: 0.6741 - val_precision: 0.6906 - val_recall: 0.3463
# Epoch 5/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.0538 - accuracy: 0.6594 - precision: 0.5702 - recall: 0.6408 - val_loss: 1.1518 - val_accuracy: 0.6920 - val_precision: 0.6044 - val_recall: 0.6814
# Epoch 6/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.0829 - accuracy: 0.6717 - precision: 0.5783 - recall: 0.6659 - val_loss: 1.1241 - val_accuracy: 0.6908 - val_precision: 0.6200 - val_recall: 0.6011
# Epoch 7/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1251 - accuracy: 0.6694 - precision: 0.5828 - recall: 0.6594 - val_loss: 1.1249 - val_accuracy: 0.6920 - val_precision: 0.6218 - val_recall: 0.6011
# Epoch 8/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1215 - accuracy: 0.6644 - precision: 0.5708 - recall: 0.6551 - val_loss: 1.1167 - val_accuracy: 0.6953 - val_precision: 0.6236 - val_recall: 0.6150
# Epoch 9/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1248 - accuracy: 0.6697 - precision: 0.5786 - recall: 0.6648 - val_loss: 1.1169 - val_accuracy: 0.6987 - val_precision: 0.6233 - val_recall: 0.6371
# Epoch 10/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1151 - accuracy: 0.6684 - precision: 0.5820 - recall: 0.6600 - val_loss: 1.1271 - val_accuracy: 0.6931 - val_precision: 0.6229 - val_recall: 0.6039
# Epoch 11/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.0993 - accuracy: 0.6748 - precision: 0.5802 - recall: 0.6605 - val_loss: 1.1218 - val_accuracy: 0.6975 - val_precision: 0.6230 - val_recall: 0.6316
# Epoch 12/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.1324 - accuracy: 0.6621 - precision: 0.5682 - recall: 0.6491 - val_loss: 1.1141 - val_accuracy: 0.6975 - val_precision: 0.6223 - val_recall: 0.6343
# Epoch 13/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.0986 - accuracy: 0.6614 - precision: 0.5610 - recall: 0.6568 - val_loss: 1.1220 - val_accuracy: 0.6975 - val_precision: 0.6236 - val_recall: 0.6288
# Epoch 14/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.0820 - accuracy: 0.6751 - precision: 0.5900 - recall: 0.6653 - val_loss: 1.1251 - val_accuracy: 0.6953 - val_precision: 0.6215 - val_recall: 0.6233
# Epoch 15/20
# 508/508 [==============================] - 103s 203ms/step - loss: 1.0892 - accuracy: 0.6729 - precision: 0.5760 - recall: 0.6756 - val_loss: 1.1267 - val_accuracy: 0.6975 - val_precision: 0.6230 - val_recall: 0.6316
# Epoch 16/20
# 508/508 [==============================] - 103s 203ms/step - loss: 1.0848 - accuracy: 0.6783 - precision: 0.5832 - recall: 0.6663 - val_loss: 1.1259 - val_accuracy: 0.6964 - val_precision: 0.6246 - val_recall: 0.6177
# Epoch 17/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1020 - accuracy: 0.6788 - precision: 0.5866 - recall: 0.6666 - val_loss: 1.1206 - val_accuracy: 0.6975 - val_precision: 0.6243 - val_recall: 0.6260
# Epoch 18/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.1610 - accuracy: 0.6605 - precision: 0.5720 - recall: 0.6454 - val_loss: 1.1254 - val_accuracy: 0.6964 - val_precision: 0.6226 - val_recall: 0.6260
# Epoch 19/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1329 - accuracy: 0.6626 - precision: 0.5630 - recall: 0.6507 - val_loss: 1.1255 - val_accuracy: 0.6942 - val_precision: 0.6205 - val_recall: 0.6205
# Epoch 20/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.0976 - accuracy: 0.6759 - precision: 0.5841 - recall: 0.6718 - val_loss: 1.1236 - val_accuracy: 0.6953 - val_precision: 0.6189 - val_recall: 0.6343

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet.history[met])
    ax[i].plot(history_dpnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 1s 17ms/step - loss: 1.0821 - accuracy: 0.6976 - precision: 0.6166 - recall: 0.6327
# Loss of the model is -  1.0821166038513184
# Accuracy of the model is -  69.76401209831238 %
# Precision of the model is -  0.6166365146636963
# Recall of the model is -  0.6326530575752258

# %% [markdown]
# ## DP-Net - logits
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_logits_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-logits')
    return dpnet

# %%
dpnet_logits = dpnet_logits_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_logits.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=False,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_logits.summary()
# Out:
# Model: "DP-Net-logits"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_logits = dpnet_logits.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# 508/508 [==============================] - 111s 207ms/step - loss: 0.8817 - accuracy: 0.6163 - precision: 0.5156 - recall: 0.6088 - val_loss: 1.1602 - val_accuracy: 0.6618 - val_precision: 0.5612 - val_recall: 0.7368
# Epoch 2/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0609 - accuracy: 0.6669 - precision: 0.5697 - recall: 0.6751 - val_loss: 1.6020 - val_accuracy: 0.5915 - val_precision: 0.4960 - val_recall: 0.8504
# Epoch 3/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.0729 - accuracy: 0.6612 - precision: 0.5661 - recall: 0.6577 - val_loss: 1.4890 - val_accuracy: 0.6205 - val_precision: 0.5183 - val_recall: 0.8227
# Epoch 4/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0137 - accuracy: 0.6730 - precision: 0.5792 - recall: 0.6650 - val_loss: 1.1992 - val_accuracy: 0.6551 - val_precision: 0.5544 - val_recall: 0.7341
# Epoch 5/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.0282 - accuracy: 0.6696 - precision: 0.5748 - recall: 0.6619 - val_loss: 1.0889 - val_accuracy: 0.6752 - val_precision: 0.5822 - val_recall: 0.6870
# Epoch 6/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.0266 - accuracy: 0.6742 - precision: 0.5770 - recall: 0.6683 - val_loss: 1.0978 - val_accuracy: 0.6975 - val_precision: 0.6148 - val_recall: 0.6676
# Epoch 7/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.0483 - accuracy: 0.6802 - precision: 0.5820 - recall: 0.6757 - val_loss: 1.0889 - val_accuracy: 0.6897 - val_precision: 0.6030 - val_recall: 0.6731
# Epoch 8/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.0750 - accuracy: 0.6665 - precision: 0.5822 - recall: 0.6547 - val_loss: 1.1111 - val_accuracy: 0.6886 - val_precision: 0.5981 - val_recall: 0.6925
# Epoch 9/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0590 - accuracy: 0.6753 - precision: 0.5867 - recall: 0.6649 - val_loss: 1.1075 - val_accuracy: 0.6875 - val_precision: 0.5976 - val_recall: 0.6870
# Epoch 10/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0669 - accuracy: 0.6682 - precision: 0.5747 - recall: 0.6556 - val_loss: 1.1046 - val_accuracy: 0.6931 - val_precision: 0.6070 - val_recall: 0.6759
# Epoch 11/20
# 508/508 [==============================] - 103s 203ms/step - loss: 1.0686 - accuracy: 0.6752 - precision: 0.5910 - recall: 0.6597 - val_loss: 1.1187 - val_accuracy: 0.6830 - val_precision: 0.5902 - val_recall: 0.6981
# Epoch 12/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.0472 - accuracy: 0.6784 - precision: 0.5869 - recall: 0.6733 - val_loss: 1.1195 - val_accuracy: 0.6786 - val_precision: 0.5839 - val_recall: 0.7036
# Epoch 13/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.0226 - accuracy: 0.6818 - precision: 0.5888 - recall: 0.6697 - val_loss: 1.1121 - val_accuracy: 0.6830 - val_precision: 0.5914 - val_recall: 0.6898
# Epoch 14/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.1040 - accuracy: 0.6678 - precision: 0.5741 - recall: 0.6530 - val_loss: 1.1034 - val_accuracy: 0.6897 - val_precision: 0.6015 - val_recall: 0.6814
# Epoch 15/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.0528 - accuracy: 0.6684 - precision: 0.5747 - recall: 0.6644 - val_loss: 1.1128 - val_accuracy: 0.6897 - val_precision: 0.5990 - val_recall: 0.6953
# Epoch 16/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.0540 - accuracy: 0.6752 - precision: 0.5860 - recall: 0.6673 - val_loss: 1.1103 - val_accuracy: 0.6908 - val_precision: 0.6014 - val_recall: 0.6898
# Epoch 17/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0505 - accuracy: 0.6793 - precision: 0.5903 - recall: 0.6661 - val_loss: 1.1159 - val_accuracy: 0.6864 - val_precision: 0.5943 - val_recall: 0.6981
# Epoch 18/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0827 - accuracy: 0.6681 - precision: 0.5762 - recall: 0.6426 - val_loss: 1.1122 - val_accuracy: 0.6886 - val_precision: 0.5986 - val_recall: 0.6898
# Epoch 19/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0686 - accuracy: 0.6717 - precision: 0.5894 - recall: 0.6557 - val_loss: 1.1126 - val_accuracy: 0.6842 - val_precision: 0.5929 - val_recall: 0.6898
# Epoch 20/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.0566 - accuracy: 0.6764 - precision: 0.5856 - recall: 0.6565 - val_loss: 1.1177 - val_accuracy: 0.6864 - val_precision: 0.5943 - val_recall: 0.6981

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_logits.history[met])
    ax[i].plot(history_dpnet_logits.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_logits.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 1s 17ms/step - loss: 1.1008 - accuracy: 0.6895 - precision: 0.5925 - recall: 0.7013
# Loss of the model is -  1.1007635593414307
# Accuracy of the model is -  68.95280480384827 %
# Precision of the model is -  0.592476487159729
# Recall of the model is -  0.701298713684082

# %% [markdown]
# ## DP-Net nobn
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_nobn_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-nobn')
    return dpnet

# %%
dpnet_nobn = dpnet_nobn_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_nobn.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_nobn.summary()
# Out:
# Model: "DP-Net-nobn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                230432
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 241,777
# Trainable params: 241,777
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_nobn = dpnet_nobn.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 106s 200ms/step - loss: 1.5233 - accuracy: 0.5874 - precision: 0.1113 - recall: 0.0022 - val_loss: 1.4600 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 508/508 [==============================] - 102s 200ms/step - loss: 1.7443 - accuracy: 0.5925 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4332 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 508/508 [==============================] - 102s 200ms/step - loss: 1.7603 - accuracy: 0.5932 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4386 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 508/508 [==============================] - 102s 201ms/step - loss: 1.8151 - accuracy: 0.5976 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.5232 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 508/508 [==============================] - 102s 200ms/step - loss: 1.8112 - accuracy: 0.5989 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4702 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 508/508 [==============================] - 102s 201ms/step - loss: 1.8194 - accuracy: 0.5974 - precision: 0.2161 - recall: 1.4867e-04 - val_loss: 1.4921 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 508/508 [==============================] - 102s 201ms/step - loss: 1.8331 - accuracy: 0.5964 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4829 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 508/508 [==============================] - 102s 201ms/step - loss: 1.8144 - accuracy: 0.6002 - precision: 0.2652 - recall: 2.3234e-04 - val_loss: 1.4909 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 508/508 [==============================] - 102s 201ms/step - loss: 1.8166 - accuracy: 0.5990 - precision: 0.4037 - recall: 4.3287e-04 - val_loss: 1.4895 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 508/508 [==============================] - 102s 201ms/step - loss: 1.8196 - accuracy: 0.5970 - precision: 0.2878 - recall: 2.3044e-04 - val_loss: 1.4888 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 508/508 [==============================] - 102s 201ms/step - loss: 1.8552 - accuracy: 0.5926 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4869 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 508/508 [==============================] - 102s 201ms/step - loss: 1.8108 - accuracy: 0.6012 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4861 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 508/508 [==============================] - 102s 200ms/step - loss: 1.8522 - accuracy: 0.5950 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4844 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 508/508 [==============================] - 102s 200ms/step - loss: 1.8173 - accuracy: 0.5981 - precision: 0.4047 - recall: 1.5848e-04 - val_loss: 1.4837 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 508/508 [==============================] - 102s 201ms/step - loss: 1.8067 - accuracy: 0.5996 - precision: 0.5422 - recall: 2.3914e-04 - val_loss: 1.4837 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 508/508 [==============================] - 102s 200ms/step - loss: 1.8701 - accuracy: 0.5885 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4831 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 508/508 [==============================] - 101s 200ms/step - loss: 1.8368 - accuracy: 0.5975 - precision: 0.7446 - recall: 0.0020 - val_loss: 1.4820 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 508/508 [==============================] - 102s 200ms/step - loss: 1.7790 - accuracy: 0.6065 - precision: 0.4951 - recall: 2.0995e-04 - val_loss: 1.4819 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 508/508 [==============================] - 102s 200ms/step - loss: 1.7778 - accuracy: 0.6075 - precision: 0.4489 - recall: 2.1922e-04 - val_loss: 1.4822 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 508/508 [==============================] - 102s 200ms/step - loss: 1.8045 - accuracy: 0.6009 - precision: 0.4794 - recall: 1.9971e-04 - val_loss: 1.4812 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_nobn.history[met])
    ax[i].plot(history_dpnet_nobn.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_nobn.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 2s 17ms/step - loss: 1.4676 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss of the model is -  1.4675997495651245
# Accuracy of the model is -  60.25073528289795 %
# Precision of the model is -  0.0
# Recall of the model is -  0.0

# %% [markdown]
# ## DP-Net pneu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_pneu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-pneu')
    return dpnet

# %%
dpnet_pneu = dpnet_pneu_builder()

# load weights from pneumonia pretraining
dpnet_pneu.load_weights(weights_path+'dpnet_tanh_public_weights.h5')

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_pneu.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_pneu.summary()
# Out:
# Model: "DP-Net-pneu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_pneu = dpnet_pneu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 111s 206ms/step - loss: 0.9345 - accuracy: 0.6410 - precision: 0.5355 - recall: 0.7635 - val_loss: 1.3275 - val_accuracy: 0.6574 - val_precision: 0.5572 - val_recall: 0.7285
# Epoch 2/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.1995 - accuracy: 0.6725 - precision: 0.5673 - recall: 0.7447 - val_loss: 2.2287 - val_accuracy: 0.6205 - val_precision: 0.5166 - val_recall: 0.9030
# Epoch 3/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.2588 - accuracy: 0.6813 - precision: 0.5806 - recall: 0.7468 - val_loss: 1.2591 - val_accuracy: 0.6875 - val_precision: 0.6723 - val_recall: 0.4377
# Epoch 4/20
# 508/508 [==============================] - 104s 206ms/step - loss: 1.2065 - accuracy: 0.6778 - precision: 0.5739 - recall: 0.7646 - val_loss: 1.6373 - val_accuracy: 0.6406 - val_precision: 0.5321 - val_recall: 0.8947
# Epoch 5/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.1686 - accuracy: 0.6848 - precision: 0.5816 - recall: 0.7708 - val_loss: 2.4897 - val_accuracy: 0.4542 - val_precision: 0.4218 - val_recall: 0.9557
# Epoch 6/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.1769 - accuracy: 0.6806 - precision: 0.5805 - recall: 0.7475 - val_loss: 1.3202 - val_accuracy: 0.7009 - val_precision: 0.6898 - val_recall: 0.4681
# Epoch 7/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1654 - accuracy: 0.6848 - precision: 0.5842 - recall: 0.7465 - val_loss: 1.3587 - val_accuracy: 0.7009 - val_precision: 0.6946 - val_recall: 0.4598
# Epoch 8/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1426 - accuracy: 0.6824 - precision: 0.5813 - recall: 0.7491 - val_loss: 1.1852 - val_accuracy: 0.7076 - val_precision: 0.6469 - val_recall: 0.6039
# Epoch 9/20
# 508/508 [==============================] - 103s 203ms/step - loss: 1.1598 - accuracy: 0.6850 - precision: 0.5801 - recall: 0.7480 - val_loss: 1.1894 - val_accuracy: 0.7076 - val_precision: 0.6495 - val_recall: 0.5956
# Epoch 10/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.1490 - accuracy: 0.6865 - precision: 0.5887 - recall: 0.7464 - val_loss: 1.1969 - val_accuracy: 0.7054 - val_precision: 0.6502 - val_recall: 0.5817
# Epoch 11/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.1337 - accuracy: 0.6840 - precision: 0.5840 - recall: 0.7529 - val_loss: 1.1738 - val_accuracy: 0.7121 - val_precision: 0.6467 - val_recall: 0.6288
# Epoch 12/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.1391 - accuracy: 0.6927 - precision: 0.5962 - recall: 0.7506 - val_loss: 1.1715 - val_accuracy: 0.7098 - val_precision: 0.6439 - val_recall: 0.6260
# Epoch 13/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.1474 - accuracy: 0.6889 - precision: 0.5914 - recall: 0.7515 - val_loss: 1.1750 - val_accuracy: 0.7132 - val_precision: 0.6503 - val_recall: 0.6233
# Epoch 14/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.1658 - accuracy: 0.6824 - precision: 0.5859 - recall: 0.7402 - val_loss: 1.1789 - val_accuracy: 0.7121 - val_precision: 0.6484 - val_recall: 0.6233
# Epoch 15/20
# 508/508 [==============================] - 104s 204ms/step - loss: 1.1439 - accuracy: 0.6858 - precision: 0.5814 - recall: 0.7509 - val_loss: 1.1803 - val_accuracy: 0.7087 - val_precision: 0.6462 - val_recall: 0.6122
# Epoch 16/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1378 - accuracy: 0.6840 - precision: 0.5893 - recall: 0.7414 - val_loss: 1.1744 - val_accuracy: 0.7109 - val_precision: 0.6449 - val_recall: 0.6288
# Epoch 17/20
# 508/508 [==============================] - 105s 207ms/step - loss: 1.1398 - accuracy: 0.6834 - precision: 0.5808 - recall: 0.7543 - val_loss: 1.1799 - val_accuracy: 0.7154 - val_precision: 0.6532 - val_recall: 0.6260
# Epoch 18/20
# 508/508 [==============================] - 104s 206ms/step - loss: 1.1439 - accuracy: 0.6894 - precision: 0.5829 - recall: 0.7614 - val_loss: 1.1819 - val_accuracy: 0.7121 - val_precision: 0.6493 - val_recall: 0.6205
# Epoch 19/20
# 508/508 [==============================] - 104s 205ms/step - loss: 1.1703 - accuracy: 0.6872 - precision: 0.5882 - recall: 0.7592 - val_loss: 1.1742 - val_accuracy: 0.7143 - val_precision: 0.6522 - val_recall: 0.6233
# Epoch 20/20
# 508/508 [==============================] - 103s 204ms/step - loss: 1.1314 - accuracy: 0.6906 - precision: 0.5897 - recall: 0.7583 - val_loss: 1.1768 - val_accuracy: 0.7109 - val_precision: 0.6491 - val_recall: 0.6150

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_pneu.history[met])
    ax[i].plot(history_dpnet_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 1s 17ms/step - loss: 1.1409 - accuracy: 0.7220 - precision: 0.6594 - recall: 0.6215
# Loss of the model is -  1.1409249305725098
# Accuracy of the model is -  72.19763994216919 %
# Precision of the model is -  0.6594488024711609
# Recall of the model is -  0.6215213537216187

# %% [markdown]
# ## Evaluation

# %%
models = [
    dpnet_relu,
    dpnet,
    dpnet_logits,
    dpnet_nobn,
    dpnet_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating DP-Net-relu ...
# 85/85 [==============================] - 2s 18ms/step - loss: 0.9779 - accuracy: 0.6770 - precision: 0.5933 - recall: 0.5955
#
#
# Evaluating DP-Net ...
# 85/85 [==============================] - 1s 17ms/step - loss: 1.0821 - accuracy: 0.6976 - precision: 0.6166 - recall: 0.6327
#
#
# Evaluating DP-Net-logits ...
# 85/85 [==============================] - 1s 17ms/step - loss: 1.1008 - accuracy: 0.6895 - precision: 0.5925 - recall: 0.7013
#
#
# Evaluating DP-Net-nobn ...
# 85/85 [==============================] - 1s 17ms/step - loss: 1.4676 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating DP-Net-pneu ...
# 85/85 [==============================] - 1s 17ms/step - loss: 1.1409 - accuracy: 0.7220 - precision: 0.6594 - recall: 0.6215

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 2.023

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 2.0
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.197% and noise_multiplier = 0.752803130208254 iterated over 10170 steps satisfies differential privacy with eps = 2 and delta = 0.0001.
# 0.752803130208254

# %% [markdown]
# #### Membership Inference Attack

# %%
# run membership inference attack
def run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack):
    # predict on train
    probs_train = model.predict(x_train_attack)
    # predict on test
    probs_test = model.predict(x_test_attack)

    # only label as output instead of prob
    #probs_train = np.round(logits_train)
    #probs_test = np.round(logits_test)

    # compute losses
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant

    loss_train = np.array([x[0] for x in bc(constant([[y] for y in y_train_attack]), constant(probs_train), from_logits=False).numpy()])
    loss_test = np.array([x[0] for x in bc(constant([[y] for y in y_test_attack]), constant(probs_test), from_logits=False).numpy()])

    # labels
    train_labels = np.array(y_train_attack)
    test_labels = np.array(y_test_attack)

    # prepare attacks
    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = train_labels,
        labels_test = test_labels
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,)

    attack_types = [
        AttackType.THRESHOLD_ATTACK,
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    plt.show()

    # print a user-friendly summary of the attacks
    print(attacks_result.summary(by_slices=False)) #TODO fix low auc sometimes

# %%
for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack)
    print('\n')
# Out:
# Membership Inference Attack on DP-Net-relu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.69 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.36 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   THRESHOLD_ATTACK (with 3253 training and 539 test examples) achieved an AUC of 0.35 on slice CLASS=1
#   THRESHOLD_ATTACK (with 3253 training and 539 test examples) achieved an advantage of 0.26 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-logits...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.68 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.31 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-nobn...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.64 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.28 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-pneu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.70 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.37 on slice CLASS=1
