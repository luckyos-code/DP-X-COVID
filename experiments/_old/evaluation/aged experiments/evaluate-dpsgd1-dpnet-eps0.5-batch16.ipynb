# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install 'tensorflow-privacy==0.5.2'
#!pip -q install git+https://github.com/tensorflow/privacy #TODO fix this
# Out:
#      |████████████████████████████████| 194kB 774kB/s

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.experimental.preprocessing import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

#import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 780MB [00:09, 82.5MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.1
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 16
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 1.48
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-test split
x_train, x_test, y_train, y_test = train_test_split(files, labels, test_size=TEST_SPLIT, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(files, labels, test_size=VAL_SPLIT, random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 8136, Val: 904, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4883, 'COVID-19': 3253}
# val set:  {'normal': 541, 'COVID-19': 363}
# test set:   {'normal': 817, 'COVID-19': 539}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# seperate train labels and images for attacks
train_unbatched= prepare_dataset(train_ds,
                                 pre=True,
                                 shuffle=True,
                                 repeat=False,
                                 batch=False,
                                 augment=False,
                                 cache=False)
x_train_attack = prepare_dataset(train_unbatched,
                                 pre=False,
                                 shuffle=False,
                                 repeat=False,
                                 batch=1,
                                 augment=False)
y_train_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(train_unbatched):
    y_train_attack.append(y)

# seperate test labels and images for attacks
test_unbatched = prepare_dataset(test_ds,
                                 pre=True,
                                 shuffle=False,
                                 repeat=False,
                                 batch=False,
                                 augment=False,
                                 cache=False)
x_test_attack = prepare_dataset(test_unbatched,
                                pre=False,
                                shuffle=False,
                                repeat=False,
                                batch=1,
                                augment=False)

y_test_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(test_unbatched):
    y_test_attack.append(y)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## DP-Net - relu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_relu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='relu'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-relu')
    return dpnet

# %%
dpnet_relu = dpnet_relu_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_relu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_relu.summary()
# Out:
# Model: "DP-Net-relu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization (BatchNo (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                230432
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_relu = dpnet_relu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 150s 231ms/step - loss: 0.8850 - accuracy: 0.5174 - precision: 0.4220 - recall: 0.5315 - val_loss: 0.6754 - val_accuracy: 0.6150 - val_precision: 0.5270 - val_recall: 0.4321
# Epoch 2/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.8328 - accuracy: 0.5549 - precision: 0.4562 - recall: 0.5439 - val_loss: 0.7103 - val_accuracy: 0.6272 - val_precision: 0.5449 - val_recall: 0.4543
# Epoch 3/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.8446 - accuracy: 0.5595 - precision: 0.4594 - recall: 0.5297 - val_loss: 0.7755 - val_accuracy: 0.6105 - val_precision: 0.5188 - val_recall: 0.4598
# Epoch 4/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.8786 - accuracy: 0.5699 - precision: 0.4689 - recall: 0.5377 - val_loss: 0.7474 - val_accuracy: 0.6429 - val_precision: 0.5581 - val_recall: 0.5457
# Epoch 5/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.8563 - accuracy: 0.5924 - precision: 0.4964 - recall: 0.5680 - val_loss: 0.7794 - val_accuracy: 0.6540 - val_precision: 0.5630 - val_recall: 0.6316
# Epoch 6/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.8980 - accuracy: 0.5796 - precision: 0.4808 - recall: 0.5577 - val_loss: 0.7546 - val_accuracy: 0.6484 - val_precision: 0.5650 - val_recall: 0.5540
# Epoch 7/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.8616 - accuracy: 0.5826 - precision: 0.4877 - recall: 0.5645 - val_loss: 0.7586 - val_accuracy: 0.6473 - val_precision: 0.5637 - val_recall: 0.5512
# Epoch 8/20
# 508/508 [==============================] - 106s 209ms/step - loss: 0.8938 - accuracy: 0.5780 - precision: 0.4812 - recall: 0.5585 - val_loss: 0.7600 - val_accuracy: 0.6518 - val_precision: 0.5660 - val_recall: 0.5817
# Epoch 9/20
# 508/508 [==============================] - 106s 210ms/step - loss: 0.8921 - accuracy: 0.5831 - precision: 0.4845 - recall: 0.5510 - val_loss: 0.7599 - val_accuracy: 0.6507 - val_precision: 0.5645 - val_recall: 0.5817
# Epoch 10/20
# 508/508 [==============================] - 106s 210ms/step - loss: 0.8638 - accuracy: 0.5823 - precision: 0.4825 - recall: 0.5661 - val_loss: 0.7513 - val_accuracy: 0.6484 - val_precision: 0.5657 - val_recall: 0.5485
# Epoch 11/20
# 508/508 [==============================] - 106s 210ms/step - loss: 0.8718 - accuracy: 0.5883 - precision: 0.4890 - recall: 0.5607 - val_loss: 0.7628 - val_accuracy: 0.6518 - val_precision: 0.5668 - val_recall: 0.5762
# Epoch 12/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.8534 - accuracy: 0.5929 - precision: 0.4867 - recall: 0.5686 - val_loss: 0.7618 - val_accuracy: 0.6518 - val_precision: 0.5646 - val_recall: 0.5928
# Epoch 13/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.8699 - accuracy: 0.5827 - precision: 0.4862 - recall: 0.5616 - val_loss: 0.7626 - val_accuracy: 0.6484 - val_precision: 0.5635 - val_recall: 0.5651
# Epoch 14/20
# 508/508 [==============================] - 107s 211ms/step - loss: 0.8896 - accuracy: 0.5749 - precision: 0.4742 - recall: 0.5495 - val_loss: 0.7631 - val_accuracy: 0.6529 - val_precision: 0.5676 - val_recall: 0.5817
# Epoch 15/20
# 508/508 [==============================] - 107s 211ms/step - loss: 0.8913 - accuracy: 0.5786 - precision: 0.4799 - recall: 0.5457 - val_loss: 0.7576 - val_accuracy: 0.6451 - val_precision: 0.5609 - val_recall: 0.5485
# Epoch 16/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.8871 - accuracy: 0.5871 - precision: 0.4869 - recall: 0.5591 - val_loss: 0.7555 - val_accuracy: 0.6484 - val_precision: 0.5650 - val_recall: 0.5540
# Epoch 17/20
# 508/508 [==============================] - 107s 211ms/step - loss: 0.8926 - accuracy: 0.5797 - precision: 0.4818 - recall: 0.5487 - val_loss: 0.7624 - val_accuracy: 0.6507 - val_precision: 0.5670 - val_recall: 0.5623
# Epoch 18/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.8748 - accuracy: 0.5796 - precision: 0.4780 - recall: 0.5485 - val_loss: 0.7538 - val_accuracy: 0.6473 - val_precision: 0.5627 - val_recall: 0.5596
# Epoch 19/20
# 508/508 [==============================] - 107s 211ms/step - loss: 0.8635 - accuracy: 0.5912 - precision: 0.4908 - recall: 0.5725 - val_loss: 0.7637 - val_accuracy: 0.6484 - val_precision: 0.5635 - val_recall: 0.5651
# Epoch 20/20
# 508/508 [==============================] - 106s 209ms/step - loss: 0.8696 - accuracy: 0.5820 - precision: 0.4840 - recall: 0.5581 - val_loss: 0.7625 - val_accuracy: 0.6484 - val_precision: 0.5622 - val_recall: 0.5762

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_relu.history[met])
    ax[i].plot(history_dpnet_relu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_relu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 3s 33ms/step - loss: 0.7633 - accuracy: 0.6490 - precision: 0.5560 - recall: 0.5807
# Loss of the model is -  0.7633460760116577
# Accuracy of the model is -  64.89675641059875 %
# Precision of the model is -  0.5559502840042114
# Recall of the model is -  0.5807049870491028

# %% [markdown]
# ## DP-Net - CNN Architecture for DP-SGD
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net')
    return dpnet

# %%
dpnet = dpnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet.summary()
# Out:
# Model: "DP-Net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet = dpnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 114s 212ms/step - loss: 0.9218 - accuracy: 0.5103 - precision: 0.4127 - recall: 0.5114 - val_loss: 1.1101 - val_accuracy: 0.5893 - val_precision: 0.4945 - val_recall: 0.8753
# Epoch 2/20
# 508/508 [==============================] - 107s 210ms/step - loss: 0.9749 - accuracy: 0.6059 - precision: 0.5067 - recall: 0.6177 - val_loss: 0.9613 - val_accuracy: 0.6808 - val_precision: 0.5835 - val_recall: 0.7258
# Epoch 3/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.1391 - accuracy: 0.6288 - precision: 0.5346 - recall: 0.6327 - val_loss: 1.0697 - val_accuracy: 0.6797 - val_precision: 0.5925 - val_recall: 0.6565
# Epoch 4/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1387 - accuracy: 0.6353 - precision: 0.5417 - recall: 0.6342 - val_loss: 1.0935 - val_accuracy: 0.6853 - val_precision: 0.5904 - val_recall: 0.7147
# Epoch 5/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.0969 - accuracy: 0.6528 - precision: 0.5589 - recall: 0.6482 - val_loss: 1.0768 - val_accuracy: 0.6808 - val_precision: 0.5899 - val_recall: 0.6814
# Epoch 6/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.0816 - accuracy: 0.6501 - precision: 0.5567 - recall: 0.6538 - val_loss: 1.0930 - val_accuracy: 0.6875 - val_precision: 0.5995 - val_recall: 0.6759
# Epoch 7/20
# 508/508 [==============================] - 106s 210ms/step - loss: 1.0598 - accuracy: 0.6561 - precision: 0.5642 - recall: 0.6440 - val_loss: 1.1022 - val_accuracy: 0.6842 - val_precision: 0.5965 - val_recall: 0.6676
# Epoch 8/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.0971 - accuracy: 0.6498 - precision: 0.5609 - recall: 0.6502 - val_loss: 1.0996 - val_accuracy: 0.6886 - val_precision: 0.6010 - val_recall: 0.6759
# Epoch 9/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.0798 - accuracy: 0.6590 - precision: 0.5664 - recall: 0.6509 - val_loss: 1.1080 - val_accuracy: 0.6842 - val_precision: 0.5924 - val_recall: 0.6925
# Epoch 10/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.0866 - accuracy: 0.6573 - precision: 0.5645 - recall: 0.6566 - val_loss: 1.0994 - val_accuracy: 0.6842 - val_precision: 0.5990 - val_recall: 0.6537
# Epoch 11/20
# 508/508 [==============================] - 106s 210ms/step - loss: 1.0962 - accuracy: 0.6578 - precision: 0.5702 - recall: 0.6494 - val_loss: 1.1031 - val_accuracy: 0.6864 - val_precision: 0.5957 - val_recall: 0.6898
# Epoch 12/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1099 - accuracy: 0.6563 - precision: 0.5582 - recall: 0.6546 - val_loss: 1.1094 - val_accuracy: 0.6853 - val_precision: 0.5934 - val_recall: 0.6953
# Epoch 13/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.0661 - accuracy: 0.6612 - precision: 0.5640 - recall: 0.6704 - val_loss: 1.0966 - val_accuracy: 0.6875 - val_precision: 0.6010 - val_recall: 0.6676
# Epoch 14/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.0992 - accuracy: 0.6467 - precision: 0.5424 - recall: 0.6474 - val_loss: 1.0985 - val_accuracy: 0.6875 - val_precision: 0.6005 - val_recall: 0.6704
# Epoch 15/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1296 - accuracy: 0.6472 - precision: 0.5586 - recall: 0.6460 - val_loss: 1.0968 - val_accuracy: 0.6875 - val_precision: 0.6015 - val_recall: 0.6648
# Epoch 16/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1149 - accuracy: 0.6479 - precision: 0.5502 - recall: 0.6437 - val_loss: 1.0976 - val_accuracy: 0.6842 - val_precision: 0.5990 - val_recall: 0.6537
# Epoch 17/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1363 - accuracy: 0.6493 - precision: 0.5475 - recall: 0.6466 - val_loss: 1.1016 - val_accuracy: 0.6864 - val_precision: 0.5962 - val_recall: 0.6870
# Epoch 18/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.0830 - accuracy: 0.6493 - precision: 0.5526 - recall: 0.6519 - val_loss: 1.0997 - val_accuracy: 0.6864 - val_precision: 0.5995 - val_recall: 0.6676
# Epoch 19/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1316 - accuracy: 0.6454 - precision: 0.5539 - recall: 0.6373 - val_loss: 1.1027 - val_accuracy: 0.6886 - val_precision: 0.5990 - val_recall: 0.6870
# Epoch 20/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1131 - accuracy: 0.6551 - precision: 0.5542 - recall: 0.6548 - val_loss: 1.1068 - val_accuracy: 0.6864 - val_precision: 0.5957 - val_recall: 0.6898

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet.history[met])
    ax[i].plot(history_dpnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 1s 15ms/step - loss: 1.0766 - accuracy: 0.6903 - precision: 0.5940 - recall: 0.6976
# Loss of the model is -  1.076643943786621
# Accuracy of the model is -  69.02654767036438 %
# Precision of the model is -  0.5939968228340149
# Recall of the model is -  0.6975881457328796

# %% [markdown]
# ## DP-Net nobn
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_nobn_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-nobn')
    return dpnet

# %%
dpnet_nobn = dpnet_nobn_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_nobn.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_nobn.summary()
# Out:
# Model: "DP-Net-nobn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                230432
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 241,777
# Trainable params: 241,777
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_nobn = dpnet_nobn.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 106s 199ms/step - loss: 1.3539 - accuracy: 0.5892 - precision: 0.3618 - recall: 0.0369 - val_loss: 1.3657 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.6800 - accuracy: 0.6027 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2747 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.6386 - accuracy: 0.6030 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3411 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7237 - accuracy: 0.6002 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4657 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7614 - accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4233 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7307 - accuracy: 0.6017 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4179 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 508/508 [==============================] - 101s 200ms/step - loss: 1.7211 - accuracy: 0.6026 - precision: 0.9784 - recall: 0.0012 - val_loss: 1.4185 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 508/508 [==============================] - 101s 200ms/step - loss: 1.7150 - accuracy: 0.6059 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4230 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7751 - accuracy: 0.5916 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4236 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 508/508 [==============================] - 101s 200ms/step - loss: 1.7575 - accuracy: 0.5963 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4238 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7512 - accuracy: 0.5987 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4238 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7586 - accuracy: 0.5943 - precision: 0.8527 - recall: 5.7944e-04 - val_loss: 1.4240 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7621 - accuracy: 0.5967 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4244 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7386 - accuracy: 0.6003 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4248 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 508/508 [==============================] - 101s 198ms/step - loss: 1.7377 - accuracy: 0.5999 - precision: 0.5992 - recall: 2.7896e-04 - val_loss: 1.4249 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 508/508 [==============================] - 101s 200ms/step - loss: 1.7587 - accuracy: 0.5976 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4250 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7662 - accuracy: 0.5950 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4253 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7544 - accuracy: 0.5973 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4255 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7329 - accuracy: 0.6010 - precision: 0.8232 - recall: 5.2821e-04 - val_loss: 1.4253 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 508/508 [==============================] - 101s 199ms/step - loss: 1.7669 - accuracy: 0.5921 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4254 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_nobn.history[met])
    ax[i].plot(history_dpnet_nobn.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_nobn.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 1s 15ms/step - loss: 1.4013 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss of the model is -  1.4013123512268066
# Accuracy of the model is -  60.25073528289795 %
# Precision of the model is -  0.0
# Recall of the model is -  0.0

# %% [markdown]
# ## DP-Net pneu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_pneu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-pneu')
    return dpnet

# %%
dpnet_pneu = dpnet_pneu_builder()

# load weights from pneumonia pretraining
dpnet_pneu.load_weights(weights_path+'dpnet_tanh_public_weights.h5')

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_pneu.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_pneu.summary()
# Out:
# Model: "DP-Net-pneu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_pneu = dpnet_pneu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 114s 212ms/step - loss: 0.8864 - accuracy: 0.6497 - precision: 0.5423 - recall: 0.7613 - val_loss: 4.7128 - val_accuracy: 0.4051 - val_precision: 0.4034 - val_recall: 0.9945
# Epoch 2/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.0950 - accuracy: 0.6780 - precision: 0.5809 - recall: 0.7382 - val_loss: 1.5476 - val_accuracy: 0.6842 - val_precision: 0.5712 - val_recall: 0.8670
# Epoch 3/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1600 - accuracy: 0.6769 - precision: 0.5831 - recall: 0.7509 - val_loss: 1.2642 - val_accuracy: 0.6998 - val_precision: 0.6679 - val_recall: 0.5069
# Epoch 4/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1435 - accuracy: 0.6775 - precision: 0.5816 - recall: 0.7657 - val_loss: 1.1380 - val_accuracy: 0.6786 - val_precision: 0.5706 - val_recall: 0.8172
# Epoch 5/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.2587 - accuracy: 0.6672 - precision: 0.5708 - recall: 0.7422 - val_loss: 1.5220 - val_accuracy: 0.6250 - val_precision: 0.5199 - val_recall: 0.9058
# Epoch 6/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.2008 - accuracy: 0.6695 - precision: 0.5711 - recall: 0.7442 - val_loss: 1.9854 - val_accuracy: 0.5714 - val_precision: 0.4836 - val_recall: 0.9391
# Epoch 7/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.2130 - accuracy: 0.6705 - precision: 0.5674 - recall: 0.7459 - val_loss: 1.3843 - val_accuracy: 0.7042 - val_precision: 0.6765 - val_recall: 0.5097
# Epoch 8/20
# 508/508 [==============================] - 106s 210ms/step - loss: 1.1887 - accuracy: 0.6834 - precision: 0.5790 - recall: 0.7572 - val_loss: 1.2651 - val_accuracy: 0.7165 - val_precision: 0.6616 - val_recall: 0.6066
# Epoch 9/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.1978 - accuracy: 0.6846 - precision: 0.5864 - recall: 0.7557 - val_loss: 1.2862 - val_accuracy: 0.7098 - val_precision: 0.6656 - val_recall: 0.5623
# Epoch 10/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.1697 - accuracy: 0.6838 - precision: 0.5799 - recall: 0.7645 - val_loss: 1.2885 - val_accuracy: 0.7054 - val_precision: 0.6570 - val_recall: 0.5623
# Epoch 11/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.1845 - accuracy: 0.6798 - precision: 0.5784 - recall: 0.7558 - val_loss: 1.2503 - val_accuracy: 0.7210 - val_precision: 0.6677 - val_recall: 0.6122
# Epoch 12/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.2206 - accuracy: 0.6733 - precision: 0.5785 - recall: 0.7397 - val_loss: 1.2456 - val_accuracy: 0.7176 - val_precision: 0.6646 - val_recall: 0.6039
# Epoch 13/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.1304 - accuracy: 0.6882 - precision: 0.5909 - recall: 0.7584 - val_loss: 1.2513 - val_accuracy: 0.7154 - val_precision: 0.6616 - val_recall: 0.6011
# Epoch 14/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.2044 - accuracy: 0.6765 - precision: 0.5748 - recall: 0.7456 - val_loss: 1.2463 - val_accuracy: 0.7199 - val_precision: 0.6657 - val_recall: 0.6122
# Epoch 15/20
# 508/508 [==============================] - 106s 210ms/step - loss: 1.1934 - accuracy: 0.6755 - precision: 0.5782 - recall: 0.7428 - val_loss: 1.2522 - val_accuracy: 0.7154 - val_precision: 0.6606 - val_recall: 0.6039
# Epoch 16/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1948 - accuracy: 0.6817 - precision: 0.5802 - recall: 0.7506 - val_loss: 1.2555 - val_accuracy: 0.7154 - val_precision: 0.6616 - val_recall: 0.6011
# Epoch 17/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.2104 - accuracy: 0.6752 - precision: 0.5713 - recall: 0.7476 - val_loss: 1.2500 - val_accuracy: 0.7154 - val_precision: 0.6606 - val_recall: 0.6039
# Epoch 18/20
# 508/508 [==============================] - 107s 211ms/step - loss: 1.1742 - accuracy: 0.6846 - precision: 0.5934 - recall: 0.7456 - val_loss: 1.2566 - val_accuracy: 0.7143 - val_precision: 0.6615 - val_recall: 0.5956
# Epoch 19/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.1859 - accuracy: 0.6783 - precision: 0.5783 - recall: 0.7502 - val_loss: 1.2508 - val_accuracy: 0.7165 - val_precision: 0.6636 - val_recall: 0.6011
# Epoch 20/20
# 508/508 [==============================] - 107s 210ms/step - loss: 1.2050 - accuracy: 0.6756 - precision: 0.5665 - recall: 0.7547 - val_loss: 1.2578 - val_accuracy: 0.7165 - val_precision: 0.6636 - val_recall: 0.6011

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_pneu.history[met])
    ax[i].plot(history_dpnet_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 1s 15ms/step - loss: 1.2188 - accuracy: 0.7212 - precision: 0.6528 - recall: 0.6382
# Loss of the model is -  1.2187989950180054
# Accuracy of the model is -  72.1238911151886 %
# Precision of the model is -  0.6527514457702637
# Recall of the model is -  0.6382189393043518

# %% [markdown]
# ## Evaluation

# %%
models = [
    dpnet_relu,
    dpnet,
    dpnet_nobn,
    dpnet_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating DP-Net-relu ...
# 85/85 [==============================] - 1s 16ms/step - loss: 0.7633 - accuracy: 0.6490 - precision: 0.5560 - recall: 0.5807
#
#
# Evaluating DP-Net ...
# 85/85 [==============================] - 1s 15ms/step - loss: 1.0766 - accuracy: 0.6903 - precision: 0.5940 - recall: 0.6976
#
#
# Evaluating DP-Net-nobn ...
# 85/85 [==============================] - 1s 15ms/step - loss: 1.4013 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating DP-Net-pneu ...
# 85/85 [==============================] - 1s 15ms/step - loss: 1.2188 - accuracy: 0.7212 - precision: 0.6528 - recall: 0.6382

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 0.501

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 0.5
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.197% and noise_multiplier = 1.4824957599890232 iterated over 10170 steps satisfies differential privacy with eps = 0.5 and delta = 0.0001.
# 1.4824957599890232

# %% [markdown]
# #### Membership Inference Attack

# %%
# run membership inference attack
def run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack):
    # predict on train
    probs_train = model.predict(x_train_attack)
    # predict on test
    probs_test = model.predict(x_test_attack)

    # only label as output instead of prob
    #probs_train = np.round(logits_train)
    #probs_test = np.round(logits_test)

    # compute losses
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant

    loss_train = np.array([x[0] for x in bc(constant([[y] for y in y_train_attack]), constant(probs_train), from_logits=False).numpy()])
    loss_test = np.array([x[0] for x in bc(constant([[y] for y in y_test_attack]), constant(probs_test), from_logits=False).numpy()])

    # labels
    train_labels = np.array(y_train_attack)
    test_labels = np.array(y_test_attack)

    # prepare attacks
    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = train_labels,
        labels_test = test_labels
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,)

    attack_types = [
        AttackType.THRESHOLD_ATTACK,
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    plt.show()

    # print a user-friendly summary of the attacks
    print(attacks_result.summary(by_slices=False)) #TODO fix low auc sometimes

# %%
for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack)
    print('\n')
# Out:
# Membership Inference Attack on DP-Net-relu...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 817 training and 817 test examples) achieved an AUC of 0.60 on slice CLASS=0
#   LOGISTIC_REGRESSION (with 817 training and 817 test examples) achieved an advantage of 0.22 on slice CLASS=0
#
#
# Membership Inference Attack on DP-Net...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   THRESHOLD_ATTACK (with 3253 training and 539 test examples) achieved an AUC of 0.36 on slice CLASS=1
#   THRESHOLD_ATTACK (with 3253 training and 539 test examples) achieved an advantage of 0.24 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-nobn...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   THRESHOLD_ATTACK (with 3253 training and 539 test examples) achieved an AUC of 0.37 on slice CLASS=1
#   THRESHOLD_ATTACK (with 3253 training and 539 test examples) achieved an advantage of 0.21 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-pneu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.71 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.38 on slice CLASS=1
