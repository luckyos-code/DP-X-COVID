# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install 'tensorflow-privacy==0.5.2'
#!pip -q install git+https://github.com/tensorflow/privacy #TODO fix this
# Out:
#      |████████████████████████████████| 194kB 4.1MB/s

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.experimental.preprocessing import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

#import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 780MB [00:04, 174MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.1
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 8
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 0.75
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-test split
x_train, x_test, y_train, y_test = train_test_split(files, labels, test_size=TEST_SPLIT, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(files, labels, test_size=VAL_SPLIT, random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 8136, Val: 904, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4883, 'COVID-19': 3253}
# val set:  {'normal': 541, 'COVID-19': 363}
# test set:   {'normal': 817, 'COVID-19': 539}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# seperate train labels and images for attacks
train_unbatched= prepare_dataset(train_ds,
                                 pre=True,
                                 shuffle=True,
                                 repeat=False,
                                 batch=False,
                                 augment=False,
                                 cache=False)
x_train_attack = prepare_dataset(train_unbatched,
                                 pre=False,
                                 shuffle=False,
                                 repeat=False,
                                 batch=1,
                                 augment=False)
y_train_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(train_unbatched):
    y_train_attack.append(y)

# seperate test labels and images for attacks
test_unbatched = prepare_dataset(test_ds,
                                 pre=True,
                                 shuffle=False,
                                 repeat=False,
                                 batch=False,
                                 augment=False,
                                 cache=False)
x_test_attack = prepare_dataset(test_unbatched,
                                pre=False,
                                shuffle=False,
                                repeat=False,
                                batch=1,
                                augment=False)

y_test_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(test_unbatched):
    y_test_attack.append(y)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## ResNet50V2
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %% [markdown]
# Transfer learning: initalize with weights pretrained on ImageNet

# %%
def resnet50_builder():
    # load pretrained ResNet50V2 (ImageNet) without output
    resnet50 = ResNet50V2(include_top = False,
                          weights = 'imagenet',
                          input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]),)
    
    # make layers trainable
    resnet50.trainable = True
    
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet50, # add pretrained resnet layers to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet50V2')
    
    return model

# %%
resnet50 = resnet50_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet50.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50v2_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94674944/94668760 [==============================] - 2s 0us/step

# %%
resnet50.summary()
# Out:
# Model: "ResNet50V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_6 (ModuleWrap (None, 8, 8, 2048)        23564800
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 2048)              0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 2049
# =================================================================
# Total params: 23,566,849
# Trainable params: 23,521,409
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet50 = resnet50.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 1017/1017 [==============================] - 643s 562ms/step - loss: 0.7135 - accuracy: 0.5657 - precision: 0.4363 - recall: 0.2179 - val_loss: 4.1931 - val_accuracy: 0.5996 - val_precision: 1.0000 - val_recall: 0.0028
# Epoch 2/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7224 - accuracy: 0.5798 - precision: 0.4739 - recall: 0.1939 - val_loss: 1.7492 - val_accuracy: 0.6206 - val_precision: 0.5442 - val_recall: 0.3388
# Epoch 3/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.7208 - accuracy: 0.5375 - precision: 0.4382 - recall: 0.5138 - val_loss: 1.8649 - val_accuracy: 0.6294 - val_precision: 0.5407 - val_recall: 0.5124
# Epoch 4/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7199 - accuracy: 0.4977 - precision: 0.4255 - recall: 0.7190 - val_loss: 1.1241 - val_accuracy: 0.5376 - val_precision: 0.4567 - val_recall: 0.7989
# Epoch 5/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.7616 - accuracy: 0.4976 - precision: 0.4207 - recall: 0.6556 - val_loss: 1.4825 - val_accuracy: 0.5088 - val_precision: 0.4389 - val_recall: 0.8017
# Epoch 6/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.9018 - accuracy: 0.5266 - precision: 0.4405 - recall: 0.6404 - val_loss: 1.1576 - val_accuracy: 0.5631 - val_precision: 0.4720 - val_recall: 0.7438
# Epoch 7/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.8306 - accuracy: 0.5303 - precision: 0.4459 - recall: 0.6648 - val_loss: 0.8704 - val_accuracy: 0.5299 - val_precision: 0.4530 - val_recall: 0.8237
# Epoch 8/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8231 - accuracy: 0.5285 - precision: 0.4429 - recall: 0.6555 - val_loss: 0.9254 - val_accuracy: 0.5409 - val_precision: 0.4590 - val_recall: 0.8017
# Epoch 9/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8157 - accuracy: 0.5279 - precision: 0.4386 - recall: 0.6644 - val_loss: 0.9199 - val_accuracy: 0.5376 - val_precision: 0.4572 - val_recall: 0.8099
# Epoch 10/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8467 - accuracy: 0.5324 - precision: 0.4426 - recall: 0.6510 - val_loss: 0.9494 - val_accuracy: 0.5476 - val_precision: 0.4635 - val_recall: 0.8044
# Epoch 11/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.8522 - accuracy: 0.5263 - precision: 0.4393 - recall: 0.6466 - val_loss: 0.9792 - val_accuracy: 0.5431 - val_precision: 0.4602 - val_recall: 0.7961
# Epoch 12/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8319 - accuracy: 0.5289 - precision: 0.4377 - recall: 0.6590 - val_loss: 0.9598 - val_accuracy: 0.5409 - val_precision: 0.4586 - val_recall: 0.7934
# Epoch 13/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.8473 - accuracy: 0.5329 - precision: 0.4448 - recall: 0.6562 - val_loss: 0.9765 - val_accuracy: 0.5387 - val_precision: 0.4573 - val_recall: 0.7961
# Epoch 14/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8411 - accuracy: 0.5362 - precision: 0.4502 - recall: 0.6738 - val_loss: 0.9540 - val_accuracy: 0.5365 - val_precision: 0.4560 - val_recall: 0.7989
# Epoch 15/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8291 - accuracy: 0.5361 - precision: 0.4522 - recall: 0.6482 - val_loss: 0.9112 - val_accuracy: 0.5354 - val_precision: 0.4555 - val_recall: 0.8044
# Epoch 16/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8451 - accuracy: 0.5302 - precision: 0.4430 - recall: 0.6515 - val_loss: 0.9822 - val_accuracy: 0.5465 - val_precision: 0.4625 - val_recall: 0.7989
# Epoch 17/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8349 - accuracy: 0.5248 - precision: 0.4397 - recall: 0.6619 - val_loss: 0.9291 - val_accuracy: 0.5343 - val_precision: 0.4544 - val_recall: 0.7961
# Epoch 18/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8458 - accuracy: 0.5343 - precision: 0.4496 - recall: 0.6611 - val_loss: 0.9095 - val_accuracy: 0.5354 - val_precision: 0.4558 - val_recall: 0.8099
# Epoch 19/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8433 - accuracy: 0.5271 - precision: 0.4412 - recall: 0.6589 - val_loss: 0.9422 - val_accuracy: 0.5343 - val_precision: 0.4544 - val_recall: 0.7961
# Epoch 20/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.8212 - accuracy: 0.5320 - precision: 0.4461 - recall: 0.6505 - val_loss: 0.9537 - val_accuracy: 0.5354 - val_precision: 0.4547 - val_recall: 0.7879

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet50.history[met])
    ax[i].plot(history_resnet50.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet50.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 170/170 [==============================] - 4s 26ms/step - loss: 0.9263 - accuracy: 0.5442 - precision: 0.4576 - recall: 0.7904
# Loss of the model is -  0.926344633102417
# Accuracy of the model is -  54.42478060722351 %
# Precision of the model is -  0.45757248997688293
# Recall of the model is -  0.7903525233268738

# %% [markdown]
# ## ResNet50V2 - low lr
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %% [markdown]
# Transfer learning: initalize with weights pretrained on ImageNet

# %%
def resnet50_lr_builder():
    # load pretrained ResNet50V2 (ImageNet) without output
    resnet50 = ResNet50V2(include_top = False,
                          weights = 'imagenet',
                          input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]),)
    
    # make layers trainable
    resnet50.trainable = True
    
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet50, # add pretrained resnet layers to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet50V2-lr')
    
    return model

# %%
resnet50_lr = resnet50_lr_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet50_lr.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        # very low learning rate to adapt pretrained weights to new data without
        # overfitting from small dataset
        learning_rate=1e-5
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet50_lr.summary()
# Out:
# Model: "ResNet50V2-lr"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_7 (ModuleWrap (None, 8, 8, 2048)        23564800
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 2048)              0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 2049
# =================================================================
# Total params: 23,566,849
# Trainable params: 23,521,409
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet50_lr = resnet50_lr.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 1017/1017 [==============================] - 617s 561ms/step - loss: 0.7936 - accuracy: 0.5372 - precision: 0.2334 - recall: 0.0659 - val_loss: 0.7808 - val_accuracy: 0.4403 - val_precision: 0.2400 - val_recall: 0.1818
# Epoch 2/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7951 - accuracy: 0.5381 - precision: 0.2481 - recall: 0.0720 - val_loss: 0.7711 - val_accuracy: 0.4469 - val_precision: 0.2545 - val_recall: 0.1956
# Epoch 3/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7841 - accuracy: 0.5579 - precision: 0.2736 - recall: 0.0634 - val_loss: 0.7693 - val_accuracy: 0.4480 - val_precision: 0.2671 - val_recall: 0.2149
# Epoch 4/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.7899 - accuracy: 0.5487 - precision: 0.2354 - recall: 0.0521 - val_loss: 0.7581 - val_accuracy: 0.4757 - val_precision: 0.2618 - val_recall: 0.1680
# Epoch 5/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7870 - accuracy: 0.5518 - precision: 0.2487 - recall: 0.0573 - val_loss: 0.7527 - val_accuracy: 0.4812 - val_precision: 0.2810 - val_recall: 0.1873
# Epoch 6/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.7859 - accuracy: 0.5648 - precision: 0.2676 - recall: 0.0511 - val_loss: 0.7518 - val_accuracy: 0.4723 - val_precision: 0.2625 - val_recall: 0.1736
# Epoch 7/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.7803 - accuracy: 0.5637 - precision: 0.2845 - recall: 0.0554 - val_loss: 0.7523 - val_accuracy: 0.4701 - val_precision: 0.2661 - val_recall: 0.1818
# Epoch 8/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7893 - accuracy: 0.5632 - precision: 0.2644 - recall: 0.0507 - val_loss: 0.7492 - val_accuracy: 0.4912 - val_precision: 0.2679 - val_recall: 0.1543
# Epoch 9/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7888 - accuracy: 0.5736 - precision: 0.3264 - recall: 0.0521 - val_loss: 0.7361 - val_accuracy: 0.5177 - val_precision: 0.3147 - val_recall: 0.1708
# Epoch 10/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.7866 - accuracy: 0.5709 - precision: 0.2590 - recall: 0.0381 - val_loss: 0.7303 - val_accuracy: 0.5210 - val_precision: 0.3158 - val_recall: 0.1653
# Epoch 11/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 0.7878 - accuracy: 0.5733 - precision: 0.2856 - recall: 0.0400 - val_loss: 0.7342 - val_accuracy: 0.5188 - val_precision: 0.3043 - val_recall: 0.1543
# Epoch 12/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7888 - accuracy: 0.5717 - precision: 0.2488 - recall: 0.0310 - val_loss: 0.7275 - val_accuracy: 0.5277 - val_precision: 0.3222 - val_recall: 0.1598
# Epoch 13/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7771 - accuracy: 0.5810 - precision: 0.2617 - recall: 0.0285 - val_loss: 0.7188 - val_accuracy: 0.5487 - val_precision: 0.3602 - val_recall: 0.1598
# Epoch 14/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7820 - accuracy: 0.5827 - precision: 0.2954 - recall: 0.0296 - val_loss: 0.7134 - val_accuracy: 0.5520 - val_precision: 0.3600 - val_recall: 0.1488
# Epoch 15/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 0.7705 - accuracy: 0.5988 - precision: 0.4652 - recall: 0.0424 - val_loss: 0.7113 - val_accuracy: 0.5509 - val_precision: 0.3576 - val_recall: 0.1488
# Epoch 16/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 0.7800 - accuracy: 0.5941 - precision: 0.4168 - recall: 0.0390 - val_loss: 0.7091 - val_accuracy: 0.5631 - val_precision: 0.3824 - val_recall: 0.1433
# Epoch 17/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 0.7843 - accuracy: 0.5879 - precision: 0.3608 - recall: 0.0258 - val_loss: 0.7034 - val_accuracy: 0.5719 - val_precision: 0.4000 - val_recall: 0.1322
# Epoch 18/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 0.7822 - accuracy: 0.5980 - precision: 0.4443 - recall: 0.0310 - val_loss: 0.7013 - val_accuracy: 0.5719 - val_precision: 0.3824 - val_recall: 0.1074
# Epoch 19/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7787 - accuracy: 0.5977 - precision: 0.3735 - recall: 0.0217 - val_loss: 0.7056 - val_accuracy: 0.5830 - val_precision: 0.4255 - val_recall: 0.1102
# Epoch 20/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 0.7893 - accuracy: 0.5953 - precision: 0.4168 - recall: 0.0241 - val_loss: 0.6973 - val_accuracy: 0.5863 - val_precision: 0.4421 - val_recall: 0.1157

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet50_lr.history[met])
    ax[i].plot(history_resnet50_lr.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet50_lr.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 170/170 [==============================] - 4s 24ms/step - loss: 0.6839 - accuracy: 0.6018 - precision: 0.4964 - recall: 0.1262
# Loss of the model is -  0.683867335319519
# Accuracy of the model is -  60.176992416381836 %
# Precision of the model is -  0.49635037779808044
# Recall of the model is -  0.12615954875946045

# %% [markdown]
# ## ResNet50V2 - no imagenet
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %% [markdown]
# Transfer learning: initalize with weights pretrained on ImageNet

# %%
def resnet50_noimgnet_builder():
    # load pretrained ResNet50V2 (ImageNet) without output
    resnet50 = ResNet50V2(include_top = False,
                          weights = None,
                          input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]),)
    
    # make layers trainable
    resnet50.trainable = True
    
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet50, # add pretrained resnet layers to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet50V2-noimgnet')
    
    return model

# %%
resnet50_noimgnet = resnet50_noimgnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet50_noimgnet.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet50_noimgnet.summary()
# Out:
# Model: "ResNet50V2-noimgnet"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_8 (ModuleWrap (None, 8, 8, 2048)        23564800
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 2048)              0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 2049
# =================================================================
# Total params: 23,566,849
# Trainable params: 23,521,409
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet50_noimgnet = resnet50_noimgnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 1017/1017 [==============================] - 617s 560ms/step - loss: 0.8120 - accuracy: 0.6011 - precision: 0.4042 - recall: 0.0068 - val_loss: 3.9684 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 1017/1017 [==============================] - 568s 559ms/step - loss: 1.4604 - accuracy: 0.6011 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 6.1827 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 2.3765 - accuracy: 0.6009 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.4168 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 1017/1017 [==============================] - 570s 560ms/step - loss: 2.4035 - accuracy: 0.6021 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 2.6094 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 1017/1017 [==============================] - 571s 561ms/step - loss: 2.6996 - accuracy: 0.5994 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.2814 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 2.7247 - accuracy: 0.6036 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8340 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 2.7597 - accuracy: 0.5931 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8440 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 1017/1017 [==============================] - 568s 559ms/step - loss: 2.7259 - accuracy: 0.5968 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8521 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 1017/1017 [==============================] - 568s 559ms/step - loss: 2.7452 - accuracy: 0.5963 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8165 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 1017/1017 [==============================] - 568s 559ms/step - loss: 2.7105 - accuracy: 0.5987 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8336 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 1017/1017 [==============================] - 568s 559ms/step - loss: 2.7269 - accuracy: 0.5952 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8184 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 1017/1017 [==============================] - 568s 559ms/step - loss: 2.7274 - accuracy: 0.5998 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8351 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 1017/1017 [==============================] - 568s 559ms/step - loss: 2.7078 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8133 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 1017/1017 [==============================] - 569s 560ms/step - loss: 2.7529 - accuracy: 0.5938 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8230 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 2.7200 - accuracy: 0.5971 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8071 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 2.7362 - accuracy: 0.5955 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8244 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 1017/1017 [==============================] - 568s 559ms/step - loss: 2.7574 - accuracy: 0.5945 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8172 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 2.7466 - accuracy: 0.5950 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8108 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 2.6828 - accuracy: 0.6023 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8292 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 2.7276 - accuracy: 0.5952 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.8173 - val_accuracy: 0.5985 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet50_noimgnet.history[met])
    ax[i].plot(history_resnet50_noimgnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet50_noimgnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 170/170 [==============================] - 4s 24ms/step - loss: 1.7983 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss of the model is -  1.7983475923538208
# Accuracy of the model is -  60.25073528289795 %
# Precision of the model is -  0.0
# Recall of the model is -  0.0

# %% [markdown]
# ## ResNet50V2 - pneu
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %% [markdown]
# Transfer learning: initalize with weights pretrained on ImageNet

# %%
def resnet50_pneu_builder():
    # load pretrained ResNet50V2 (ImageNet) without output
    resnet50 = ResNet50V2(include_top = False,
                          weights = None,
                          input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2]),)
    
    # make layers trainable
    resnet50.trainable = True
    
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet50, # add pretrained resnet layers to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet50V2-pneu')
    
    return model

# %%
resnet50_pneu = resnet50_pneu_builder()

# load weights from pneumonia pretraining
resnet50_pneu.load_weights(weights_path+'resnet50_relu_public_weights.h5')

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet50_pneu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet50_pneu.summary()
# Out:
# Model: "ResNet50V2-pneu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_9 (ModuleWrap (None, 8, 8, 2048)        23564800
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 2048)              0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 2049
# =================================================================
# Total params: 23,566,849
# Trainable params: 23,521,409
# Non-trainable params: 45,440
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet50_pneu = resnet50_pneu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 1017/1017 [==============================] - 617s 561ms/step - loss: 0.9086 - accuracy: 0.6961 - precision: 0.6151 - recall: 0.6866 - val_loss: 1.1856 - val_accuracy: 0.7046 - val_precision: 0.7182 - val_recall: 0.4353
# Epoch 2/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 0.9779 - accuracy: 0.7189 - precision: 0.6706 - recall: 0.6040 - val_loss: 1.9977 - val_accuracy: 0.6173 - val_precision: 0.6308 - val_recall: 0.1129
# Epoch 3/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0527 - accuracy: 0.7102 - precision: 0.6644 - recall: 0.5700 - val_loss: 1.1562 - val_accuracy: 0.6936 - val_precision: 0.6777 - val_recall: 0.4518
# Epoch 4/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 0.9830 - accuracy: 0.7188 - precision: 0.6549 - recall: 0.6312 - val_loss: 2.6556 - val_accuracy: 0.6217 - val_precision: 0.6780 - val_recall: 0.1102
# Epoch 5/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0259 - accuracy: 0.7170 - precision: 0.6664 - recall: 0.5897 - val_loss: 3.3231 - val_accuracy: 0.6018 - val_precision: 1.0000 - val_recall: 0.0083
# Epoch 6/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0644 - accuracy: 0.7009 - precision: 0.6711 - recall: 0.4958 - val_loss: 0.9828 - val_accuracy: 0.7157 - val_precision: 0.6853 - val_recall: 0.5399
# Epoch 7/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0758 - accuracy: 0.7008 - precision: 0.6754 - recall: 0.4990 - val_loss: 0.8976 - val_accuracy: 0.7367 - val_precision: 0.6972 - val_recall: 0.6088
# Epoch 8/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0829 - accuracy: 0.7103 - precision: 0.6914 - recall: 0.5129 - val_loss: 1.0048 - val_accuracy: 0.7257 - val_precision: 0.7018 - val_recall: 0.5510
# Epoch 9/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0781 - accuracy: 0.7017 - precision: 0.6655 - recall: 0.5134 - val_loss: 0.9122 - val_accuracy: 0.7345 - val_precision: 0.6762 - val_recall: 0.6501
# Epoch 10/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0389 - accuracy: 0.7171 - precision: 0.6885 - recall: 0.5418 - val_loss: 0.9631 - val_accuracy: 0.7301 - val_precision: 0.6964 - val_recall: 0.5813
# Epoch 11/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0430 - accuracy: 0.7166 - precision: 0.6894 - recall: 0.5314 - val_loss: 0.9504 - val_accuracy: 0.7279 - val_precision: 0.6997 - val_recall: 0.5647
# Epoch 12/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0483 - accuracy: 0.7162 - precision: 0.6927 - recall: 0.5383 - val_loss: 0.9528 - val_accuracy: 0.7268 - val_precision: 0.6973 - val_recall: 0.5647
# Epoch 13/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0871 - accuracy: 0.7118 - precision: 0.6759 - recall: 0.5336 - val_loss: 0.9493 - val_accuracy: 0.7279 - val_precision: 0.6970 - val_recall: 0.5702
# Epoch 14/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0809 - accuracy: 0.7141 - precision: 0.6889 - recall: 0.5289 - val_loss: 0.9534 - val_accuracy: 0.7268 - val_precision: 0.6946 - val_recall: 0.5702
# Epoch 15/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0624 - accuracy: 0.7091 - precision: 0.6805 - recall: 0.5268 - val_loss: 0.9501 - val_accuracy: 0.7334 - val_precision: 0.7007 - val_recall: 0.5868
# Epoch 16/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0674 - accuracy: 0.7150 - precision: 0.6892 - recall: 0.5294 - val_loss: 0.9636 - val_accuracy: 0.7290 - val_precision: 0.7021 - val_recall: 0.5647
# Epoch 17/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0607 - accuracy: 0.7141 - precision: 0.6829 - recall: 0.5223 - val_loss: 0.9435 - val_accuracy: 0.7279 - val_precision: 0.6970 - val_recall: 0.5702
# Epoch 18/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0984 - accuracy: 0.7050 - precision: 0.6723 - recall: 0.5197 - val_loss: 0.9414 - val_accuracy: 0.7268 - val_precision: 0.6946 - val_recall: 0.5702
# Epoch 19/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0276 - accuracy: 0.7187 - precision: 0.6918 - recall: 0.5410 - val_loss: 0.9485 - val_accuracy: 0.7312 - val_precision: 0.6974 - val_recall: 0.5840
# Epoch 20/20
# 1017/1017 [==============================] - 569s 559ms/step - loss: 1.0401 - accuracy: 0.7199 - precision: 0.6880 - recall: 0.5468 - val_loss: 0.9549 - val_accuracy: 0.7268 - val_precision: 0.6986 - val_recall: 0.5620

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet50_pneu.history[met])
    ax[i].plot(history_resnet50_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet50_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 170/170 [==============================] - 4s 24ms/step - loss: 0.9608 - accuracy: 0.7345 - precision: 0.7020 - recall: 0.5770
# Loss of the model is -  0.9608470797538757
# Accuracy of the model is -  73.45132827758789 %
# Precision of the model is -  0.7020316123962402
# Recall of the model is -  0.5769944190979004

# %% [markdown]
# ## Evaluation

# %%
models = [
    resnet50,
    resnet50_lr,
    resnet50_noimgnet,
    resnet50_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating ResNet50V2 ...
# 170/170 [==============================] - 4s 23ms/step - loss: 0.9263 - accuracy: 0.5442 - precision: 0.4576 - recall: 0.7904
#
#
# Evaluating ResNet50V2-lr ...
# 170/170 [==============================] - 4s 24ms/step - loss: 0.6839 - accuracy: 0.6018 - precision: 0.4964 - recall: 0.1262
#
#
# Evaluating ResNet50V2-noimgnet ...
# 170/170 [==============================] - 4s 24ms/step - loss: 1.7983 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating ResNet50V2-pneu ...
# 170/170 [==============================] - 4s 24ms/step - loss: 0.9608 - accuracy: 0.7345 - precision: 0.7020 - recall: 0.5770

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 1.477

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 2.0
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.0983% and noise_multiplier = 0.6894884631669522 iterated over 20340 steps satisfies differential privacy with eps = 2 and delta = 0.0001.
# 0.6894884631669522

# %% [markdown]
# #### Membership Inference Attack

# %%
# run membership inference attack
def run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack):
    # predict on train
    probs_train = model.predict(x_train_attack)
    # predict on test
    probs_test = model.predict(x_test_attack)

    # only label as output instead of prob
    #probs_train = np.round(logits_train)
    #probs_test = np.round(logits_test)

    # compute losses
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant

    loss_train = np.array([x[0] for x in bc(constant([[y] for y in y_train_attack]), constant(probs_train), from_logits=False).numpy()])
    loss_test = np.array([x[0] for x in bc(constant([[y] for y in y_test_attack]), constant(probs_test), from_logits=False).numpy()])

    # labels
    train_labels = np.array(y_train_attack)
    test_labels = np.array(y_test_attack)

    # prepare attacks
    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = train_labels,
        labels_test = test_labels
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,)

    attack_types = [
        AttackType.THRESHOLD_ATTACK,
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    plt.show()

    # print a user-friendly summary of the attacks
    print(attacks_result.summary(by_slices=False)) #TODO fix low auc sometimes

# %%
for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack)
    print('\n')
# Out:
# Membership Inference Attack on ResNet50V2...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 817 training and 817 test examples) achieved an AUC of 0.59 on slice CLASS=0
#   LOGISTIC_REGRESSION (with 817 training and 817 test examples) achieved an advantage of 0.19 on slice CLASS=0
#
#
# Membership Inference Attack on ResNet50V2-lr...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.53 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.09 on slice CLASS=1
#
#
# Membership Inference Attack on ResNet50V2-noimgnet...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.62 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.26 on slice CLASS=1
#
#
# Membership Inference Attack on ResNet50V2-pneu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.68 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.36 on slice CLASS=1
