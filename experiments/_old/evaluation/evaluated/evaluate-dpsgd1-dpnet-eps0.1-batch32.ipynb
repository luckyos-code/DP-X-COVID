# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install git+https://github.com/tensorflow/privacy
# Out:
#      |████████████████████████████████| 4.0 MB 7.5 MB/s
#   Building wheel for tensorflow-privacy (setup.py) ... done

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SingleAttackResult
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 100% 780M/780M [00:03<00:00, 217MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 9.0
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-val-test split with 80-5-15
x_train, x_rest, y_train, y_rest = train_test_split(files, labels, test_size=VAL_SPLIT+TEST_SPLIT, random_state=random_state)
x_test, x_val, y_test, y_val = train_test_split(x_rest, y_rest, test_size=VAL_SPLIT/(VAL_SPLIT+TEST_SPLIT), random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7232, Val: 452, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4339, 'COVID-19': 2893}
# val set:  {'normal': 272, 'COVID-19': 180}
# test set:   {'normal': 813, 'COVID-19': 543}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# set for attack on train set
train_attack_data = prepare_dataset(train_ds,
                                    pre=True,
                                    shuffle=False,
                                    repeat=False,
                                    batch=1,
                                    augment=False,
                                    cache=False)

# set for attack on test set
test_attack_data = prepare_dataset(test_ds,
                                   pre=True,
                                   shuffle=False,
                                   repeat=False,
                                   batch=1,
                                   augment=False,
                                   cache=False)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## DP-Net - relu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_relu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='relu'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-relu')
    return dpnet

# %%
dpnet_relu = dpnet_relu_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_relu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_relu.summary()
# Out:
# Model: "DP-Net-relu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization (BatchNo (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                230432
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_relu = dpnet_relu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4994: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 226/226 [==============================] - 129s 463ms/step - loss: 0.8407 - accuracy: 0.5176 - precision: 0.4180 - recall: 0.5254 - val_loss: 0.6652 - val_accuracy: 0.6027 - val_precision: 0.5000 - val_recall: 0.6685
# Epoch 2/20
# 226/226 [==============================] - 100s 442ms/step - loss: 0.8319 - accuracy: 0.5268 - precision: 0.4252 - recall: 0.5195 - val_loss: 0.6698 - val_accuracy: 0.5714 - val_precision: 0.4673 - val_recall: 0.5618
# Epoch 3/20
# 226/226 [==============================] - 98s 436ms/step - loss: 0.8286 - accuracy: 0.5351 - precision: 0.4353 - recall: 0.5451 - val_loss: 0.9620 - val_accuracy: 0.4107 - val_precision: 0.3976 - val_recall: 0.9382
# Epoch 4/20
# 226/226 [==============================] - 99s 438ms/step - loss: 0.8270 - accuracy: 0.5360 - precision: 0.4357 - recall: 0.5427 - val_loss: 0.8535 - val_accuracy: 0.4531 - val_precision: 0.3943 - val_recall: 0.7022
# Epoch 5/20
# 226/226 [==============================] - 99s 440ms/step - loss: 0.8429 - accuracy: 0.5295 - precision: 0.4277 - recall: 0.5213 - val_loss: 0.8484 - val_accuracy: 0.4643 - val_precision: 0.3987 - val_recall: 0.6854
# Epoch 6/20
# 226/226 [==============================] - 101s 447ms/step - loss: 0.8346 - accuracy: 0.5346 - precision: 0.4334 - recall: 0.5320 - val_loss: 0.8468 - val_accuracy: 0.4754 - val_precision: 0.4034 - val_recall: 0.6685
# Epoch 7/20
# 226/226 [==============================] - 98s 435ms/step - loss: 0.8383 - accuracy: 0.5336 - precision: 0.4330 - recall: 0.5361 - val_loss: 0.8455 - val_accuracy: 0.4754 - val_precision: 0.4034 - val_recall: 0.6685
# Epoch 8/20
# 226/226 [==============================] - 98s 435ms/step - loss: 0.8377 - accuracy: 0.5344 - precision: 0.4337 - recall: 0.5358 - val_loss: 0.8504 - val_accuracy: 0.4688 - val_precision: 0.3993 - val_recall: 0.6685
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net')
    return dpnet

# %%
dpnet = dpnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet.summary()
# Out:
# Model: "DP-Net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet = dpnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4994: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 226/226 [==============================] - 105s 440ms/step - loss: 0.8265 - accuracy: 0.5261 - precision: 0.4233 - recall: 0.5092 - val_loss: 0.9384 - val_accuracy: 0.3996 - val_precision: 0.3888 - val_recall: 0.8933
# Epoch 2/20
# 226/226 [==============================] - 98s 434ms/step - loss: 0.8298 - accuracy: 0.5361 - precision: 0.4341 - recall: 0.5258 - val_loss: 0.7308 - val_accuracy: 0.5804 - val_precision: 0.4713 - val_recall: 0.4607
# Epoch 3/20
# 226/226 [==============================] - 100s 444ms/step - loss: 0.8988 - accuracy: 0.5507 - precision: 0.4504 - recall: 0.5586 - val_loss: 0.8430 - val_accuracy: 0.6138 - val_precision: 0.5333 - val_recall: 0.2247
# Epoch 4/20
# 226/226 [==============================] - 98s 437ms/step - loss: 0.8641 - accuracy: 0.5484 - precision: 0.4465 - recall: 0.5382 - val_loss: 0.6636 - val_accuracy: 0.6384 - val_precision: 0.5412 - val_recall: 0.5899
# Epoch 5/20
# 226/226 [==============================] - 98s 436ms/step - loss: 0.8450 - accuracy: 0.5890 - precision: 0.4888 - recall: 0.5963 - val_loss: 0.8997 - val_accuracy: 0.5246 - val_precision: 0.4437 - val_recall: 0.7753
# Epoch 6/20
# 226/226 [==============================] - 99s 438ms/step - loss: 0.8621 - accuracy: 0.5816 - precision: 0.4811 - recall: 0.5838 - val_loss: 0.6893 - val_accuracy: 0.6540 - val_precision: 0.5906 - val_recall: 0.4213
# Epoch 7/20
# 226/226 [==============================] - 98s 433ms/step - loss: 0.8170 - accuracy: 0.5946 - precision: 0.4943 - recall: 0.5890 - val_loss: 0.6587 - val_accuracy: 0.6473 - val_precision: 0.5538 - val_recall: 0.5787
# Epoch 8/20
# 226/226 [==============================] - 99s 437ms/step - loss: 0.8081 - accuracy: 0.6069 - precision: 0.5073 - recall: 0.6032 - val_loss: 0.6547 - val_accuracy: 0.6696 - val_precision: 0.5915 - val_recall: 0.5449
# Epoch 9/20
# 226/226 [==============================] - 98s 435ms/step - loss: 0.8236 - accuracy: 0.5951 - precision: 0.4949 - recall: 0.5928 - val_loss: 0.6660 - val_accuracy: 0.6562 - val_precision: 0.5645 - val_recall: 0.5899
# Epoch 10/20
# 226/226 [==============================] - 100s 442ms/step - loss: 0.8278 - accuracy: 0.5997 - precision: 0.4997 - recall: 0.5938 - val_loss: 0.6706 - val_accuracy: 0.6585 - val_precision: 0.5635 - val_recall: 0.6236
# Epoch 11/20
# 226/226 [==============================] - 98s 435ms/step - loss: 0.8049 - accuracy: 0.6073 - precision: 0.5076 - recall: 0.6080 - val_loss: 0.6714 - val_accuracy: 0.6540 - val_precision: 0.5602 - val_recall: 0.6011
# Epoch 12/20
# 226/226 [==============================] - 101s 446ms/step - loss: 0.8233 - accuracy: 0.6032 - precision: 0.5033 - recall: 0.6008 - val_loss: 0.6759 - val_accuracy: 0.6496 - val_precision: 0.5533 - val_recall: 0.6124
# Epoch 13/20
# 226/226 [==============================] - 98s 436ms/step - loss: 0.8176 - accuracy: 0.6063 - precision: 0.5067 - recall: 0.6046 - val_loss: 0.6703 - val_accuracy: 0.6496 - val_precision: 0.5550 - val_recall: 0.5955
# Epoch 14/20
# 226/226 [==============================] - 99s 439ms/step - loss: 0.8358 - accuracy: 0.5913 - precision: 0.4910 - recall: 0.5907 - val_loss: 0.6723 - val_accuracy: 0.6540 - val_precision: 0.5596 - val_recall: 0.6067
# Epoch 15/20
# 226/226 [==============================] - 99s 440ms/step - loss: 0.8134 - accuracy: 0.6080 - precision: 0.5085 - recall: 0.6018 - val_loss: 0.6721 - val_accuracy: 0.6540 - val_precision: 0.5608 - val_recall: 0.5955
# Epoch 16/20
# 226/226 [==============================] - 99s 439ms/step - loss: 0.8232 - accuracy: 0.6019 - precision: 0.5020 - recall: 0.5963 - val_loss: 0.6728 - val_accuracy: 0.6496 - val_precision: 0.5550 - val_recall: 0.5955
# Epoch 17/20
# 226/226 [==============================] - 99s 438ms/step - loss: 0.8152 - accuracy: 0.6051 - precision: 0.5054 - recall: 0.6015 - val_loss: 0.6727 - val_accuracy: 0.6540 - val_precision: 0.5596 - val_recall: 0.6067
# Epoch 18/20
# 226/226 [==============================] - 98s 434ms/step - loss: 0.8150 - accuracy: 0.6047 - precision: 0.5049 - recall: 0.6018 - val_loss: 0.6712 - val_accuracy: 0.6518 - val_precision: 0.5573 - val_recall: 0.6011
# Epoch 19/20
# 226/226 [==============================] - 99s 439ms/step - loss: 0.8184 - accuracy: 0.6026 - precision: 0.5027 - recall: 0.6101 - val_loss: 0.6727 - val_accuracy: 0.6540 - val_precision: 0.5596 - val_recall: 0.6067
# Epoch 20/20
# 226/226 [==============================] - 98s 434ms/step - loss: 0.8306 - accuracy: 0.5940 - precision: 0.4938 - recall: 0.5873 - val_loss: 0.6730 - val_accuracy: 0.6562 - val_precision: 0.5625 - val_recall: 0.6067

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet.history[met])
    ax[i].plot(history_dpnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 30ms/step - loss: 0.7067 - accuracy: 0.6696 - precision: 0.5796 - recall: 0.6372
# Loss of the model is -  0.7067245841026306
# Accuracy of the model is -  66.96165204048157 %
# Precision of the model is -  0.5795645117759705
# Recall of the model is -  0.6372007131576538

# %% [markdown]
# ## DP-Net - logits
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_logits_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-logits')
    return dpnet

# %%
dpnet_logits = dpnet_logits_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_logits.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=False,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_logits.summary()
# Out:
# Model: "DP-Net-logits"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_logits = dpnet_logits.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# 226/226 [==============================] - 105s 437ms/step - loss: 0.8170 - accuracy: 0.5357 - precision: 0.4349 - recall: 0.5365 - val_loss: 0.7188 - val_accuracy: 0.6071 - val_precision: 0.5033 - val_recall: 0.8483
# Epoch 2/20
# 226/226 [==============================] - 99s 439ms/step - loss: 0.7753 - accuracy: 0.5749 - precision: 0.4752 - recall: 0.6001 - val_loss: 0.6220 - val_accuracy: 0.6987 - val_precision: 0.6080 - val_recall: 0.6798
# Epoch 3/20
# 226/226 [==============================] - 99s 438ms/step - loss: 0.8027 - accuracy: 0.5758 - precision: 0.4752 - recall: 0.5807 - val_loss: 0.8322 - val_accuracy: 0.6138 - val_precision: 0.5086 - val_recall: 0.8315
- accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss of the model is -  1.4144659042358398
# Accuracy of the model is -  59.95575189590454 %
# Precision of the model is -  0.0
# Recall of the model is -  0.0

# %% [markdown]
# ## DP-Net pneu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_pneu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-pneu')
    return dpnet

# %%
dpnet_pneu = dpnet_pneu_builder()

# load weights from pneumonia pretraining
dpnet_pneu.load_weights(weights_path+'dpnet_tanh_public_weights.h5')

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_pneu.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_pneu.summary()
# Out:
# Model: "DP-Net-pneu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_pneu = dpnet_pneu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4994: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 226/226 [==============================] - 106s 444ms/step - loss: 0.8539 - accuracy: 0.6592 - precision: 0.5526 - recall: 0.7774 - val_loss: 5.5800 - val_accuracy: 0.3996 - val_precision: 0.3978 - val_recall: 0.9944
# Epoch 2/20
# 226/226 [==============================] - 99s 438ms/step - loss: 0.8957 - accuracy: 0.6470 - precision: 0.5415 - recall: 0.7667 - val_loss: 2.0907 - val_accuracy: 0.5424 - val_precision: 0.4613 - val_recall: 0.9045
# Epoch 3/20
# 226/226 [==============================] - 99s 439ms/step - loss: 0.9135 - accuracy: 0.6681 - precision: 0.5631 - recall: 0.7608 - val_loss: 6.0331 - val_accuracy: 0.3951 - val_precision: 0.3960 - val_recall: 0.9944
# Epoch 4/20
# 226/226 [==============================] - 98s 436ms/step - loss: 1.0125 - accuracy: 0.6485 - precision: 0.5458 - recall: 0.7231 - val_loss: 2.2818 - val_accuracy: 0.5558 - val_precision: 0.4697 - val_recall: 0.9157
# Epoch 5/20
# 226/226 [==============================] - 100s 445ms/step - loss: 1.0582 - accuracy: 0.6481 - precision: 0.5447 - recall: 0.7328 - val_loss: 1.1046 - val_accuracy: 0.6964 - val_precision: 0.6129 - val_recall: 0.6404
# Epoch 6/20
# 226/226 [==============================] - 99s 439ms/step - loss: 1.0507 - accuracy: 0.6477 - precision: 0.5441 - recall: 0.7359 - val_loss: 1.0244 - val_accuracy: 0.7121 - val_precision: 0.6667 - val_recall: 0.5506
# Epoch 7/20
# 226/226 [==============================] - 98s 436ms/step - loss: 1.0498 - accuracy: 0.6421 - precision: 0.5391 - recall: 0.7273 - val_loss: 1.1003 - val_accuracy: 0.6942 - val_precision: 0.6085 - val_recall: 0.6461
# Epoch 8/20
# 226/226 [==============================] - 99s 438ms/step - loss: 1.0645 - accuracy: 0.6495 - precision: 0.5463 - recall: 0.7293 - val_loss: 1.0102 - val_accuracy: 0.7054 - val_precision: 0.6667 - val_recall: 0.5169
# Epoch 9/20
# 226/226 [==============================] - 99s 438ms/step - loss: 1.0466 - accuracy: 0.6456 - precision: 0.5420 - recall: 0.7359 - val_loss: 1.0246 - val_accuracy: 0.6987 - val_precision: 0.6503 - val_recall: 0.5225
# Epoch 10/20
# 226/226 [==============================] - 99s 440ms/step - loss: 1.0487 - accuracy: 0.6485 - precision: 0.5449 - recall: 0.7356 - val_loss: 1.0612 - val_accuracy: 0.6920 - val_precision: 0.6124 - val_recall: 0.6124
# Epoch 11/20
# 226/226 [==============================] - 98s 436ms/step - loss: 1.0635 - accuracy: 0.6510 - precision: 0.5473 - recall: 0.7380 - val_loss: 1.0342 - val_accuracy: 0.6920 - val_precision: 0.6250 - val_recall: 0.5618
# Epoch 12/20
# 226/226 [==============================] - 98s 434ms/step - loss: 1.0554 - accuracy: 0.6467 - precision: 0.5432 - recall: 0.7338 - val_loss: 1.0434 - val_accuracy: 0.6875 - val_precision: 0.6187 - val_recall: 0.5562
# Epoch 13/20
# 226/226 [==============================] - 99s 437ms/step - loss: 1.0650 - accuracy: 0.6421 - precision: 0.5390 - recall: 0.7290 - val_loss: 1.0438 - val_accuracy: 0.6897 - val_precision: 0.6242 - val_recall: 0.5506
# Epoch 14/20
# 226/226 [==============================] - 98s 436ms/step - loss: 1.0458 - accuracy: 0.6575 - precision: 0.5531 - recall: 0.7490 - val_loss: 1.0495 - val_accuracy: 0.6830 - val_precision: 0.6084 - val_recall: 0.5674
# Epoch 15/20
# 226/226 [==============================] - 99s 439ms/step - loss: 1.0457 - accuracy: 0.6481 - precision: 0.5442 - recall: 0.7411 - val_loss: 1.0468 - val_accuracy: 0.6875 - val_precision: 0.6203 - val_recall: 0.5506
# Epoch 16/20
# 226/226 [==============================] - 99s 437ms/step - loss: 1.0540 - accuracy: 0.6459 - precision: 0.5425 - recall: 0.7318 - val_loss: 1.0393 - val_accuracy: 0.6875 - val_precision: 0.6203 - val_recall: 0.5506
# Epoch 17/20
# 226/226 [==============================] - 98s 436ms/step - loss: 1.0542 - accuracy: 0.6500 - precision: 0.5466 - recall: 0.7338 - val_loss: 1.0497 - val_accuracy: 0.6853 - val_precision: 0.6135 - val_recall: 0.5618
# Epoch 18/20
# 226/226 [==============================] - 98s 435ms/step - loss: 1.0644 - accuracy: 0.6524 - precision: 0.5490 - recall: 0.7342 - val_loss: 1.0454 - val_accuracy: 0.6853 - val_precision: 0.6149 - val_recall: 0.5562
# Epoch 19/20
# 226/226 [==============================] - 99s 440ms/step - loss: 1.0685 - accuracy: 0.6503 - precision: 0.5470 - recall: 0.7321 - val_loss: 1.0448 - val_accuracy: 0.6897 - val_precision: 0.6242 - val_recall: 0.5506
# Epoch 20/20
# 226/226 [==============================] - 99s 437ms/step - loss: 1.0518 - accuracy: 0.6426 - precision: 0.5394 - recall: 0.7283 - val_loss: 1.0608 - val_accuracy: 0.6830 - val_precision: 0.6098 - val_recall: 0.5618

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_pneu.history[met])
    ax[i].plot(history_dpnet_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 29ms/step - loss: 0.9516 - accuracy: 0.7058 - precision: 0.6290 - recall: 0.6464
# Loss of the model is -  0.9515778422355652
# Accuracy of the model is -  70.57521939277649 %
# Precision of the model is -  0.6290322542190552
# Recall of the model is -  0.6464088559150696

# %% [markdown]
# ## Evaluation

# %%
models = [
    dpnet_relu,
    dpnet,
    dpnet_logits,
    dpnet_nobn,
    dpnet_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating DP-Net-relu ...
# 43/43 [==============================] - 1s 29ms/step - loss: 0.8246 - accuracy: 0.4565 - precision: 0.3880 - recall: 0.6188
#
#
# Evaluating DP-Net ...
# 43/43 [==============================] - 1s 29ms/step - loss: 0.7067 - accuracy: 0.6696 - precision: 0.5796 - recall: 0.6372
#
#
# Evaluating DP-Net-logits ...
# 43/43 [==============================] - 1s 30ms/step - loss: 0.6783 - accuracy: 0.6829 - precision: 0.6068 - recall: 0.5912
#
#
# Evaluating DP-Net-nobn ...
# 43/43 [==============================] - 1s 29ms/step - loss: 1.4145 - accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating DP-Net-pneu ...
# 43/43 [==============================] - 1s 29ms/step - loss: 0.9516 - accuracy: 0.7058 - precision: 0.6290 - recall: 0.6464

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 0.100

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 0.1
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.442% and noise_multiplier = 8.836744240938424 iterated over 4520 steps satisfies differential privacy with eps = 0.1 and delta = 0.0001.
# 8.836744240938424

# %% [markdown]
# #### Membership Inference Attack

# %%
def compute_attack_inputs(attack_data):
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant
    # get labels
    labels = []
    for x, y in attack_data.as_numpy_iterator():
        labels.append(y[0])
    # predict
    probs = model.predict(attack_data)
    # compute loss
    losses = np.array([x[0] for x in bc(constant([[y] for y in labels]), constant(probs), from_logits=False).numpy()])
    
    return (np.array(probs), np.array(losses), np.array(labels))

# run membership inference attack
def run_mia(model, train_attack_input, test_attack_input):
    # prepare attacks
    probs_train, loss_train, labels_train = train_attack_input
    probs_test, loss_test, labels_test = test_attack_input

    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = labels_train,
        labels_test = labels_test
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
        by_classification_correctness = True
    )

    attack_types = [
        #AttackType.THRESHOLD_ATTACK, # logistic was always better, so no threshold to save time
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    #plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    #plt.show()

    # print a user-friendly summary of the attacks
    #print(attacks_result.summary(by_slices=False))

    max_auc = attacks_result.get_result_with_max_auc().get_auc()
    max_adv = attacks_result.get_result_with_max_attacker_advantage().get_attacker_advantage()

    return max_auc, max_adv

# epsilon estimation based on attack, metric adapted for AUC from https://paperswithcode.com/paper/antipodes-of-label-differential-privacy-pate
def empirical_eps(auc):
    if auc <= 0.5:
        return 0
    if auc == 1:
        return np.inf
    return np.log(auc / (1 - auc))

from contextlib import contextmanager
import sys
@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout

# %%
import scipy.stats as st

for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    SAMPLE_NB = 100
    
    train_attack_input = compute_attack_inputs(train_attack_data)
    test_attack_input = compute_attack_inputs(test_attack_data)

    aucs = []
    advs = []
    emp_eps = []
    for i in range(SAMPLE_NB):
        with suppress_stdout():
            max_auc, max_adv = run_mia(model, train_attack_input, test_attack_input)
        aucs.append(max_auc)
        advs.append(max_adv)
        emp_eps.append(empirical_eps(max_auc))

    auc_low, auc_high = st.t.interval(0.95, len(aucs)-1, loc=np.mean(aucs), scale=st.sem(aucs))
    adv_low, adv_high = st.t.interval(0.95, len(advs)-1, loc=np.mean(advs), scale=st.sem(advs))
    eps_low, eps_high = st.t.interval(0.95, len(emp_eps)-1, loc=np.mean(emp_eps), scale=st.sem(emp_eps))

    print('95%%-CI based on %i attack samples'%(SAMPLE_NB))
    print('AUC: %0.2f-%0.2f'%(auc_low, auc_high))
    print('Attacker advantage: %0.2f-%0.2f'%(adv_low, adv_high))
    print('Empirical epsilon bounds from AUC: %0.2f-%0.2f\n'%(eps_low, eps_high))
# Out:
# Membership Inference Attack on DP-Net-relu...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.12-0.15
#
# Membership Inference Attack on DP-Net...
# 95%-CI based on 100 attack samples
# AUC: 0.54-0.55
# Attacker advantage: 0.13-0.15
# Empirical epsilon bounds from AUC: 0.16-0.20
#
# Membership Inference Attack on DP-Net-logits...
# 95%-CI based on 100 attack samples
# AUC: 0.54-0.55
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.16-0.18
#
# Membership Inference Attack on DP-Net-nobn...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.11-0.14
#
# Membership Inference Attack on DP-Net-pneu...
# 95%-CI based on 100 attack samples
# AUC: 0.54-0.55
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.15-0.18
