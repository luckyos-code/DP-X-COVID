# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install git+https://github.com/tensorflow/privacy
# Out:
#   Building wheel for tensorflow-privacy (setup.py) ... done

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SingleAttackResult
from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 780MB [00:05, 154MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 1.267
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-val-test split with 80-5-15
x_train, x_rest, y_train, y_rest = train_test_split(files, labels, test_size=VAL_SPLIT+TEST_SPLIT, random_state=random_state)
x_test, x_val, y_test, y_val = train_test_split(x_rest, y_rest, test_size=VAL_SPLIT/(VAL_SPLIT+TEST_SPLIT), random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7232, Val: 452, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4339, 'COVID-19': 2893}
# val set:  {'normal': 272, 'COVID-19': 180}
# test set:   {'normal': 813, 'COVID-19': 543}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# set for attack on train set
train_attack_data = prepare_dataset(train_ds,
                                    pre=True,
                                    shuffle=False,
                                    repeat=False,
                                    batch=1,
                                    augment=False,
                                    cache=False)

# set for attack on test set
test_attack_data = prepare_dataset(test_ds,
                                   pre=True,
                                   shuffle=False,
                                   repeat=False,
                                   batch=1,
                                   augment=False,
                                   cache=False)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## DP-Net - relu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_relu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='relu'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-relu')
    return dpnet

# %%
dpnet_relu = dpnet_relu_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_relu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_relu.summary()
# Out:
# Model: "DP-Net-relu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization (BatchNo (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                230432
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_relu = dpnet_relu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 226/226 [==============================] - 147s 500ms/step - loss: 0.8236 - accuracy: 0.5272 - precision: 0.4340 - recall: 0.5369 - val_loss: 0.7506 - val_accuracy: 0.5089 - val_precision: 0.4426 - val_recall: 0.9101
# Epoch 2/20
# 226/226 [==============================] - 108s 480ms/step - loss: 0.7988 - accuracy: 0.6103 - precision: 0.5199 - recall: 0.5856 - val_loss: 0.8755 - val_accuracy: 0.6027 - val_precision: 0.5000 - val_recall: 0.8596
# Epoch 3/20
# 226/226 [==============================] - 110s 486ms/step - loss: 0.8344 - accuracy: 0.6424 - precision: 0.5567 - recall: 0.6175 - val_loss: 0.7786 - val_accuracy: 0.6964 - val_precision: 0.5955 - val_recall: 0.7360
# Epoch 4/20
# 226/226 [==============================] - 108s 480ms/step - loss: 0.8648 - accuracy: 0.6652 - precision: 0.5811 - recall: 0.6408 - val_loss: 0.7540 - val_accuracy: 0.7143 - val_precision: 0.6344 - val_recall: 0.6629
# Epoch 5/20
# 226/226 [==============================] - 109s 482ms/step - loss: 0.8583 - accuracy: 0.6641 - precision: 0.5744 - recall: 0.6412 - val_loss: 0.7947 - val_accuracy: 0.7031 - val_precision: 0.6119 - val_recall: 0.6910
# Epoch 6/20
# 226/226 [==============================] - 109s 482ms/step - loss: 0.8798 - accuracy: 0.6682 - precision: 0.5856 - recall: 0.6534 - val_loss: 0.7777 - val_accuracy: 0.7165 - val_precision: 0.6364 - val_recall: 0.6685
# Epoch 7/20
# 226/226 [==============================] - 109s 481ms/step - loss: 0.8879 - accuracy: 0.6574 - precision: 0.5695 - recall: 0.6436 - val_loss: 0.7742 - val_accuracy: 0.7165 - val_precision: 0.6364 - val_recall: 0.6685
# Epoch 8/20
# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_relu.history[met])
    ax[i].plot(history_dpnet_relu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_relu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 3s 67ms/step - loss: 0.8033 - accuracy: 0.6999 - precision: 0.6227 - recall: 0.6354
# Loss of the model is -  0.8032889366149902
# Accuracy of the model is -  69.98525261878967 %
# Precision of the model is -  0.6227436661720276
# Recall of the model is -  0.6353591084480286

# %% [markdown]
# ## DP-Net - CNN Architecture for DP-SGD
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net')
    return dpnet

# %%
dpnet = dpnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet.summary()
# Out:
# Model: "DP-Net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet = dpnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 226/226 [==============================] - 117s 487ms/step - loss: 0.8447 - accuracy: 0.5749 - precision: 0.4824 - recall: 0.5720 - val_loss: 1.3680 - val_accuracy: 0.4888 - val_precision: 0.4320 - val_recall: 0.9101
# Epoch 2/20
# 226/226 [==============================] - 109s 483ms/step - loss: 1.0703 - accuracy: 0.6498 - precision: 0.5514 - recall: 0.6524 - val_loss: 1.0193 - val_accuracy: 0.6830 - val_precision: 0.6059 - val_recall: 0.5787
# Epoch 3/20
# 226/226 [==============================] - 108s 478ms/step - loss: 1.1619 - accuracy: 0.6606 - precision: 0.5689 - recall: 0.6593 - val_loss: 1.5545 - val_accuracy: 0.6094 - val_precision: 0.5052 - val_recall: 0.8146
# Epoch 4/20
# 226/226 [==============================] - 108s 479ms/step - loss: 1.1801 - accuracy: 0.6643 - precision: 0.5721 - recall: 0.6532 - val_loss: 1.1758 - val_accuracy: 0.7121 - val_precision: 0.6195 - val_recall: 0.7135
# Epoch 5/20
# 226/226 [==============================] - 107s 477ms/step - loss: 1.2127 - accuracy: 0.6715 - precision: 0.5844 - recall: 0.6495 - val_loss: 1.0518 - val_accuracy: 0.7121 - val_precision: 0.6667 - val_recall: 0.5506
# Epoch 6/20
# 226/226 [==============================] - 107s 476ms/step - loss: 1.1807 - accuracy: 0.6696 - precision: 0.5836 - recall: 0.6473 - val_loss: 1.0683 - val_accuracy: 0.7098 - val_precision: 0.6379 - val_recall: 0.6236
# Epoch 7/20
# 226/226 [==============================] - 107s 476ms/step - loss: 1.1814 - accuracy: 0.6713 - precision: 0.5792 - recall: 0.6475 - val_loss: 1.0586 - val_accuracy: 0.7188 - val_precision: 0.6566 - val_recall: 0.6124
# Epoch 8/20
# 226/226 [==============================] - 110s 488ms/step - loss: 1.1715 - accuracy: 0.6746 - precision: 0.5874 - recall: 0.6544 - val_loss: 1.0559 - val_accuracy: 0.7188 - val_precision: 0.6625 - val_recall: 0.5955
# Epoch 9/20
# 226/226 [==============================] - 108s 481ms/step - loss: 1.2049 - accuracy: 0.6620 - precision: 0.5722 - recall: 0.6350 - val_loss: 1.0640 - val_accuracy: 0.7188 - val_precision: 0.6646 - val_recall: 0.5899
# Epoch 10/20
# 226/226 [==============================] - 109s 483ms/step - loss: 1.1759 - accuracy: 0.6745 - precision: 0.5892 - recall: 0.6488 - val_loss: 1.0526 - val_accuracy: 0.7143 - val_precision: 0.6488 - val_recall: 0.6124
# Epoch 11/20
# 226/226 [==============================] - 106s 471ms/step - loss: 1.1748 - accuracy: 0.6659 - precision: 0.5787 - recall: 0.6449 - val_loss: 1.0568 - val_accuracy: 0.7165 - val_precision: 0.6545 - val_recall: 0.6067
# Epoch 12/20
# 226/226 [==============================] - 109s 481ms/step - loss: 1.1626 - accuracy: 0.6720 - precision: 0.5868 - recall: 0.6485 - val_loss: 1.0544 - val_accuracy: 0.7143 - val_precision: 0.6471 - val_recall: 0.6180
# Epoch 13/20
# 226/226 [==============================] - 109s 483ms/step - loss: 1.1752 - accuracy: 0.6681 - precision: 0.5850 - recall: 0.6452 - val_loss: 1.0568 - val_accuracy: 0.7165 - val_precision: 0.6545 - val_recall: 0.6067
# Epoch 14/20
# 226/226 [==============================] - 109s 482ms/step - loss: 1.1844 - accuracy: 0.6688 - precision: 0.5851 - recall: 0.6565 - val_loss: 1.0621 - val_accuracy: 0.7188 - val_precision: 0.6646 - val_recall: 0.5899
# Epoch 15/20
# 226/226 [==============================] - 107s 476ms/step - loss: 1.1762 - accuracy: 0.6659 - precision: 0.5815 - recall: 0.6389 - val_loss: 1.0596 - val_accuracy: 0.7210 - val_precision: 0.6646 - val_recall: 0.6011
# Epoch 16/20
# 226/226 [==============================] - 108s 480ms/step - loss: 1.1845 - accuracy: 0.6682 - precision: 0.5873 - recall: 0.6372 - val_loss: 1.0635 - val_accuracy: 0.7210 - val_precision: 0.6688 - val_recall: 0.5899
# Epoch 17/20
# 226/226 [==============================] - 106s 468ms/step - loss: 1.1616 - accuracy: 0.6728 - precision: 0.5853 - recall: 0.6516 - val_loss: 1.0571 - val_accuracy: 0.7210 - val_precision: 0.6626 - val_recall: 0.6067
# Epoch 18/20
# 226/226 [==============================] - 108s 479ms/step - loss: 1.1873 - accuracy: 0.6640 - precision: 0.5739 - recall: 0.6457 - val_loss: 1.0594 - val_accuracy: 0.7210 - val_precision: 0.6626 - val_recall: 0.6067
# Epoch 19/20
# 226/226 [==============================] - 109s 482ms/step - loss: 1.1735 - accuracy: 0.6758 - precision: 0.5937 - recall: 0.6521 - val_loss: 1.0551 - val_accuracy: 0.7143 - val_precision: 0.6471 - val_recall: 0.6180
# Epoch 20/20
# 226/226 [==============================] - 107s 475ms/step - loss: 1.2104 - accuracy: 0.6595 - precision: 0.5751 - recall: 0.6361 - val_loss: 1.0552 - val_accuracy: 0.7165 - val_precision: 0.6527 - val_recall: 0.6124

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet.history[met])
    ax[i].plot(history_dpnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 31ms/step - loss: 1.0954 - accuracy: 0.7006 - precision: 0.6330 - recall: 0.6004
# Loss of the model is -  1.095402717590332
# Accuracy of the model is -  70.05899548530579 %
# Precision of the model is -  0.6330097317695618
# Recall of the model is -  0.600368320941925

# %% [markdown]
# ## DP-Net - logits
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_logits_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-logits')
    return dpnet

# %%
dpnet_logits = dpnet_logits_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_logits.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=False,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_logits.summary()
# Out:
# Model: "DP-Net-logits"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_logits = dpnet_logits.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# 226/226 [==============================] - 113s 470ms/step - loss: 0.8460 - accuracy: 0.5919 - precision: 0.5011 - recall: 0.5980 - val_loss: 1.1355 - val_accuracy: 0.6205 - val_precision: 0.5130 - val_recall: 0.8876
# Epoch 2/20
# 226/226 [==============================] - 107s 477ms/step - loss: 1.0512 - accuracy: 0.6572 - precision: 0.5685 - recall: 0.6581 - val_loss: 1.3679 - val_accuracy: 0.6406 - val_precision: 0.5302 - val_recall: 0.8371
# Epoch 3/20
# 226/226 [==============================] - 106s 470ms/step - loss: 1.1049 - accuracy: 0.6643 - precision: 0.5732 - recall: 0.6612 - val_loss: 1.0885 - val_accuracy: 0.7031 - val_precision: 0.5991 - val_recall: 0.7640
# Epoch 4/20
# 226/226 [==============================] - 107s 474ms/step - loss: 1.0953 - accuracy: 0.6787 - precision: 0.5904 - recall: 0.6617 - val_loss: 1.0820 - val_accuracy: 0.7165 - val_precision: 0.6164 - val_recall: 0.7584
# Epoch 5/20
# 226/226 [==============================] - 106s 470ms/step - loss: 1.1232 - accuracy: 0.6640 - precision: 0.5695 - recall: 0.6626 - val_loss: 0.9977 - val_accuracy: 0.7165 - val_precision: 0.6294 - val_recall: 0.6966
# Epoch 6/20
# 226/226 [==============================] - 106s 470ms/step - loss: 1.1272 - accuracy: 0.6617 - precision: 0.5784 - recall: 0.6507 - val_loss: 1.2891 - val_accuracy: 0.6429 - val_precision: 0.8000 - val_recall: 0.1348
# Epoch 7/20
# 226/226 [==============================] - 109s 483ms/step - loss: 1.0719 - accuracy: 0.6723 - precision: 0.5860 - recall: 0.6568 - val_loss: 0.9862 - val_accuracy: 0.7009 - val_precision: 0.6048 - val_recall: 0.7135
# Epoch 8/20
# 226/226 [==============================] - 108s 479ms/step - loss: 1.0872 - accuracy: 0.6717 - precision: 0.5862 - recall: 0.6635 - val_loss: 0.9422 - val_accuracy: 0.7121 - val_precision: 0.6581 - val_recall: 0.5730
# Epoch 9/20
# 226/226 [==============================] - 108s 478ms/step - loss: 1.0876 - accuracy: 0.6789 - precision: 0.5912 - recall: 0.6561 - val_loss: 1.0773 - val_accuracy: 0.6987 - val_precision: 0.5900 - val_recall: 0.7921
# Epoch 10/20
# 226/226 [==============================] - 108s 481ms/step - loss: 1.1408 - accuracy: 0.6817 - precision: 0.5980 - recall: 0.6483 - val_loss: 1.5823 - val_accuracy: 0.6429 - val_precision: 0.5310 - val_recall: 0.8652
# Epoch 11/20
# 226/226 [==============================] - 109s 483ms/step - loss: 1.1659 - accuracy: 0.6802 - precision: 0.5970 - recall: 0.6707 - val_loss: 1.0119 - val_accuracy: 0.7232 - val_precision: 0.6588 - val_recall: 0.6292
# Epoch 12/20
# 226/226 [==============================] - 107s 474ms/step - loss: 1.1538 - accuracy: 0.6811 - precision: 0.5992 - recall: 0.6474 - val_loss: 1.0578 - val_accuracy: 0.7098 - val_precision: 0.6200 - val_recall: 0.6966
# Epoch 13/20
# 226/226 [==============================] - 109s 482ms/step - loss: 1.1834 - accuracy: 0.6715 - precision: 0.5846 - recall: 0.6433 - val_loss: 1.0439 - val_accuracy: 0.7232 - val_precision: 0.6392 - val_recall: 0.6966
# Epoch 14/20
# 226/226 [==============================] - 108s 478ms/step - loss: 1.1479 - accuracy: 0.6833 - precision: 0.6032 - recall: 0.6581 - val_loss: 1.0409 - val_accuracy: 0.7254 - val_precision: 0.6440 - val_recall: 0.6910
# Epoch 15/20
# 226/226 [==============================] - 108s 480ms/step - loss: 1.1793 - accuracy: 0.6740 - precision: 0.5830 - recall: 0.6493 - val_loss: 1.0364 - val_accuracy: 0.7232 - val_precision: 0.6436 - val_recall: 0.6798
# Epoch 16/20
# 226/226 [==============================] - 108s 479ms/step - loss: 1.1739 - accuracy: 0.6784 - precision: 0.5953 - recall: 0.6484 - val_loss: 1.0322 - val_accuracy: 0.7299 - val_precision: 0.6575 - val_recall: 0.6685
# Epoch 17/20
# 226/226 [==============================] - 108s 479ms/step - loss: 1.1780 - accuracy: 0.6742 - precision: 0.5868 - recall: 0.6420 - val_loss: 1.0353 - val_accuracy: 0.7232 - val_precision: 0.6436 - val_recall: 0.6798
# Epoch 18/20
# 226/226 [==============================] - 107s 475ms/step - loss: 1.1597 - accuracy: 0.6810 - precision: 0.5944 - recall: 0.6520 - val_loss: 1.0351 - val_accuracy: 0.7232 - val_precision: 0.6436 - val_recall: 0.6798
# Epoch 19/20
# 226/226 [==============================] - 107s 477ms/step - loss: 1.1553 - accuracy: 0.6781 - precision: 0.5970 - recall: 0.6499 - val_loss: 1.0373 - val_accuracy: 0.7210 - val_precision: 0.6359 - val_recall: 0.6966
# Epoch 20/20
# 226/226 [==============================] - 109s 482ms/step - loss: 1.1716 - accuracy: 0.6822 - precision: 0.5992 - recall: 0.6563 - val_loss: 1.0371 - val_accuracy: 0.7232 - val_precision: 0.6392 - val_recall: 0.6966

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_logits.history[met])
    ax[i].plot(history_dpnet_logits.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_logits.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 29ms/step - loss: 1.0398 - accuracy: 0.7109 - precision: 0.6327 - recall: 0.6630
# Loss of the model is -  1.0397714376449585
# Accuracy of the model is -  71.09144330024719 %
# Precision of the model is -  0.6326889395713806
# Recall of the model is -  0.6629834175109863

# %% [markdown]
# ## DP-Net nobn
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_nobn_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-nobn')
    return dpnet

# %%
dpnet_nobn = dpnet_nobn_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_nobn.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_nobn.summary()
# Out:
# Model: "DP-Net-nobn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                230432
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 241,777
# Trainable params: 241,777
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_nobn = dpnet_nobn.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
#
# Epoch 3/20
# 226/226 [==============================] - 107s 472ms/step - loss: 1.1015 - accuracy: 0.6835 - precision: 0.5849 - recall: 0.7595 - val_loss: 4.6179 - val_accuracy: 0.3973 - val_precision: 0.3973 - val_recall: 1.0000
# Epoch 4/20
# 226/226 [==============================] - 108s 480ms/step - loss: 1.1694 - accuracy: 0.6806 - precision: 0.5845 - recall: 0.7539 - val_loss: 1.4018 - val_accuracy: 0.6629 - val_precision: 0.6452 - val_recall: 0.3371
# Epoch 5/20
# 226/226 [==============================] - 107s 473ms/step - loss: 1.1841 - accuracy: 0.6827 - precision: 0.5794 - recall: 0.7640 - val_loss: 1.8419 - val_accuracy: 0.6004 - val_precision: 0.4985 - val_recall: 0.9213
# Epoch 6/20
# 226/226 [==============================] - 107s 475ms/step - loss: 1.2092 - accuracy: 0.6736 - precision: 0.5795 - recall: 0.7509 - val_loss: 3.1056 - val_accuracy: 0.6027 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 226/226 [==============================] - 108s 479ms/step - loss: 1.2027 - accuracy: 0.6844 - precision: 0.5857 - recall: 0.7539 - val_loss: 1.2023 - val_accuracy: 0.7165 - val_precision: 0.6123 - val_recall: 0.7809
# Epoch 8/20
# 226/226 [==============================] - 107s 476ms/step - loss: 1.2307 - accuracy: 0.6829 - precision: 0.5895 - recall: 0.7582 - val_loss: 1.1220 - val_accuracy: 0.7299 - val_precision: 0.6647 - val_recall: 0.6461
# Epoch 9/20
# 226/226 [==============================] - 107s 474ms/step - loss: 1.1871 - accuracy: 0.6879 - precision: 0.5894 - recall: 0.7665 - val_loss: 1.1754 - val_accuracy: 0.7188 - val_precision: 0.6226 - val_recall: 0.7416
# Epoch 10/20
# 226/226 [==============================] - 107s 474ms/step - loss: 1.1656 - accuracy: 0.6974 - precision: 0.5994 - recall: 0.7672 - val_loss: 1.1385 - val_accuracy: 0.7121 - val_precision: 0.6601 - val_recall: 0.5674
# Epoch 11/20
# 226/226 [==============================] - 108s 480ms/step - loss: 1.1801 - accuracy: 0.6872 - precision: 0.5881 - recall: 0.7611 - val_loss: 1.1492 - val_accuracy: 0.7188 - val_precision: 0.6646 - val_recall: 0.5899
# Epoch 12/20
# 226/226 [==============================] - 108s 479ms/step - loss: 1.1620 - accuracy: 0.6890 - precision: 0.5894 - recall: 0.7707 - val_loss: 1.1433 - val_accuracy: 0.7188 - val_precision: 0.6585 - val_recall: 0.6067
# Epoch 13/20
# 226/226 [==============================] - 108s 478ms/step - loss: 1.1642 - accuracy: 0.6945 - precision: 0.5975 - recall: 0.7747 - val_loss: 1.1449 - val_accuracy: 0.7188 - val_precision: 0.6585 - val_recall: 0.6067
# Epoch 14/20
# 226/226 [==============================] - 106s 472ms/step - loss: 1.1418 - accuracy: 0.6993 - precision: 0.6009 - recall: 0.7811 - val_loss: 1.1481 - val_accuracy: 0.7165 - val_precision: 0.6564 - val_recall: 0.6011
# Epoch 15/20
# 226/226 [==============================] - 107s 477ms/step - loss: 1.1856 - accuracy: 0.6928 - precision: 0.5930 - recall: 0.7663 - val_loss: 1.1496 - val_accuracy: 0.7165 - val_precision: 0.6564 - val_recall: 0.6011
# Epoch 16/20
# 226/226 [==============================] - 107s 476ms/step - loss: 1.1684 - accuracy: 0.6889 - precision: 0.5904 - recall: 0.7622 - val_loss: 1.1522 - val_accuracy: 0.7165 - val_precision: 0.6564 - val_recall: 0.6011
# Epoch 17/20
# 226/226 [==============================] - 109s 483ms/step - loss: 1.1679 - accuracy: 0.6854 - precision: 0.5854 - recall: 0.7605 - val_loss: 1.1524 - val_accuracy: 0.7165 - val_precision: 0.6564 - val_recall: 0.6011
# Epoch 18/20
# 226/226 [==============================] - 107s 476ms/step - loss: 1.1769 - accuracy: 0.6967 - precision: 0.5951 - recall: 0.7713 - val_loss: 1.1489 - val_accuracy: 0.7165 - val_precision: 0.6564 - val_recall: 0.6011
# Epoch 19/20
# 226/226 [==============================] - 108s 479ms/step - loss: 1.1778 - accuracy: 0.6894 - precision: 0.5876 - recall: 0.7635 - val_loss: 1.1436 - val_accuracy: 0.7165 - val_precision: 0.6564 - val_recall: 0.6011
# Epoch 20/20
# 226/226 [==============================] - 108s 477ms/step - loss: 1.1957 - accuracy: 0.6894 - precision: 0.5901 - recall: 0.7561 - val_loss: 1.1448 - val_accuracy: 0.7165 - val_precision: 0.6564 - val_recall: 0.6011

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_pneu.history[met])
    ax[i].plot(history_dpnet_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 31ms/step - loss: 1.0841 - accuracy: 0.7367 - precision: 0.6775 - recall: 0.6538
# Loss of the model is -  1.0840551853179932
# Accuracy of the model is -  73.67256879806519 %
# Precision of the model is -  0.677480936050415
# Recall of the model is -  0.6537753343582153

# %% [markdown]
# ## Evaluation

# %%
models = [
    dpnet_relu,
    dpnet,
    dpnet_logits,
    dpnet_nobn,
    dpnet_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating DP-Net-relu ...
# 43/43 [==============================] - 1s 31ms/step - loss: 0.8033 - accuracy: 0.6999 - precision: 0.6227 - recall: 0.6354
#
#
# Evaluating DP-Net ...
# 43/43 [==============================] - 1s 31ms/step - loss: 1.0954 - accuracy: 0.7006 - precision: 0.6330 - recall: 0.6004
#
#
# Evaluating DP-Net-logits ...
# 43/43 [==============================] - 1s 31ms/step - loss: 1.0398 - accuracy: 0.7109 - precision: 0.6327 - recall: 0.6630
#
#
# Evaluating DP-Net-nobn ...
# 43/43 [==============================] - 1s 31ms/step - loss: 1.4010 - accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating DP-Net-pneu ...
# 43/43 [==============================] - 1s 29ms/step - loss: 1.0841 - accuracy: 0.7367 - precision: 0.6775 - recall: 0.6538

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 1.000

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 1.0
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.442% and noise_multiplier = 1.2673231247985364 iterated over 4520 steps satisfies differential privacy with eps = 1 and delta = 0.0001.
# 1.2673231247985364

# %% [markdown]
# #### Membership Inference Attack

# %%
def compute_attack_inputs(attack_data):
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant
    # get labels
    labels = []
    for x, y in attack_data.as_numpy_iterator():
        labels.append(y[0])
    # predict
    probs = model.predict(attack_data)
    # compute loss
    losses = np.array([x[0] for x in bc(constant([[y] for y in labels]), constant(probs), from_logits=False).numpy()])
    
    return (np.array(probs), np.array(losses), np.array(labels))

# run membership inference attack
def run_mia(model, train_attack_input, test_attack_input):
    # prepare attacks
    probs_train, loss_train, labels_train = train_attack_input
    probs_test, loss_test, labels_test = test_attack_input

    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = labels_train,
        labels_test = labels_test
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
        by_classification_correctness = True
    )

    attack_types = [
        #AttackType.THRESHOLD_ATTACK, # logistic was always better, so no threshold to save time
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    #plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    #plt.show()

    # print a user-friendly summary of the attacks
    #print(attacks_result.summary(by_slices=False))

    max_auc = attacks_result.get_result_with_max_auc().get_auc()
    max_adv = attacks_result.get_result_with_max_attacker_advantage().get_attacker_advantage()

    return max_auc, max_adv

# epsilon estimation based on attack, metric adapted for AUC from https://paperswithcode.com/paper/antipodes-of-label-differential-privacy-pate
def empirical_eps(auc):
    if auc <= 0.5:
        return 0
    if auc == 1:
        return np.inf
    return np.log(auc / (1 - auc))

from contextlib import contextmanager
import sys
@contextmanager
def suppress_stdout():
    with open(os.devnull, "w") as devnull:
        old_stdout = sys.stdout
        sys.stdout = devnull
        try:  
            yield
        finally:
            sys.stdout = old_stdout

# %%
import scipy.stats as st

for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    SAMPLE_NB = 100
    
    train_attack_input = compute_attack_inputs(train_attack_data)
    test_attack_input = compute_attack_inputs(test_attack_data)

    aucs = []
    advs = []
    emp_eps = []
    for i in range(SAMPLE_NB):
        with suppress_stdout():
            max_auc, max_adv = run_mia(model, train_attack_input, test_attack_input)
        aucs.append(max_auc)
        advs.append(max_adv)
        emp_eps.append(empirical_eps(max_auc))

    auc_low, auc_high = st.t.interval(0.95, len(aucs)-1, loc=np.mean(aucs), scale=st.sem(aucs))
    adv_low, adv_high = st.t.interval(0.95, len(advs)-1, loc=np.mean(advs), scale=st.sem(advs))
    eps_low, eps_high = st.t.interval(0.95, len(emp_eps)-1, loc=np.mean(emp_eps), scale=st.sem(emp_eps))

    print('95%%-CI based on %i attack samples'%(SAMPLE_NB))
    print('AUC: %0.2f-%0.2f'%(auc_low, auc_high))
    print('Attacker advantage: %0.2f-%0.2f'%(adv_low, adv_high))
    print('Empirical epsilon bounds from AUC: %0.2f-%0.2f\n'%(eps_low, eps_high))
# Out:
# Membership Inference Attack on DP-Net-relu...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.13-0.16
#
# Membership Inference Attack on DP-Net...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.53
# Attacker advantage: 0.11-0.13
# Empirical epsilon bounds from AUC: 0.11-0.14
#
# Membership Inference Attack on DP-Net-logits...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.13-0.16
#
# Membership Inference Attack on DP-Net-nobn...
# 95%-CI based on 100 attack samples
# AUC: 0.53-0.54
# Attacker advantage: 0.12-0.13
# Empirical epsilon bounds from AUC: 0.13-0.17
#
# Membership Inference Attack on DP-Net-pneu...
# 95%-CI based on 100 attack samples
# AUC: 0.55-0.55
# Attacker advantage: 0.13-0.14
# Empirical epsilon bounds from AUC: 0.18-0.22
