# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install 'tensorflow-privacy==0.5.2'
#!pip -q install git+https://github.com/tensorflow/privacy #TODO fix this
# Out:
#      |████████████████████████████████| 194kB 7.3MB/s

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.experimental.preprocessing import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

#import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 780MB [00:04, 170MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 2.083
L2_NORM_CLIP = 1.5
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-test split
x_train, x_test, y_train, y_test = train_test_split(files, labels, test_size=TEST_SPLIT, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=VAL_SPLIT, random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7299, Val: 385, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4380, 'COVID-19': 2919}
# val set:  {'normal': 227, 'COVID-19': 158}
# test set:   {'normal': 817, 'COVID-19': 539}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# seperate train labels and images for attacks
x_train_attack = prepare_dataset(train_ds,
                                 pre=True,
                                 shuffle=True,
                                 repeat=False,
                                 batch=1,
                                 augment=False,
                                 cache=False)

y_train_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(x_train_attack):
    y_train_attack.append(y)

# seperate test labels and images for attacks
x_test_attack = prepare_dataset(test_ds,
                                pre=True,
                                shuffle=False,
                                repeat=False,
                                batch=1,
                                augment=False,
                                cache=False)

y_test_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(x_test_attack):
    y_test_attack.append(y)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## DP-Net - relu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_relu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='relu'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-relu')
    return dpnet

# %%
dpnet_relu = dpnet_relu_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_relu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_relu.summary()
# Out:
# Model: "DP-Net-relu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization (BatchNo (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                230432
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_relu = dpnet_relu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 146s 492ms/step - loss: 0.8733 - accuracy: 0.5202 - precision: 0.4211 - recall: 0.5307 - val_loss: 0.8357 - val_accuracy: 0.4375 - val_precision: 0.4194 - val_recall: 0.9557
# Epoch 2/20
# 228/228 [==============================] - 107s 470ms/step - loss: 0.8440 - accuracy: 0.5647 - precision: 0.4698 - recall: 0.5626 - val_loss: 0.6318 - val_accuracy: 0.6276 - val_precision: 0.5472 - val_recall: 0.5506
# Epoch 3/20
# 228/228 [==============================] - 108s 475ms/step - loss: 0.7924 - accuracy: 0.5922 - precision: 0.4949 - recall: 0.5866 - val_loss: 0.7178 - val_accuracy: 0.5964 - val_precision: 0.5211 - val_recall: 0.2342
# Epoch 4/20
# 228/228 [==============================] - 107s 470ms/step - loss: 0.8398 - accuracy: 0.6015 - precision: 0.5049 - recall: 0.5898 - val_loss: 0.8157 - val_accuracy: 0.6146 - val_precision: 0.5269 - val_recall: 0.6203
# Epoch 5/20
# 228/228 [==============================] - 106s 467ms/step - loss: 0.8146 - accuracy: 0.6179 - precision: 0.5260 - recall: 0.6017 - val_loss: 0.8467 - val_accuracy: 0.6224 - val_precision: 0.5320 - val_recall: 0.6835
# Epoch 6/20
# 228/228 [==============================] - 105s 463ms/step - loss: 0.8046 - accuracy: 0.6212 - precision: 0.5274 - recall: 0.5939 - val_loss: 0.8296 - val_accuracy: 0.6406 - val_precision: 0.5515 - val_recall: 0.6772
# Epoch 7/20
# 228/228 [==============================] - 106s 466ms/step - loss: 0.8198 - accuracy: 0.6207 - precision: 0.5180 - recall: 0.5911 - val_loss: 0.8012 - val_accuracy: 0.6328 - val_precision: 0.5450 - val_recall: 0.6519
# Epoch 8/20
# 228/228 [==============================] - 106s 465ms/step - loss: 0.8350 - accuracy: 0.6182 - precision: 0.5172 - recall: 0.5949 - val_loss: 0.7942 - val_accuracy: 0.6302 - val_precision: 0.5435 - val_recall: 0.6329
# Epoch 9/20
# 228/228 [==============================] - 105s 462ms/step - loss: 0.8505 - accuracy: 0.6053 - precision: 0.5097 - recall: 0.5744 - val_loss: 0.7945 - val_accuracy: 0.6276 - val_precision: 0.5405 - val_recall: 0.6329
# Epoch 10/20
# 228/228 [==============================] - 106s 467ms/step - loss: 0.8234 - accuracy: 0.6183 - precision: 0.5211 - recall: 0.5959 - val_loss: 0.8027 - val_accuracy: 0.6276 - val_precision: 0.5401 - val_recall: 0.6392
# Epoch 11/20
# 228/228 [==============================] - 106s 467ms/step - loss: 0.8212 - accuracy: 0.6108 - precision: 0.5107 - recall: 0.5847 - val_loss: 0.8089 - val_accuracy: 0.6328 - val_precision: 0.5450 - val_recall: 0.6519
# Epoch 12/20
# 228/228 [==============================] - 107s 469ms/step - loss: 0.8386 - accuracy: 0.6133 - precision: 0.5164 - recall: 0.5931 - val_loss: 0.7919 - val_accuracy: 0.6276 - val_precision: 0.5405 - val_recall: 0.6329
# Epoch 13/20
# 228/228 [==============================] - 107s 469ms/step - loss: 0.8529 - accuracy: 0.6132 - precision: 0.5146 - recall: 0.5889 - val_loss: 0.7977 - val_accuracy: 0.6302 - val_precision: 0.5430 - val_recall: 0.6392
# Epoch 14/20
# 228/228 [==============================] - 107s 470ms/step - loss: 0.8207 - accuracy: 0.6245 - precision: 0.5215 - recall: 0.6051 - val_loss: 0.7857 - val_accuracy: 0.6276 - val_precision: 0.5410 - val_recall: 0.6266
# Epoch 15/20
# 228/228 [==============================] - 106s 464ms/step - loss: 0.8082 - accuracy: 0.6294 - precision: 0.5318 - recall: 0.6093 - val_loss: 0.7825 - val_accuracy: 0.6276 - val_precision: 0.5414 - val_recall: 0.6203
# Epoch 16/20
# 228/228 [==============================] - 106s 468ms/step - loss: 0.8273 - accuracy: 0.6226 - precision: 0.5251 - recall: 0.5996 - val_loss: 0.7845 - val_accuracy: 0.6250 - val_precision: 0.5385 - val_recall: 0.6203
# Epoch 17/20
# 228/228 [==============================] - 106s 465ms/step - loss: 0.8353 - accuracy: 0.6156 - precision: 0.5170 - recall: 0.5939 - val_loss: 0.7892 - val_accuracy: 0.6302 - val_precision: 0.5435 - val_recall: 0.6329
# Epoch 18/20
# 228/228 [==============================] - 105s 462ms/step - loss: 0.8183 - accuracy: 0.6240 - precision: 0.5239 - recall: 0.6084 - val_loss: 0.7860 - val_accuracy: 0.6250 - val_precision: 0.5385 - val_recall: 0.6203
# Epoch 19/20
# 228/228 [==============================] - 106s 465ms/step - loss: 0.8372 - accuracy: 0.6074 - precision: 0.5038 - recall: 0.5830 - val_loss: 0.7987 - val_accuracy: 0.6302 - val_precision: 0.5426 - val_recall: 0.6456
# Epoch 20/20
# 228/228 [==============================] - 107s 471ms/step - loss: 0.8303 - accuracy: 0.6053 - precision: 0.5103 - recall: 0.5806 - val_loss: 0.7990 - val_accuracy: 0.6276 - val_precision: 0.5401 - val_recall: 0.6392

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_relu.history[met])
    ax[i].plot(history_dpnet_relu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_relu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 3s 65ms/step - loss: 0.7795 - accuracy: 0.6733 - precision: 0.5708 - recall: 0.7180
# Loss of the model is -  0.7794986367225647
# Accuracy of the model is -  67.33038425445557 %
# Precision of the model is -  0.5707964897155762
# Recall of the model is -  0.7179962992668152

# %% [markdown]
# ## DP-Net - CNN Architecture for DP-SGD
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net')
    return dpnet

# %%
dpnet = dpnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet.summary()
# Out:
# Model: "DP-Net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet = dpnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 115s 476ms/step - loss: 0.9163 - accuracy: 0.5060 - precision: 0.4095 - recall: 0.5328 - val_loss: 0.6211 - val_accuracy: 0.6484 - val_precision: 0.5714 - val_recall: 0.5823
# Epoch 2/20
# 228/228 [==============================] - 108s 473ms/step - loss: 0.8992 - accuracy: 0.6099 - precision: 0.5149 - recall: 0.6279 - val_loss: 0.8278 - val_accuracy: 0.6589 - val_precision: 0.5754 - val_recall: 0.6519
# Epoch 3/20
# 228/228 [==============================] - 106s 467ms/step - loss: 0.9637 - accuracy: 0.6325 - precision: 0.5336 - recall: 0.6367 - val_loss: 0.9917 - val_accuracy: 0.6615 - val_precision: 0.5787 - val_recall: 0.6519
# Epoch 4/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.0971 - accuracy: 0.6335 - precision: 0.5384 - recall: 0.6231 - val_loss: 0.9793 - val_accuracy: 0.6536 - val_precision: 0.5723 - val_recall: 0.6266
# Epoch 5/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1078 - accuracy: 0.6363 - precision: 0.5399 - recall: 0.6291 - val_loss: 0.9840 - val_accuracy: 0.6406 - val_precision: 0.5568 - val_recall: 0.6203
# Epoch 6/20
# 228/228 [==============================] - 108s 473ms/step - loss: 1.1067 - accuracy: 0.6357 - precision: 0.5451 - recall: 0.6267 - val_loss: 0.9810 - val_accuracy: 0.6536 - val_precision: 0.5731 - val_recall: 0.6203
# Epoch 7/20
# 228/228 [==============================] - 108s 475ms/step - loss: 1.0985 - accuracy: 0.6442 - precision: 0.5532 - recall: 0.6343 - val_loss: 0.9796 - val_accuracy: 0.6562 - val_precision: 0.5774 - val_recall: 0.6139
# Epoch 8/20
# 228/228 [==============================] - 108s 476ms/step - loss: 1.1035 - accuracy: 0.6392 - precision: 0.5439 - recall: 0.6391 - val_loss: 0.9762 - val_accuracy: 0.6562 - val_precision: 0.5774 - val_recall: 0.6139
# Epoch 9/20
# 228/228 [==============================] - 109s 480ms/step - loss: 1.1148 - accuracy: 0.6347 - precision: 0.5438 - recall: 0.6317 - val_loss: 0.9790 - val_accuracy: 0.6562 - val_precision: 0.5774 - val_recall: 0.6139
# Epoch 10/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.0785 - accuracy: 0.6476 - precision: 0.5557 - recall: 0.6400 - val_loss: 0.9850 - val_accuracy: 0.6510 - val_precision: 0.5698 - val_recall: 0.6203
# Epoch 11/20
# 228/228 [==============================] - 108s 473ms/step - loss: 1.1011 - accuracy: 0.6387 - precision: 0.5494 - recall: 0.6306 - val_loss: 0.9939 - val_accuracy: 0.6432 - val_precision: 0.5593 - val_recall: 0.6266
# Epoch 12/20
# 228/228 [==============================] - 108s 476ms/step - loss: 1.1391 - accuracy: 0.6314 - precision: 0.5379 - recall: 0.6293 - val_loss: 0.9816 - val_accuracy: 0.6562 - val_precision: 0.5774 - val_recall: 0.6139
# Epoch 13/20
# 228/228 [==============================] - 107s 471ms/step - loss: 1.1031 - accuracy: 0.6370 - precision: 0.5450 - recall: 0.6354 - val_loss: 0.9841 - val_accuracy: 0.6562 - val_precision: 0.5774 - val_recall: 0.6139
# Epoch 14/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.0953 - accuracy: 0.6397 - precision: 0.5437 - recall: 0.6364 - val_loss: 0.9710 - val_accuracy: 0.6615 - val_precision: 0.5843 - val_recall: 0.6139
# Epoch 15/20
# 228/228 [==============================] - 106s 466ms/step - loss: 1.0902 - accuracy: 0.6400 - precision: 0.5405 - recall: 0.6352 - val_loss: 0.9729 - val_accuracy: 0.6589 - val_precision: 0.5818 - val_recall: 0.6076
# Epoch 16/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1013 - accuracy: 0.6404 - precision: 0.5425 - recall: 0.6307 - val_loss: 0.9724 - val_accuracy: 0.6615 - val_precision: 0.5843 - val_recall: 0.6139
# Epoch 17/20
# 228/228 [==============================] - 107s 468ms/step - loss: 1.1020 - accuracy: 0.6302 - precision: 0.5386 - recall: 0.6310 - val_loss: 0.9784 - val_accuracy: 0.6562 - val_precision: 0.5774 - val_recall: 0.6139
# Epoch 18/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.0749 - accuracy: 0.6428 - precision: 0.5414 - recall: 0.6450 - val_loss: 0.9749 - val_accuracy: 0.6615 - val_precision: 0.5843 - val_recall: 0.6139
# Epoch 19/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.1305 - accuracy: 0.6343 - precision: 0.5340 - recall: 0.6305 - val_loss: 0.9842 - val_accuracy: 0.6510 - val_precision: 0.5698 - val_recall: 0.6203
# Epoch 20/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1272 - accuracy: 0.6257 - precision: 0.5289 - recall: 0.6276 - val_loss: 0.9860 - val_accuracy: 0.6536 - val_precision: 0.5723 - val_recall: 0.6266

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet.history[met])
    ax[i].plot(history_dpnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 29ms/step - loss: 0.9994 - accuracy: 0.6652 - precision: 0.5661 - recall: 0.6753
# Loss of the model is -  0.9993550181388855
# Accuracy of the model is -  66.51917695999146 %
# Precision of the model is -  0.5660964250564575
# Recall of the model is -  0.6753246784210205

# %% [markdown]
# ## DP-Net nobn
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_nobn_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-nobn')
    return dpnet

# %%
dpnet_nobn = dpnet_nobn_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_nobn.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_nobn.summary()
# Out:
# Model: "DP-Net-nobn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                230432
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 241,777
# Trainable params: 241,777
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_nobn = dpnet_nobn.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 98s 408ms/step - loss: 1.1686 - accuracy: 0.5910 - precision: 0.3802 - recall: 0.0278 - val_loss: 1.3186 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 228/228 [==============================] - 93s 408ms/step - loss: 1.5083 - accuracy: 0.5932 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2639 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 228/228 [==============================] - 93s 408ms/step - loss: 1.5105 - accuracy: 0.5991 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2756 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 228/228 [==============================] - 93s 411ms/step - loss: 1.5411 - accuracy: 0.5963 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3654 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.6104 - accuracy: 0.5951 - precision: 0.6157 - recall: 3.2305e-04 - val_loss: 1.2658 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 228/228 [==============================] - 94s 412ms/step - loss: 1.5280 - accuracy: 0.5958 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2707 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 228/228 [==============================] - 92s 407ms/step - loss: 1.5475 - accuracy: 0.5946 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2704 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 228/228 [==============================] - 93s 408ms/step - loss: 1.5582 - accuracy: 0.5910 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2689 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.5461 - accuracy: 0.5955 - precision: 0.7293 - recall: 4.3720e-04 - val_loss: 1.2689 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 228/228 [==============================] - 93s 408ms/step - loss: 1.5296 - accuracy: 0.5998 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2685 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 228/228 [==============================] - 93s 409ms/step - loss: 1.5315 - accuracy: 0.5994 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2686 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.5382 - accuracy: 0.5977 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2685 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 228/228 [==============================] - 92s 403ms/step - loss: 1.5252 - accuracy: 0.5990 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2683 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 228/228 [==============================] - 93s 407ms/step - loss: 1.5191 - accuracy: 0.6007 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2681 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.5375 - accuracy: 0.5976 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2681 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.5132 - accuracy: 0.6022 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2682 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.5358 - accuracy: 0.5970 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2684 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.5429 - accuracy: 0.5939 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2685 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.5580 - accuracy: 0.5902 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2683 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 228/228 [==============================] - 93s 408ms/step - loss: 1.5603 - accuracy: 0.5922 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.2684 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_nobn.history[met])
    ax[i].plot(history_dpnet_nobn.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_nobn.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 29ms/step - loss: 1.2149 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss of the model is -  1.2148956060409546
# Accuracy of the model is -  60.25073528289795 %
# Precision of the model is -  0.0
# Recall of the model is -  0.0

# %% [markdown]
# ## DP-Net pneu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_pneu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-pneu')
    return dpnet

# %%
dpnet_pneu = dpnet_pneu_builder()

# load weights from pneumonia pretraining
dpnet_pneu.load_weights(weights_path+'dpnet_tanh_public_weights.h5')

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_pneu.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_pneu.summary()
# Out:
# Model: "DP-Net-pneu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_pneu = dpnet_pneu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 115s 477ms/step - loss: 0.8348 - accuracy: 0.6735 - precision: 0.5688 - recall: 0.7862 - val_loss: 6.0879 - val_accuracy: 0.4089 - val_precision: 0.4099 - val_recall: 0.9937
# Epoch 2/20
# 228/228 [==============================] - 106s 468ms/step - loss: 0.9427 - accuracy: 0.6700 - precision: 0.5619 - recall: 0.7720 - val_loss: 3.7382 - val_accuracy: 0.4401 - val_precision: 0.4228 - val_recall: 0.9873
# Epoch 3/20
# 228/228 [==============================] - 107s 471ms/step - loss: 1.0166 - accuracy: 0.6773 - precision: 0.5798 - recall: 0.7505 - val_loss: 4.7088 - val_accuracy: 0.4115 - val_precision: 0.4115 - val_recall: 1.0000
# Epoch 4/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.0563 - accuracy: 0.6774 - precision: 0.5801 - recall: 0.7392 - val_loss: 1.3797 - val_accuracy: 0.6484 - val_precision: 0.5657 - val_recall: 0.6266
# Epoch 5/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1230 - accuracy: 0.6772 - precision: 0.5762 - recall: 0.7621 - val_loss: 1.4435 - val_accuracy: 0.6354 - val_precision: 0.6154 - val_recall: 0.3038
# Epoch 6/20
# 228/228 [==============================] - 107s 471ms/step - loss: 1.1071 - accuracy: 0.6813 - precision: 0.5777 - recall: 0.7533 - val_loss: 1.3935 - val_accuracy: 0.6667 - val_precision: 0.6875 - val_recall: 0.3481
# Epoch 7/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1422 - accuracy: 0.6730 - precision: 0.5762 - recall: 0.7490 - val_loss: 1.2270 - val_accuracy: 0.6589 - val_precision: 0.5971 - val_recall: 0.5253
# Epoch 8/20
# 228/228 [==============================] - 108s 473ms/step - loss: 1.1325 - accuracy: 0.6678 - precision: 0.5638 - recall: 0.7555 - val_loss: 1.2809 - val_accuracy: 0.6641 - val_precision: 0.6306 - val_recall: 0.4430
# Epoch 9/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1176 - accuracy: 0.6730 - precision: 0.5658 - recall: 0.7575 - val_loss: 1.2235 - val_accuracy: 0.6667 - val_precision: 0.6042 - val_recall: 0.5506
# Epoch 10/20
# 228/228 [==============================] - 108s 473ms/step - loss: 1.1492 - accuracy: 0.6714 - precision: 0.5672 - recall: 0.7554 - val_loss: 1.2695 - val_accuracy: 0.6745 - val_precision: 0.5943 - val_recall: 0.6582
# Epoch 11/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1246 - accuracy: 0.6756 - precision: 0.5789 - recall: 0.7557 - val_loss: 1.2466 - val_accuracy: 0.6641 - val_precision: 0.6090 - val_recall: 0.5127
# Epoch 12/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.1297 - accuracy: 0.6699 - precision: 0.5666 - recall: 0.7565 - val_loss: 1.2370 - val_accuracy: 0.6667 - val_precision: 0.6027 - val_recall: 0.5570
# Epoch 13/20
# 228/228 [==============================] - 107s 471ms/step - loss: 1.1046 - accuracy: 0.6688 - precision: 0.5636 - recall: 0.7596 - val_loss: 1.2332 - val_accuracy: 0.6615 - val_precision: 0.5921 - val_recall: 0.5696
# Epoch 14/20
# 228/228 [==============================] - 107s 468ms/step - loss: 1.1132 - accuracy: 0.6780 - precision: 0.5676 - recall: 0.7746 - val_loss: 1.2421 - val_accuracy: 0.6641 - val_precision: 0.5986 - val_recall: 0.5570
# Epoch 15/20
# 228/228 [==============================] - 107s 468ms/step - loss: 1.1392 - accuracy: 0.6807 - precision: 0.5746 - recall: 0.7638 - val_loss: 1.2429 - val_accuracy: 0.6667 - val_precision: 0.6027 - val_recall: 0.5570
# Epoch 16/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1324 - accuracy: 0.6740 - precision: 0.5765 - recall: 0.7594 - val_loss: 1.2455 - val_accuracy: 0.6641 - val_precision: 0.6014 - val_recall: 0.5443
# Epoch 17/20
# 228/228 [==============================] - 106s 466ms/step - loss: 1.1060 - accuracy: 0.6818 - precision: 0.5752 - recall: 0.7696 - val_loss: 1.2379 - val_accuracy: 0.6641 - val_precision: 0.5973 - val_recall: 0.5633
# Epoch 18/20
# 228/228 [==============================] - 106s 465ms/step - loss: 1.1224 - accuracy: 0.6762 - precision: 0.5766 - recall: 0.7532 - val_loss: 1.2374 - val_accuracy: 0.6641 - val_precision: 0.5986 - val_recall: 0.5570
# Epoch 19/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1520 - accuracy: 0.6686 - precision: 0.5694 - recall: 0.7571 - val_loss: 1.2366 - val_accuracy: 0.6667 - val_precision: 0.6027 - val_recall: 0.5570
# Epoch 20/20
# 228/228 [==============================] - 106s 465ms/step - loss: 1.1075 - accuracy: 0.6783 - precision: 0.5776 - recall: 0.7615 - val_loss: 1.2294 - val_accuracy: 0.6641 - val_precision: 0.5973 - val_recall: 0.5633

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_pneu.history[met])
    ax[i].plot(history_dpnet_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 28ms/step - loss: 1.1129 - accuracy: 0.7139 - precision: 0.6531 - recall: 0.5974
# Loss of the model is -  1.1129469871520996
# Accuracy of the model is -  71.38643264770508 %
# Precision of the model is -  0.6531440019607544
# Recall of the model is -  0.5974025726318359

# %% [markdown]
# ## Evaluation

# %%
models = [
    dpnet_relu,
    dpnet,
    dpnet_nobn,
    dpnet_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating DP-Net-relu ...
# 43/43 [==============================] - 1s 28ms/step - loss: 0.7795 - accuracy: 0.6733 - precision: 0.5708 - recall: 0.7180
#
#
# Evaluating DP-Net ...
# 43/43 [==============================] - 1s 28ms/step - loss: 0.9994 - accuracy: 0.6652 - precision: 0.5661 - recall: 0.6753
#
#
# Evaluating DP-Net-nobn ...
# 43/43 [==============================] - 1s 29ms/step - loss: 1.2149 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating DP-Net-pneu ...
# 43/43 [==============================] - 1s 28ms/step - loss: 1.1129 - accuracy: 0.7139 - precision: 0.6531 - recall: 0.5974

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 0.500

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 0.5
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.438% and noise_multiplier = 2.083147287949324 iterated over 4562 steps satisfies differential privacy with eps = 0.5 and delta = 0.0001.
# 2.083147287949324

# %% [markdown]
# #### Membership Inference Attack

# %%
# run membership inference attack
def run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack):
    # predict on train
    probs_train = model.predict(x_train_attack)
    # predict on test
    probs_test = model.predict(x_test_attack)

    # only label as output instead of prob
    #probs_train = np.round(logits_train)
    #probs_test = np.round(logits_test)

    # compute losses
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant

    loss_train = np.array([x[0] for x in bc(constant([[y] for y in y_train_attack]), constant(probs_train), from_logits=False).numpy()])
    loss_test = np.array([x[0] for x in bc(constant([[y] for y in y_test_attack]), constant(probs_test), from_logits=False).numpy()])

    # labels
    train_labels = np.array(y_train_attack)
    test_labels = np.array(y_test_attack)

    # prepare attacks
    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = train_labels,
        labels_test = test_labels
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,)

    attack_types = [
        AttackType.THRESHOLD_ATTACK,
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    plt.show()

    # print a user-friendly summary of the attacks
    print(attacks_result.summary(by_slices=False)) #TODO fix low auc sometimes

# %%
for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack)
    print('\n')
# Out:
# Membership Inference Attack on DP-Net-relu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   THRESHOLD_ATTACK (with 2919 training and 539 test examples) achieved an AUC of 0.36 on slice CLASS=1
#   THRESHOLD_ATTACK (with 2919 training and 539 test examples) achieved an advantage of 0.24 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.63 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.26 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-nobn...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.65 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.26 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-pneu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.63 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.27 on slice CLASS=1
