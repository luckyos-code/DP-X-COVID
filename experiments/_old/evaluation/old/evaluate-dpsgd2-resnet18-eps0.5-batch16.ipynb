# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install 'tensorflow-privacy==0.5.2'
#!pip -q install git+https://github.com/tensorflow/privacy #TODO fix this
# Out:
#      |████████████████████████████████| 194kB 4.3MB/s

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.experimental.preprocessing import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SingleAttackResult
from tensorflow_privacy.privacy.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 780MB [00:05, 130MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 16
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 1.548
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-test split
x_train, x_test, y_train, y_test = train_test_split(files, labels, test_size=TEST_SPLIT, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=VAL_SPLIT, random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7299, Val: 385, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4380, 'COVID-19': 2919}
# val set:  {'normal': 227, 'COVID-19': 158}
# test set:   {'normal': 817, 'COVID-19': 539}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# set for attack on train set
train_attack_data = prepare_dataset(train_ds,
                                    pre=True,
                                    shuffle=False,
                                    repeat=False,
                                    batch=1,
                                    augment=False,
                                    cache=False)

# set for attack on test set
test_attack_data = prepare_dataset(test_ds,
                                   pre=True,
                                   shuffle=False,
                                   repeat=False,
                                   batch=1,
                                   augment=False,
                                   cache=False)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## ResNet18V2 relu
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('relu', name=name + '_preact_relu')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride)(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('relu', name=name + '_1_relu')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('relu', name=name + '_2_relu')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    x = stack_fn(x)
    x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
    x = Activation('relu', name='post_relu')(x)
    # Create model.
    model = tf.keras.models.Model(input, x, name=model_name)
    return model

def ResNet18V2(input):
    def stack_fn(x):
        x = resnet_stack(x, 16, 2, name='conv2') # original: 64
        x = resnet_stack(x, 32, 2, name='conv3')
        x = resnet_stack(x, 64, 2, name='conv4')
        x = resnet_stack(x, 128, 2, stride1=1, name='conv5')
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_relu_builder():
    # ResNet18V2 without head
    resnet18 = ResNet18V2(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet18V2-relu')
    
    return model

# %%
resnet18_relu = resnet18_relu_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet18_relu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet18_relu.summary()
# Out:
# Model: "ResNet18V2-relu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_6 (ModuleWrap (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet18_relu = resnet18_relu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 456/456 [==============================] - 200s 320ms/step - loss: 0.6909 - accuracy: 0.5864 - precision: 0.4822 - recall: 0.4068 - val_loss: 0.7984 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 456/456 [==============================] - 142s 312ms/step - loss: 0.8286 - accuracy: 0.5939 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.1367 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.0882 - accuracy: 0.5973 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 3.2763 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.3528 - accuracy: 0.5973 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.9788 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.4176 - accuracy: 0.5931 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0823 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.4444 - accuracy: 0.5964 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0315 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.4066 - accuracy: 0.6046 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0367 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.4318 - accuracy: 0.6029 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0331 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.4565 - accuracy: 0.5969 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0366 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.4391 - accuracy: 0.5991 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0320 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 456/456 [==============================] - 143s 313ms/step - loss: 1.4265 - accuracy: 0.6010 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0378 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.4365 - accuracy: 0.5984 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0319 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.4444 - accuracy: 0.5995 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0350 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.4279 - accuracy: 0.6045 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0328 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.4399 - accuracy: 0.6001 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0310 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.4397 - accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0360 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.4375 - accuracy: 0.5997 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0330 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.4272 - accuracy: 0.6023 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0417 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.4279 - accuracy: 0.6041 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0319 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.4490 - accuracy: 0.5957 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0384 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet18_relu.history[met])
    ax[i].plot(history_resnet18_relu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet18_relu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 2s 23ms/step - loss: 1.0004 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss of the model is -  1.0004446506500244
# Accuracy of the model is -  60.25073528289795 %
# Precision of the model is -  0.0
# Recall of the model is -  0.0

# %% [markdown]
# ## ResNet18V2 (DP-SGD)
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('tanh', name=name + '_preact_tanh')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride)(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('tanh', name=name + '_1_tanh')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('tanh', name=name + '_2_tanh')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    x = stack_fn(x)
    x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
    x = Activation('tanh', name='post_tanh')(x)
    # Create model
    model = tf.keras.models.Model(input, x, name=model_name)
    return model
    
def ResNet18V2(input):
    def stack_fn(x):
        x = resnet_stack(x, 16, 2, name='conv2') # original: 64
        x = resnet_stack(x, 32, 2, name='conv3')
        x = resnet_stack(x, 64, 2, name='conv4')
        x = resnet_stack(x, 128, 2, stride1=1, name='conv5')
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_builder():
    # get ResNet18V2 without head
    resnet18 = ResNet18V2(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet18V2')

    return model

# %%
resnet18 = resnet18_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet18.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet18.summary()
# Out:
# Model: "ResNet18V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_7 (ModuleWrap (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet18 = resnet18.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 456/456 [==============================] - 171s 314ms/step - loss: 0.6662 - accuracy: 0.6150 - precision: 0.5159 - recall: 0.6105 - val_loss: 0.7163 - val_accuracy: 0.5859 - val_precision: 0.4762 - val_recall: 0.0633
# Epoch 2/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.6726 - accuracy: 0.6397 - precision: 0.5504 - recall: 0.6012 - val_loss: 0.7603 - val_accuracy: 0.6120 - val_precision: 0.9091 - val_recall: 0.0633
# Epoch 3/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.7172 - accuracy: 0.6524 - precision: 0.5582 - recall: 0.6246 - val_loss: 0.7618 - val_accuracy: 0.6615 - val_precision: 0.7000 - val_recall: 0.3101
# Epoch 4/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.7898 - accuracy: 0.6582 - precision: 0.5701 - recall: 0.6095 - val_loss: 0.8344 - val_accuracy: 0.6484 - val_precision: 0.6322 - val_recall: 0.3481
# Epoch 5/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8043 - accuracy: 0.6679 - precision: 0.5793 - recall: 0.6273 - val_loss: 0.9494 - val_accuracy: 0.6380 - val_precision: 0.5463 - val_recall: 0.7089
# Epoch 6/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8518 - accuracy: 0.6518 - precision: 0.5674 - recall: 0.6115 - val_loss: 0.8635 - val_accuracy: 0.6536 - val_precision: 0.5723 - val_recall: 0.6266
# Epoch 7/20
# 456/456 [==============================] - 142s 312ms/step - loss: 0.8166 - accuracy: 0.6615 - precision: 0.5763 - recall: 0.6228 - val_loss: 0.8523 - val_accuracy: 0.6589 - val_precision: 0.5828 - val_recall: 0.6013
# Epoch 8/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8331 - accuracy: 0.6621 - precision: 0.5739 - recall: 0.6176 - val_loss: 0.8608 - val_accuracy: 0.6641 - val_precision: 0.5868 - val_recall: 0.6203
# Epoch 9/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8381 - accuracy: 0.6652 - precision: 0.5830 - recall: 0.6211 - val_loss: 0.8624 - val_accuracy: 0.6667 - val_precision: 0.5893 - val_recall: 0.6266
# Epoch 10/20
# 456/456 [==============================] - 142s 312ms/step - loss: 0.8169 - accuracy: 0.6666 - precision: 0.5799 - recall: 0.6375 - val_loss: 0.8586 - val_accuracy: 0.6667 - val_precision: 0.5893 - val_recall: 0.6266
# Epoch 11/20
# 456/456 [==============================] - 142s 312ms/step - loss: 0.8272 - accuracy: 0.6599 - precision: 0.5797 - recall: 0.6033 - val_loss: 0.8602 - val_accuracy: 0.6641 - val_precision: 0.5858 - val_recall: 0.6266
# Epoch 12/20
# 456/456 [==============================] - 142s 312ms/step - loss: 0.8344 - accuracy: 0.6583 - precision: 0.5730 - recall: 0.6109 - val_loss: 0.8560 - val_accuracy: 0.6641 - val_precision: 0.5868 - val_recall: 0.6203
# Epoch 13/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8602 - accuracy: 0.6485 - precision: 0.5625 - recall: 0.6027 - val_loss: 0.8614 - val_accuracy: 0.6641 - val_precision: 0.5858 - val_recall: 0.6266
# Epoch 14/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8353 - accuracy: 0.6613 - precision: 0.5715 - recall: 0.6191 - val_loss: 0.8549 - val_accuracy: 0.6641 - val_precision: 0.5868 - val_recall: 0.6203
# Epoch 15/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8198 - accuracy: 0.6653 - precision: 0.5730 - recall: 0.6231 - val_loss: 0.8649 - val_accuracy: 0.6641 - val_precision: 0.5858 - val_recall: 0.6266
# Epoch 16/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8343 - accuracy: 0.6586 - precision: 0.5663 - recall: 0.6158 - val_loss: 0.8584 - val_accuracy: 0.6641 - val_precision: 0.5868 - val_recall: 0.6203
# Epoch 17/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.8502 - accuracy: 0.6505 - precision: 0.5655 - recall: 0.6041 - val_loss: 0.8556 - val_accuracy: 0.6641 - val_precision: 0.5868 - val_recall: 0.6203
# Epoch 18/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8469 - accuracy: 0.6562 - precision: 0.5603 - recall: 0.6131 - val_loss: 0.8564 - val_accuracy: 0.6641 - val_precision: 0.5868 - val_recall: 0.6203
# Epoch 19/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8253 - accuracy: 0.6711 - precision: 0.5784 - recall: 0.6396 - val_loss: 0.8601 - val_accuracy: 0.6641 - val_precision: 0.5858 - val_recall: 0.6266
# Epoch 20/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8385 - accuracy: 0.6585 - precision: 0.5693 - recall: 0.6149 - val_loss: 0.8623 - val_accuracy: 0.6667 - val_precision: 0.5893 - val_recall: 0.6266

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet18.history[met])
    ax[i].plot(history_resnet18.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet18.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 1s 13ms/step - loss: 0.7434 - accuracy: 0.6976 - precision: 0.6122 - recall: 0.6531
# Loss of the model is -  0.7433955073356628
# Accuracy of the model is -  69.76401209831238 %
# Precision of the model is -  0.6121739149093628
# Recall of the model is -  0.6530612111091614

# %% [markdown]
# ## ResNet18V2 logits
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('tanh', name=name + '_preact_tanh')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride)(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('tanh', name=name + '_1_tanh')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('tanh', name=name + '_2_tanh')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    x = stack_fn(x)
    x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
    x = Activation('tanh', name='post_tanh')(x)
    # Create model
    model = tf.keras.models.Model(input, x, name=model_name)
    return model
    
def ResNet18V2(input):
    def stack_fn(x):
        x = resnet_stack(x, 16, 2, name='conv2') # original: 64
        x = resnet_stack(x, 32, 2, name='conv3')
        x = resnet_stack(x, 64, 2, name='conv4')
        x = resnet_stack(x, 128, 2, stride1=1, name='conv5')
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_logits_builder():
    # get ResNet18V2 without head
    resnet18 = ResNet18V2(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet18V2-logits')

    return model

# %%
resnet18_logits = resnet18_logits_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet18_logits.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=False,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet18_logits.summary()
# Out:
# Model: "ResNet18V2-logits"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_8 (ModuleWrap (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet18_logits = resnet18_logits.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# Epoch 1/20
# 456/456 [==============================] - 169s 313ms/step - loss: 0.6661 - accuracy: 0.6118 - precision: 0.5139 - recall: 0.6017 - val_loss: 0.9158 - val_accuracy: 0.4245 - val_precision: 0.4113 - val_recall: 0.9241
# Epoch 2/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.6661 - accuracy: 0.6496 - precision: 0.5624 - recall: 0.6279 - val_loss: 1.2543 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.6965 - accuracy: 0.6616 - precision: 0.5731 - recall: 0.6126 - val_loss: 1.0428 - val_accuracy: 0.5885 - val_precision: 0.5000 - val_recall: 0.0063
# Epoch 4/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.7673 - accuracy: 0.6710 - precision: 0.5856 - recall: 0.6361 - val_loss: 0.9684 - val_accuracy: 0.6250 - val_precision: 0.5315 - val_recall: 0.7468
# Epoch 5/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.7784 - accuracy: 0.6728 - precision: 0.5897 - recall: 0.6332 - val_loss: 0.9790 - val_accuracy: 0.6354 - val_precision: 0.5417 - val_recall: 0.7405
# Epoch 6/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.7974 - accuracy: 0.6699 - precision: 0.5839 - recall: 0.6392 - val_loss: 0.8594 - val_accuracy: 0.6927 - val_precision: 0.6299 - val_recall: 0.6139
# Epoch 7/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.8036 - accuracy: 0.6818 - precision: 0.6028 - recall: 0.6332 - val_loss: 0.8529 - val_accuracy: 0.6875 - val_precision: 0.6439 - val_recall: 0.5380
# Epoch 8/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.8018 - accuracy: 0.6715 - precision: 0.5923 - recall: 0.6317 - val_loss: 0.8561 - val_accuracy: 0.6927 - val_precision: 0.6538 - val_recall: 0.5380
# Epoch 9/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.8090 - accuracy: 0.6636 - precision: 0.5792 - recall: 0.6214 - val_loss: 0.8568 - val_accuracy: 0.6901 - val_precision: 0.6466 - val_recall: 0.5443
# Epoch 10/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.8134 - accuracy: 0.6657 - precision: 0.5761 - recall: 0.6228 - val_loss: 0.8573 - val_accuracy: 0.6953 - val_precision: 0.6475 - val_recall: 0.5696
# Epoch 11/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.8064 - accuracy: 0.6754 - precision: 0.5885 - recall: 0.6316 - val_loss: 0.8573 - val_accuracy: 0.6927 - val_precision: 0.6471 - val_recall: 0.5570
# Epoch 12/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8176 - accuracy: 0.6781 - precision: 0.5951 - recall: 0.6252 - val_loss: 0.8582 - val_accuracy: 0.6927 - val_precision: 0.6471 - val_recall: 0.5570
# Epoch 13/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8047 - accuracy: 0.6752 - precision: 0.5881 - recall: 0.6355 - val_loss: 0.8582 - val_accuracy: 0.6953 - val_precision: 0.6496 - val_recall: 0.5633
# Epoch 14/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.8223 - accuracy: 0.6680 - precision: 0.5772 - recall: 0.6307 - val_loss: 0.8591 - val_accuracy: 0.6927 - val_precision: 0.6449 - val_recall: 0.5633
# Epoch 15/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8145 - accuracy: 0.6708 - precision: 0.5846 - recall: 0.6283 - val_loss: 0.8590 - val_accuracy: 0.6927 - val_precision: 0.6471 - val_recall: 0.5570
# Epoch 16/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.8303 - accuracy: 0.6601 - precision: 0.5665 - recall: 0.6196 - val_loss: 0.8595 - val_accuracy: 0.6927 - val_precision: 0.6449 - val_recall: 0.5633
# Epoch 17/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8193 - accuracy: 0.6746 - precision: 0.5886 - recall: 0.6420 - val_loss: 0.8584 - val_accuracy: 0.6927 - val_precision: 0.6471 - val_recall: 0.5570
# Epoch 18/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8022 - accuracy: 0.6737 - precision: 0.5939 - recall: 0.6216 - val_loss: 0.8585 - val_accuracy: 0.6953 - val_precision: 0.6496 - val_recall: 0.5633
# Epoch 19/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8176 - accuracy: 0.6625 - precision: 0.5831 - recall: 0.6167 - val_loss: 0.8589 - val_accuracy: 0.6927 - val_precision: 0.6471 - val_recall: 0.5570
# Epoch 20/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8230 - accuracy: 0.6669 - precision: 0.5859 - recall: 0.6239 - val_loss: 0.8598 - val_accuracy: 0.6953 - val_precision: 0.6519 - val_recall: 0.5570

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet18_logits.history[met])
    ax[i].plot(history_resnet18_logits.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet18_logits.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 1s 15ms/step - loss: 0.7087 - accuracy: 0.7168 - precision: 0.6572 - recall: 0.6011
# Loss of the model is -  0.7087181806564331
# Accuracy of the model is -  71.68141603469849 %
# Precision of the model is -  0.657200813293457
# Recall of the model is -  0.6011132001876831

# %% [markdown]
# ## ResNet18V2 - dropout
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('tanh', name=name + '_preact_tanh')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride)(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('tanh', name=name + '_1_tanh')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('tanh', name=name + '_2_tanh')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    x = stack_fn(x)
    x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
    x = Activation('tanh', name='post_tanh')(x)
    # Create model
    model = tf.keras.models.Model(input, x, name=model_name)
    return model
    
def ResNet18V2(input):
    def stack_fn(x):
        x = resnet_stack(x, 16, 2, name='conv2') # original: 64
        x = resnet_stack(x, 32, 2, name='conv3')
        x = resnet_stack(x, 64, 2, name='conv4')
        x = resnet_stack(x, 128, 2, stride1=1, name='conv5')
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_drop_builder():
    # ResNet18V2 without head
    resnet18 = ResNet18V2(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dropout(0.2, name='Dropout'), # add dropout (inspired by inception-resnet-v2)
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet18V2-drop')
    
    return model

# %%
resnet18_drop = resnet18_drop_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet18_drop.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet18_drop.summary()
# Out:
# Model: "ResNet18V2-drop"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_9 (ModuleWrap (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet18_drop = resnet18_drop.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 456/456 [==============================] - 170s 313ms/step - loss: 0.6730 - accuracy: 0.5935 - precision: 0.4979 - recall: 0.6060 - val_loss: 0.7885 - val_accuracy: 0.4583 - val_precision: 0.4247 - val_recall: 0.8924
# Epoch 2/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.6650 - accuracy: 0.6390 - precision: 0.5382 - recall: 0.6418 - val_loss: 0.6342 - val_accuracy: 0.6120 - val_precision: 0.5319 - val_recall: 0.4747
# Epoch 3/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.7253 - accuracy: 0.6526 - precision: 0.5638 - recall: 0.6453 - val_loss: 0.8698 - val_accuracy: 0.6250 - val_precision: 0.6061 - val_recall: 0.2532
# Epoch 4/20
# 456/456 [==============================] - 142s 312ms/step - loss: 0.8421 - accuracy: 0.6502 - precision: 0.5615 - recall: 0.6221 - val_loss: 0.8422 - val_accuracy: 0.6458 - val_precision: 0.5714 - val_recall: 0.5570
# Epoch 5/20
# 456/456 [==============================] - 142s 312ms/step - loss: 0.8588 - accuracy: 0.6632 - precision: 0.5752 - recall: 0.6425 - val_loss: 1.2536 - val_accuracy: 0.6302 - val_precision: 0.5342 - val_recall: 0.7911
# Epoch 6/20
# 456/456 [==============================] - 142s 312ms/step - loss: 0.8839 - accuracy: 0.6650 - precision: 0.5719 - recall: 0.6398 - val_loss: 1.1504 - val_accuracy: 0.6406 - val_precision: 0.5476 - val_recall: 0.7278
# Epoch 7/20
# 456/456 [==============================] - 142s 312ms/step - loss: 0.9141 - accuracy: 0.6635 - precision: 0.5809 - recall: 0.6299 - val_loss: 0.9843 - val_accuracy: 0.6745 - val_precision: 0.6107 - val_recall: 0.5759
# Epoch 8/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.8937 - accuracy: 0.6679 - precision: 0.5752 - recall: 0.6553 - val_loss: 0.9908 - val_accuracy: 0.6719 - val_precision: 0.6053 - val_recall: 0.5823
# Epoch 9/20
# 456/456 [==============================] - 142s 310ms/step - loss: 0.9130 - accuracy: 0.6618 - precision: 0.5645 - recall: 0.6463 - val_loss: 0.9900 - val_accuracy: 0.6745 - val_precision: 0.6078 - val_recall: 0.5886
# Epoch 10/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.9012 - accuracy: 0.6645 - precision: 0.5735 - recall: 0.6336 - val_loss: 0.9864 - val_accuracy: 0.6745 - val_precision: 0.6078 - val_recall: 0.5886
# Epoch 11/20
# 456/456 [==============================] - 141s 310ms/step - loss: 0.9219 - accuracy: 0.6655 - precision: 0.5831 - recall: 0.6380 - val_loss: 0.9898 - val_accuracy: 0.6745 - val_precision: 0.6065 - val_recall: 0.5949
# Epoch 12/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.9268 - accuracy: 0.6591 - precision: 0.5667 - recall: 0.6391 - val_loss: 0.9884 - val_accuracy: 0.6745 - val_precision: 0.6065 - val_recall: 0.5949
# Epoch 13/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.8978 - accuracy: 0.6673 - precision: 0.5739 - recall: 0.6512 - val_loss: 0.9921 - val_accuracy: 0.6745 - val_precision: 0.6078 - val_recall: 0.5886
# Epoch 14/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.9262 - accuracy: 0.6558 - precision: 0.5565 - recall: 0.6367 - val_loss: 0.9852 - val_accuracy: 0.6797 - val_precision: 0.6144 - val_recall: 0.5949
# Epoch 15/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.9310 - accuracy: 0.6642 - precision: 0.5701 - recall: 0.6332 - val_loss: 0.9914 - val_accuracy: 0.6719 - val_precision: 0.6053 - val_recall: 0.5823
# Epoch 16/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.9032 - accuracy: 0.6712 - precision: 0.5869 - recall: 0.6532 - val_loss: 0.9902 - val_accuracy: 0.6771 - val_precision: 0.6118 - val_recall: 0.5886
# Epoch 17/20
# 456/456 [==============================] - 142s 312ms/step - loss: 0.9376 - accuracy: 0.6600 - precision: 0.5651 - recall: 0.6354 - val_loss: 0.9886 - val_accuracy: 0.6797 - val_precision: 0.6144 - val_recall: 0.5949
# Epoch 18/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.9428 - accuracy: 0.6567 - precision: 0.5682 - recall: 0.6335 - val_loss: 0.9913 - val_accuracy: 0.6745 - val_precision: 0.6078 - val_recall: 0.5886
# Epoch 19/20
# 456/456 [==============================] - 142s 310ms/step - loss: 0.9087 - accuracy: 0.6607 - precision: 0.5749 - recall: 0.6339 - val_loss: 0.9882 - val_accuracy: 0.6745 - val_precision: 0.6093 - val_recall: 0.5823
# Epoch 20/20
# 456/456 [==============================] - 142s 311ms/step - loss: 0.9202 - accuracy: 0.6607 - precision: 0.5713 - recall: 0.6435 - val_loss: 0.9937 - val_accuracy: 0.6745 - val_precision: 0.6078 - val_recall: 0.5886

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet18_drop.history[met])
    ax[i].plot(history_resnet18_drop.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet18_drop.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 2s 28ms/step - loss: 0.8188 - accuracy: 0.6999 - precision: 0.6222 - recall: 0.6234
# Loss of the model is -  0.8187874555587769
# Accuracy of the model is -  69.98525261878967 %
# Precision of the model is -  0.6222222447395325
# Recall of the model is -  0.6233766078948975

# %% [markdown]
# ## ResNet18V2 pneu
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('tanh', name=name + '_preact_tanh')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride)(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('tanh', name=name + '_1_tanh')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('tanh', name=name + '_2_tanh')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    x = stack_fn(x)
    x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
    x = Activation('tanh', name='post_tanh')(x)
    # Create model
    model = tf.keras.models.Model(input, x, name=model_name)
    return model
    
def ResNet18V2(input):
    def stack_fn(x):
        x = resnet_stack(x, 16, 2, name='conv2') # original: 64
        x = resnet_stack(x, 32, 2, name='conv3')
        x = resnet_stack(x, 64, 2, name='conv4')
        x = resnet_stack(x, 128, 2, stride1=1, name='conv5')
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_pneu_builder():
    # ResNet18V2 without head
    resnet18 = ResNet18V2(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet18V2-pneu')
    
    return model

# %%
resnet18_pneu = resnet18_pneu_builder()

# load weights from pneumonia pretraining
resnet18_pneu.load_weights(weights_path+'resnet18_tanh_public_weights.h5')

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet18_pneu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet18_pneu.summary()
# Out:
# Model: "ResNet18V2-pneu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_10 (ModuleWra (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet18_pneu = resnet18_pneu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 456/456 [==============================] - 170s 313ms/step - loss: 0.9168 - accuracy: 0.6821 - precision: 0.5821 - recall: 0.7723 - val_loss: 1.8607 - val_accuracy: 0.6120 - val_precision: 0.5182 - val_recall: 0.8101
# Epoch 2/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.2025 - accuracy: 0.6983 - precision: 0.6077 - recall: 0.7257 - val_loss: 4.2878 - val_accuracy: 0.5964 - val_precision: 1.0000 - val_recall: 0.0190
# Epoch 3/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.1802 - accuracy: 0.7111 - precision: 0.6146 - recall: 0.7499 - val_loss: 1.1589 - val_accuracy: 0.7188 - val_precision: 0.6712 - val_recall: 0.6203
# Epoch 4/20
# 456/456 [==============================] - 142s 310ms/step - loss: 1.1820 - accuracy: 0.7116 - precision: 0.6103 - recall: 0.7531 - val_loss: 2.7353 - val_accuracy: 0.5677 - val_precision: 0.4870 - val_recall: 0.9494
# Epoch 5/20
# 456/456 [==============================] - 141s 310ms/step - loss: 1.2296 - accuracy: 0.6960 - precision: 0.5999 - recall: 0.7335 - val_loss: 1.4675 - val_accuracy: 0.6693 - val_precision: 0.5771 - val_recall: 0.7342
# Epoch 6/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.1890 - accuracy: 0.6910 - precision: 0.5896 - recall: 0.7318 - val_loss: 1.2656 - val_accuracy: 0.7057 - val_precision: 0.6552 - val_recall: 0.6013
# Epoch 7/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.1767 - accuracy: 0.7085 - precision: 0.6129 - recall: 0.7427 - val_loss: 1.5609 - val_accuracy: 0.6745 - val_precision: 0.6897 - val_recall: 0.3797
# Epoch 8/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.1525 - accuracy: 0.7009 - precision: 0.6109 - recall: 0.7310 - val_loss: 1.2161 - val_accuracy: 0.7083 - val_precision: 0.6533 - val_recall: 0.6203
# Epoch 9/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.1475 - accuracy: 0.7072 - precision: 0.6194 - recall: 0.7315 - val_loss: 1.2175 - val_accuracy: 0.7057 - val_precision: 0.6452 - val_recall: 0.6329
# Epoch 10/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.1659 - accuracy: 0.6945 - precision: 0.5982 - recall: 0.7333 - val_loss: 1.2235 - val_accuracy: 0.7057 - val_precision: 0.6452 - val_recall: 0.6329
# Epoch 11/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.1318 - accuracy: 0.7106 - precision: 0.6127 - recall: 0.7544 - val_loss: 1.2248 - val_accuracy: 0.7057 - val_precision: 0.6452 - val_recall: 0.6329
# Epoch 12/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.1470 - accuracy: 0.7103 - precision: 0.6219 - recall: 0.7396 - val_loss: 1.2283 - val_accuracy: 0.7057 - val_precision: 0.6452 - val_recall: 0.6329
# Epoch 13/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.1460 - accuracy: 0.7093 - precision: 0.6108 - recall: 0.7539 - val_loss: 1.2183 - val_accuracy: 0.7057 - val_precision: 0.6452 - val_recall: 0.6329
# Epoch 14/20
# 456/456 [==============================] - 142s 312ms/step - loss: 1.1339 - accuracy: 0.7216 - precision: 0.6269 - recall: 0.7584 - val_loss: 1.2317 - val_accuracy: 0.7057 - val_precision: 0.6452 - val_recall: 0.6329
# Epoch 15/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.1027 - accuracy: 0.7124 - precision: 0.6158 - recall: 0.7539 - val_loss: 1.2170 - val_accuracy: 0.7031 - val_precision: 0.6410 - val_recall: 0.6329
# Epoch 16/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.1153 - accuracy: 0.7072 - precision: 0.6202 - recall: 0.7311 - val_loss: 1.2214 - val_accuracy: 0.7031 - val_precision: 0.6410 - val_recall: 0.6329
# Epoch 17/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.1313 - accuracy: 0.7083 - precision: 0.6081 - recall: 0.7507 - val_loss: 1.2271 - val_accuracy: 0.7057 - val_precision: 0.6452 - val_recall: 0.6329
# Epoch 18/20
# 456/456 [==============================] - 142s 310ms/step - loss: 1.1386 - accuracy: 0.7080 - precision: 0.6077 - recall: 0.7408 - val_loss: 1.2156 - val_accuracy: 0.7057 - val_precision: 0.6452 - val_recall: 0.6329
# Epoch 19/20
# 456/456 [==============================] - 141s 310ms/step - loss: 1.1031 - accuracy: 0.7142 - precision: 0.6143 - recall: 0.7533 - val_loss: 1.2290 - val_accuracy: 0.7057 - val_precision: 0.6433 - val_recall: 0.6392
# Epoch 20/20
# 456/456 [==============================] - 142s 311ms/step - loss: 1.1733 - accuracy: 0.6994 - precision: 0.6057 - recall: 0.7305 - val_loss: 1.2154 - val_accuracy: 0.7057 - val_precision: 0.6452 - val_recall: 0.6329

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet18_pneu.history[met])
    ax[i].plot(history_resnet18_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet18_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 2s 28ms/step - loss: 0.9810 - accuracy: 0.7529 - precision: 0.6875 - recall: 0.6939
# Loss of the model is -  0.9809615612030029
# Accuracy of the model is -  75.29498338699341 %
# Precision of the model is -  0.6875
# Recall of the model is -  0.6938775777816772

# %% [markdown]
# ## Evaluation

# %%
models = [
    resnet18_relu,
    resnet18,
    resnet18_logits,
    resnet18_drop,
    resnet18_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating ResNet18V2-relu ...
# 85/85 [==============================] - 3s 29ms/step - loss: 1.0004 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating ResNet18V2 ...
# 85/85 [==============================] - 2s 28ms/step - loss: 0.7434 - accuracy: 0.6976 - precision: 0.6122 - recall: 0.6531
#
#
# Evaluating ResNet18V2-logits ...
# 85/85 [==============================] - 2s 28ms/step - loss: 0.7087 - accuracy: 0.7168 - precision: 0.6572 - recall: 0.6011
#
#
# Evaluating ResNet18V2-drop ...
# 85/85 [==============================] - 3s 29ms/step - loss: 0.8188 - accuracy: 0.6999 - precision: 0.6222 - recall: 0.6234
#
#
# Evaluating ResNet18V2-pneu ...
# 85/85 [==============================] - 2s 27ms/step - loss: 0.9810 - accuracy: 0.7529 - precision: 0.6875 - recall: 0.6939

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 0.500

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 0.5
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.219% and noise_multiplier = 1.5488810238230233 iterated over 9124 steps satisfies differential privacy with eps = 0.5 and delta = 0.0001.
# 1.5488810238230233

# %% [markdown]
# #### Membership Inference Attack

# %%
def calc_attack_inputs(attack_data):
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant

    probs = []
    losses = []
    labels = []
    for x, y in attack_data.as_numpy_iterator():
        y = y[0]
        # predict
        pred = model.predict(x)[0]
        #pred = np.round(pred) # only label as output instead of prob
        probs.append(pred)
        # compute loss
        loss = bc(constant([y]), constant(pred), from_logits=False).numpy()[0]
        losses.append(loss)
        # get label
        labels.append(y)

    return np.array(probs), np.array(losses), np.array(labels)

# %%
# run membership inference attack
def run_mia(model, train_attack_data, test_attack_data):
    # get values for train set
    probs_train, loss_train, labels_train = calc_attack_inputs(train_attack_data)
    # get values for test set
    probs_test, loss_test, labels_test = calc_attack_inputs(test_attack_data)

    # prepare attacks
    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = labels_train,
        labels_test = labels_test
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
        by_classification_correctness = True
    )

    attack_types = [
        #AttackType.THRESHOLD_ATTACK, # logistic was always better, so no threshold to save time
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    plt.show()

    # print a user-friendly summary of the attacks
    print(attacks_result.summary(by_slices=False))

    # epsilon estimation based on attack, metric adapted for AUC from https://paperswithcode.com/paper/antipodes-of-label-differential-privacy-pate
    def empirical_eps(auc):
        if auc <= 0.5:
            return 0
        if auc == 1:
            return np.inf
        return np.log(auc / (1 - auc))

    # function to get lowest AUC result
    def get_result_with_min_auc(self) -> SingleAttackResult:
        aucs = [result.get_auc() for result in self.single_attack_results]
        return self.single_attack_results[np.argmin(aucs)]
    attacks_result.get_result_with_min_auc = get_result_with_min_auc

    min_auc = attacks_result.get_result_with_min_auc(attacks_result).get_auc()
    max_auc = attacks_result.get_result_with_max_auc().get_auc()
    eps_min_auc =  empirical_eps(min_auc) # lower bound
    eps_max_auc = empirical_eps(max_auc) # upper bound
    print('Empirical epsilon bounds from AUC: %0.2f, %0.2f'%(eps_min_auc, eps_max_auc))

# %%
for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    run_mia(model, train_attack_data, test_attack_data)
    print('\n')
# Out:
# Membership Inference Attack on ResNet18V2-relu...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.48 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.13 on slice CLASS=1
# Empirical epsilon bounds from AUC: 0.00, 0.22
#
#
# Membership Inference Attack on ResNet18V2...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.48 on slice CORRECTLY_CLASSIFIED=False
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.10 on slice CORRECTLY_CLASSIFIED=False
# Empirical epsilon bounds from AUC: 0.00, 0.01
#
#
# Membership Inference Attack on ResNet18V2-logits...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.43 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.18 on slice CLASS=1
# Empirical epsilon bounds from AUC: 0.00, 0.28
#
#
# Membership Inference Attack on ResNet18V2-drop...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 817 training and 817 test examples) achieved an AUC of 0.55 on slice CORRECTLY_CLASSIFIED=True
#   LOGISTIC_REGRESSION (with 817 training and 817 test examples) achieved an advantage of 0.14 on slice CORRECTLY_CLASSIFIED=True
# Empirical epsilon bounds from AUC: 0.00, 0.19
#
#
# Membership Inference Attack on ResNet18V2-pneu...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.47 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.11 on slice CLASS=1
# Empirical epsilon bounds from AUC: 0.00, 0.22
