# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install 'tensorflow-privacy==0.5.2'
#!pip -q install git+https://github.com/tensorflow/privacy #TODO fix this

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.experimental.preprocessing import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

#import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 8.79
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-test split
x_train, x_test, y_train, y_test = train_test_split(files, labels, test_size=TEST_SPLIT, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=VAL_SPLIT, random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7299, Val: 385, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4380, 'COVID-19': 2919}
# val set:  {'normal': 227, 'COVID-19': 158}
# test set:   {'normal': 817, 'COVID-19': 539}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# seperate train labels and images for attacks
x_train_attack = prepare_dataset(train_ds,
                                 pre=True,
                                 shuffle=True,
                                 repeat=False,
                                 batch=1,
                                 augment=False,
                                 cache=False)

y_train_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(x_train_attack):
    y_train_attack.append(y)

# seperate test labels and images for attacks
x_test_attack = prepare_dataset(test_ds,
                                pre=True,
                                shuffle=False,
                                repeat=False,
                                batch=1,
                                augment=False,
                                cache=False)

y_test_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(x_test_attack):
    y_test_attack.append(y)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## DP-Net - relu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_relu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='relu'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-relu')
    return dpnet

# %%
dpnet_relu = dpnet_relu_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_relu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_relu.summary()
# Out:
# Model: "DP-Net-relu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization (BatchNo (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                230432
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_relu = dpnet_relu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 135s 441ms/step - loss: 0.9048 - accuracy: 0.5118 - precision: 0.4121 - recall: 0.5176 - val_loss: 0.7369 - val_accuracy: 0.4766 - val_precision: 0.4370 - val_recall: 0.9430
# Epoch 2/20
# 228/228 [==============================] - 92s 405ms/step - loss: 0.8911 - accuracy: 0.5179 - precision: 0.4244 - recall: 0.5250 - val_loss: 0.7314 - val_accuracy: 0.5990 - val_precision: 0.6667 - val_recall: 0.0506
# Epoch 3/20
# 228/228 [==============================] - 92s 404ms/step - loss: 0.8837 - accuracy: 0.5046 - precision: 0.4066 - recall: 0.4998 - val_loss: 0.6797 - val_accuracy: 0.5833 - val_precision: 0.4167 - val_recall: 0.0316
# Epoch 4/20
# 228/228 [==============================] - 91s 401ms/step - loss: 0.8943 - accuracy: 0.4939 - precision: 0.3942 - recall: 0.4770 - val_loss: 0.8001 - val_accuracy: 0.4766 - val_precision: 0.3595 - val_recall: 0.3481
# Epoch 5/20
# 228/228 [==============================] - 91s 402ms/step - loss: 0.8763 - accuracy: 0.5119 - precision: 0.4159 - recall: 0.4969 - val_loss: 0.7189 - val_accuracy: 0.5677 - val_precision: 0.4655 - val_recall: 0.3418
# Epoch 6/20
# 228/228 [==============================] - 91s 401ms/step - loss: 0.8688 - accuracy: 0.5215 - precision: 0.4235 - recall: 0.5147 - val_loss: 0.7577 - val_accuracy: 0.5000 - val_precision: 0.3963 - val_recall: 0.4114
# Epoch 7/20
# 228/228 [==============================] - 92s 403ms/step - loss: 0.8806 - accuracy: 0.5112 - precision: 0.4055 - recall: 0.5072 - val_loss: 0.7329 - val_accuracy: 0.5391 - val_precision: 0.4431 - val_recall: 0.4684
# Epoch 8/20
# 228/228 [==============================] - 93s 408ms/step - loss: 0.8767 - accuracy: 0.5206 - precision: 0.4151 - recall: 0.5045 - val_loss: 0.7404 - val_accuracy: 0.5234 - val_precision: 0.4260 - val_recall: 0.4557
# Epoch 9/20
# 228/228 [==============================] - 92s 404ms/step - loss: 0.8681 - accuracy: 0.5205 - precision: 0.4217 - recall: 0.5080 - val_loss: 0.7455 - val_accuracy: 0.5260 - val_precision: 0.4326 - val_recall: 0.4873
# Epoch 10/20
# 228/228 [==============================] - 91s 401ms/step - loss: 0.8623 - accuracy: 0.5305 - precision: 0.4296 - recall: 0.5203 - val_loss: 0.7430 - val_accuracy: 0.5182 - val_precision: 0.4220 - val_recall: 0.4620
# Epoch 11/20
# 228/228 [==============================] - 91s 400ms/step - loss: 0.8758 - accuracy: 0.5065 - precision: 0.4023 - recall: 0.4869 - val_loss: 0.7485 - val_accuracy: 0.5156 - val_precision: 0.4213 - val_recall: 0.4747
# Epoch 12/20
# 228/228 [==============================] - 92s 403ms/step - loss: 0.8665 - accuracy: 0.5098 - precision: 0.4098 - recall: 0.5004 - val_loss: 0.7475 - val_accuracy: 0.5260 - val_precision: 0.4318 - val_recall: 0.4810
# Epoch 13/20
# 228/228 [==============================] - 91s 401ms/step - loss: 0.8996 - accuracy: 0.5040 - precision: 0.4019 - recall: 0.4891 - val_loss: 0.7463 - val_accuracy: 0.5260 - val_precision: 0.4310 - val_recall: 0.4747
# Epoch 14/20
# 228/228 [==============================] - 91s 402ms/step - loss: 0.8901 - accuracy: 0.5017 - precision: 0.3924 - recall: 0.4755 - val_loss: 0.7422 - val_accuracy: 0.5234 - val_precision: 0.4251 - val_recall: 0.4494
# Epoch 15/20
# 228/228 [==============================] - 92s 403ms/step - loss: 0.8974 - accuracy: 0.5016 - precision: 0.3998 - recall: 0.4916 - val_loss: 0.7427 - val_accuracy: 0.5260 - val_precision: 0.4302 - val_recall: 0.4684
# Epoch 16/20
# 228/228 [==============================] - 92s 404ms/step - loss: 0.8860 - accuracy: 0.5047 - precision: 0.4036 - recall: 0.4949 - val_loss: 0.7415 - val_accuracy: 0.5286 - val_precision: 0.4335 - val_recall: 0.4747
# Epoch 17/20
# 228/228 [==============================] - 93s 408ms/step - loss: 0.8801 - accuracy: 0.5086 - precision: 0.4064 - recall: 0.4959 - val_loss: 0.7445 - val_accuracy: 0.5234 - val_precision: 0.4260 - val_recall: 0.4557
# Epoch 18/20
# 228/228 [==============================] - 93s 409ms/step - loss: 0.8631 - accuracy: 0.5146 - precision: 0.4101 - recall: 0.4983 - val_loss: 0.7414 - val_accuracy: 0.5234 - val_precision: 0.4251 - val_recall: 0.4494
# Epoch 19/20
# 228/228 [==============================] - 92s 406ms/step - loss: 0.8855 - accuracy: 0.5079 - precision: 0.4032 - recall: 0.5022 - val_loss: 0.7466 - val_accuracy: 0.5208 - val_precision: 0.4235 - val_recall: 0.4557
# Epoch 20/20
# 228/228 [==============================] - 93s 408ms/step - loss: 0.8946 - accuracy: 0.5026 - precision: 0.4057 - recall: 0.4971 - val_loss: 0.7428 - val_accuracy: 0.5208 - val_precision: 0.4244 - val_recall: 0.4620

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_relu.history[met])
    ax[i].plot(history_dpnet_relu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_relu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 4s 84ms/step - loss: 0.7879 - accuracy: 0.5103 - precision: 0.4013 - recall: 0.4712
# Loss of the model is -  0.787923276424408
# Accuracy of the model is -  51.032447814941406 %
# Precision of the model is -  0.4012638330459595
# Recall of the model is -  0.4712430536746979

# %% [markdown]
# ## DP-Net - CNN Architecture for DP-SGD
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net')
    return dpnet

# %%
dpnet = dpnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet.summary()
# Out:
# Model: "DP-Net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet = dpnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 101s 412ms/step - loss: 0.9666 - accuracy: 0.4733 - precision: 0.3751 - recall: 0.4756 - val_loss: 0.7201 - val_accuracy: 0.6042 - val_precision: 0.5625 - val_recall: 0.1709
# Epoch 2/20
# 228/228 [==============================] - 93s 408ms/step - loss: 0.9729 - accuracy: 0.4786 - precision: 0.3866 - recall: 0.4904 - val_loss: 0.7727 - val_accuracy: 0.5990 - val_precision: 0.5147 - val_recall: 0.4430
# Epoch 3/20
# 228/228 [==============================] - 92s 403ms/step - loss: 0.9330 - accuracy: 0.5077 - precision: 0.4065 - recall: 0.5026 - val_loss: 0.8021 - val_accuracy: 0.5547 - val_precision: 0.4741 - val_recall: 0.7532
# Epoch 4/20
# 228/228 [==============================] - 91s 401ms/step - loss: 0.9446 - accuracy: 0.5265 - precision: 0.4290 - recall: 0.5347 - val_loss: 0.8025 - val_accuracy: 0.5443 - val_precision: 0.4605 - val_recall: 0.6266
# Epoch 5/20
# 228/228 [==============================] - 92s 403ms/step - loss: 0.9330 - accuracy: 0.5231 - precision: 0.4243 - recall: 0.5292 - val_loss: 0.7976 - val_accuracy: 0.5391 - val_precision: 0.4566 - val_recall: 0.6329
# Epoch 6/20
# 228/228 [==============================] - 91s 402ms/step - loss: 0.9205 - accuracy: 0.5324 - precision: 0.4390 - recall: 0.5386 - val_loss: 0.8001 - val_accuracy: 0.5417 - val_precision: 0.4587 - val_recall: 0.6329
# Epoch 7/20
# 228/228 [==============================] - 91s 398ms/step - loss: 0.9225 - accuracy: 0.5316 - precision: 0.4350 - recall: 0.5214 - val_loss: 0.8041 - val_accuracy: 0.5417 - val_precision: 0.4602 - val_recall: 0.6582
# Epoch 8/20
# 228/228 [==============================] - 92s 405ms/step - loss: 0.9277 - accuracy: 0.5361 - precision: 0.4379 - recall: 0.5404 - val_loss: 0.8018 - val_accuracy: 0.5391 - val_precision: 0.4570 - val_recall: 0.6392
# Epoch 9/20
# 228/228 [==============================] - 92s 403ms/step - loss: 0.9044 - accuracy: 0.5375 - precision: 0.4446 - recall: 0.5480 - val_loss: 0.7997 - val_accuracy: 0.5365 - val_precision: 0.4533 - val_recall: 0.6139
# Epoch 10/20
# 228/228 [==============================] - 92s 403ms/step - loss: 0.9092 - accuracy: 0.5422 - precision: 0.4459 - recall: 0.5457 - val_loss: 0.8014 - val_accuracy: 0.5417 - val_precision: 0.4602 - val_recall: 0.6582
# Epoch 11/20
# 228/228 [==============================] - 92s 403ms/step - loss: 0.9572 - accuracy: 0.5199 - precision: 0.4271 - recall: 0.5226 - val_loss: 0.8001 - val_accuracy: 0.5469 - val_precision: 0.4643 - val_recall: 0.6582
# Epoch 12/20
# 228/228 [==============================] - 91s 402ms/step - loss: 0.9317 - accuracy: 0.5212 - precision: 0.4255 - recall: 0.5245 - val_loss: 0.8019 - val_accuracy: 0.5443 - val_precision: 0.4615 - val_recall: 0.6456
# Epoch 13/20
# 228/228 [==============================] - 92s 404ms/step - loss: 0.9350 - accuracy: 0.5358 - precision: 0.4410 - recall: 0.5415 - val_loss: 0.7972 - val_accuracy: 0.5391 - val_precision: 0.4562 - val_recall: 0.6266
# Epoch 14/20
# 228/228 [==============================] - 92s 404ms/step - loss: 0.9190 - accuracy: 0.5485 - precision: 0.4492 - recall: 0.5546 - val_loss: 0.8045 - val_accuracy: 0.5391 - val_precision: 0.4570 - val_recall: 0.6392
# Epoch 15/20
# 228/228 [==============================] - 92s 404ms/step - loss: 0.9327 - accuracy: 0.5292 - precision: 0.4261 - recall: 0.5286 - val_loss: 0.8021 - val_accuracy: 0.5391 - val_precision: 0.4562 - val_recall: 0.6266
# Epoch 16/20
# 228/228 [==============================] - 91s 401ms/step - loss: 0.9243 - accuracy: 0.5360 - precision: 0.4351 - recall: 0.5467 - val_loss: 0.8034 - val_accuracy: 0.5469 - val_precision: 0.4633 - val_recall: 0.6392
# Epoch 17/20
# 228/228 [==============================] - 91s 402ms/step - loss: 0.9463 - accuracy: 0.5219 - precision: 0.4277 - recall: 0.5209 - val_loss: 0.8013 - val_accuracy: 0.5417 - val_precision: 0.4595 - val_recall: 0.6456
# Epoch 18/20
# 228/228 [==============================] - 92s 407ms/step - loss: 0.8934 - accuracy: 0.5425 - precision: 0.4385 - recall: 0.5501 - val_loss: 0.8002 - val_accuracy: 0.5417 - val_precision: 0.4583 - val_recall: 0.6266
# Epoch 19/20
# 228/228 [==============================] - 92s 406ms/step - loss: 0.9544 - accuracy: 0.5200 - precision: 0.4171 - recall: 0.5203 - val_loss: 0.8002 - val_accuracy: 0.5417 - val_precision: 0.4591 - val_recall: 0.6392
# Epoch 20/20
# 228/228 [==============================] - 92s 407ms/step - loss: 0.9464 - accuracy: 0.5191 - precision: 0.4206 - recall: 0.5228 - val_loss: 0.8001 - val_accuracy: 0.5391 - val_precision: 0.4570 - val_recall: 0.6392

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet.history[met])
    ax[i].plot(history_dpnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 33ms/step - loss: 0.8149 - accuracy: 0.5361 - precision: 0.4442 - recall: 0.6642
# Loss of the model is -  0.8148705363273621
# Accuracy of the model is -  53.61356735229492 %
# Precision of the model is -  0.44416874647140503
# Recall of the model is -  0.6641929745674133

# %% [markdown]
# ## DP-Net nobn
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_nobn_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-nobn')
    return dpnet

# %%
dpnet_nobn = dpnet_nobn_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_nobn.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_nobn.summary()
# Out:
# Model: "DP-Net-nobn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                230432
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 241,777
# Trainable params: 241,777
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_nobn = dpnet_nobn.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 94s 392ms/step - loss: 0.7960 - accuracy: 0.5676 - precision: 0.3283 - recall: 0.0747 - val_loss: 1.4377 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 228/228 [==============================] - 88s 387ms/step - loss: 1.7077 - accuracy: 0.5932 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4371 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 228/228 [==============================] - 88s 387ms/step - loss: 1.7384 - accuracy: 0.5991 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3395 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 228/228 [==============================] - 88s 387ms/step - loss: 1.7017 - accuracy: 0.5963 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4240 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 228/228 [==============================] - 88s 386ms/step - loss: 1.7180 - accuracy: 0.5949 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3534 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 228/228 [==============================] - 88s 386ms/step - loss: 1.6456 - accuracy: 0.5958 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.3923 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 228/228 [==============================] - 88s 386ms/step - loss: 1.6881 - accuracy: 0.5946 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4128 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 228/228 [==============================] - 89s 390ms/step - loss: 1.7262 - accuracy: 0.5910 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4134 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 228/228 [==============================] - 88s 386ms/step - loss: 1.7096 - accuracy: 0.5955 - precision: 0.7860 - recall: 5.1508e-04 - val_loss: 1.4145 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 228/228 [==============================] - 88s 388ms/step - loss: 1.6919 - accuracy: 0.5998 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4144 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 228/228 [==============================] - 88s 387ms/step - loss: 1.6924 - accuracy: 0.5994 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4144 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 228/228 [==============================] - 88s 386ms/step - loss: 1.6981 - accuracy: 0.5977 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4145 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 228/228 [==============================] - 88s 385ms/step - loss: 1.7005 - accuracy: 0.5990 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4145 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 228/228 [==============================] - 88s 387ms/step - loss: 1.6883 - accuracy: 0.6007 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4142 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 228/228 [==============================] - 88s 387ms/step - loss: 1.7011 - accuracy: 0.5978 - precision: 0.7773 - recall: 5.0739e-04 - val_loss: 1.4141 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 228/228 [==============================] - 88s 387ms/step - loss: 1.6812 - accuracy: 0.6022 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4143 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 228/228 [==============================] - 88s 389ms/step - loss: 1.7047 - accuracy: 0.5970 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4144 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 228/228 [==============================] - 89s 390ms/step - loss: 1.7186 - accuracy: 0.5939 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4145 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 228/228 [==============================] - 88s 387ms/step - loss: 1.7326 - accuracy: 0.5902 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4145 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 228/228 [==============================] - 88s 388ms/step - loss: 1.7213 - accuracy: 0.5922 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4147 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_nobn.history[met])
    ax[i].plot(history_dpnet_nobn.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_nobn.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 29ms/step - loss: 1.3569 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss of the model is -  1.3569022417068481
# Accuracy of the model is -  60.25073528289795 %
# Precision of the model is -  0.0
# Recall of the model is -  0.0

# %% [markdown]
# ## DP-Net pneu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_pneu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-pneu')
    return dpnet

# %%
dpnet_pneu = dpnet_pneu_builder()

# load weights from pneumonia pretraining
dpnet_pneu.load_weights(weights_path+'dpnet_tanh_public_weights.h5')

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_pneu.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_pneu.summary()
# Out:
# Model: "DP-Net-pneu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_pneu = dpnet_pneu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 99s 407ms/step - loss: 0.8722 - accuracy: 0.6611 - precision: 0.5582 - recall: 0.7617 - val_loss: 5.9275 - val_accuracy: 0.4115 - val_precision: 0.4115 - val_recall: 1.0000
# Epoch 2/20
# 228/228 [==============================] - 91s 402ms/step - loss: 0.8739 - accuracy: 0.6470 - precision: 0.5392 - recall: 0.7652 - val_loss: 1.8468 - val_accuracy: 0.5677 - val_precision: 0.4867 - val_recall: 0.9241
# Epoch 3/20
# 228/228 [==============================] - 92s 404ms/step - loss: 0.9044 - accuracy: 0.6630 - precision: 0.5645 - recall: 0.7479 - val_loss: 6.2756 - val_accuracy: 0.4115 - val_precision: 0.4115 - val_recall: 1.0000
# Epoch 4/20
# 228/228 [==============================] - 91s 402ms/step - loss: 0.9884 - accuracy: 0.6572 - precision: 0.5598 - recall: 0.7240 - val_loss: 3.4974 - val_accuracy: 0.4766 - val_precision: 0.4377 - val_recall: 0.9557
# Epoch 5/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.0777 - accuracy: 0.6502 - precision: 0.5515 - recall: 0.7213 - val_loss: 1.0646 - val_accuracy: 0.6797 - val_precision: 0.6048 - val_recall: 0.6392
# Epoch 6/20
# 228/228 [==============================] - 92s 404ms/step - loss: 1.0926 - accuracy: 0.6536 - precision: 0.5504 - recall: 0.7299 - val_loss: 1.0270 - val_accuracy: 0.6927 - val_precision: 0.6266 - val_recall: 0.6266
# Epoch 7/20
# 228/228 [==============================] - 92s 404ms/step - loss: 1.0652 - accuracy: 0.6537 - precision: 0.5576 - recall: 0.7277 - val_loss: 1.0382 - val_accuracy: 0.6823 - val_precision: 0.6098 - val_recall: 0.6329
# Epoch 8/20
# 228/228 [==============================] - 92s 404ms/step - loss: 1.0837 - accuracy: 0.6544 - precision: 0.5518 - recall: 0.7303 - val_loss: 1.0115 - val_accuracy: 0.6979 - val_precision: 0.6400 - val_recall: 0.6076
# Epoch 9/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.0993 - accuracy: 0.6510 - precision: 0.5449 - recall: 0.7301 - val_loss: 1.0225 - val_accuracy: 0.6875 - val_precision: 0.6203 - val_recall: 0.6203
# Epoch 10/20
# 228/228 [==============================] - 92s 404ms/step - loss: 1.0949 - accuracy: 0.6424 - precision: 0.5398 - recall: 0.7264 - val_loss: 1.0846 - val_accuracy: 0.6693 - val_precision: 0.5876 - val_recall: 0.6582
# Epoch 11/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.1025 - accuracy: 0.6435 - precision: 0.5480 - recall: 0.7310 - val_loss: 1.0457 - val_accuracy: 0.6901 - val_precision: 0.6211 - val_recall: 0.6329
# Epoch 12/20
# 228/228 [==============================] - 92s 403ms/step - loss: 1.0542 - accuracy: 0.6611 - precision: 0.5593 - recall: 0.7327 - val_loss: 1.0315 - val_accuracy: 0.6979 - val_precision: 0.6400 - val_recall: 0.6076
# Epoch 13/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.1167 - accuracy: 0.6430 - precision: 0.5399 - recall: 0.7189 - val_loss: 1.0297 - val_accuracy: 0.6927 - val_precision: 0.6299 - val_recall: 0.6139
# Epoch 14/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.1256 - accuracy: 0.6399 - precision: 0.5325 - recall: 0.7123 - val_loss: 1.0206 - val_accuracy: 0.6979 - val_precision: 0.6400 - val_recall: 0.6076
# Epoch 15/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.0963 - accuracy: 0.6418 - precision: 0.5371 - recall: 0.7299 - val_loss: 1.0168 - val_accuracy: 0.6979 - val_precision: 0.6400 - val_recall: 0.6076
# Epoch 16/20
# 228/228 [==============================] - 92s 404ms/step - loss: 1.1039 - accuracy: 0.6472 - precision: 0.5509 - recall: 0.7334 - val_loss: 1.0273 - val_accuracy: 0.6953 - val_precision: 0.6376 - val_recall: 0.6013
# Epoch 17/20
# 228/228 [==============================] - 92s 404ms/step - loss: 1.1043 - accuracy: 0.6480 - precision: 0.5434 - recall: 0.7261 - val_loss: 1.0300 - val_accuracy: 0.6979 - val_precision: 0.6382 - val_recall: 0.6139
# Epoch 18/20
# 228/228 [==============================] - 92s 404ms/step - loss: 1.1017 - accuracy: 0.6429 - precision: 0.5447 - recall: 0.7200 - val_loss: 1.0289 - val_accuracy: 0.7005 - val_precision: 0.6424 - val_recall: 0.6139
# Epoch 19/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.0903 - accuracy: 0.6545 - precision: 0.5572 - recall: 0.7310 - val_loss: 1.0332 - val_accuracy: 0.6979 - val_precision: 0.6382 - val_recall: 0.6139
# Epoch 20/20
# 228/228 [==============================] - 92s 407ms/step - loss: 1.0956 - accuracy: 0.6386 - precision: 0.5401 - recall: 0.7155 - val_loss: 1.0349 - val_accuracy: 0.6875 - val_precision: 0.6218 - val_recall: 0.6139

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_pneu.history[met])
    ax[i].plot(history_dpnet_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 30ms/step - loss: 1.0165 - accuracy: 0.6858 - precision: 0.6068 - recall: 0.5955
# Loss of the model is -  1.0165079832077026
# Accuracy of the model is -  68.58407258987427 %
# Precision of the model is -  0.6068052649497986
# Recall of the model is -  0.5955473184585571

# %% [markdown]
# ## Evaluation

# %%
models = [
    dpnet_relu,
    dpnet,
    dpnet_nobn,
    dpnet_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating DP-Net-relu ...
# 43/43 [==============================] - 1s 29ms/step - loss: 0.7879 - accuracy: 0.5103 - precision: 0.4013 - recall: 0.4712
#
#
# Evaluating DP-Net ...
# 43/43 [==============================] - 1s 30ms/step - loss: 0.8149 - accuracy: 0.5361 - precision: 0.4442 - recall: 0.6642
#
#
# Evaluating DP-Net-nobn ...
# 43/43 [==============================] - 1s 30ms/step - loss: 1.3569 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating DP-Net-pneu ...
# 43/43 [==============================] - 1s 30ms/step - loss: 1.0165 - accuracy: 0.6858 - precision: 0.6068 - recall: 0.5955

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 0.102

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 0.1
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.438% and noise_multiplier = 8.79647419846654 iterated over 4562 steps satisfies differential privacy with eps = 0.1 and delta = 0.0001.
# 8.79647419846654

# %% [markdown]
# #### Membership Inference Attack

# %%
# run membership inference attack
def run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack):
    # predict on train
    probs_train = model.predict(x_train_attack)
    # predict on test
    probs_test = model.predict(x_test_attack)

    # only label as output instead of prob
    #probs_train = np.round(logits_train)
    #probs_test = np.round(logits_test)

    # compute losses
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant

    loss_train = np.array([x[0] for x in bc(constant([[y] for y in y_train_attack]), constant(probs_train), from_logits=False).numpy()])
    loss_test = np.array([x[0] for x in bc(constant([[y] for y in y_test_attack]), constant(probs_test), from_logits=False).numpy()])

    # labels
    train_labels = np.array(y_train_attack)
    test_labels = np.array(y_test_attack)

    # prepare attacks
    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = train_labels,
        labels_test = test_labels
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,)

    attack_types = [
        AttackType.THRESHOLD_ATTACK,
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    plt.show()

    # print a user-friendly summary of the attacks
    print(attacks_result.summary(by_slices=False)) #TODO fix low auc sometimes

# %%
for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack)
    print('\n')
# Out:
# Membership Inference Attack on DP-Net-relu...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 817 training and 817 test examples) achieved an AUC of 0.52 on slice CLASS=0
#   LOGISTIC_REGRESSION (with 817 training and 817 test examples) achieved an advantage of 0.08 on slice CLASS=0
#
#
# Membership Inference Attack on DP-Net...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.57 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.18 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-nobn...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   THRESHOLD_ATTACK (with 2919 training and 539 test examples) achieved an AUC of 0.36 on slice CLASS=1
#   THRESHOLD_ATTACK (with 2919 training and 539 test examples) achieved an advantage of 0.22 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-pneu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.64 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.26 on slice CLASS=1
