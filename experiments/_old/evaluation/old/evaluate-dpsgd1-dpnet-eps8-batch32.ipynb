# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install 'tensorflow-privacy==0.5.2'
#!pip -q install git+https://github.com/tensorflow/privacy #TODO fix this
# Out:
#      |████████████████████████████████| 194kB 5.1MB/s

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.experimental.preprocessing import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

#import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 780MB [00:05, 131MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 0.5636
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-test split
x_train, x_test, y_train, y_test = train_test_split(files, labels, test_size=TEST_SPLIT, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=VAL_SPLIT, random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7299, Val: 385, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4380, 'COVID-19': 2919}
# val set:  {'normal': 227, 'COVID-19': 158}
# test set:   {'normal': 817, 'COVID-19': 539}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# seperate train labels and images for attacks
x_train_attack = prepare_dataset(train_ds,
                                 pre=True,
                                 shuffle=True,
                                 repeat=False,
                                 batch=1,
                                 augment=False,
                                 cache=False)

y_train_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(x_train_attack):
    y_train_attack.append(y)

# seperate test labels and images for attacks
x_test_attack = prepare_dataset(test_ds,
                                pre=True,
                                shuffle=False,
                                repeat=False,
                                batch=1,
                                augment=False,
                                cache=False)

y_test_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(x_test_attack):
    y_test_attack.append(y)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## DP-Net - relu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_relu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='relu'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-relu')
    return dpnet

# %%
dpnet_relu = dpnet_relu_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_relu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_relu.summary()
# Out:
# Model: "DP-Net-relu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization (BatchNo (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                230432
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_relu = dpnet_relu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 147s 498ms/step - loss: 0.8735 - accuracy: 0.5549 - precision: 0.4556 - recall: 0.5615 - val_loss: 0.9114 - val_accuracy: 0.6068 - val_precision: 0.5137 - val_recall: 0.8291
# Epoch 2/20
# 228/228 [==============================] - 108s 477ms/step - loss: 0.9788 - accuracy: 0.6358 - precision: 0.5446 - recall: 0.6277 - val_loss: 0.9297 - val_accuracy: 0.6484 - val_precision: 0.5511 - val_recall: 0.7848
# Epoch 3/20
# 228/228 [==============================] - 108s 473ms/step - loss: 0.9429 - accuracy: 0.6531 - precision: 0.5603 - recall: 0.6436 - val_loss: 0.7214 - val_accuracy: 0.7005 - val_precision: 0.6463 - val_recall: 0.6013
# Epoch 4/20
# 228/228 [==============================] - 108s 474ms/step - loss: 0.8599 - accuracy: 0.6817 - precision: 0.5950 - recall: 0.6572 - val_loss: 0.7801 - val_accuracy: 0.7005 - val_precision: 0.6870 - val_recall: 0.5000
# Epoch 5/20
# 228/228 [==============================] - 108s 475ms/step - loss: 0.8907 - accuracy: 0.6859 - precision: 0.6071 - recall: 0.6442 - val_loss: 1.0986 - val_accuracy: 0.6875 - val_precision: 0.7714 - val_recall: 0.3418
# Epoch 6/20
# 228/228 [==============================] - 107s 472ms/step - loss: 0.8905 - accuracy: 0.6818 - precision: 0.5985 - recall: 0.6428 - val_loss: 0.7798 - val_accuracy: 0.7318 - val_precision: 0.7068 - val_recall: 0.5949
# Epoch 7/20
# 228/228 [==============================] - 108s 476ms/step - loss: 0.9006 - accuracy: 0.6881 - precision: 0.5953 - recall: 0.6605 - val_loss: 0.7315 - val_accuracy: 0.7370 - val_precision: 0.7080 - val_recall: 0.6139
# Epoch 8/20
# 228/228 [==============================] - 108s 475ms/step - loss: 0.8688 - accuracy: 0.6969 - precision: 0.6056 - recall: 0.6816 - val_loss: 0.7848 - val_accuracy: 0.7396 - val_precision: 0.7377 - val_recall: 0.5696
# Epoch 9/20
# 228/228 [==============================] - 109s 477ms/step - loss: 0.8995 - accuracy: 0.6919 - precision: 0.6098 - recall: 0.6568 - val_loss: 0.7885 - val_accuracy: 0.7370 - val_precision: 0.7355 - val_recall: 0.5633
# Epoch 10/20
# 228/228 [==============================] - 109s 480ms/step - loss: 0.8612 - accuracy: 0.7014 - precision: 0.6173 - recall: 0.6731 - val_loss: 0.7848 - val_accuracy: 0.7448 - val_precision: 0.7419 - val_recall: 0.5823
# Epoch 11/20
# 228/228 [==============================] - 109s 480ms/step - loss: 0.8961 - accuracy: 0.6869 - precision: 0.5976 - recall: 0.6597 - val_loss: 0.7892 - val_accuracy: 0.7422 - val_precision: 0.7398 - val_recall: 0.5759
# Epoch 12/20
# 228/228 [==============================] - 108s 474ms/step - loss: 0.8919 - accuracy: 0.6982 - precision: 0.6150 - recall: 0.6667 - val_loss: 0.7856 - val_accuracy: 0.7396 - val_precision: 0.7377 - val_recall: 0.5696
# Epoch 13/20
# 228/228 [==============================] - 108s 476ms/step - loss: 0.9263 - accuracy: 0.6923 - precision: 0.6058 - recall: 0.6627 - val_loss: 0.7870 - val_accuracy: 0.7422 - val_precision: 0.7398 - val_recall: 0.5759
# Epoch 14/20
# 228/228 [==============================] - 107s 469ms/step - loss: 0.8927 - accuracy: 0.6882 - precision: 0.5952 - recall: 0.6583 - val_loss: 0.7860 - val_accuracy: 0.7396 - val_precision: 0.7377 - val_recall: 0.5696
# Epoch 15/20
# 228/228 [==============================] - 107s 470ms/step - loss: 0.8797 - accuracy: 0.6958 - precision: 0.6092 - recall: 0.6687 - val_loss: 0.7888 - val_accuracy: 0.7370 - val_precision: 0.7355 - val_recall: 0.5633
# Epoch 16/20
# 228/228 [==============================] - 108s 473ms/step - loss: 0.9339 - accuracy: 0.6790 - precision: 0.5893 - recall: 0.6541 - val_loss: 0.7895 - val_accuracy: 0.7370 - val_precision: 0.7355 - val_recall: 0.5633
# Epoch 17/20
# 228/228 [==============================] - 108s 473ms/step - loss: 0.9030 - accuracy: 0.6797 - precision: 0.5906 - recall: 0.6510 - val_loss: 0.7900 - val_accuracy: 0.7370 - val_precision: 0.7355 - val_recall: 0.5633
# Epoch 18/20
# 228/228 [==============================] - 107s 469ms/step - loss: 0.8751 - accuracy: 0.6964 - precision: 0.6101 - recall: 0.6561 - val_loss: 0.7901 - val_accuracy: 0.7370 - val_precision: 0.7355 - val_recall: 0.5633
# Epoch 19/20
# 228/228 [==============================] - 107s 472ms/step - loss: 0.8958 - accuracy: 0.6893 - precision: 0.5960 - recall: 0.6736 - val_loss: 0.7891 - val_accuracy: 0.7422 - val_precision: 0.7398 - val_recall: 0.5759
# Epoch 20/20
# 228/228 [==============================] - 107s 470ms/step - loss: 0.8954 - accuracy: 0.6839 - precision: 0.6013 - recall: 0.6478 - val_loss: 0.7923 - val_accuracy: 0.7422 - val_precision: 0.7398 - val_recall: 0.5759

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_relu.history[met])
    ax[i].plot(history_dpnet_relu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_relu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 3s 68ms/step - loss: 0.7948 - accuracy: 0.7360 - precision: 0.7202 - recall: 0.5492
# Loss of the model is -  0.7948288917541504
# Accuracy of the model is -  73.5988199710846 %
# Precision of the model is -  0.7201946377754211
# Recall of the model is -  0.5491651296615601

# %% [markdown]
# ## DP-Net - CNN Architecture for DP-SGD
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net')
    return dpnet

# %%
dpnet = dpnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet.summary()
# Out:
# Model: "DP-Net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet = dpnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 116s 479ms/step - loss: 1.0323 - accuracy: 0.5630 - precision: 0.4654 - recall: 0.6025 - val_loss: 1.0628 - val_accuracy: 0.6432 - val_precision: 0.5493 - val_recall: 0.7405
# Epoch 2/20
# 228/228 [==============================] - 109s 481ms/step - loss: 1.2299 - accuracy: 0.6567 - precision: 0.5662 - recall: 0.6484 - val_loss: 1.1046 - val_accuracy: 0.6667 - val_precision: 0.5987 - val_recall: 0.5759
# Epoch 3/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1984 - accuracy: 0.6593 - precision: 0.5640 - recall: 0.6493 - val_loss: 1.1934 - val_accuracy: 0.6380 - val_precision: 0.5442 - val_recall: 0.7405
# Epoch 4/20
# 228/228 [==============================] - 109s 478ms/step - loss: 1.0808 - accuracy: 0.6714 - precision: 0.5822 - recall: 0.6490 - val_loss: 1.0497 - val_accuracy: 0.7005 - val_precision: 0.6525 - val_recall: 0.5823
# Epoch 5/20
# 228/228 [==============================] - 108s 473ms/step - loss: 1.1122 - accuracy: 0.6818 - precision: 0.5942 - recall: 0.6527 - val_loss: 1.0699 - val_accuracy: 0.7031 - val_precision: 0.6410 - val_recall: 0.6329
# Epoch 6/20
# 228/228 [==============================] - 109s 480ms/step - loss: 1.1655 - accuracy: 0.6568 - precision: 0.5717 - recall: 0.6249 - val_loss: 1.1070 - val_accuracy: 0.7031 - val_precision: 0.6803 - val_recall: 0.5253
# Epoch 7/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1482 - accuracy: 0.6711 - precision: 0.5855 - recall: 0.6445 - val_loss: 1.0612 - val_accuracy: 0.7135 - val_precision: 0.6538 - val_recall: 0.6456
# Epoch 8/20
# 228/228 [==============================] - 109s 478ms/step - loss: 1.1153 - accuracy: 0.6736 - precision: 0.5842 - recall: 0.6533 - val_loss: 1.0683 - val_accuracy: 0.7083 - val_precision: 0.6513 - val_recall: 0.6266
# Epoch 9/20
# 228/228 [==============================] - 108s 475ms/step - loss: 1.1649 - accuracy: 0.6708 - precision: 0.5866 - recall: 0.6462 - val_loss: 1.0647 - val_accuracy: 0.7083 - val_precision: 0.6513 - val_recall: 0.6266
# Epoch 10/20
# 228/228 [==============================] - 108s 473ms/step - loss: 1.1522 - accuracy: 0.6730 - precision: 0.5868 - recall: 0.6457 - val_loss: 1.0641 - val_accuracy: 0.7135 - val_precision: 0.6538 - val_recall: 0.6456
# Epoch 11/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1631 - accuracy: 0.6642 - precision: 0.5794 - recall: 0.6419 - val_loss: 1.0598 - val_accuracy: 0.7188 - val_precision: 0.6582 - val_recall: 0.6582
# Epoch 12/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1717 - accuracy: 0.6672 - precision: 0.5804 - recall: 0.6398 - val_loss: 1.0673 - val_accuracy: 0.7083 - val_precision: 0.6513 - val_recall: 0.6266
# Epoch 13/20
# 228/228 [==============================] - 108s 476ms/step - loss: 1.1400 - accuracy: 0.6709 - precision: 0.5848 - recall: 0.6502 - val_loss: 1.0643 - val_accuracy: 0.7083 - val_precision: 0.6513 - val_recall: 0.6266
# Epoch 14/20
# 228/228 [==============================] - 107s 473ms/step - loss: 1.1496 - accuracy: 0.6851 - precision: 0.5974 - recall: 0.6611 - val_loss: 1.0718 - val_accuracy: 0.7083 - val_precision: 0.6554 - val_recall: 0.6139
# Epoch 15/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1464 - accuracy: 0.6737 - precision: 0.5797 - recall: 0.6560 - val_loss: 1.0711 - val_accuracy: 0.7083 - val_precision: 0.6554 - val_recall: 0.6139
# Epoch 16/20
# 228/228 [==============================] - 107s 471ms/step - loss: 1.1505 - accuracy: 0.6681 - precision: 0.5744 - recall: 0.6486 - val_loss: 1.0707 - val_accuracy: 0.7083 - val_precision: 0.6554 - val_recall: 0.6139
# Epoch 17/20
# 228/228 [==============================] - 108s 475ms/step - loss: 1.1355 - accuracy: 0.6759 - precision: 0.5920 - recall: 0.6529 - val_loss: 1.0681 - val_accuracy: 0.7083 - val_precision: 0.6513 - val_recall: 0.6266
# Epoch 18/20
# 228/228 [==============================] - 109s 478ms/step - loss: 1.1110 - accuracy: 0.6797 - precision: 0.5853 - recall: 0.6561 - val_loss: 1.0693 - val_accuracy: 0.7083 - val_precision: 0.6554 - val_recall: 0.6139
# Epoch 19/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.1215 - accuracy: 0.6758 - precision: 0.5829 - recall: 0.6496 - val_loss: 1.0642 - val_accuracy: 0.7109 - val_precision: 0.6536 - val_recall: 0.6329
# Epoch 20/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1337 - accuracy: 0.6743 - precision: 0.5846 - recall: 0.6542 - val_loss: 1.0633 - val_accuracy: 0.7135 - val_precision: 0.6538 - val_recall: 0.6456

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet.history[met])
    ax[i].plot(history_dpnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 30ms/step - loss: 1.0061 - accuracy: 0.7050 - precision: 0.6387 - recall: 0.5937
# Loss of the model is -  1.00613534450531
# Accuracy of the model is -  70.50147652626038 %
# Precision of the model is -  0.6387225389480591
# Recall of the model is -  0.5936920046806335

# %% [markdown]
# ## DP-Net - logits
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_logits_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-logits')
    return dpnet

# %%
dpnet_logits = dpnet_logits_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_logits.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=False,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_logits.summary()
# Out:
# Model: "DP-Net-logits"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_logits = dpnet_logits.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# 228/228 [==============================] - 116s 479ms/step - loss: 0.9043 - accuracy: 0.6277 - precision: 0.5308 - recall: 0.6301 - val_loss: 1.2720 - val_accuracy: 0.5911 - val_precision: 0.5019 - val_recall: 0.8354
# Epoch 2/20
# 228/228 [==============================] - 108s 473ms/step - loss: 1.1262 - accuracy: 0.6623 - precision: 0.5749 - recall: 0.6516 - val_loss: 1.9300 - val_accuracy: 0.5573 - val_precision: 0.4796 - val_recall: 0.8924
# Epoch 3/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.1298 - accuracy: 0.6668 - precision: 0.5735 - recall: 0.6587 - val_loss: 1.7526 - val_accuracy: 0.5990 - val_precision: 0.5072 - val_recall: 0.8924
# Epoch 4/20
# 228/228 [==============================] - 108s 476ms/step - loss: 1.0824 - accuracy: 0.6769 - precision: 0.5860 - recall: 0.6814 - val_loss: 0.9969 - val_accuracy: 0.6927 - val_precision: 0.6163 - val_recall: 0.6709
# Epoch 5/20
# 228/228 [==============================] - 109s 478ms/step - loss: 1.0785 - accuracy: 0.6809 - precision: 0.5949 - recall: 0.6644 - val_loss: 0.9869 - val_accuracy: 0.6901 - val_precision: 0.6226 - val_recall: 0.6266
# Epoch 6/20
# 228/228 [==============================] - 108s 476ms/step - loss: 1.1020 - accuracy: 0.6777 - precision: 0.5898 - recall: 0.6652 - val_loss: 1.0288 - val_accuracy: 0.6927 - val_precision: 0.6220 - val_recall: 0.6456
# Epoch 7/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.0578 - accuracy: 0.6856 - precision: 0.5988 - recall: 0.6813 - val_loss: 1.1150 - val_accuracy: 0.7005 - val_precision: 0.6114 - val_recall: 0.7468
# Epoch 8/20
# 228/228 [==============================] - 107s 468ms/step - loss: 1.1063 - accuracy: 0.6767 - precision: 0.5926 - recall: 0.6719 - val_loss: 1.0128 - val_accuracy: 0.6849 - val_precision: 0.6164 - val_recall: 0.6203
# Epoch 9/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.1075 - accuracy: 0.6728 - precision: 0.5832 - recall: 0.6700 - val_loss: 1.0246 - val_accuracy: 0.6927 - val_precision: 0.6163 - val_recall: 0.6709
# Epoch 10/20
# 228/228 [==============================] - 107s 468ms/step - loss: 1.1191 - accuracy: 0.6720 - precision: 0.5788 - recall: 0.6624 - val_loss: 1.0165 - val_accuracy: 0.6927 - val_precision: 0.6176 - val_recall: 0.6646
# Epoch 11/20
# 228/228 [==============================] - 108s 473ms/step - loss: 1.0977 - accuracy: 0.6711 - precision: 0.5778 - recall: 0.6654 - val_loss: 1.0163 - val_accuracy: 0.7031 - val_precision: 0.6250 - val_recall: 0.6962
# Epoch 12/20
# 228/228 [==============================] - 108s 475ms/step - loss: 1.1551 - accuracy: 0.6623 - precision: 0.5690 - recall: 0.6662 - val_loss: 1.0190 - val_accuracy: 0.6849 - val_precision: 0.6108 - val_recall: 0.6456
# Epoch 13/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.1164 - accuracy: 0.6760 - precision: 0.5852 - recall: 0.6571 - val_loss: 1.0161 - val_accuracy: 0.6901 - val_precision: 0.6154 - val_recall: 0.6582
# Epoch 14/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.1306 - accuracy: 0.6667 - precision: 0.5721 - recall: 0.6513 - val_loss: 1.0212 - val_accuracy: 0.6927 - val_precision: 0.6235 - val_recall: 0.6392
# Epoch 15/20
# 228/228 [==============================] - 107s 471ms/step - loss: 1.1094 - accuracy: 0.6712 - precision: 0.5797 - recall: 0.6655 - val_loss: 1.0186 - val_accuracy: 0.6927 - val_precision: 0.6250 - val_recall: 0.6329
# Epoch 16/20
# 228/228 [==============================] - 108s 473ms/step - loss: 1.1426 - accuracy: 0.6680 - precision: 0.5709 - recall: 0.6635 - val_loss: 1.0194 - val_accuracy: 0.6953 - val_precision: 0.6306 - val_recall: 0.6266
# Epoch 17/20
# 228/228 [==============================] - 108s 476ms/step - loss: 1.1046 - accuracy: 0.6770 - precision: 0.5859 - recall: 0.6766 - val_loss: 1.0186 - val_accuracy: 0.6901 - val_precision: 0.6182 - val_recall: 0.6456
# Epoch 18/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1089 - accuracy: 0.6745 - precision: 0.5877 - recall: 0.6655 - val_loss: 1.0196 - val_accuracy: 0.6927 - val_precision: 0.6235 - val_recall: 0.6392
# Epoch 19/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1232 - accuracy: 0.6705 - precision: 0.5884 - recall: 0.6523 - val_loss: 1.0167 - val_accuracy: 0.6875 - val_precision: 0.6131 - val_recall: 0.6519
# Epoch 20/20
# 228/228 [==============================] - 107s 468ms/step - loss: 1.1033 - accuracy: 0.6778 - precision: 0.5919 - recall: 0.6765 - val_loss: 1.0153 - val_accuracy: 0.6979 - val_precision: 0.6221 - val_recall: 0.6772

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_logits.history[met])
    ax[i].plot(history_dpnet_logits.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_logits.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 29ms/step - loss: 1.0024 - accuracy: 0.6991 - precision: 0.6189 - recall: 0.6327
# Loss of the model is -  1.0024014711380005
# Accuracy of the model is -  69.91150379180908 %
# Precision of the model is -  0.6188747882843018
# Recall of the model is -  0.6326530575752258

# %% [markdown]
# ## DP-Net nobn
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_nobn_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-nobn')
    return dpnet

# %%
dpnet_nobn = dpnet_nobn_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_nobn.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_nobn.summary()
# Out:
# Model: "DP-Net-nobn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                230432
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 241,777
# Trainable params: 241,777
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_nobn = dpnet_nobn.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 98s 411ms/step - loss: 1.6323 - accuracy: 0.5931 - precision: 0.2728 - recall: 0.0065 - val_loss: 1.3040 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 228/228 [==============================] - 94s 411ms/step - loss: 1.6541 - accuracy: 0.6028 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4720 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 228/228 [==============================] - 93s 410ms/step - loss: 1.7280 - accuracy: 0.5936 - precision: 0.3362 - recall: 1.3858e-04 - val_loss: 1.3915 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 228/228 [==============================] - 93s 408ms/step - loss: 1.6931 - accuracy: 0.5950 - precision: 0.6070 - recall: 3.1487e-04 - val_loss: 1.4510 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 228/228 [==============================] - 94s 415ms/step - loss: 1.7100 - accuracy: 0.5955 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4873 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 228/228 [==============================] - 93s 407ms/step - loss: 1.7453 - accuracy: 0.6003 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4589 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 228/228 [==============================] - 94s 413ms/step - loss: 1.7609 - accuracy: 0.5924 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4472 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 228/228 [==============================] - 93s 411ms/step - loss: 1.7116 - accuracy: 0.5997 - precision: 0.7729 - recall: 8.2808e-04 - val_loss: 1.4466 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 228/228 [==============================] - 93s 409ms/step - loss: 1.6975 - accuracy: 0.6034 - precision: 0.4694 - recall: 4.5184e-04 - val_loss: 1.4457 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 228/228 [==============================] - 94s 414ms/step - loss: 1.7188 - accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4442 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 228/228 [==============================] - 93s 408ms/step - loss: 1.7443 - accuracy: 0.5913 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4438 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.7173 - accuracy: 0.5988 - precision: 0.7336 - recall: 4.4374e-04 - val_loss: 1.4428 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 228/228 [==============================] - 93s 409ms/step - loss: 1.7048 - accuracy: 0.6004 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4419 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 228/228 [==============================] - 93s 408ms/step - loss: 1.6862 - accuracy: 0.6052 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4422 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 228/228 [==============================] - 93s 409ms/step - loss: 1.6931 - accuracy: 0.6017 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4426 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 228/228 [==============================] - 93s 408ms/step - loss: 1.7245 - accuracy: 0.5919 - precision: 0.1004 - recall: 3.5888e-05 - val_loss: 1.4420 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.7003 - accuracy: 0.6017 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4419 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 228/228 [==============================] - 93s 408ms/step - loss: 1.7198 - accuracy: 0.5954 - precision: 0.6856 - recall: 3.8765e-04 - val_loss: 1.4418 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.7334 - accuracy: 0.5935 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4411 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 228/228 [==============================] - 93s 409ms/step - loss: 1.7190 - accuracy: 0.5956 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4401 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_nobn.history[met])
    ax[i].plot(history_dpnet_nobn.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_nobn.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 29ms/step - loss: 1.3938 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss of the model is -  1.3938490152359009
# Accuracy of the model is -  60.25073528289795 %
# Precision of the model is -  0.0
# Recall of the model is -  0.0

# %% [markdown]
# ## DP-Net pneu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_pneu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-pneu')
    return dpnet

# %%
dpnet_pneu = dpnet_pneu_builder()

# load weights from pneumonia pretraining
dpnet_pneu.load_weights(weights_path+'dpnet_tanh_public_weights.h5')

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_pneu.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_pneu.summary()
# Out:
# Model: "DP-Net-pneu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_pneu = dpnet_pneu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 114s 472ms/step - loss: 0.9277 - accuracy: 0.6625 - precision: 0.5623 - recall: 0.7613 - val_loss: 4.3086 - val_accuracy: 0.4115 - val_precision: 0.4115 - val_recall: 1.0000
# Epoch 2/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1301 - accuracy: 0.6731 - precision: 0.5731 - recall: 0.7646 - val_loss: 2.2618 - val_accuracy: 0.5469 - val_precision: 0.4753 - val_recall: 0.9747
# Epoch 3/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.2060 - accuracy: 0.6825 - precision: 0.5796 - recall: 0.7586 - val_loss: 3.2602 - val_accuracy: 0.4401 - val_precision: 0.4236 - val_recall: 1.0000
# Epoch 4/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.2044 - accuracy: 0.6740 - precision: 0.5652 - recall: 0.7699 - val_loss: 2.4243 - val_accuracy: 0.5885 - val_precision: 0.5000 - val_recall: 0.0380
# Epoch 5/20
# 228/228 [==============================] - 108s 475ms/step - loss: 1.1915 - accuracy: 0.6883 - precision: 0.5853 - recall: 0.7717 - val_loss: 1.5531 - val_accuracy: 0.6536 - val_precision: 0.6582 - val_recall: 0.3291
# Epoch 6/20
# 228/228 [==============================] - 109s 479ms/step - loss: 1.2141 - accuracy: 0.6871 - precision: 0.5804 - recall: 0.7648 - val_loss: 1.5343 - val_accuracy: 0.6615 - val_precision: 0.6707 - val_recall: 0.3481
# Epoch 7/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1928 - accuracy: 0.6898 - precision: 0.5869 - recall: 0.7672 - val_loss: 1.6378 - val_accuracy: 0.6510 - val_precision: 0.6622 - val_recall: 0.3101
# Epoch 8/20
# 228/228 [==============================] - 108s 475ms/step - loss: 1.2415 - accuracy: 0.6925 - precision: 0.5955 - recall: 0.7622 - val_loss: 1.3572 - val_accuracy: 0.6927 - val_precision: 0.6852 - val_recall: 0.4684
# Epoch 9/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.2217 - accuracy: 0.6886 - precision: 0.5917 - recall: 0.7604 - val_loss: 1.3007 - val_accuracy: 0.7005 - val_precision: 0.6903 - val_recall: 0.4937
# Epoch 10/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.2348 - accuracy: 0.6927 - precision: 0.5919 - recall: 0.7587 - val_loss: 1.2275 - val_accuracy: 0.7057 - val_precision: 0.6037 - val_recall: 0.8291
# Epoch 11/20
# 228/228 [==============================] - 108s 475ms/step - loss: 1.2321 - accuracy: 0.6846 - precision: 0.5802 - recall: 0.7695 - val_loss: 1.1755 - val_accuracy: 0.7161 - val_precision: 0.6713 - val_recall: 0.6076
# Epoch 12/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.2033 - accuracy: 0.6922 - precision: 0.5945 - recall: 0.7724 - val_loss: 1.1509 - val_accuracy: 0.7318 - val_precision: 0.6425 - val_recall: 0.7848
# Epoch 13/20
# 228/228 [==============================] - 108s 476ms/step - loss: 1.1842 - accuracy: 0.6909 - precision: 0.5844 - recall: 0.7871 - val_loss: 1.1463 - val_accuracy: 0.7214 - val_precision: 0.6759 - val_recall: 0.6203
# Epoch 14/20
# 228/228 [==============================] - 109s 477ms/step - loss: 1.2063 - accuracy: 0.6917 - precision: 0.5879 - recall: 0.7786 - val_loss: 1.5404 - val_accuracy: 0.6536 - val_precision: 0.6471 - val_recall: 0.3481
# Epoch 15/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1815 - accuracy: 0.6968 - precision: 0.5937 - recall: 0.7745 - val_loss: 1.2725 - val_accuracy: 0.7057 - val_precision: 0.6923 - val_recall: 0.5127
# Epoch 16/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.2222 - accuracy: 0.6970 - precision: 0.6030 - recall: 0.7588 - val_loss: 1.1726 - val_accuracy: 0.7188 - val_precision: 0.6712 - val_recall: 0.6203
# Epoch 17/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.2057 - accuracy: 0.6985 - precision: 0.5932 - recall: 0.7702 - val_loss: 1.1342 - val_accuracy: 0.7448 - val_precision: 0.6648 - val_recall: 0.7658
# Epoch 18/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1944 - accuracy: 0.6949 - precision: 0.5891 - recall: 0.7627 - val_loss: 1.1419 - val_accuracy: 0.7344 - val_precision: 0.6728 - val_recall: 0.6899
# Epoch 19/20
# 228/228 [==============================] - 108s 475ms/step - loss: 1.2057 - accuracy: 0.6977 - precision: 0.5903 - recall: 0.7820 - val_loss: 1.1298 - val_accuracy: 0.7344 - val_precision: 0.6647 - val_recall: 0.7152
# Epoch 20/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1633 - accuracy: 0.6967 - precision: 0.5950 - recall: 0.7794 - val_loss: 1.1700 - val_accuracy: 0.7188 - val_precision: 0.6736 - val_recall: 0.6139

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_pneu.history[met])
    ax[i].plot(history_dpnet_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 28ms/step - loss: 1.2309 - accuracy: 0.7131 - precision: 0.6589 - recall: 0.5770
# Loss of the model is -  1.2308628559112549
# Accuracy of the model is -  71.31268382072449 %
# Precision of the model is -  0.6588982939720154
# Recall of the model is -  0.5769944190979004

# %% [markdown]
# ## Evaluation

# %%
models = [
    dpnet_relu,
    dpnet,
    dpnet_logits,
    dpnet_nobn,
    dpnet_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating DP-Net-relu ...
# 43/43 [==============================] - 1s 29ms/step - loss: 0.7948 - accuracy: 0.7360 - precision: 0.7202 - recall: 0.5492
#
#
# Evaluating DP-Net ...
# 43/43 [==============================] - 1s 29ms/step - loss: 1.0061 - accuracy: 0.7050 - precision: 0.6387 - recall: 0.5937
#
#
# Evaluating DP-Net-logits ...
# 43/43 [==============================] - 1s 29ms/step - loss: 1.0024 - accuracy: 0.6991 - precision: 0.6189 - recall: 0.6327
#
#
# Evaluating DP-Net-nobn ...
# 43/43 [==============================] - 1s 29ms/step - loss: 1.3938 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating DP-Net-pneu ...
# 43/43 [==============================] - 1s 28ms/step - loss: 1.2309 - accuracy: 0.7131 - precision: 0.6589 - recall: 0.5770

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 8.000

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 8.0
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.438% and noise_multiplier = 0.5644398166120053 iterated over 4562 steps satisfies differential privacy with eps = 8 and delta = 0.0001.
# 0.5644398166120053

# %% [markdown]
# #### Membership Inference Attack

# %%
# run membership inference attack
def run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack):
    # predict on train
    probs_train = model.predict(x_train_attack)
    # predict on test
    probs_test = model.predict(x_test_attack)

    # only label as output instead of prob
    #probs_train = np.round(logits_train)
    #probs_test = np.round(logits_test)

    # compute losses
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant

    loss_train = np.array([x[0] for x in bc(constant([[y] for y in y_train_attack]), constant(probs_train), from_logits=False).numpy()])
    loss_test = np.array([x[0] for x in bc(constant([[y] for y in y_test_attack]), constant(probs_test), from_logits=False).numpy()])

    # labels
    train_labels = np.array(y_train_attack)
    test_labels = np.array(y_test_attack)

    # prepare attacks
    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = train_labels,
        labels_test = test_labels
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,)

    attack_types = [
        AttackType.THRESHOLD_ATTACK,
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    plt.show()

    # print a user-friendly summary of the attacks
    print(attacks_result.summary(by_slices=False)) #TODO fix low auc sometimes

# %%
for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack)
    print('\n')
# Out:
# Membership Inference Attack on DP-Net-relu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 1356 training and 1356 test examples) achieved an AUC of 0.67 on slice Entire dataset
#   LOGISTIC_REGRESSION (with 1356 training and 1356 test examples) achieved an advantage of 0.29 on slice Entire dataset
#
#
# Membership Inference Attack on DP-Net...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   THRESHOLD_ATTACK (with 2919 training and 539 test examples) achieved an AUC of 0.35 on slice CLASS=1
#   THRESHOLD_ATTACK (with 2919 training and 539 test examples) achieved an advantage of 0.24 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-logits...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   THRESHOLD_ATTACK (with 2919 training and 539 test examples) achieved an AUC of 0.35 on slice CLASS=1
#   THRESHOLD_ATTACK (with 2919 training and 539 test examples) achieved an advantage of 0.24 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-nobn...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.71 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.35 on slice CLASS=1
#
#
# Membership Inference Attack on DP-Net-pneu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.65 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.30 on slice CLASS=1
