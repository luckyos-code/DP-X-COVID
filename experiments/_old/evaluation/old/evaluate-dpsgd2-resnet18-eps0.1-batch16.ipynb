# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install 'tensorflow-privacy==0.5.2'
#!pip -q install git+https://github.com/tensorflow/privacy #TODO fix this
# Out:
#      |████████████████████████████████| 194kB 9.1MB/s

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.experimental.preprocessing import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

#import tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.plotting as plotting
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackType
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import SlicingSpec
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack.data_structures import AttackInputData
#from tensorflow_privacy.privacy.privacy_tests.membership_inference_attack import membership_inference_attack as mia

import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 780MB [00:05, 132MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.1
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 16
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 5.91
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-test split
x_train, x_test, y_train, y_test = train_test_split(files, labels, test_size=TEST_SPLIT, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(files, labels, test_size=VAL_SPLIT, random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 8136, Val: 904, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4883, 'COVID-19': 3253}
# val set:  {'normal': 541, 'COVID-19': 363}
# test set:   {'normal': 817, 'COVID-19': 539}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# seperate train labels and images for attacks
x_train_attack = prepare_dataset(train_ds,
                                 pre=True,
                                 shuffle=True,
                                 repeat=False,
                                 batch=1,
                                 augment=False,
                                 cache=False)

y_train_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(x_train_attack):
    y_train_attack.append(y)

# seperate test labels and images for attacks
x_test_attack = prepare_dataset(test_ds,
                                pre=True,
                                shuffle=False,
                                repeat=False,
                                batch=1,
                                augment=False,
                                cache=False)

y_test_attack = []
for x, y in tf.data.Dataset.as_numpy_iterator(x_test_attack):
    y_test_attack.append(y)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## ResNet18V2 relu
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('relu', name=name + '_preact_relu')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride)(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('relu', name=name + '_1_relu')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('relu', name=name + '_2_relu')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    x = stack_fn(x)
    x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
    x = Activation('relu', name='post_relu')(x)
    # Create model.
    model = tf.keras.models.Model(input, x, name=model_name)
    return model

def ResNet18V2(input):
    def stack_fn(x):
        x = resnet_stack(x, 16, 2, name='conv2') # original: 64
        x = resnet_stack(x, 32, 2, name='conv3')
        x = resnet_stack(x, 64, 2, name='conv4')
        x = resnet_stack(x, 128, 2, stride1=1, name='conv5')
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_relu_builder():
    # ResNet18V2 without head
    resnet18 = ResNet18V2(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet18V2-relu')
    
    return model

# %%
resnet18_relu = resnet18_relu_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet18_relu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet18_relu.summary()
# Out:
# Model: "ResNet18V2-relu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_6 (ModuleWrap (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet18_relu = resnet18_relu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 205s 313ms/step - loss: 0.6993 - accuracy: 0.4143 - precision: 0.4012 - recall: 0.9209 - val_loss: 0.6970 - val_accuracy: 0.4598 - val_precision: 0.3369 - val_recall: 0.3518
# Epoch 2/20
# 508/508 [==============================] - 156s 308ms/step - loss: 0.6999 - accuracy: 0.5749 - precision: 0.4319 - recall: 0.1250 - val_loss: 0.6756 - val_accuracy: 0.6105 - val_precision: 0.5156 - val_recall: 0.5485
# Epoch 3/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.7446 - accuracy: 0.5978 - precision: 0.9941 - recall: 0.0015 - val_loss: 0.7152 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.7661 - accuracy: 0.5986 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.0607 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 508/508 [==============================] - 156s 308ms/step - loss: 0.8639 - accuracy: 0.5958 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7390 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 508/508 [==============================] - 157s 309ms/step - loss: 0.8735 - accuracy: 0.5975 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7460 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 508/508 [==============================] - 156s 308ms/step - loss: 0.8876 - accuracy: 0.5942 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7444 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.8849 - accuracy: 0.5960 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7446 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 508/508 [==============================] - 156s 308ms/step - loss: 0.8863 - accuracy: 0.5973 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7462 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 508/508 [==============================] - 156s 308ms/step - loss: 0.8801 - accuracy: 0.5988 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7443 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.8828 - accuracy: 0.5988 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7459 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.8725 - accuracy: 0.6052 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7463 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.8872 - accuracy: 0.5957 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7452 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.8826 - accuracy: 0.5988 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7456 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 508/508 [==============================] - 156s 308ms/step - loss: 0.8858 - accuracy: 0.5970 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7457 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.8867 - accuracy: 0.5991 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7465 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.8873 - accuracy: 0.5964 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7473 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.8820 - accuracy: 0.6000 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7471 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 508/508 [==============================] - 156s 308ms/step - loss: 0.8787 - accuracy: 0.5998 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7466 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 508/508 [==============================] - 156s 308ms/step - loss: 0.8888 - accuracy: 0.5967 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 0.7467 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet18_relu.history[met])
    ax[i].plot(history_resnet18_relu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet18_relu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 2s 20ms/step - loss: 0.7377 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss of the model is -  0.7376603484153748
# Accuracy of the model is -  60.25073528289795 %
# Precision of the model is -  0.0
# Recall of the model is -  0.0

# %% [markdown]
# ## ResNet18V2 (DP-SGD)
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('tanh', name=name + '_preact_tanh')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride)(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('tanh', name=name + '_1_tanh')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('tanh', name=name + '_2_tanh')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    x = stack_fn(x)
    x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
    x = Activation('tanh', name='post_tanh')(x)
    # Create model
    model = tf.keras.models.Model(input, x, name=model_name)
    return model
    
def ResNet18V2(input):
    def stack_fn(x):
        x = resnet_stack(x, 16, 2, name='conv2') # original: 64
        x = resnet_stack(x, 32, 2, name='conv3')
        x = resnet_stack(x, 64, 2, name='conv4')
        x = resnet_stack(x, 128, 2, stride1=1, name='conv5')
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_builder():
    # get ResNet18V2 without head
    resnet18 = ResNet18V2(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet18V2')

    return model

# %%
resnet18 = resnet18_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet18.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet18.summary()
# Out:
# Model: "ResNet18V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_7 (ModuleWrap (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet18 = resnet18.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 177s 308ms/step - loss: 0.6827 - accuracy: 0.5536 - precision: 0.4592 - recall: 0.6098 - val_loss: 0.6675 - val_accuracy: 0.6596 - val_precision: 0.5633 - val_recall: 0.6898
# Epoch 2/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6549 - accuracy: 0.6553 - precision: 0.5687 - recall: 0.5782 - val_loss: 0.6686 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6542 - accuracy: 0.6548 - precision: 0.5759 - recall: 0.5567 - val_loss: 0.6558 - val_accuracy: 0.6049 - val_precision: 1.0000 - val_recall: 0.0194
# Epoch 4/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6536 - accuracy: 0.6385 - precision: 0.5577 - recall: 0.5130 - val_loss: 0.8046 - val_accuracy: 0.4743 - val_precision: 0.4282 - val_recall: 0.9086
# Epoch 5/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6523 - accuracy: 0.6535 - precision: 0.5778 - recall: 0.5132 - val_loss: 0.7166 - val_accuracy: 0.5971 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6412 - accuracy: 0.6721 - precision: 0.6110 - recall: 0.5170 - val_loss: 0.6109 - val_accuracy: 0.6786 - val_precision: 0.6077 - val_recall: 0.5706
# Epoch 7/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6506 - accuracy: 0.6670 - precision: 0.5995 - recall: 0.5220 - val_loss: 0.6092 - val_accuracy: 0.6652 - val_precision: 0.6187 - val_recall: 0.4404
# Epoch 8/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6554 - accuracy: 0.6588 - precision: 0.5918 - recall: 0.5265 - val_loss: 0.6032 - val_accuracy: 0.6819 - val_precision: 0.6462 - val_recall: 0.4654
# Epoch 9/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6490 - accuracy: 0.6680 - precision: 0.5961 - recall: 0.5424 - val_loss: 0.6381 - val_accuracy: 0.6819 - val_precision: 0.5826 - val_recall: 0.7424
# Epoch 10/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6591 - accuracy: 0.6568 - precision: 0.5804 - recall: 0.5353 - val_loss: 0.6094 - val_accuracy: 0.6629 - val_precision: 0.6482 - val_recall: 0.3573
# Epoch 11/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6468 - accuracy: 0.6692 - precision: 0.6038 - recall: 0.5463 - val_loss: 0.6078 - val_accuracy: 0.6775 - val_precision: 0.5994 - val_recall: 0.6011
# Epoch 12/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6501 - accuracy: 0.6622 - precision: 0.5822 - recall: 0.5361 - val_loss: 0.6137 - val_accuracy: 0.6786 - val_precision: 0.5943 - val_recall: 0.6371
# Epoch 13/20
# 508/508 [==============================] - 156s 308ms/step - loss: 0.6460 - accuracy: 0.6652 - precision: 0.5877 - recall: 0.5446 - val_loss: 0.6089 - val_accuracy: 0.6763 - val_precision: 0.5962 - val_recall: 0.6094
# Epoch 14/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6429 - accuracy: 0.6672 - precision: 0.5816 - recall: 0.5473 - val_loss: 0.6098 - val_accuracy: 0.6786 - val_precision: 0.5973 - val_recall: 0.6205
# Epoch 15/20
# 508/508 [==============================] - 156s 308ms/step - loss: 0.6532 - accuracy: 0.6617 - precision: 0.5934 - recall: 0.5441 - val_loss: 0.6094 - val_accuracy: 0.6763 - val_precision: 0.5957 - val_recall: 0.6122
# Epoch 16/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6527 - accuracy: 0.6687 - precision: 0.5887 - recall: 0.5616 - val_loss: 0.6087 - val_accuracy: 0.6797 - val_precision: 0.6016 - val_recall: 0.6066
# Epoch 17/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6539 - accuracy: 0.6617 - precision: 0.5755 - recall: 0.5528 - val_loss: 0.6080 - val_accuracy: 0.6808 - val_precision: 0.6033 - val_recall: 0.6066
# Epoch 18/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6483 - accuracy: 0.6613 - precision: 0.5827 - recall: 0.5436 - val_loss: 0.6089 - val_accuracy: 0.6786 - val_precision: 0.5989 - val_recall: 0.6122
# Epoch 19/20
# 508/508 [==============================] - 156s 306ms/step - loss: 0.6587 - accuracy: 0.6549 - precision: 0.5799 - recall: 0.5343 - val_loss: 0.6097 - val_accuracy: 0.6786 - val_precision: 0.5973 - val_recall: 0.6205
# Epoch 20/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6529 - accuracy: 0.6648 - precision: 0.5805 - recall: 0.5484 - val_loss: 0.6090 - val_accuracy: 0.6786 - val_precision: 0.5979 - val_recall: 0.6177

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet18.history[met])
    ax[i].plot(history_resnet18.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet18.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 1s 10ms/step - loss: 0.6039 - accuracy: 0.6858 - precision: 0.5986 - recall: 0.6364
# Loss of the model is -  0.6038860082626343
# Accuracy of the model is -  68.58407258987427 %
# Precision of the model is -  0.5986038446426392
# Recall of the model is -  0.6363636255264282

# %% [markdown]
# ## ResNet18V2 - dropout
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('tanh', name=name + '_preact_tanh')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride)(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('tanh', name=name + '_1_tanh')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('tanh', name=name + '_2_tanh')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    x = stack_fn(x)
    x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
    x = Activation('tanh', name='post_tanh')(x)
    # Create model
    model = tf.keras.models.Model(input, x, name=model_name)
    return model
    
def ResNet18V2(input):
    def stack_fn(x):
        x = resnet_stack(x, 16, 2, name='conv2') # original: 64
        x = resnet_stack(x, 32, 2, name='conv3')
        x = resnet_stack(x, 64, 2, name='conv4')
        x = resnet_stack(x, 128, 2, stride1=1, name='conv5')
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_drop_builder():
    # ResNet18V2 without head
    resnet18 = ResNet18V2(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dropout(0.2, name='Dropout'), # add dropout (inspired by inception-resnet-v2)
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet18V2-drop')
    
    return model

# %%
resnet18_drop = resnet18_drop_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet18_drop.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet18_drop.summary()
# Out:
# Model: "ResNet18V2-drop"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_8 (ModuleWrap (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet18_drop = resnet18_drop.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 177s 308ms/step - loss: 0.6872 - accuracy: 0.5446 - precision: 0.4444 - recall: 0.5449 - val_loss: 0.7235 - val_accuracy: 0.4911 - val_precision: 0.4339 - val_recall: 0.8643
# Epoch 2/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6678 - accuracy: 0.6123 - precision: 0.5098 - recall: 0.6556 - val_loss: 0.6326 - val_accuracy: 0.6663 - val_precision: 0.5975 - val_recall: 0.5263
# Epoch 3/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6544 - accuracy: 0.6351 - precision: 0.5324 - recall: 0.6537 - val_loss: 0.6231 - val_accuracy: 0.6629 - val_precision: 0.5758 - val_recall: 0.6205
# Epoch 4/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6506 - accuracy: 0.6425 - precision: 0.5456 - recall: 0.6337 - val_loss: 0.6349 - val_accuracy: 0.6417 - val_precision: 0.5763 - val_recall: 0.4183
# Epoch 5/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6469 - accuracy: 0.6484 - precision: 0.5531 - recall: 0.6358 - val_loss: 0.6740 - val_accuracy: 0.5971 - val_precision: 0.5000 - val_recall: 0.0055
# Epoch 6/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6405 - accuracy: 0.6552 - precision: 0.5609 - recall: 0.6218 - val_loss: 0.6296 - val_accuracy: 0.6685 - val_precision: 0.5821 - val_recall: 0.6288
# Epoch 7/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6504 - accuracy: 0.6535 - precision: 0.5597 - recall: 0.6054 - val_loss: 0.6109 - val_accuracy: 0.6842 - val_precision: 0.6168 - val_recall: 0.5706
# Epoch 8/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6401 - accuracy: 0.6557 - precision: 0.5582 - recall: 0.6088 - val_loss: 0.6167 - val_accuracy: 0.6830 - val_precision: 0.6170 - val_recall: 0.5623
# Epoch 9/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6452 - accuracy: 0.6634 - precision: 0.5822 - recall: 0.6225 - val_loss: 0.6161 - val_accuracy: 0.6641 - val_precision: 0.6014 - val_recall: 0.4931
# Epoch 10/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6413 - accuracy: 0.6666 - precision: 0.5813 - recall: 0.6219 - val_loss: 0.6287 - val_accuracy: 0.6808 - val_precision: 0.6005 - val_recall: 0.6205
# Epoch 11/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6521 - accuracy: 0.6590 - precision: 0.5693 - recall: 0.6174 - val_loss: 0.6266 - val_accuracy: 0.6819 - val_precision: 0.6016 - val_recall: 0.6233
# Epoch 12/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6468 - accuracy: 0.6599 - precision: 0.5747 - recall: 0.6247 - val_loss: 0.6275 - val_accuracy: 0.6819 - val_precision: 0.6005 - val_recall: 0.6288
# Epoch 13/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6381 - accuracy: 0.6759 - precision: 0.5921 - recall: 0.6365 - val_loss: 0.6273 - val_accuracy: 0.6819 - val_precision: 0.6022 - val_recall: 0.6205
# Epoch 14/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6378 - accuracy: 0.6635 - precision: 0.5723 - recall: 0.6277 - val_loss: 0.6269 - val_accuracy: 0.6808 - val_precision: 0.6027 - val_recall: 0.6094
# Epoch 15/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6356 - accuracy: 0.6672 - precision: 0.5767 - recall: 0.6345 - val_loss: 0.6264 - val_accuracy: 0.6763 - val_precision: 0.5989 - val_recall: 0.5956
# Epoch 16/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6438 - accuracy: 0.6702 - precision: 0.5844 - recall: 0.6250 - val_loss: 0.6284 - val_accuracy: 0.6786 - val_precision: 0.5984 - val_recall: 0.6150
# Epoch 17/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6425 - accuracy: 0.6718 - precision: 0.5890 - recall: 0.6281 - val_loss: 0.6280 - val_accuracy: 0.6819 - val_precision: 0.6011 - val_recall: 0.6260
# Epoch 18/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6550 - accuracy: 0.6572 - precision: 0.5691 - recall: 0.6125 - val_loss: 0.6278 - val_accuracy: 0.6830 - val_precision: 0.6027 - val_recall: 0.6260
# Epoch 19/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6507 - accuracy: 0.6610 - precision: 0.5696 - recall: 0.6169 - val_loss: 0.6283 - val_accuracy: 0.6819 - val_precision: 0.6011 - val_recall: 0.6260
# Epoch 20/20
# 508/508 [==============================] - 156s 307ms/step - loss: 0.6404 - accuracy: 0.6806 - precision: 0.6035 - recall: 0.6325 - val_loss: 0.6282 - val_accuracy: 0.6819 - val_precision: 0.6005 - val_recall: 0.6288

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet18_drop.history[met])
    ax[i].plot(history_resnet18_drop.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet18_drop.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 2s 23ms/step - loss: 0.6193 - accuracy: 0.6851 - precision: 0.5959 - recall: 0.6456
# Loss of the model is -  0.6192687153816223
# Accuracy of the model is -  68.51032376289368 %
# Precision of the model is -  0.5958904027938843
# Recall of the model is -  0.6456400752067566

# %% [markdown]
# ## ResNet18V2 pneu
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('tanh', name=name + '_preact_tanh')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride)(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('tanh', name=name + '_1_tanh')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('tanh', name=name + '_2_tanh')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    x = stack_fn(x)
    x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
    x = Activation('tanh', name='post_tanh')(x)
    # Create model
    model = tf.keras.models.Model(input, x, name=model_name)
    return model
    
def ResNet18V2(input):
    def stack_fn(x):
        x = resnet_stack(x, 16, 2, name='conv2') # original: 64
        x = resnet_stack(x, 32, 2, name='conv3')
        x = resnet_stack(x, 64, 2, name='conv4')
        x = resnet_stack(x, 128, 2, stride1=1, name='conv5')
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_pneu_builder():
    # ResNet18V2 without head
    resnet18 = ResNet18V2(Input(shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])))
    model = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        resnet18, # add resnet18 to model
        GlobalAveragePooling2D(name='AvgPool'), # add last pooling layer
        Dense(units=1, activation='sigmoid', name='Output'), # add classification layer for normal/COVID-19
    ], name='ResNet18V2-pneu')
    
    return model

# %%
resnet18_pneu = resnet18_pneu_builder()

# load weights from pneumonia pretraining
resnet18_pneu.load_weights(weights_path+'resnet18_tanh_public_weights.h5')

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet18_pneu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
resnet18_pneu.summary()
# Out:
# Model: "ResNet18V2-pneu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# module_wrapper_9 (ModuleWrap (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet18_pneu = resnet18_pneu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks = [learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 508/508 [==============================] - 177s 308ms/step - loss: 0.8565 - accuracy: 0.6586 - precision: 0.5498 - recall: 0.7918 - val_loss: 1.7843 - val_accuracy: 0.5848 - val_precision: 0.4918 - val_recall: 0.9086
# Epoch 2/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.0176 - accuracy: 0.6977 - precision: 0.6028 - recall: 0.7456 - val_loss: 6.3334 - val_accuracy: 0.4040 - val_precision: 0.4034 - val_recall: 1.0000
# Epoch 3/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.0317 - accuracy: 0.7002 - precision: 0.6098 - recall: 0.7500 - val_loss: 4.3437 - val_accuracy: 0.5926 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1452 - accuracy: 0.7100 - precision: 0.6245 - recall: 0.7330 - val_loss: 1.1737 - val_accuracy: 0.7098 - val_precision: 0.6535 - val_recall: 0.5956
# Epoch 5/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.0997 - accuracy: 0.7048 - precision: 0.6157 - recall: 0.7337 - val_loss: 1.3629 - val_accuracy: 0.6763 - val_precision: 0.6340 - val_recall: 0.4654
# Epoch 6/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1425 - accuracy: 0.7036 - precision: 0.6158 - recall: 0.7162 - val_loss: 1.2336 - val_accuracy: 0.7054 - val_precision: 0.6520 - val_recall: 0.5762
# Epoch 7/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1066 - accuracy: 0.7082 - precision: 0.6124 - recall: 0.7395 - val_loss: 1.2344 - val_accuracy: 0.7020 - val_precision: 0.6536 - val_recall: 0.5540
# Epoch 8/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1167 - accuracy: 0.7058 - precision: 0.6079 - recall: 0.7404 - val_loss: 1.2387 - val_accuracy: 0.7031 - val_precision: 0.6498 - val_recall: 0.5706
# Epoch 9/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1383 - accuracy: 0.7016 - precision: 0.6112 - recall: 0.7277 - val_loss: 1.2472 - val_accuracy: 0.7087 - val_precision: 0.6562 - val_recall: 0.5817
# Epoch 10/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1487 - accuracy: 0.7075 - precision: 0.6128 - recall: 0.7322 - val_loss: 1.2225 - val_accuracy: 0.7098 - val_precision: 0.6544 - val_recall: 0.5928
# Epoch 11/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1488 - accuracy: 0.7056 - precision: 0.6152 - recall: 0.7180 - val_loss: 1.2380 - val_accuracy: 0.7109 - val_precision: 0.6574 - val_recall: 0.5900
# Epoch 12/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1431 - accuracy: 0.6999 - precision: 0.6139 - recall: 0.7172 - val_loss: 1.2603 - val_accuracy: 0.7031 - val_precision: 0.6518 - val_recall: 0.5651
# Epoch 13/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.0736 - accuracy: 0.7174 - precision: 0.6300 - recall: 0.7384 - val_loss: 1.2317 - val_accuracy: 0.7121 - val_precision: 0.6585 - val_recall: 0.5928
# Epoch 14/20
# 508/508 [==============================] - 156s 308ms/step - loss: 1.1301 - accuracy: 0.7134 - precision: 0.6202 - recall: 0.7377 - val_loss: 1.2389 - val_accuracy: 0.7109 - val_precision: 0.6574 - val_recall: 0.5900
# Epoch 15/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1074 - accuracy: 0.7162 - precision: 0.6280 - recall: 0.7384 - val_loss: 1.2294 - val_accuracy: 0.7121 - val_precision: 0.6565 - val_recall: 0.5983
# Epoch 16/20
# 508/508 [==============================] - 156s 306ms/step - loss: 1.1230 - accuracy: 0.7115 - precision: 0.6181 - recall: 0.7385 - val_loss: 1.2267 - val_accuracy: 0.7087 - val_precision: 0.6534 - val_recall: 0.5900
# Epoch 17/20
# 508/508 [==============================] - 156s 306ms/step - loss: 1.1592 - accuracy: 0.7014 - precision: 0.6038 - recall: 0.7348 - val_loss: 1.2403 - val_accuracy: 0.7132 - val_precision: 0.6595 - val_recall: 0.5956
# Epoch 18/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1346 - accuracy: 0.7085 - precision: 0.6244 - recall: 0.7350 - val_loss: 1.2363 - val_accuracy: 0.7098 - val_precision: 0.6573 - val_recall: 0.5845
# Epoch 19/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1257 - accuracy: 0.7083 - precision: 0.6186 - recall: 0.7243 - val_loss: 1.2352 - val_accuracy: 0.7109 - val_precision: 0.6574 - val_recall: 0.5900
# Epoch 20/20
# 508/508 [==============================] - 156s 307ms/step - loss: 1.1386 - accuracy: 0.7099 - precision: 0.6107 - recall: 0.7287 - val_loss: 1.2473 - val_accuracy: 0.7054 - val_precision: 0.6530 - val_recall: 0.5734

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet18_pneu.history[met])
    ax[i].plot(history_resnet18_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet18_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 85/85 [==============================] - 2s 25ms/step - loss: 1.2259 - accuracy: 0.7176 - precision: 0.6529 - recall: 0.6178
# Loss of the model is -  1.225852131843567
# Accuracy of the model is -  71.75516486167908 %
# Precision of the model is -  0.6529411673545837
# Recall of the model is -  0.6178107857704163

# %% [markdown]
# ## Evaluation

# %%
models = [
    resnet18_relu,
    resnet18,
    resnet18_drop,
    resnet18_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating ResNet18V2-relu ...
# 85/85 [==============================] - 2s 25ms/step - loss: 0.7377 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating ResNet18V2 ...
# 85/85 [==============================] - 2s 24ms/step - loss: 0.6039 - accuracy: 0.6858 - precision: 0.5986 - recall: 0.6364
#
#
# Evaluating ResNet18V2-drop ...
# 85/85 [==============================] - 2s 24ms/step - loss: 0.6193 - accuracy: 0.6851 - precision: 0.5959 - recall: 0.6456
#
#
# Evaluating ResNet18V2-pneu ...
# 85/85 [==============================] - 2s 24ms/step - loss: 1.2259 - accuracy: 0.7176 - precision: 0.6529 - recall: 0.6178

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 0.102

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 0.1
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.197% and noise_multiplier = 5.914696365295647 iterated over 10170 steps satisfies differential privacy with eps = 0.1 and delta = 0.0001.
# 5.914696365295647

# %% [markdown]
# #### Membership Inference Attack

# %%
# run membership inference attack
def run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack):
    # predict on train
    probs_train = model.predict(x_train_attack)
    # predict on test
    probs_test = model.predict(x_test_attack)

    # only label as output instead of prob
    #probs_train = np.round(logits_train)
    #probs_test = np.round(logits_test)

    # compute losses
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant

    loss_train = np.array([x[0] for x in bc(constant([[y] for y in y_train_attack]), constant(probs_train), from_logits=False).numpy()])
    loss_test = np.array([x[0] for x in bc(constant([[y] for y in y_test_attack]), constant(probs_test), from_logits=False).numpy()])

    # labels
    train_labels = np.array(y_train_attack)
    test_labels = np.array(y_test_attack)

    # prepare attacks
    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = train_labels,
        labels_test = test_labels
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,)

    attack_types = [
        AttackType.THRESHOLD_ATTACK,
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    plt.show()

    # print a user-friendly summary of the attacks
    print(attacks_result.summary(by_slices=False)) #TODO fix low auc sometimes

# %%
for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    run_mia(model, x_train_attack, x_test_attack, y_train_attack, y_test_attack)
    print('\n')
# Out:
# Membership Inference Attack on ResNet18V2-relu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   THRESHOLD_ATTACK (with 3253 training and 539 test examples) achieved an AUC of 0.39 on slice CLASS=1
#   THRESHOLD_ATTACK (with 3253 training and 539 test examples) achieved an advantage of 0.16 on slice CLASS=1
#
#
# Membership Inference Attack on ResNet18V2...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.68 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.29 on slice CLASS=1
#
#
# Membership Inference Attack on ResNet18V2-drop...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.62 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.25 on slice CLASS=1
#
#
# Membership Inference Attack on ResNet18V2-pneu...
# Suspiciously low AUC detected: %.2f. There might be a bug in the classifier
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.71 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.35 on slice CLASS=1
