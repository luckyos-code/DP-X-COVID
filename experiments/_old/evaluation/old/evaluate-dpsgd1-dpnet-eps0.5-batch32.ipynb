# %% [markdown]
# # Detection of COVID-19 in X-Ray Images (COVID-19 vs. Normal)

# %%
# set up path to doogle drive folder with weights
weights_path = '/content/drive/MyDrive/Uni/MA/model_weights/'

# %% [markdown]
# ##### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip -q install 'tensorflow-privacy==0.5.2'
#!pip -q install git+https://github.com/tensorflow/privacy #TODO fix this
# Out:
#      |████████████████████████████████| 194kB 15.4MB/s

# %% [markdown]
# ##### Import libraries

# %%
import os, random
import numpy as np
import seaborn as sns
import tensorflow as tf
import matplotlib.pyplot as plt

from sklearn.utils import class_weight
from sklearn.model_selection import train_test_split

import keras
from keras.models import Sequential
from keras.losses import BinaryCrossentropy
from keras.callbacks import ReduceLROnPlateau
from tensorflow.keras.applications import ResNet50V2
from keras.preprocessing.image import ImageDataGenerator
from keras.layers.experimental.preprocessing import Resizing, Rescaling, RandomFlip, RandomRotation, RandomTranslation, RandomZoom
from keras.layers import Layer, Input, InputLayer, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, ZeroPadding2D, Flatten

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.analysis.compute_noise_from_budget_lib import compute_noise
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasAdamOptimizer

import tensorflow_privacy.privacy.membership_inference_attack.plotting as plotting
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackType
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SlicingSpec
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import AttackInputData
from tensorflow_privacy.privacy.membership_inference_attack.data_structures import SingleAttackResult
from tensorflow_privacy.privacy.membership_inference_attack import membership_inference_attack as mia

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 780MB [00:12, 64.8MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Data parameters
TEST_SPLIT = 0.15
VAL_SPLIT = 0.05
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 32
IMG_SHAPE = [256, 256, 3] # original dataset image size is 299x299x3
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 2.083
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# Set fixed random seed
SEED = 42
random.seed(SEED)
random_state = SEED
np.random.seed(SEED)
tf.random.set_seed(SEED)

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-test split
x_train, x_test, y_train, y_test = train_test_split(files, labels, test_size=TEST_SPLIT, random_state=random_state)
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=VAL_SPLIT, random_state=random_state)

# %%
TRAIN_IMG_COUNT = len(y_train)
VAL_IMG_COUNT = len(y_val)
TEST_IMG_COUNT = len(y_test)
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 7299, Val: 385, Test: 1356

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set: ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4380, 'COVID-19': 2919}
# val set:  {'normal': 227, 'COVID-19': 158}
# test set:   {'normal': 817, 'COVID-19': 539}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
preprocessing = Sequential([
  Resizing(IMG_SHAPE[0], IMG_SHAPE[1]),
  Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for overview
datagen = ImageDataGenerator(
        rotation_range=10,
        zoom_range=(0.85, 1.15),
        brightness_range=(0.9, 1.1),
        width_shift_range=0.1,
        height_shift_range=0.1,
        horizontal_flip = True,
        fill_mode='constant',
        cval=0.,)

# %%
class RandomBrightness(Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = Sequential([
  RandomFlip("horizontal"),
  RandomRotation(0.1, fill_mode='constant'),
  RandomTranslation(0.1, 0.1, fill_mode='constant'),
  RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_dataset(ds, cache=True, pre=False, shuffle=False, repeat=False, batch=False, augment=False, shuffle_buffer_size=1000):
    # give string to cache preprocessing for datasets outside of memory
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()
    # Resize and rescale images
    if pre:
        ds = ds.map(lambda x, y: (preprocessing(x), y),
                    num_parallel_calls=AUTOTUNE)
    # shuffle dataset
    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)
    # repeat set forever or once
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)
    # batch dataset
    if batch:
        if str(batch) == '1':
            ds = ds.batch(batch).prefetch(buffer_size=AUTOTUNE)
        else:
            ds = ds.batch(BATCH_SIZE).prefetch(buffer_size=AUTOTUNE)
    # use data augmentation
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
# batch datasets
train_batched = prepare_dataset(train_ds,
                                pre=True,
                                shuffle=True,
                                repeat=True,
                                batch=True,
                                augment=True,
                                cache='./data.tfcache')
val_batched = prepare_dataset(val_ds,
                              pre=True,
                              shuffle=False,
                              repeat=False,
                              batch=True,
                              augment=False)
test_batched = prepare_dataset(test_ds,
                               pre=True,
                               shuffle=False,
                               repeat=False,
                               batch=True,
                               augment=False)

# %%
# set for attack on train set
train_attack_data = prepare_dataset(train_ds,
                                    pre=True,
                                    shuffle=False,
                                    repeat=False,
                                    batch=1,
                                    augment=False,
                                    cache=False)

# set for attack on test set
test_attack_data = prepare_dataset(test_ds,
                                   pre=True,
                                   shuffle=False,
                                   repeat=False,
                                   batch=1,
                                   augment=False,
                                   cache=False)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# ###### Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)
class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())

print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ## DP-Net - relu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_relu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='relu'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='relu'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-relu')
    return dpnet

# %%
dpnet_relu = dpnet_relu_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_relu.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_relu.summary()
# Out:
# Model: "DP-Net-relu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization (BatchNo (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 7200)              0
# _________________________________________________________________
# dense (Dense)                (None, 32)                230432
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 32)                128
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_relu = dpnet_relu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/array_ops.py:5049: calling gather (from tensorflow.python.ops.array_ops) with validate_indices is deprecated and will be removed in a future version.
# Instructions for updating:
# The `validate_indices` argument has no effect. Indices are always validated on CPU and never validated on GPU.
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 145s 487ms/step - loss: 0.8291 - accuracy: 0.5328 - precision: 0.4329 - recall: 0.5403 - val_loss: 0.7055 - val_accuracy: 0.5312 - val_precision: 0.4618 - val_recall: 0.8418
# Epoch 2/20
# 228/228 [==============================] - 105s 463ms/step - loss: 0.8205 - accuracy: 0.5737 - precision: 0.4786 - recall: 0.5621 - val_loss: 0.7117 - val_accuracy: 0.6146 - val_precision: 0.5212 - val_recall: 0.7785
# Epoch 3/20
# 228/228 [==============================] - 106s 467ms/step - loss: 0.7745 - accuracy: 0.6026 - precision: 0.5057 - recall: 0.5867 - val_loss: 0.7206 - val_accuracy: 0.6276 - val_precision: 0.5359 - val_recall: 0.7089
# Epoch 4/20
# 228/228 [==============================] - 107s 469ms/step - loss: 0.7923 - accuracy: 0.6155 - precision: 0.5200 - recall: 0.5911 - val_loss: 0.7356 - val_accuracy: 0.6458 - val_precision: 0.5655 - val_recall: 0.6013
# Epoch 5/20
# 228/228 [==============================] - 107s 469ms/step - loss: 0.7794 - accuracy: 0.6208 - precision: 0.5301 - recall: 0.5899 - val_loss: 0.7513 - val_accuracy: 0.6302 - val_precision: 0.5476 - val_recall: 0.5823
# Epoch 6/20
# 228/228 [==============================] - 106s 468ms/step - loss: 0.7718 - accuracy: 0.6333 - precision: 0.5408 - recall: 0.6060 - val_loss: 0.7512 - val_accuracy: 0.6276 - val_precision: 0.5444 - val_recall: 0.5823
# Epoch 7/20
# 228/228 [==============================] - 107s 469ms/step - loss: 0.7892 - accuracy: 0.6145 - precision: 0.5113 - recall: 0.5830 - val_loss: 0.7544 - val_accuracy: 0.6198 - val_precision: 0.5349 - val_recall: 0.5823
# Epoch 8/20
# 228/228 [==============================] - 107s 470ms/step - loss: 0.7494 - accuracy: 0.6451 - precision: 0.5475 - recall: 0.6163 - val_loss: 0.7502 - val_accuracy: 0.6354 - val_precision: 0.5549 - val_recall: 0.5759
# Epoch 9/20
# 228/228 [==============================] - 106s 467ms/step - loss: 0.7759 - accuracy: 0.6272 - precision: 0.5342 - recall: 0.5941 - val_loss: 0.7539 - val_accuracy: 0.6224 - val_precision: 0.5380 - val_recall: 0.5823
# Epoch 10/20
# 228/228 [==============================] - 107s 470ms/step - loss: 0.7791 - accuracy: 0.6276 - precision: 0.5318 - recall: 0.5967 - val_loss: 0.7541 - val_accuracy: 0.6198 - val_precision: 0.5349 - val_recall: 0.5823
# Epoch 11/20
# 228/228 [==============================] - 107s 470ms/step - loss: 0.7836 - accuracy: 0.6280 - precision: 0.5301 - recall: 0.5961 - val_loss: 0.7571 - val_accuracy: 0.6224 - val_precision: 0.5376 - val_recall: 0.5886
# Epoch 12/20
# 228/228 [==============================] - 108s 473ms/step - loss: 0.7784 - accuracy: 0.6297 - precision: 0.5348 - recall: 0.6013 - val_loss: 0.7545 - val_accuracy: 0.6224 - val_precision: 0.5380 - val_recall: 0.5823
# Epoch 13/20
# 228/228 [==============================] - 106s 467ms/step - loss: 0.7675 - accuracy: 0.6330 - precision: 0.5374 - recall: 0.5981 - val_loss: 0.7568 - val_accuracy: 0.6198 - val_precision: 0.5349 - val_recall: 0.5823
# Epoch 14/20
# 228/228 [==============================] - 105s 462ms/step - loss: 0.7825 - accuracy: 0.6367 - precision: 0.5353 - recall: 0.6132 - val_loss: 0.7479 - val_accuracy: 0.6302 - val_precision: 0.5482 - val_recall: 0.5759
# Epoch 15/20
# 228/228 [==============================] - 106s 466ms/step - loss: 0.7640 - accuracy: 0.6392 - precision: 0.5429 - recall: 0.6209 - val_loss: 0.7488 - val_accuracy: 0.6302 - val_precision: 0.5482 - val_recall: 0.5759
# Epoch 16/20
# 228/228 [==============================] - 107s 472ms/step - loss: 0.7829 - accuracy: 0.6206 - precision: 0.5231 - recall: 0.6024 - val_loss: 0.7514 - val_accuracy: 0.6276 - val_precision: 0.5449 - val_recall: 0.5759
# Epoch 17/20
# 228/228 [==============================] - 107s 471ms/step - loss: 0.7614 - accuracy: 0.6312 - precision: 0.5342 - recall: 0.6082 - val_loss: 0.7547 - val_accuracy: 0.6224 - val_precision: 0.5380 - val_recall: 0.5823
# Epoch 18/20
# 228/228 [==============================] - 107s 469ms/step - loss: 0.7685 - accuracy: 0.6302 - precision: 0.5314 - recall: 0.5955 - val_loss: 0.7552 - val_accuracy: 0.6302 - val_precision: 0.5482 - val_recall: 0.5759
# Epoch 19/20
# 228/228 [==============================] - 107s 471ms/step - loss: 0.7656 - accuracy: 0.6316 - precision: 0.5302 - recall: 0.6127 - val_loss: 0.7597 - val_accuracy: 0.6198 - val_precision: 0.5349 - val_recall: 0.5823
# Epoch 20/20
# 228/228 [==============================] - 107s 470ms/step - loss: 0.7602 - accuracy: 0.6426 - precision: 0.5522 - recall: 0.6112 - val_loss: 0.7578 - val_accuracy: 0.6224 - val_precision: 0.5380 - val_recall: 0.5823

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_relu.history[met])
    ax[i].plot(history_dpnet_relu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_relu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 3s 66ms/step - loss: 0.6986 - accuracy: 0.6519 - precision: 0.5571 - recall: 0.6067
# Loss of the model is -  0.6986468434333801
# Accuracy of the model is -  65.19173979759216 %
# Precision of the model is -  0.5570698380470276
# Recall of the model is -  0.6066790223121643

# %% [markdown]
# ## DP-Net - CNN Architecture for DP-SGD
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net')
    return dpnet

# %%
dpnet = dpnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet.summary()
# Out:
# Model: "DP-Net"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 32)                128
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet = dpnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 114s 470ms/step - loss: 0.8178 - accuracy: 0.5724 - precision: 0.4716 - recall: 0.5698 - val_loss: 1.1499 - val_accuracy: 0.4792 - val_precision: 0.4360 - val_recall: 0.9051
# Epoch 2/20
# 228/228 [==============================] - 107s 469ms/step - loss: 0.9631 - accuracy: 0.6175 - precision: 0.5232 - recall: 0.6247 - val_loss: 1.2627 - val_accuracy: 0.6510 - val_precision: 0.5632 - val_recall: 0.6772
# Epoch 3/20
# 228/228 [==============================] - 105s 462ms/step - loss: 1.1511 - accuracy: 0.6517 - precision: 0.5537 - recall: 0.6626 - val_loss: 1.3522 - val_accuracy: 0.6276 - val_precision: 0.5366 - val_recall: 0.6962
# Epoch 4/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.1751 - accuracy: 0.6485 - precision: 0.5540 - recall: 0.6482 - val_loss: 1.3277 - val_accuracy: 0.6458 - val_precision: 0.5632 - val_recall: 0.6203
# Epoch 5/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.1879 - accuracy: 0.6501 - precision: 0.5556 - recall: 0.6397 - val_loss: 1.2809 - val_accuracy: 0.6458 - val_precision: 0.5632 - val_recall: 0.6203
# Epoch 6/20
# 228/228 [==============================] - 105s 463ms/step - loss: 1.1274 - accuracy: 0.6541 - precision: 0.5653 - recall: 0.6467 - val_loss: 1.3077 - val_accuracy: 0.6458 - val_precision: 0.5632 - val_recall: 0.6203
# Epoch 7/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1787 - accuracy: 0.6475 - precision: 0.5562 - recall: 0.6440 - val_loss: 1.3062 - val_accuracy: 0.6484 - val_precision: 0.5665 - val_recall: 0.6203
# Epoch 8/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1653 - accuracy: 0.6516 - precision: 0.5574 - recall: 0.6511 - val_loss: 1.3015 - val_accuracy: 0.6484 - val_precision: 0.5673 - val_recall: 0.6139
# Epoch 9/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.2216 - accuracy: 0.6371 - precision: 0.5476 - recall: 0.6236 - val_loss: 1.3072 - val_accuracy: 0.6510 - val_precision: 0.5698 - val_recall: 0.6203
# Epoch 10/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.1724 - accuracy: 0.6480 - precision: 0.5567 - recall: 0.6348 - val_loss: 1.3090 - val_accuracy: 0.6458 - val_precision: 0.5625 - val_recall: 0.6266
# Epoch 11/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1912 - accuracy: 0.6497 - precision: 0.5615 - recall: 0.6423 - val_loss: 1.3169 - val_accuracy: 0.6484 - val_precision: 0.5642 - val_recall: 0.6392
# Epoch 12/20
# 228/228 [==============================] - 106s 466ms/step - loss: 1.2065 - accuracy: 0.6416 - precision: 0.5505 - recall: 0.6223 - val_loss: 1.3055 - val_accuracy: 0.6510 - val_precision: 0.5698 - val_recall: 0.6203
# Epoch 13/20
# 228/228 [==============================] - 106s 468ms/step - loss: 1.1989 - accuracy: 0.6410 - precision: 0.5504 - recall: 0.6300 - val_loss: 1.3052 - val_accuracy: 0.6484 - val_precision: 0.5665 - val_recall: 0.6203
# Epoch 14/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1363 - accuracy: 0.6624 - precision: 0.5694 - recall: 0.6505 - val_loss: 1.2942 - val_accuracy: 0.6484 - val_precision: 0.5689 - val_recall: 0.6013
# Epoch 15/20
# 228/228 [==============================] - 106s 466ms/step - loss: 1.1737 - accuracy: 0.6491 - precision: 0.5505 - recall: 0.6445 - val_loss: 1.2961 - val_accuracy: 0.6484 - val_precision: 0.5689 - val_recall: 0.6013
# Epoch 16/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.1956 - accuracy: 0.6440 - precision: 0.5469 - recall: 0.6304 - val_loss: 1.2965 - val_accuracy: 0.6484 - val_precision: 0.5689 - val_recall: 0.6013
# Epoch 17/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1885 - accuracy: 0.6454 - precision: 0.5569 - recall: 0.6259 - val_loss: 1.3061 - val_accuracy: 0.6484 - val_precision: 0.5673 - val_recall: 0.6139
# Epoch 18/20
# 228/228 [==============================] - 106s 465ms/step - loss: 1.1720 - accuracy: 0.6428 - precision: 0.5420 - recall: 0.6393 - val_loss: 1.2973 - val_accuracy: 0.6484 - val_precision: 0.5689 - val_recall: 0.6013
# Epoch 19/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.1849 - accuracy: 0.6503 - precision: 0.5511 - recall: 0.6506 - val_loss: 1.3048 - val_accuracy: 0.6510 - val_precision: 0.5698 - val_recall: 0.6203
# Epoch 20/20
# 228/228 [==============================] - 106s 465ms/step - loss: 1.1264 - accuracy: 0.6648 - precision: 0.5719 - recall: 0.6583 - val_loss: 1.3112 - val_accuracy: 0.6458 - val_precision: 0.5625 - val_recall: 0.6266

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet.history[met])
    ax[i].plot(history_dpnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 29ms/step - loss: 1.1949 - accuracy: 0.6622 - precision: 0.5699 - recall: 0.6122
# Loss of the model is -  1.1948639154434204
# Accuracy of the model is -  66.22418761253357 %
# Precision of the model is -  0.5699481964111328
# Recall of the model is -  0.6122449040412903

# %% [markdown]
# ## DP-Net - logits
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_logits_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-logits')
    return dpnet

# %%
dpnet_logits = dpnet_logits_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_logits.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=False,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_logits.summary()
# Out:
# Model: "DP-Net-logits"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 32)                128
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_logits = dpnet_logits.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# 228/228 [==============================] - 115s 477ms/step - loss: 0.7990 - accuracy: 0.5641 - precision: 0.4653 - recall: 0.5724 - val_loss: 1.0288 - val_accuracy: 0.5911 - val_precision: 0.5019 - val_recall: 0.8481
# Epoch 2/20
# 228/228 [==============================] - 105s 463ms/step - loss: 0.9478 - accuracy: 0.6273 - precision: 0.5349 - recall: 0.6445 - val_loss: 1.5673 - val_accuracy: 0.5885 - val_precision: 0.5000 - val_recall: 0.8228
# Epoch 3/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.0367 - accuracy: 0.6508 - precision: 0.5554 - recall: 0.6471 - val_loss: 1.4220 - val_accuracy: 0.6042 - val_precision: 0.5123 - val_recall: 0.7911
# Epoch 4/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.1389 - accuracy: 0.6465 - precision: 0.5535 - recall: 0.6424 - val_loss: 1.2651 - val_accuracy: 0.6693 - val_precision: 0.5820 - val_recall: 0.6962
# Epoch 5/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1295 - accuracy: 0.6494 - precision: 0.5592 - recall: 0.6355 - val_loss: 1.2445 - val_accuracy: 0.6693 - val_precision: 0.5829 - val_recall: 0.6899
# Epoch 6/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.1133 - accuracy: 0.6587 - precision: 0.5675 - recall: 0.6555 - val_loss: 1.2395 - val_accuracy: 0.6719 - val_precision: 0.5860 - val_recall: 0.6899
# Epoch 7/20
# 228/228 [==============================] - 106s 466ms/step - loss: 1.1085 - accuracy: 0.6579 - precision: 0.5676 - recall: 0.6557 - val_loss: 1.2512 - val_accuracy: 0.6693 - val_precision: 0.5812 - val_recall: 0.7025
# Epoch 8/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.0988 - accuracy: 0.6586 - precision: 0.5709 - recall: 0.6658 - val_loss: 1.2397 - val_accuracy: 0.6719 - val_precision: 0.5860 - val_recall: 0.6899
# Epoch 9/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1123 - accuracy: 0.6538 - precision: 0.5628 - recall: 0.6487 - val_loss: 1.2419 - val_accuracy: 0.6719 - val_precision: 0.5860 - val_recall: 0.6899
# Epoch 10/20
# 228/228 [==============================] - 106s 465ms/step - loss: 1.1403 - accuracy: 0.6529 - precision: 0.5571 - recall: 0.6485 - val_loss: 1.2528 - val_accuracy: 0.6667 - val_precision: 0.5781 - val_recall: 0.7025
# Epoch 11/20
# 228/228 [==============================] - 106s 466ms/step - loss: 1.1053 - accuracy: 0.6587 - precision: 0.5633 - recall: 0.6600 - val_loss: 1.2600 - val_accuracy: 0.6693 - val_precision: 0.5803 - val_recall: 0.7089
# Epoch 12/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1213 - accuracy: 0.6583 - precision: 0.5654 - recall: 0.6509 - val_loss: 1.2385 - val_accuracy: 0.6719 - val_precision: 0.5860 - val_recall: 0.6899
# Epoch 13/20
# 228/228 [==============================] - 106s 464ms/step - loss: 1.1260 - accuracy: 0.6444 - precision: 0.5489 - recall: 0.6345 - val_loss: 1.2467 - val_accuracy: 0.6719 - val_precision: 0.5851 - val_recall: 0.6962
# Epoch 14/20
# 228/228 [==============================] - 107s 468ms/step - loss: 1.1095 - accuracy: 0.6575 - precision: 0.5613 - recall: 0.6503 - val_loss: 1.2345 - val_accuracy: 0.6719 - val_precision: 0.5870 - val_recall: 0.6835
# Epoch 15/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.0994 - accuracy: 0.6617 - precision: 0.5694 - recall: 0.6535 - val_loss: 1.2309 - val_accuracy: 0.6719 - val_precision: 0.5879 - val_recall: 0.6772
# Epoch 16/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.1359 - accuracy: 0.6519 - precision: 0.5538 - recall: 0.6408 - val_loss: 1.2321 - val_accuracy: 0.6719 - val_precision: 0.5879 - val_recall: 0.6772
# Epoch 17/20
# 228/228 [==============================] - 106s 466ms/step - loss: 1.1294 - accuracy: 0.6509 - precision: 0.5577 - recall: 0.6453 - val_loss: 1.2421 - val_accuracy: 0.6719 - val_precision: 0.5860 - val_recall: 0.6899
# Epoch 18/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.0872 - accuracy: 0.6692 - precision: 0.5804 - recall: 0.6687 - val_loss: 1.2342 - val_accuracy: 0.6719 - val_precision: 0.5860 - val_recall: 0.6899
# Epoch 19/20
# 228/228 [==============================] - 107s 471ms/step - loss: 1.1011 - accuracy: 0.6517 - precision: 0.5649 - recall: 0.6526 - val_loss: 1.2460 - val_accuracy: 0.6745 - val_precision: 0.5873 - val_recall: 0.7025
# Epoch 20/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1275 - accuracy: 0.6608 - precision: 0.5728 - recall: 0.6618 - val_loss: 1.2499 - val_accuracy: 0.6667 - val_precision: 0.5781 - val_recall: 0.7025

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_logits.history[met])
    ax[i].plot(history_dpnet_logits.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_logits.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 28ms/step - loss: 1.1588 - accuracy: 0.6829 - precision: 0.5856 - recall: 0.6920
# Loss of the model is -  1.1588075160980225
# Accuracy of the model is -  68.28908324241638 %
# Precision of the model is -  0.5855572819709778
# Recall of the model is -  0.6920222640037537

# %% [markdown]
# ## DP-Net nobn
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_nobn_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-nobn')
    return dpnet

# %%
dpnet_nobn = dpnet_nobn_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_nobn.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_nobn.summary()
# Out:
# Model: "DP-Net-nobn"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 32)                230432
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 241,777
# Trainable params: 241,777
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_nobn = dpnet_nobn.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 98s 409ms/step - loss: 1.2590 - accuracy: 0.5944 - precision: 0.4234 - recall: 0.0211 - val_loss: 1.4420 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 2/20
# 228/228 [==============================] - 91s 402ms/step - loss: 1.6379 - accuracy: 0.6028 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4056 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 3/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.7094 - accuracy: 0.5935 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4326 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 4/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.7129 - accuracy: 0.5949 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4736 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 5/20
# 228/228 [==============================] - 92s 404ms/step - loss: 1.7367 - accuracy: 0.5955 - precision: 0.0262 - recall: 9.0420e-06 - val_loss: 1.4611 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 6/20
# 228/228 [==============================] - 92s 404ms/step - loss: 1.7119 - accuracy: 0.6003 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4654 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 7/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.7596 - accuracy: 0.5924 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4641 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 8/20
# 228/228 [==============================] - 93s 407ms/step - loss: 1.7245 - accuracy: 0.5993 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4613 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 9/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.7151 - accuracy: 0.6033 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4610 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 10/20
# 228/228 [==============================] - 92s 404ms/step - loss: 1.7319 - accuracy: 0.5996 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4607 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 11/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.7714 - accuracy: 0.5913 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4605 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 12/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.7368 - accuracy: 0.5986 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4602 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 13/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.7194 - accuracy: 0.6004 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4599 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 14/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.7015 - accuracy: 0.6052 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4596 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 15/20
# 228/228 [==============================] - 92s 403ms/step - loss: 1.7216 - accuracy: 0.6017 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4597 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 16/20
# 228/228 [==============================] - 92s 403ms/step - loss: 1.7510 - accuracy: 0.5919 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4595 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 17/20
# 228/228 [==============================] - 92s 407ms/step - loss: 1.7158 - accuracy: 0.6017 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4596 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 18/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.7448 - accuracy: 0.5953 - precision: 0.3493 - recall: 1.4468e-04 - val_loss: 1.4597 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 19/20
# 228/228 [==============================] - 92s 406ms/step - loss: 1.7502 - accuracy: 0.5935 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4596 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# Epoch 20/20
# 228/228 [==============================] - 92s 405ms/step - loss: 1.7452 - accuracy: 0.5956 - precision: 0.0000e+00 - recall: 0.0000e+00 - val_loss: 1.4590 - val_accuracy: 0.5885 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_nobn.history[met])
    ax[i].plot(history_dpnet_nobn.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_nobn.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 28ms/step - loss: 1.4052 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
# Loss of the model is -  1.4051692485809326
# Accuracy of the model is -  60.25073528289795 %
# Precision of the model is -  0.0
# Recall of the model is -  0.0

# %% [markdown]
# ## DP-Net pneu
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# \([Paper 2](https://openreview.net/forum?id=rJg851rYwH)\)
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_pneu_builder():
    # create DP-Net
    dpnet = Sequential([
        InputLayer(input_shape=(IMG_SHAPE[0], IMG_SHAPE[1], IMG_SHAPE[2])),
        Conv2D(filters=16, kernel_size=(8,8), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Conv2D(filters=32, kernel_size=(4,4), strides=2, padding='valid', activation='tanh'),
        BatchNormalization(),
        MaxPooling2D(pool_size=(2,2)),
        Flatten(),
        Dense(units=32, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ], name='DP-Net-pneu')
    return dpnet

# %%
dpnet_pneu = dpnet_pneu_builder()

# load weights from pneumonia pretraining
dpnet_pneu.load_weights(weights_path+'dpnet_tanh_public_weights.h5')

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet_pneu.compile(  
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet_pneu.summary()
# Out:
# Model: "DP-Net-pneu"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_8 (Conv2D)            (None, 125, 125, 16)      3088
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 125, 125, 16)      64
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 62, 62, 16)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 30, 30, 32)        8224
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 30, 30, 32)        128
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 15, 15, 32)        0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 7200)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 32)                230432
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 242,097
# Trainable params: 241,937
# Non-trainable params: 160
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet_pneu = dpnet_pneu.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT//BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT//BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# /usr/local/lib/python3.7/dist-packages/keras/backend.py:4982: UserWarning: "`binary_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
#   '"`binary_crossentropy` received `from_logits=True`, but the `output`'
# 228/228 [==============================] - 113s 467ms/step - loss: 0.8696 - accuracy: 0.6556 - precision: 0.5540 - recall: 0.7791 - val_loss: 6.0688 - val_accuracy: 0.4115 - val_precision: 0.4115 - val_recall: 1.0000
# Epoch 2/20
# 228/228 [==============================] - 107s 471ms/step - loss: 0.9798 - accuracy: 0.6613 - precision: 0.5605 - recall: 0.7696 - val_loss: 3.1607 - val_accuracy: 0.4479 - val_precision: 0.4254 - val_recall: 0.9747
# Epoch 3/20
# 228/228 [==============================] - 106s 464ms/step - loss: 1.0590 - accuracy: 0.6686 - precision: 0.5639 - recall: 0.7651 - val_loss: 5.0401 - val_accuracy: 0.4089 - val_precision: 0.4099 - val_recall: 0.9937
# Epoch 4/20
# 228/228 [==============================] - 107s 471ms/step - loss: 1.0823 - accuracy: 0.6757 - precision: 0.5675 - recall: 0.7632 - val_loss: 1.4007 - val_accuracy: 0.6250 - val_precision: 0.5302 - val_recall: 0.7785
# Epoch 5/20
# 228/228 [==============================] - 106s 467ms/step - loss: 1.1880 - accuracy: 0.6726 - precision: 0.5710 - recall: 0.7483 - val_loss: 1.9802 - val_accuracy: 0.6094 - val_precision: 0.7000 - val_recall: 0.0886
# Epoch 6/20
# 228/228 [==============================] - 106s 465ms/step - loss: 1.1771 - accuracy: 0.6766 - precision: 0.5701 - recall: 0.7581 - val_loss: 1.1992 - val_accuracy: 0.6719 - val_precision: 0.6379 - val_recall: 0.4684
# Epoch 7/20
# 228/228 [==============================] - 108s 474ms/step - loss: 1.1929 - accuracy: 0.6768 - precision: 0.5745 - recall: 0.7514 - val_loss: 1.3706 - val_accuracy: 0.6406 - val_precision: 0.5467 - val_recall: 0.7405
# Epoch 8/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.1546 - accuracy: 0.6821 - precision: 0.5839 - recall: 0.7613 - val_loss: 2.3592 - val_accuracy: 0.5443 - val_precision: 0.4723 - val_recall: 0.9177
# Epoch 9/20
# 228/228 [==============================] - 106s 466ms/step - loss: 1.1789 - accuracy: 0.6749 - precision: 0.5753 - recall: 0.7722 - val_loss: 1.1809 - val_accuracy: 0.6927 - val_precision: 0.6754 - val_recall: 0.4873
# Epoch 10/20
# 228/228 [==============================] - 107s 471ms/step - loss: 1.1615 - accuracy: 0.6775 - precision: 0.5740 - recall: 0.7684 - val_loss: 1.1569 - val_accuracy: 0.6927 - val_precision: 0.6695 - val_recall: 0.5000
# Epoch 11/20
# 228/228 [==============================] - 106s 466ms/step - loss: 1.1614 - accuracy: 0.6803 - precision: 0.5754 - recall: 0.7698 - val_loss: 1.1496 - val_accuracy: 0.7057 - val_precision: 0.6829 - val_recall: 0.5316
# Epoch 12/20
# 228/228 [==============================] - 106s 465ms/step - loss: 1.1473 - accuracy: 0.6808 - precision: 0.5817 - recall: 0.7746 - val_loss: 1.1467 - val_accuracy: 0.7057 - val_precision: 0.6800 - val_recall: 0.5380
# Epoch 13/20
# 228/228 [==============================] - 105s 462ms/step - loss: 1.1512 - accuracy: 0.6919 - precision: 0.5867 - recall: 0.7774 - val_loss: 1.1453 - val_accuracy: 0.7083 - val_precision: 0.6667 - val_recall: 0.5823
# Epoch 14/20
# 228/228 [==============================] - 107s 469ms/step - loss: 1.1358 - accuracy: 0.6858 - precision: 0.5821 - recall: 0.7726 - val_loss: 1.1587 - val_accuracy: 0.7057 - val_precision: 0.6364 - val_recall: 0.6646
# Epoch 15/20
# 228/228 [==============================] - 105s 463ms/step - loss: 1.1556 - accuracy: 0.6918 - precision: 0.5886 - recall: 0.7704 - val_loss: 1.1572 - val_accuracy: 0.7083 - val_precision: 0.6533 - val_recall: 0.6203
# Epoch 16/20
# 228/228 [==============================] - 107s 472ms/step - loss: 1.1521 - accuracy: 0.6861 - precision: 0.5888 - recall: 0.7704 - val_loss: 1.1537 - val_accuracy: 0.7057 - val_precision: 0.6692 - val_recall: 0.5633
# Epoch 17/20
# 228/228 [==============================] - 105s 464ms/step - loss: 1.1316 - accuracy: 0.6841 - precision: 0.5777 - recall: 0.7711 - val_loss: 1.1538 - val_accuracy: 0.7109 - val_precision: 0.6822 - val_recall: 0.5570
# Epoch 18/20
# 228/228 [==============================] - 107s 468ms/step - loss: 1.1532 - accuracy: 0.6826 - precision: 0.5753 - recall: 0.7642 - val_loss: 1.1563 - val_accuracy: 0.7109 - val_precision: 0.6794 - val_recall: 0.5633
# Epoch 19/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.1420 - accuracy: 0.6898 - precision: 0.5834 - recall: 0.7680 - val_loss: 1.1508 - val_accuracy: 0.7083 - val_precision: 0.6691 - val_recall: 0.5759
# Epoch 20/20
# 228/228 [==============================] - 107s 470ms/step - loss: 1.1753 - accuracy: 0.6775 - precision: 0.5762 - recall: 0.7625 - val_loss: 1.1538 - val_accuracy: 0.7109 - val_precision: 0.6741 - val_recall: 0.5759

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet_pneu.history[met])
    ax[i].plot(history_dpnet_pneu.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet_pneu.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 43/43 [==============================] - 1s 28ms/step - loss: 1.0072 - accuracy: 0.7448 - precision: 0.7075 - recall: 0.6104
# Loss of the model is -  1.0071579217910767
# Accuracy of the model is -  74.4837760925293 %
# Precision of the model is -  0.7075268626213074
# Recall of the model is -  0.6103895902633667

# %% [markdown]
# ## Evaluation

# %%
models = [
    dpnet_relu,
    dpnet,
    dpnet_logits,
    dpnet_nobn,
    dpnet_pneu,
]

# %% [markdown]
# ### Model Analysis

# %%
for model in models:
    print("Evaluating %s ..." % (model.name))
    loss, acc, prec, rec = model.evaluate(test_batched)
    print('\n')
# Out:
# Evaluating DP-Net-relu ...
# 43/43 [==============================] - 1s 28ms/step - loss: 0.6986 - accuracy: 0.6519 - precision: 0.5571 - recall: 0.6067
#
#
# Evaluating DP-Net ...
# 43/43 [==============================] - 1s 28ms/step - loss: 1.1949 - accuracy: 0.6622 - precision: 0.5699 - recall: 0.6122
#
#
# Evaluating DP-Net-logits ...
# 43/43 [==============================] - 1s 28ms/step - loss: 1.1588 - accuracy: 0.6829 - precision: 0.5856 - recall: 0.6920
#
#
# Evaluating DP-Net-nobn ...
# 43/43 [==============================] - 1s 28ms/step - loss: 1.4052 - accuracy: 0.6025 - precision: 0.0000e+00 - recall: 0.0000e+00
#
#
# Evaluating DP-Net-pneu ...
# 43/43 [==============================] - 1s 28ms/step - loss: 1.0072 - accuracy: 0.7448 - precision: 0.7075 - recall: 0.6104

# %% [markdown]
# ### Privacy Analysis

# %% [markdown]
# #### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size
DELTA = 1e-4

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(np.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS,
    DELTA)
print('Delta = %.e, Epsilon = %.3f'%(DELTA, eps))
# Out:
# Delta = 1e-04, Epsilon = 0.500

# %%
# get needed noise for target epsilon
min_noise = 1e-5
target_epsilon = 0.5
noise = compute_noise(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    target_epsilon,
    EPOCHS,
    DELTA,
    min_noise
)
print(noise)
# Out:
# DP-SGD with sampling rate = 0.438% and noise_multiplier = 2.083147287949324 iterated over 4562 steps satisfies differential privacy with eps = 0.5 and delta = 0.0001.
# 2.083147287949324

# %% [markdown]
# #### Membership Inference Attack

# %%
def calc_attack_inputs(attack_data):
    bc = tf.keras.backend.binary_crossentropy
    constant = tf.keras.backend.constant

    probs = []
    losses = []
    labels = []
    for x, y in attack_data.as_numpy_iterator():
        y = y[0]
        # predict
        pred = model.predict(x)[0]
        #pred = np.round(pred) # only label as output instead of prob
        probs.append(pred)
        # compute loss
        loss = bc(constant([y]), constant(pred), from_logits=False).numpy()[0]
        losses.append(loss)
        # get label
        labels.append(y)

    return np.array(probs), np.array(losses), np.array(labels)

# %%
# run membership inference attack
def run_mia(model, train_attack_data, test_attack_data):
    # get values for train set
    probs_train, loss_train, labels_train = calc_attack_inputs(train_attack_data)
    # get values for test set
    probs_test, loss_test, labels_test = calc_attack_inputs(test_attack_data)

    # prepare attacks
    attack_input = AttackInputData(
        probs_train = probs_train,
        probs_test = probs_test,
        loss_train = loss_train,
        loss_test = loss_test,
        labels_train = labels_train,
        labels_test = labels_test
    )

    slicing_spec = SlicingSpec(
        entire_dataset = True,
        by_class = True,
        by_percentiles = False,
        by_classification_correctness = True
    )

    attack_types = [
        #AttackType.THRESHOLD_ATTACK, # logistic was always better, so no threshold to save time
        AttackType.LOGISTIC_REGRESSION,
    ] 

    # run several attacks for different data slices
    attacks_result = mia.run_attacks(attack_input=attack_input,
                                     slicing_spec=slicing_spec,
                                     attack_types=attack_types)

    # plot the ROC curve of the best classifier
    plotting.plot_roc_curve(attacks_result.get_result_with_max_auc().roc_curve)
    plt.show()

    # print a user-friendly summary of the attacks
    print(attacks_result.summary(by_slices=False))

    # epsilon estimation based on attack, metric adapted for AUC from https://paperswithcode.com/paper/antipodes-of-label-differential-privacy-pate
    def empirical_eps(auc):
        if auc <= 0.5:
            return 0
        if auc == 1:
            return np.inf
        return np.log(auc / (1 - auc))

    # function to get lowest AUC result
    def get_result_with_min_auc(self) -> SingleAttackResult:
        aucs = [result.get_auc() for result in self.single_attack_results]
        return self.single_attack_results[np.argmin(aucs)]
    attacks_result.get_result_with_min_auc = get_result_with_min_auc

    min_auc = attacks_result.get_result_with_min_auc(attacks_result).get_auc()
    max_auc = attacks_result.get_result_with_max_auc().get_auc()
    eps_min_auc =  empirical_eps(min_auc) # lower bound
    eps_max_auc = empirical_eps(max_auc) # upper bound
    print('Empirical epsilon bounds from AUC: %0.2f, %0.2f'%(eps_min_auc, eps_max_auc))

# %%
for model in models:
    print('Membership Inference Attack on '+model.name+'...')
    run_mia(model, train_attack_data, test_attack_data)
    print('\n')
# Out:
# Membership Inference Attack on DP-Net-relu...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.45 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.17 on slice CLASS=1
# Empirical epsilon bounds from AUC: 0.00, 0.21
#
#
# Membership Inference Attack on DP-Net...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 817 training and 817 test examples) achieved an AUC of 0.55 on slice CLASS=0
#   LOGISTIC_REGRESSION (with 817 training and 817 test examples) achieved an advantage of 0.14 on slice CLASS=0
# Empirical epsilon bounds from AUC: 0.00, 0.20
#
#
# Membership Inference Attack on DP-Net-logits...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.42 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.16 on slice CLASS=1
# Empirical epsilon bounds from AUC: 0.00, 0.08
#
#
# Membership Inference Attack on DP-Net-nobn...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.49 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.10 on slice CLASS=1
# Empirical epsilon bounds from AUC: 0.00, 0.09
#
#
# Membership Inference Attack on DP-Net-pneu...
# Best-performing attacks over all slices
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an AUC of 0.45 on slice CLASS=1
#   LOGISTIC_REGRESSION (with 539 training and 539 test examples) achieved an advantage of 0.17 on slice CLASS=1
# Empirical epsilon bounds from AUC: 0.00, 0.29
