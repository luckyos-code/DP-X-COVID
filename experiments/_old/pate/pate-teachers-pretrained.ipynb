# %% [markdown]
# # Privacy-Preserving Detection of COVID-19 in X-Ray Images (PATE)

# %% [markdown]
# ###### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip install tensorflow-privacy
# Out:
# Collecting tensorflow-privacy
#   Downloading https://files.pythonhosted.org/packages/5e/53/31a388f82202a155f248f75cc0f45bd0b85a0ef020a2472e600dc19d38d6/tensorflow_privacy-0.5.2-py3-none-any.whl (192kB)
#      |████████████████████████████████| 194kB 8.1MB/s
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-privacy) (0.1.6)
# Requirement already satisfied: scipy>=0.17 in /usr/local/lib/python3.7/dist-packages (from tensorflow-privacy) (1.4.1)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.7/dist-packages (from tensorflow-privacy) (1.2.1)
# Requirement already satisfied: tensorflow-estimator>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-privacy) (2.4.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from dm-tree~=0.1.1->tensorflow-privacy) (1.15.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy>=0.17->tensorflow-privacy) (1.19.5)
# Installing collected packages: tensorflow-privacy
# Successfully installed tensorflow-privacy-0.5.2

# %%
# !wget -nc https://raw.githubusercontent.com/Berenice2018/PySyft-Bc/master/syft/frameworks/torch/differential_privacy/pate.py
# Out:
# --2021-04-29 13:44:06--  https://raw.githubusercontent.com/Berenice2018/PySyft-Bc/master/syft/frameworks/torch/differential_privacy/pate.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 17194 (17K) [text/plain]
# Saving to: ‘pate.py’
#
# pate.py             100%[===================>]  16.79K  --.-KB/s    in 0.001s
#
# 2021-04-29 13:44:06 (32.4 MB/s) - ‘pate.py’ saved [17194/17194]

# %% [markdown]
# ##### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from pate import perform_analysis

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasSGDOptimizer, VectorizedDPKerasAdamOptimizer

from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle, class_weight

import keras
from keras.layers import Input, Conv2D, Activation, Add, BatchNormalization, MaxPooling2D, AveragePooling2D, GlobalMaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, LeakyReLU, Flatten, ZeroPadding2D
from keras import layers
from tensorflow.keras.applications import ResNet50V2, EfficientNetB0
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.layers.merge import add
from keras.activations import relu, softmax
from keras.models import Sequential
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy

import os, sys, shutil, random, cv2, math
from shutil import copyfile
from distutils.dir_util import copy_tree
from tqdm import tqdm
from progressbar import ProgressBar

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
# To: /content/COVID-19_Radiography_Database.zip
# 780MB [00:05, 136MB/s]

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Set fixed random seed
seed = 42
np.random.seed(seed)
random.seed(seed)
random_state = 42

# Data parameters
SPLIT = 0.15
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 16
IMG_SIZE = [256, 256] # dataset image size is 299x299
EPOCHS = 20

# PATE parameters
TEACHER_NB = 50
NOISE_SCALE = 10.0
NOISE_EPSILON = 1 / NOISE_SCALE

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-test split
x_train, x_test, y_train, y_test = train_test_split(files, labels, test_size=SPLIT, random_state=random_state)

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 4607, 'COVID-19': 3077}
# test set:   {'normal': 817, 'COVID-19': 539}

# %%
TRAIN_IMG_COUNT = sum(TRAIN_DISTRIBUTION.values())
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Test: ' + str(sum(TEST_DISTRIBUTION.values())),
)
# Out:
# Train: 7684, Test: 1356

# %% [markdown]
# ###### Dataset partition for teachers

# %%
def partition_dataset(train_set, nb_teachers, teacher_id):
    # Get sets
    train_data, train_labels = train_set

    # Sanity check
    assert len(train_data) == len(train_labels)
    assert int(teacher_id) < int(nb_teachers)

    # This will floor the possible number of batches
    train_batch_len = int(len(train_data) / nb_teachers)
    assert train_batch_len >= 16

    # Compute start, end indices of partition
    train_start = teacher_id * train_batch_len
    train_end = (teacher_id+1) * train_batch_len

    # Slice partition off
    train_partition = (train_data[train_start:train_end], train_labels[train_start:train_end])

    return train_partition

# %%
teacher_sets = [partition_dataset((x_train,y_train), TEACHER_NB, teacher_id) for teacher_id in range(0, TEACHER_NB)]
print("Teacher partitions: " + str(len(teacher_sets)))
print("Length first train: " + str(len(teacher_sets[0][1])))
#print("Teacher 0: " + str(teacher_sets[0]))
# Out:
# Teacher partitions: 50
# Length first train: 153

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow datasets
for teacher_id in range(0, TEACHER_NB):
    train_set = teacher_sets[teacher_id]
    teacher_sets[teacher_id] = tf.data.Dataset.from_tensor_slices(train_set)

test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# create unlabeld and test data split for student
split = 3 * BATCH_SIZE * EPOCHS
student_unlabeled_files = tf.data.Dataset.from_tensor_slices((x_test[:split], y_test[:split]))
student_test_files = tf.data.Dataset.from_tensor_slices((x_test[split:], y_test[split:]))
STUDENT_TRAIN_LENGTH = tf.data.experimental.cardinality(student_unlabeled_files).numpy()
print("Length student unlabeled: " + str(STUDENT_TRAIN_LENGTH))
print("Length student test: \t  " + str(tf.data.experimental.cardinality(student_test_files).numpy()))
# Out:
# Length student unlabeled: 960
# Length student test: 	  396

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    file_path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
for teacher_id in range(0, TEACHER_NB):
    train_files = teacher_sets[teacher_id]
    teacher_sets[teacher_id] = train_files.map(get_img, num_parallel_calls=AUTOTUNE)

test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

student_unlabeled_ds = student_unlabeled_files.map(get_img, num_parallel_calls=AUTOTUNE)
student_test_ds = student_test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMG_SIZE[0], IMG_SIZE[1]),
  layers.experimental.preprocessing.Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for quick overview
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range=(0.85, 1.15), # randomly zoom image 
        brightness_range=(0.9, 1.1), # randomly shift brightness
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False,    # randomly flip images
        fill_mode='constant',   # constant filling of points outside boundaries of input
        cval=0.,)   # fill with zeros, see fill_mode

# %%
class RandomBrightness(layers.Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal"),
  layers.experimental.preprocessing.RandomRotation(0.1, fill_mode='constant'),
  layers.experimental.preprocessing.RandomTranslation(0.1, 0.1, fill_mode='constant'),
  layers.experimental.preprocessing.RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_training(ds, scale=True, shuffle=False, repeat=False, augment=False, cache=True, batch=True, shuffle_buffer_size=1000):
    # Resize and rescale all datasets
    if scale:
        ds = ds.map(lambda x, y: (resize_and_rescale(x), y),
                    num_parallel_calls=AUTOTUNE)

    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    # repeat training set forever
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)

    # batch datasets
    if batch:
        ds = ds.batch(BATCH_SIZE)
        # fetches batches in the background while training the model
        ds = ds.prefetch(buffer_size=AUTOTUNE)

    # use data augmentation only on the training set
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    return ds

# %%
TEACHER_IMG_CNTS = []
for teacher_id in range(0, TEACHER_NB):
    train_ds = teacher_sets[teacher_id]
    TEACHER_IMG_CNTS.append(tf.data.experimental.cardinality(train_ds).numpy())
    teacher_sets[teacher_id] = prepare_training(train_ds, shuffle=True, repeat=True, augment=True, cache='cache'+str(teacher_id))

test_batched = prepare_training(test_ds)

student_unlabeled = prepare_training(student_unlabeled_ds, batch=False, shuffle=True)
# seperate labels from images
student_data = np.array([x[0] for x in list(tf.data.Dataset.as_numpy_iterator(student_unlabeled))])
student_labels = np.array([x[1] for x in list(tf.data.Dataset.as_numpy_iterator(student_unlabeled))])

student_test_batched = prepare_training(student_test_ds)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(teacher_sets[0]))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)

class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())
print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.25

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ### Early stopping

# %%
# checkpoint = ModelCheckpoint("x-covid.h5", monitor=monitor='val_loss', save_best_only=True)
# early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# ## Teacher training

# %% [markdown]
# ### Model definition

# %%
def resnet_block(x, filters, kernel_size=3, stride=1,
           conv_shortcut=False, name=None):
    preact = BatchNormalization(epsilon=1.001e-5, name=name + '_preact_bn')(x)
    preact = Activation('relu', name=name + '_preact_relu')(preact)
    if conv_shortcut is True:
        shortcut = Conv2D(4 * filters, 1, strides=stride, name=name + '_0_conv')(preact)
    else:
        shortcut = MaxPooling2D(1, strides=stride)(x) if stride > 1 else x
    x = Conv2D(filters, 1, strides=1, use_bias=False, name=name + '_1_conv')(preact)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_1_bn')(x)
    x = Activation('relu', name=name + '_1_relu')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name=name + '_2_pad')(x)
    x = Conv2D(filters, kernel_size, strides=stride, use_bias=False, name=name + '_2_conv')(x)
    x = BatchNormalization(epsilon=1.001e-5, name=name + '_2_bn')(x)
    x = Activation('relu', name=name + '_2_relu')(x)
    x = Conv2D(4 * filters, 1, name=name + '_3_conv')(x)
    x = Add(name=name + '_out')([shortcut, x])
    return x

def resnet_stack(x, filters, blocks, stride1=2, name=None):
    x = resnet_block(x, filters, conv_shortcut=True, name=name + '_block1')
    for i in range(2, blocks):
        x = resnet_block(x, filters, name=name + '_block' + str(i))
    x = resnet_block(x, filters, stride=stride1, name=name + '_block' + str(blocks))
    return x

def ResNet(stack_fn, input, model_name='resnet'):
    x = ZeroPadding2D(padding=((3, 3), (3, 3)), name='conv1_pad')(input)
    x = Conv2D(64, 7, strides=2, use_bias=True, name='conv1_conv')(x)
    x = ZeroPadding2D(padding=((1, 1), (1, 1)), name='pool1_pad')(x)
    x = MaxPooling2D(3, strides=2, name='pool1_pool')(x)
    x = stack_fn(x)
    x = BatchNormalization(epsilon=1.001e-5, name='post_bn')(x)
    x = Activation('relu', name='post_relu')(x)
    # Create model.
    model = tf.keras.models.Model(input, x, name=model_name)
    return model

def ResNet18V2(input):
    def stack_fn(x):
        x = resnet_stack(x, 16, 2, name='conv2')
        x = resnet_stack(x, 32, 2, name='conv3')
        x = resnet_stack(x, 64, 2, name='conv4')
        x = resnet_stack(x, 128, 2, stride1=1, name='conv5')
        return x
    return ResNet(stack_fn, input, 'resnet18v2')

# %%
def resnet18_builder():
    # ResNet18V2 without head
    resnet18 = ResNet18V2(Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)))
    model = Sequential([
        Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),
        # add resnet18 to model
        resnet18,
        # add last pooling layer
        GlobalAveragePooling2D(name='AvgPool'),
        # add dropout (inspired by inception-resnet-v2)
        Dropout(0.2, name='Dropout'),
        # add classification layer for normal/COVID-19
        Dense(units=1, activation='sigmoid', name='Output'),
    ], name='ResNet18V2')
    
    return model

# %%
METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

teacher_models = []
for teacher_id in range(0, TEACHER_NB):
    teacher = resnet18_builder()
    # load weights
    teacher.load_weights('resnet18_relu_public_weights.h5')
    teacher_models.append(teacher)
    teacher_models[teacher_id].compile(
        optimizer=Adam(lr=1e-3),
        loss='binary_crossentropy',
        metrics=METRICS
    )

# %%
teacher_models[0].summary()
# Out:
# Model: "ResNet18V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet18v2 (Functional)      (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
pbar = ProgressBar()
teacher_histories = []
for teacher_id in pbar(range(0, TEACHER_NB)):
    teacher_histories.append(teacher_models[teacher_id].fit(
        teacher_sets[teacher_id],
        steps_per_epoch=TEACHER_IMG_CNTS[teacher_id] // BATCH_SIZE,
        epochs=EPOCHS,
        class_weight=class_weight_dict,
        callbacks=[learning_rate_decay],
        verbose=0,
    ))
# Out:
# 100% (50 of 50) |########################| Elapsed Time: 0:37:14 Time:  0:37:14

# %% [markdown]
# ### Evaluation on test set

# %%
for teacher_id in range(0, TEACHER_NB):
    print("Teacher %d"%(teacher_id))
    loss, acc, prec, rec = teacher_models[teacher_id].evaluate(test_batched)
# Out:
# Teacher 0
# 85/85 [==============================] - 7s 67ms/step - loss: 1.3092 - accuracy: 0.5081 - precision: 0.4446 - recall: 0.9536
# Teacher 1
# 85/85 [==============================] - 2s 14ms/step - loss: 1.2488 - accuracy: 0.6209 - precision: 0.5714 - recall: 0.1855
# Teacher 2
# 85/85 [==============================] - 2s 14ms/step - loss: 0.4848 - accuracy: 0.7611 - precision: 0.7384 - recall: 0.6178
# Teacher 3
# 85/85 [==============================] - 2s 14ms/step - loss: 0.8978 - accuracy: 0.5848 - precision: 0.4868 - recall: 0.8200
# Teacher 4
# 85/85 [==============================] - 2s 14ms/step - loss: 0.5609 - accuracy: 0.7345 - precision: 0.6801 - recall: 0.6271
# Teacher 5
# 85/85 [==============================] - 2s 14ms/step - loss: 0.7991 - accuracy: 0.6364 - precision: 0.6494 - recall: 0.1855
# Teacher 6
# 85/85 [==============================] - 2s 14ms/step - loss: 2.5345 - accuracy: 0.6055 - precision: 0.8333 - recall: 0.0093
# Teacher 7
# 85/85 [==============================] - 2s 14ms/step - loss: 0.5109 - accuracy: 0.7522 - precision: 0.7042 - recall: 0.6494
# Teacher 8
# 85/85 [==============================] - 2s 14ms/step - loss: 0.5730 - accuracy: 0.7146 - precision: 0.6462 - recall: 0.6234
# Teacher 9
# 85/85 [==============================] - 2s 14ms/step - loss: 0.8364 - accuracy: 0.6903 - precision: 0.7644 - recall: 0.3191
# Teacher 10
# 85/85 [==============================] - 2s 14ms/step - loss: 0.5884 - accuracy: 0.7330 - precision: 0.6572 - recall: 0.6865
# Teacher 11
# 85/85 [==============================] - 2s 14ms/step - loss: 0.6100 - accuracy: 0.6932 - precision: 0.6323 - recall: 0.5455
# Teacher 12
# 85/85 [==============================] - 2s 14ms/step - loss: 0.9221 - accuracy: 0.6718 - precision: 0.7080 - recall: 0.2968
# Teacher 13
# 85/85 [==============================] - 2s 14ms/step - loss: 0.5463 - accuracy: 0.7471 - precision: 0.6591 - recall: 0.7532
# Teacher 14
# 85/85 [==============================] - 2s 14ms/step - loss: 0.5188 - accuracy: 0.7677 - precision: 0.6806 - recall: 0.7829
# Teacher 15
# 85/85 [==============================] - 2s 14ms/step - loss: 1.0336 - accuracy: 0.6254 - precision: 0.5452 - recall: 0.3469
# Teacher 16
# 85/85 [==============================] - 2s 14ms/step - loss: 0.5560 - accuracy: 0.7544 - precision: 0.7320 - recall: 0.6030
# Teacher 17
# 85/85 [==============================] - 2s 14ms/step - loss: 0.8357 - accuracy: 0.6888 - precision: 0.5634 - recall: 0.9647
# Teacher 18
# 85/85 [==============================] - 2s 14ms/step - loss: 1.0626 - accuracy: 0.6357 - precision: 0.6471 - recall: 0.1837
# Teacher 19
# 85/85 [==============================] - 2s 14ms/step - loss: 0.8681 - accuracy: 0.6645 - precision: 0.7442 - recall: 0.2375
# Teacher 20
# 85/85 [==============================] - 2s 14ms/step - loss: 0.9755 - accuracy: 0.6254 - precision: 0.6867 - recall: 0.1058
# Teacher 21
# 85/85 [==============================] - 2s 14ms/step - loss: 1.3915 - accuracy: 0.5391 - precision: 0.4603 - recall: 0.9239
# Teacher 22
# 85/85 [==============================] - 2s 14ms/step - loss: 2.5055 - accuracy: 0.6128 - precision: 0.6944 - recall: 0.0464
# Teacher 23
# 85/85 [==============================] - 2s 14ms/step - loss: 5.3256 - accuracy: 0.6055 - precision: 1.0000 - recall: 0.0074
# Teacher 24
# 85/85 [==============================] - 2s 14ms/step - loss: 0.5026 - accuracy: 0.7640 - precision: 0.7110 - recall: 0.6846
# Teacher 25
# 85/85 [==============================] - 2s 15ms/step - loss: 0.5590 - accuracy: 0.7323 - precision: 0.6973 - recall: 0.5770
# Teacher 26
# 85/85 [==============================] - 2s 14ms/step - loss: 0.6372 - accuracy: 0.7493 - precision: 0.7043 - recall: 0.6364
# Teacher 27
# 85/85 [==============================] - 2s 14ms/step - loss: 0.7857 - accuracy: 0.7146 - precision: 0.7360 - recall: 0.4397
# Teacher 28
# 85/85 [==============================] - 2s 14ms/step - loss: 0.7445 - accuracy: 0.6578 - precision: 0.5532 - recall: 0.7236
# Teacher 29
# 85/85 [==============================] - 2s 14ms/step - loss: 0.8429 - accuracy: 0.6504 - precision: 0.8037 - recall: 0.1596
# Teacher 30
# 85/85 [==============================] - 2s 14ms/step - loss: 0.6276 - accuracy: 0.7087 - precision: 0.6532 - recall: 0.5696
# Teacher 31
# 85/85 [==============================] - 2s 14ms/step - loss: 0.6653 - accuracy: 0.6807 - precision: 0.6216 - recall: 0.5028
# Teacher 32
# 85/85 [==============================] - 2s 14ms/step - loss: 0.8422 - accuracy: 0.6748 - precision: 0.6424 - recall: 0.4100
# Teacher 33
# 85/85 [==============================] - 2s 14ms/step - loss: 0.8715 - accuracy: 0.7080 - precision: 0.7658 - recall: 0.3822
# Teacher 34
# 85/85 [==============================] - 2s 14ms/step - loss: 0.8167 - accuracy: 0.6571 - precision: 0.5409 - recall: 0.9072
# Teacher 35
# 85/85 [==============================] - 2s 14ms/step - loss: 0.6435 - accuracy: 0.7087 - precision: 0.5870 - recall: 0.9017
# Teacher 36
# 85/85 [==============================] - 2s 14ms/step - loss: 2.2950 - accuracy: 0.6091 - precision: 0.5421 - recall: 0.1076
# Teacher 37
# 85/85 [==============================] - 2s 15ms/step - loss: 0.6302 - accuracy: 0.7190 - precision: 0.7182 - recall: 0.4824
# Teacher 38
# 85/85 [==============================] - 2s 14ms/step - loss: 1.3745 - accuracy: 0.6342 - precision: 0.6039 - recall: 0.2319
# Teacher 39
# 85/85 [==============================] - 2s 14ms/step - loss: 0.6439 - accuracy: 0.7544 - precision: 0.6476 - recall: 0.8386
# Teacher 40
# 85/85 [==============================] - 2s 14ms/step - loss: 1.1084 - accuracy: 0.6423 - precision: 0.6250 - recall: 0.2505
# Teacher 41
# 85/85 [==============================] - 2s 15ms/step - loss: 0.6681 - accuracy: 0.6976 - precision: 0.6838 - recall: 0.4453
# Teacher 42
# 85/85 [==============================] - 2s 15ms/step - loss: 0.6736 - accuracy: 0.7235 - precision: 0.7384 - recall: 0.4712
# Teacher 43
# 85/85 [==============================] - 2s 14ms/step - loss: 0.6689 - accuracy: 0.6925 - precision: 0.6155 - recall: 0.6030
# Teacher 44
# 85/85 [==============================] - 2s 14ms/step - loss: 0.6856 - accuracy: 0.6822 - precision: 0.6607 - recall: 0.4119
# Teacher 45
# 85/85 [==============================] - 4s 14ms/step - loss: 0.9126 - accuracy: 0.6453 - precision: 0.5378 - recall: 0.7662
# Teacher 46
# 85/85 [==============================] - 2s 14ms/step - loss: 0.8830 - accuracy: 0.7131 - precision: 0.6744 - recall: 0.5380
# Teacher 47
# 85/85 [==============================] - 2s 15ms/step - loss: 0.4838 - accuracy: 0.7706 - precision: 0.6913 - recall: 0.7644
# Teacher 48
# 85/85 [==============================] - 2s 14ms/step - loss: 0.6119 - accuracy: 0.7146 - precision: 0.6070 - recall: 0.7996
# Teacher 49
# 85/85 [==============================] - 2s 14ms/step - loss: 1.5501 - accuracy: 0.5929 - precision: 0.4637 - recall: 0.1540

# %% [markdown]
# ## Aggregate student dataset

# %%
def ensemble_preds(nb_teachers, data):
  # Compute shape of array that will hold probabilities produced by each
  # teacher, for each training point, and each output class
  result_shape = (nb_teachers, len(data))
  # Create array that will hold result
  result = np.zeros(result_shape, dtype=np.float32)

  # Get predictions from each teacher
  pbar = ProgressBar()
  for teacher_id in pbar(range(0, nb_teachers)):
    # Get predictions on our training data and store in result array
    result[teacher_id] = [x[0] for x in teacher_models[teacher_id].predict(data, verbose=0)]

  return result

# %%
# get teacher predictions
teacher_preds = ensemble_preds(TEACHER_NB, student_data)
# turn probs into labels
teacher_preds = np.asarray(np.round(teacher_preds), dtype=np.int32)
# Out:
# 100% (50 of 50) |########################| Elapsed Time: 0:00:49 Time:  0:00:49

# %%
def aggregate_noisy_max(preds, lap_scale):
  preds = preds.T
  labels = []
  #beta = 1 / epsilon # same as lap scale??
  for pred in preds:
    label_count = np.bincount(pred, minlength = 2)
    # convert to float for laplace
    label_count = np.asarray(label_count, dtype=np.float32)
    for i in range(len(label_count)):
      label_count[i] += np.random.laplace(loc=0.0, scale=lap_scale)
    noisy_labels = np.argmax(label_count)
    labels.append(noisy_labels)

  labels = np.asarray(labels, dtype=np.int32)
  return labels

# %%
# aggregate and add noise
aggregated_labels = aggregate_noisy_max(teacher_preds, NOISE_SCALE)

# %%
# test ensemble accuracy
assert len(aggregated_labels) == len(student_labels)
# Check against correct labels to compute correct guesses
correct = np.sum(aggregated_labels == student_labels.reshape(len(student_labels)))
# Divide by number of labels to obtain accuracy
agg_acc = float(correct) / len(student_labels)
print("Accuracy of the aggregated labels: " + str(agg_acc))
# Out:
# Accuracy of the aggregated labels: 0.5260416666666666

# %%
student_aggregated_ds = tf.data.Dataset.from_tensor_slices((student_data, aggregated_labels))
student_aggregated_batched = prepare_training(student_aggregated_ds, scale=False, cache='cache')

# %% [markdown]
# ## Student model (ResNet18V2)
# [Paper V1](https://scholar.google.com/scholar?cluster=9281510746729853742&hl=en&as_sdt=0,5)
# [Paper V2](https://scholar.google.com/scholar?cluster=14035416619237709781&hl=en&as_sdt=0,5)

# %% [markdown]
# ### Model definition

# %%
resnet18 = resnet18_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

resnet18.compile(
    optimizer=Adam(lr=1e-3),
    loss='binary_crossentropy',
    metrics=METRICS
)

# %%
resnet18.summary()
# Out:
# Model: "ResNet18V2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# resnet18v2 (Functional)      (None, 8, 8, 512)         897088
# _________________________________________________________________
# AvgPool (GlobalAveragePoolin (None, 512)               0
# _________________________________________________________________
# Dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# Output (Dense)               (None, 1)                 513
# =================================================================
# Total params: 897,601
# Trainable params: 891,713
# Non-trainable params: 5,888
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_resnet18 = resnet18.fit(
    student_aggregated_batched,
    steps_per_epoch=STUDENT_TRAIN_LENGTH // BATCH_SIZE,
    epochs=EPOCHS,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/20
# 60/60 [==============================] - 7s 63ms/step - loss: 0.6016 - accuracy: 0.6978 - precision: 0.5336 - recall: 0.5689
# Epoch 2/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.5389 - accuracy: 0.7540 - precision: 0.5985 - recall: 0.7369
# Epoch 3/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.4980 - accuracy: 0.7686 - precision: 0.6220 - recall: 0.7414
# Epoch 4/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.4769 - accuracy: 0.8048 - precision: 0.6714 - recall: 0.7813
# Epoch 5/20
# 60/60 [==============================] - 3s 43ms/step - loss: 0.4348 - accuracy: 0.7961 - precision: 0.6532 - recall: 0.8043
# Epoch 6/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.4034 - accuracy: 0.8156 - precision: 0.6799 - recall: 0.8317
# Epoch 7/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.3930 - accuracy: 0.8095 - precision: 0.6763 - recall: 0.7985
# Epoch 8/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.2978 - accuracy: 0.8629 - precision: 0.7604 - recall: 0.8445
# Epoch 9/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.2511 - accuracy: 0.8907 - precision: 0.8071 - recall: 0.8718
# Epoch 10/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.2740 - accuracy: 0.8893 - precision: 0.7931 - recall: 0.8931
# Epoch 11/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.1975 - accuracy: 0.9071 - precision: 0.8337 - recall: 0.8942
# Epoch 12/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.1564 - accuracy: 0.9274 - precision: 0.8546 - recall: 0.9377
# Epoch 13/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.1332 - accuracy: 0.9483 - precision: 0.8923 - recall: 0.9569
# Epoch 14/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.1565 - accuracy: 0.9361 - precision: 0.8654 - recall: 0.9517
# Epoch 15/20
# 60/60 [==============================] - 3s 43ms/step - loss: 0.1415 - accuracy: 0.9368 - precision: 0.8973 - recall: 0.9101
# Epoch 16/20
# 60/60 [==============================] - 3s 43ms/step - loss: 0.1296 - accuracy: 0.9446 - precision: 0.9185 - recall: 0.9099
# Epoch 17/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.0403 - accuracy: 0.9938 - precision: 0.9857 - recall: 0.9955
# Epoch 18/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.0293 - accuracy: 0.9975 - precision: 0.9923 - recall: 1.0000
# Epoch 19/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.0225 - accuracy: 0.9975 - precision: 0.9923 - recall: 1.0000
# Epoch 20/20
# 60/60 [==============================] - 3s 42ms/step - loss: 0.0192 - accuracy: 0.9984 - precision: 0.9953 - recall: 1.0000

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_resnet18.history[met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = resnet18.evaluate(student_test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)
# Out:
# 25/25 [==============================] - 3s 75ms/step - loss: 1.1964 - accuracy: 0.6944 - precision: 0.6074 - recall: 0.5467
# Loss of the model is -  1.1963717937469482
# Accuracy of the model is -  69.44444179534912 %
# Precision of the model is -  0.6074073910713196
# Recall of the model is -  0.54666668176651

# %% [markdown]
# ## Privacy

# %% [markdown]
# ### Compute epsilon

# %%
# delta rule of thumb: set to less than the inverse of the training data size (1 / TRAIN_IMG_COUNT)
DELTA = 1e-4
print('Delta = %.e'%(DELTA))
# Out:
# Delta = 1e-04

# %%
dde, die = perform_analysis(
    teacher_preds=teacher_preds,
    indices=aggregated_labels,
    noise_eps=NOISE_EPSILON,
    delta=DELTA,
    moments=8,
    beta=0.09
)
print("Data dependent epsilon = ", dde)
print("Data independent epsilon = ", die)
# Out:
# Data dependent epsilon =  31.826987203881018
# Data independent epsilon =  47.610340371976186
