# %% [markdown]
# # Privacy-Preserving Detection of COVID-19 in X-Ray Images (DP-SGD)

# %% [markdown]
# ###### Notebook settings

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ## Prerequisites

# %% [markdown]
# ###### Install packages

# %%
# !pip install tensorflow-privacy
# Out:
# Requirement already satisfied: tensorflow-privacy in /usr/local/lib/python3.7/dist-packages (0.5.2)
# Requirement already satisfied: scipy>=0.17 in /usr/local/lib/python3.7/dist-packages (from tensorflow-privacy) (1.4.1)
# Requirement already satisfied: mpmath in /usr/local/lib/python3.7/dist-packages (from tensorflow-privacy) (1.2.1)
# Requirement already satisfied: tensorflow-estimator>=2.3.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow-privacy) (2.4.0)
# Requirement already satisfied: dm-tree~=0.1.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow-privacy) (0.1.6)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.7/dist-packages (from scipy>=0.17->tensorflow-privacy) (1.19.5)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from dm-tree~=0.1.1->tensorflow-privacy) (1.15.0)

# %% [markdown]
# ##### Import libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from tensorflow_privacy.privacy.analysis.rdp_accountant import compute_rdp
from tensorflow_privacy.privacy.analysis.rdp_accountant import get_privacy_spent
from tensorflow_privacy.privacy.optimizers.dp_optimizer_keras_vectorized import VectorizedDPKerasSGDOptimizer, VectorizedDPKerasAdamOptimizer


from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle, class_weight

import keras
from keras.layers import Input, Conv2D, Activation, BatchNormalization, MaxPool2D, AveragePooling2D, GlobalMaxPooling2D, GlobalAveragePooling2D, Dense, Dropout, LeakyReLU, Flatten, ZeroPadding2D
from keras import layers
from tensorflow.keras.applications import ResNet50V2, EfficientNetB0
from keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint
from keras.layers.merge import add
from keras.activations import relu, softmax
from keras.models import Sequential
from keras import regularizers
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import to_categorical
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy

import os, sys, shutil, random, cv2, math
from shutil import copyfile
from distutils.dir_util import copy_tree
from tqdm import tqdm

# %% [markdown]
# ##### Download dataset

# %% [markdown]
# ###### *COVID-19 Radiography Database*
# [Kaggle](https://www.kaggle.com/tawsifurrahman/covid19-radiography-database)
# [Paper 1](https://ieeexplore.ieee.org/document/9144185)
# [Paper 2](https://doi.org/10.1016/j.compbiomed.2021.104319)

# %%
if not os.path.exists('COVID-19_Radiography_Dataset'):
    # !gdown https://drive.google.com/uc?id=1ZMgUQkwNqvMrZ8QaQmSbiDqXOWAewwou
    # !unzip -q COVID-19_Radiography_Database.zip
    # !rm COVID-19_Radiography_Database.zip

# %% [markdown]
# ##### Define constants

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# Set fixed random seed
seed = 42
np.random.seed(seed)
random.seed(seed)
random_state = 42

# Data parameters
SPLIT = 0.15
IMBALANCE_RATIO = 1.5

# Model parameters
BATCH_SIZE = 8
IMG_SIZE = [256, 256] # dataset image size is 299x299
EPOCHS = 20

# DP-SGD parameters
NOISE_MULTIPLIER = 0.93
L2_NORM_CLIP = 1.0
MICROBATCHES = BATCH_SIZE

# %% [markdown]
# ## Data

# %% [markdown]
# ### Create dataset

# %%
savepath = 'data'

## dataset from https://www.kaggle.com/tawsifurrahman/covid19-radiography-database

# path to normal 
normal_imgpath = 'COVID-19_Radiography_Dataset/Normal'
normal_csvpath = 'COVID-19_Radiography_Dataset/Normal.metadata.xlsx'

# path to covid-19 
covid_imgpath = 'COVID-19_Radiography_Dataset/COVID'
covid_csvpath = 'COVID-19_Radiography_Dataset/COVID.metadata.xlsx'

# path to opacity 
opacity_imgpath = 'COVID-19_Radiography_Dataset/Lung_Opacity'
opacity_csvpath = 'COVID-19_Radiography_Dataset/Lung_Opacity.metadata.xlsx'

# path to pneumonia 
pneumonia_imgpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia'
pneumonia_csvpath = 'COVID-19_Radiography_Dataset/Viral Pneumonia.metadata.xlsx'

# %%
# stats
normal_cnt = len([name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))])
covid_cnt = len([name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))])
pneumonia_cnt = len([name for name in os.listdir(opacity_imgpath) if os.path.isfile(os.path.join(opacity_imgpath, name))]) + len([name for name in os.listdir(pneumonia_imgpath) if os.path.isfile(os.path.join(pneumonia_imgpath, name))])

class_count = {'normal': normal_cnt, 'COVID-19': covid_cnt, 'pneumonia': pneumonia_cnt}
print('Class count: ', class_count)
print('Total images: ', normal_cnt + covid_cnt + pneumonia_cnt)
# Out:
# Class count:  {'normal': 10192, 'COVID-19': 3616, 'pneumonia': 7357}
# Total images:  21165

# %% [markdown]
# ### Load dataset

# %% [markdown]
# ###### Retrieve filenames (paths) and labels

# %%
def get_data(paths, label_encoding):
    normal_imgpath, covid_imgpath = paths
    filenames = []
    y_labels = []

    # COVID-19
    covid_images = [covid_imgpath + '/' + name for name in os.listdir(covid_imgpath) if os.path.isfile(os.path.join(covid_imgpath, name))]
    random.shuffle(covid_images)
    covid_images = covid_images[:int(len(covid_images))]
    filenames.extend(covid_images)
    y_labels.extend([label_encoding.index('COVID-19') for img in covid_images])

    # normal
    normal_images = [normal_imgpath + '/' + name for name in os.listdir(normal_imgpath) if os.path.isfile(os.path.join(normal_imgpath, name))]
    random.shuffle(normal_images)
    normal_images = normal_images[:int(IMBALANCE_RATIO*len(covid_images))]
    filenames.extend(normal_images)
    y_labels.extend([label_encoding.index('normal') for img in normal_images])

    return np.array(filenames), np.array(y_labels)

# %%
datapaths = ['COVID-19_Radiography_Dataset/Normal', 'COVID-19_Radiography_Dataset/COVID']
label_encoding = ['normal', 'COVID-19'] # normal = 0, COVID-19 = 1

files, labels = get_data(datapaths, label_encoding)

# %% [markdown]
# ###### Create train-test split

# %%
# create train-val-test split
x_train, x_val, y_train, y_val = train_test_split(files, labels, test_size=2*SPLIT, random_state=random_state)
x_val, x_test, y_val, y_test = train_test_split(x_val, y_val, test_size=0.5, random_state=random_state)

# %%
def get_distribution(y):
    return {'normal': np.count_nonzero(y == 0),
            'COVID-19': np.count_nonzero(y == 1)}

# %%
TRAIN_DISTRIBUTION = get_distribution(y_train)
VAL_DISTRIBUTION = get_distribution(y_val)
TEST_DISTRIBUTION = get_distribution(y_test)
print('train set: ', TRAIN_DISTRIBUTION)
print('val set:   ', VAL_DISTRIBUTION)
print('test set:  ', TEST_DISTRIBUTION)
# Out:
# train set:  {'normal': 3810, 'COVID-19': 2518}
# val set:    {'normal': 804, 'COVID-19': 552}
# test set:   {'normal': 810, 'COVID-19': 546}

# %% [markdown]
# ###### Create tensors

# %%
# build tensorflow dataset
train_files = tf.data.Dataset.from_tensor_slices((x_train, y_train))
val_files = tf.data.Dataset.from_tensor_slices((x_val, y_val))
test_files = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# ###### Image retrieval

# %%
def get_img(x, y):
    file_path = x
    label = y
    # load the raw data from the file as a string
    img = tf.io.read_file(file_path)
    # convert the compressed string to a 3D uint8 tensor
    img = tf.image.decode_image(img, channels=3, expand_animations = False)
    return img, label

# %%
train_ds = train_files.map(get_img, num_parallel_calls=AUTOTUNE)
val_ds = val_files.map(get_img, num_parallel_calls=AUTOTUNE)
test_ds = test_files.map(get_img, num_parallel_calls=AUTOTUNE)

# %%
TRAIN_IMG_COUNT = tf.data.experimental.cardinality(train_ds).numpy()
VAL_IMG_COUNT = tf.data.experimental.cardinality(val_ds).numpy()
TEST_IMG_COUNT = tf.data.experimental.cardinality(test_ds).numpy()
print(
    'Train: ' + str(TRAIN_IMG_COUNT) + ',',
    'Val: ' + str(VAL_IMG_COUNT) + ',',
    'Test: ' + str(TEST_IMG_COUNT),
)
# Out:
# Train: 6328, Val: 1356, Test: 1356

# %% [markdown]
# ### Prepare for training

# %% [markdown]
# ###### Define preprocessing

# %%
resize_and_rescale = tf.keras.Sequential([
  layers.experimental.preprocessing.Resizing(IMG_SIZE[0], IMG_SIZE[1]),
  layers.experimental.preprocessing.Rescaling(scale=1./255)
])

# %% [markdown]
# ###### Define data augmentation

# %%
# implemented as keras layers below but kept for quick overview
datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range=(0.85, 1.15), # randomly zoom image 
        brightness_range=(0.9, 1.1), # randomly shift brightness
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip = True,  # randomly flip images
        vertical_flip=False,    # randomly flip images
        fill_mode='constant',   # constant filling of points outside boundaries of input
        cval=0.,)   # fill with zeros, see fill_mode

# %%
class RandomBrightness(layers.Layer):
  def __init__(self, factor=0.1, **kwargs):
    super().__init__(**kwargs)
    self.factor = factor

  def call(self, x):
    return tf.image.random_brightness(x, max_delta=self.factor)

# %%
data_augmentation = tf.keras.Sequential([
  layers.experimental.preprocessing.RandomFlip("horizontal"),
  layers.experimental.preprocessing.RandomRotation(0.1, fill_mode='constant'),
  layers.experimental.preprocessing.RandomTranslation(0.1, 0.1, fill_mode='constant'),
  layers.experimental.preprocessing.RandomZoom(0.15, fill_mode='constant'),
  RandomBrightness(0.1),
])

# %% [markdown]
# ###### Prepare batches

# %%
def prepare_training(ds, shuffle=False, repeat=False, augment=False, cache=True, shuffle_buffer_size=1000):
    # Resize and rescale all datasets
    ds = ds.map(lambda x, y: (resize_and_rescale(x), y),
                num_parallel_calls=AUTOTUNE)

    # use `.cache(filename)` to cache preprocessing work for datasets that don't
    # fit in memory.
    if cache:
        if isinstance(cache, str):
            ds = ds.cache(cache)
        else:
            ds = ds.cache()

    if shuffle:
        ds = ds.shuffle(buffer_size=shuffle_buffer_size)

    # repeat training set forever
    if repeat:
        ds = ds.repeat()
    else:
        ds = ds.repeat(1)

    # batch all datasets
    ds = ds.batch(BATCH_SIZE)

    # use data augmentation only on the training set
    if augment:
        ds = ds.map(lambda x, y: (data_augmentation(x, training=True), y), 
                    num_parallel_calls=AUTOTUNE)

    # fetches batches in the background while training the model
    ds = ds.prefetch(buffer_size=AUTOTUNE)

    return ds

# %%
train_batched = prepare_training(train_ds, shuffle=True, repeat=True, augment=True, cache='cache')
val_batched = prepare_training(val_ds)
test_batched = prepare_training(test_ds)

# %% [markdown]
# ### Visualization

# %% [markdown]
# ###### Distribution of labels in the sets

# %%
def plot_distributions(distributions):
    sns.set_style('darkgrid')
    n_plots = len(distributions)
    fig, ax = plt.subplots(1,n_plots, figsize=(15,5))
    plt.subplots_adjust(wspace=0.2, hspace=0.2)
    for i, x in enumerate(distributions.items()):
        name = x[0]
        dis = x[1]
        keys = list(dis.keys())
        values = list(dis.values())
        sns.barplot(x=keys, y=values, ax=ax[i]).set_title(name)
    fig.show()

# %%
plot_distributions({'train': TRAIN_DISTRIBUTION, 'val': VAL_DISTRIBUTION, 'test': TEST_DISTRIBUTION})

# %% [markdown]
# ###### Images from a training batch

# %%
def show_batch(image_batch, label_batch):
    plt.figure(figsize=(10,10))
    img_num = 9 if BATCH_SIZE > 9 else BATCH_SIZE
    for n in range(img_num):
        ax = plt.subplot(np.log(img_num) / np.log(2), np.log(img_num) / np.log(2), n+1)
        plt.imshow(image_batch[n])
        if label_batch[n] == 0:
            plt.title("NORMAL")
        elif label_batch[n] == 1:
            plt.title("COVID-19")
        plt.axis("off")

# %%
image_batch, label_batch = next(iter(train_batched))

# %%
show_batch(image_batch.numpy(), label_batch.numpy())
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %% [markdown]
# ## Tuning

# %% [markdown]
# ### Data Imbalance Correction

# %% [markdown]
# Define class weights

# %%
class_weights = class_weight.compute_class_weight('balanced',
                                                 np.unique(y_train),
                                                 y_train)

class_weight_dict = dict(enumerate(class_weights))

weight_iter = iter(class_weight_dict.values())
print('Weight for normal: \t{:.2f}'.format(next(weight_iter)))
print('Weight for COVID-19: \t{:.2f}'.format(next(weight_iter)))
# Out:
# Weight for normal: 	0.83
# Weight for COVID-19: 	1.26

# %% [markdown]
# ### Learning rate decay

# %%
learning_rate_decay = ReduceLROnPlateau(monitor='val_loss', patience=2, factor=0.1, min_lr=1e-6)

# %% [markdown]
# ### Early stopping

# %%
# checkpoint = ModelCheckpoint("x-covid.h5", monitor=monitor='val_loss', save_best_only=True)
# early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# %% [markdown]
# ## DP-Net - CNN Archecture for DP-SGD
# Based on [Paper 1](https://arxiv.org/abs/2007.14191)
# [[Paper 2](https://openreview.net/forum?id=rJg851rYwH)]
# [Paper BN](https://arxiv.org/pdf/2006.10919.pdf)

# %% [markdown]
# ### Model definition

# %%
def dpnet_builder():
    # create DP-Net
    dpnet = Sequential([
        Input(shape=(IMG_SIZE[0], IMG_SIZE[1], 3)),

        Conv2D(filters=32, kernel_size=(3,3), activation='tanh', strides=1),
        BatchNormalization(),
        Conv2D(filters=32, kernel_size=(3,3), activation='tanh', strides=1),
        BatchNormalization(),
        MaxPool2D(pool_size=(2,2), strides=2),

        Conv2D(filters=64, kernel_size=(3,3), activation='tanh', strides=1),
        BatchNormalization(),
        Conv2D(filters=64, kernel_size=(3,3), activation='tanh', strides=1),
        BatchNormalization(),
        MaxPool2D(pool_size=(2,2), strides=2),

        Conv2D(filters=128, kernel_size=(3,3), activation='tanh', strides=1),
        BatchNormalization(),
        Conv2D(filters=128, kernel_size=(3,3), activation='tanh', strides=1),
        BatchNormalization(),
        MaxPool2D(pool_size=(2,2), strides=2),

        Flatten(),
        Dense(units=128, activation='tanh'),
        BatchNormalization(),
        Dense(units=1, activation='sigmoid'),
    ])
    return dpnet

# %%
dpnet = dpnet_builder()

METRICS = [
    'accuracy',
    keras.metrics.Precision(name='precision'),
    keras.metrics.Recall(name='recall')
]

dpnet.compile(
    optimizer=VectorizedDPKerasAdamOptimizer(
        l2_norm_clip=L2_NORM_CLIP,
        noise_multiplier=NOISE_MULTIPLIER,
        num_microbatches=MICROBATCHES,
        learning_rate=1e-3 # default: 1e-3
    ),
    loss=BinaryCrossentropy(
        from_logits=True,
        reduction=tf.compat.v1.losses.Reduction.NONE
        # reduction is set to NONE to get loss in a vector form
    ),
    metrics=METRICS
)

# %%
dpnet.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_6 (Conv2D)            (None, 254, 254, 32)      896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 254, 254, 32)      128
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 252, 252, 32)      9248
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 252, 252, 32)      128
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 126, 126, 32)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 124, 124, 64)      18496
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 124, 124, 64)      256
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 122, 122, 64)      36928
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 122, 122, 64)      256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 61, 61, 64)        0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 59, 59, 128)       73856
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 59, 59, 128)       512
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 57, 57, 128)       147584
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 57, 57, 128)       512
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 28, 28, 128)       0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 100352)            0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               12845184
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 128)               512
# _________________________________________________________________
# Dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 13,134,625
# Trainable params: 13,133,473
# Non-trainable params: 1,152
# _________________________________________________________________

# %% [markdown]
# ### Training

# %%
history_dpnet = dpnet.fit(
    train_batched,
    steps_per_epoch=TRAIN_IMG_COUNT // BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=val_batched,
    validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
    class_weight=class_weight_dict,
    callbacks=[learning_rate_decay],
)
# Out:
# Epoch 1/100
# 791/791 [==============================] - 351s 405ms/step - loss: 0.8625 - accuracy: 0.5423 - precision: 0.4457 - recall: 0.5609 - val_loss: 0.9178 - val_accuracy: 0.4630 - val_precision: 0.3952 - val_recall: 0.5989
# Epoch 2/100
# 791/791 [==============================] - 302s 382ms/step - loss: 0.8376 - accuracy: 0.5475 - precision: 0.4441 - recall: 0.5554 - val_loss: 0.9527 - val_accuracy: 0.5163 - val_precision: 0.3524 - val_recall: 0.2232
# Epoch 3/100
# 791/791 [==============================] - 304s 384ms/step - loss: 0.8166 - accuracy: 0.5562 - precision: 0.4608 - recall: 0.5856 - val_loss: 0.8383 - val_accuracy: 0.5695 - val_precision: 0.4790 - val_recall: 0.6407
# Epoch 4/100
# 791/791 [==============================] - 305s 385ms/step - loss: 0.8304 - accuracy: 0.5665 - precision: 0.4711 - recall: 0.5879 - val_loss: 0.9127 - val_accuracy: 0.5999 - val_precision: 0.5058 - val_recall: 0.7931
# Epoch 5/100
# 791/791 [==============================] - 304s 384ms/step - loss: 0.8884 - accuracy: 0.5422 - precision: 0.4444 - recall: 0.5722 - val_loss: 0.9615 - val_accuracy: 0.5022 - val_precision: 0.4032 - val_recall: 0.4610
# Epoch 6/100
# 791/791 [==============================] - 303s 383ms/step - loss: 0.9199 - accuracy: 0.5141 - precision: 0.4273 - recall: 0.5649 - val_loss: 0.8502 - val_accuracy: 0.5614 - val_precision: 0.4604 - val_recall: 0.4428
# Epoch 7/100
# 791/791 [==============================] - 303s 384ms/step - loss: 0.9118 - accuracy: 0.5175 - precision: 0.4236 - recall: 0.5664 - val_loss: 0.8600 - val_accuracy: 0.5377 - val_precision: 0.4305 - val_recall: 0.4156
# Epoch 8/100
# 791/791 [==============================] - 305s 385ms/step - loss: 0.8941 - accuracy: 0.5308 - precision: 0.4382 - recall: 0.5866 - val_loss: 0.8780 - val_accuracy: 0.5414 - val_precision: 0.4418 - val_recall: 0.4755
# Epoch 9/100
# 791/791 [==============================] - 304s 384ms/step - loss: 0.9286 - accuracy: 0.5123 - precision: 0.4177 - recall: 0.5670 - val_loss: 0.8856 - val_accuracy: 0.5266 - val_precision: 0.4234 - val_recall: 0.4465
# Epoch 10/100
# 791/791 [==============================] - 304s 384ms/step - loss: 0
# Epoch 40/100
# 791/791 [==============================] - 306s 387ms/step - loss: 0.9103 - accuracy: 0.5130 - precision: 0.4228 - recall: 0.5657 - val_loss: 0.8647 - val_accuracy: 0.5422 - val_precision: 0.4437 - val_recall: 0.4864
# Epoch 41/100
# 791/791 [==============================] - 306s 387ms/step - loss: 0.9113 - accuracy: 0.5236 - precision: 0.4339 - recall: 0.5819 - val_loss: 0.8678 - val_accuracy: 0.5399 - val_precision: 0.4399 - val_recall: 0.4719
# Epoch 42/100
# 791/791 [==============================] - 306s 387ms/step - loss: 0.9287 - accuracy: 0.5145 - precision: 0.4271 - recall: 0.5646 - val_loss: 0.8672 - val_accuracy: 0.5444 - val_precision: 0.4421 - val_recall: 0.4501
# Epoch 43/100
# 791/791 [==============================] - 305s 386ms/step - loss: 0.9315 - accuracy: 0.5068 - precision: 0.4101 - recall: 0.5427 - val_loss: 0.8618 - val_accuracy: 0.5370 - val_precision: 0.4355 - val_recall: 0.4592
# Epoch 44/100
# 791/791 [==============================] - 304s 384ms/step - loss: 0.9227 - accuracy: 0.5167 - precision: 0.4203 - recall: 0.5555 - val_loss: 0.8602 - val_accuracy: 0.5355 - val_precision: 0.4340 - val_recall: 0.4592
# Epoch 45/100
# 791/791 [==============================] - 305s 385ms/step - loss: 0.9359 - accuracy: 0.5144 - precision: 0.4244 - recall: 0.5744 - val_loss: 0.8598 - val_accuracy: 0.5407 - val_precision: 0.4390 - val_recall: 0.4574
# Epoch 46/100
# 791/791 [==============================] - 304s 385ms/step - loss: 0.8978 - accuracy: 0.5174 - precision: 0.4236 - recall: 0.5775 - val_loss: 0.8632 - val_accuracy: 0.5340 - val_precision: 0.4322 - val_recall: 0.4574
# Epoch 47/100
# 791/791 [==============================] - 304s 385ms/step - loss: 0.9098 - accuracy: 0.5119 - precision: 0.4186 - recall: 0.5678 - val_loss: 0.8601 - val_accuracy: 0.5422 - val_precision: 0.4410 - val_recall: 0.4610
# Epoch 48/100
# 791/791 [==============================] - 304s 384ms/step - loss: 0.9179 - accuracy: 0.5234 - precision: 0.4352 - recall: 0.5738 - val_loss: 0.8632 - val_accuracy: 0.5392 - val_precision: 0.4379 - val_recall: 0.4610
# Epoch 49/100
# 791/791 [==============================] - 303s 383ms/step - loss: 0.8999 - accuracy: 0.5247 - precision: 0.4292 - recall: 0.5887 - val_loss: 0.8593 - val_accuracy: 0.5436 - val_precision: 0.4431 - val_recall: 0.4664
# Epoch 50/100
# 791/791 [==============================] - 304s 385ms/step - loss: 0.9438 - accuracy: 0.5012 - precision: 0.4032 - recall: 0.5461 - val_loss: 0.8600 - val_accuracy: 0.5459 - val_precision: 0.4450 - val_recall: 0.4628
# Epoch 51/100
# 791/791 [==============================] - 304s 385ms/step - loss: 0.9058 - accuracy: 0.5204 - precision: 0.4230 - recall: 0.5622 - val_loss: 0.8560 - val_accuracy: 0.5525 - val_precision: 0.4504 - val_recall: 0.4446
# Epoch 52/100
# 791/791 [==============================] - 305s 385ms/step - loss: 0.9249 - accuracy: 0.5201 - precision: 0.4275 - recall: 0.5627 - val_loss: 0.8630 - val_accuracy: 0.5459 - val_precision: 0.4409 - val_recall: 0.4265
# Epoch 53/100
# 791/791 [==============================] - 304s 385ms/step - loss: 0.8817 - accuracy: 0.5341 - precision: 0.4410 - recall: 0.5887 - val_loss: 0.8609 - val_accuracy: 0.5399 - val_precision: 0.4383 - val_recall: 0.4574
# Epoch 54/100
# 791/791 [==============================] - 304s 384ms/step - loss: 0.9148 - accuracy: 0.5279 - precision: 0.4348 - recall: 0.5813 - val_loss: 0.8603 - val_accuracy: 0.5429 - val_precision: 0.4417 - val_recall: 0.4610
# Epoch 55/100
# 791/791 [==============================] - 306s 386ms/step - loss: 0.9036 - accuracy: 0.5208 - precision: 0.4243 - recall: 0.5725 - val_loss: 0.8573 - val_accuracy: 0.5407 - val_precision: 0.4390 - val_recall: 0.4574
# Epoch 56/100
# 791/791 [==============================] - 305s 386ms/step - loss: 0.9240 - accuracy: 0.5095 - precision: 0.4159 - recall: 0.5408 - val_loss: 0.8609 - val_accuracy: 0.5399 - val_precision: 0.4380 - val_recall: 0.4555
# Epoch 57/100
# 791/791 [==============================] - 304s 385ms/step - loss: 0.9111 - accuracy: 0.5249 - precision: 0.4328 - recall: 0.5768 - val_loss: 0.8629 - val_accuracy: 0.5362 - val_precision: 0.4360 - val_recall: 0.4701
# Epoch 58/100
# 791/791 [==============================] - 306s 386ms/step - loss: 0.9258 - accuracy: 0.5136 - precision: 0.4205 - recall: 0.5588 - val_loss: 0.8618 - val_accuracy: 0.5503 - val_precision: 0.4483 - val_recall: 0.4483
# Epoch 59/100
# 791/791 [==============================] - 305s 386ms/step - loss: 0.9424 - accuracy: 0.5162 - precision: 0.4213 - recall: 0.5553 - val_loss: 0.8635 - val_accuracy: 0.5422 - val_precision: 0.4414 - val_recall: 0.4646
# Epoch 60/100
# 791/791 [==============================] - 305s 386ms/step - loss: 0.9310 - accuracy: 0.5190 - precision: 0.4259 - recall: 0.5602 - val_loss: 0.8600 - val_accuracy: 0.5348 - val_precision: 0.4330 - val_recall: 0.4574
# Epoch 61/100
# 791/791 [==============================] - 306s 386ms/step - loss: 0.9242 - accuracy: 0.5102 - precision: 0.4183 - recall: 0.5581 - val_loss: 0.8674 - val_accuracy: 0.5429 - val_precision: 0.4431 - val_recall: 0.4737
# Epoch 62/100
# 791/791 [==============================] - 305s 385ms/step - loss: 0.9469 - accuracy: 0.5142 - precision: 0.4232 - recall: 0.5663 - val_loss: 0.8610 - val_accuracy: 0.5488 - val_precision: 0.4468 - val_recall: 0.4501
# Epoch 63/100
# 791/791 [==============================] - 305s 385ms/step - loss: 0.9495 - accuracy: 0.5019 - precision: 0.4072 - recall: 0.5462 - val_loss: 0.8608 - val_accuracy: 0.5355 - val_precision: 0.4333 - val_recall: 0.4537
# Epoch 64/100
# 791/791 [==============================] - 304s 384ms/step - loss: 0.9466 - accuracy: 0.5052 - precision: 0.4162 - recall: 0.5509 - val_loss: 0.8668 - val_accuracy: 0.5325 - val_precision: 0.4354 - val_recall: 0.4955
# Epoch 65/100
# 335/791 [===========>..................] - ETA: 2:54 - loss: 0.9340 - accuracy: 0.5201 - precision: 0.4367 - recall: 0.5805
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-34-e68417cccc3b> in <module>()
#       6     validation_steps=VAL_IMG_COUNT // BATCH_SIZE,
#       7     class_weight=class_weight_dict,
# ----> 8     callbacks=[learning_rate_decay],
#       9 )
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    2942     return graph_function._call_flat(
# -> 2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#    2945   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1917       # No tape is watching; skip to running the function.
#    1918       return self._build_call_outputs(self._inference_function.call(
# -> 1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#    1921         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     558               inputs=args,
#     559               attrs=attrs,
# --> 560               ctx=ctx)
#     561         else:
#     562           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# ### Evaluation

# %% [markdown]
# ###### Visualize performance

# %%
fig, ax = plt.subplots(1, 4, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['loss', 'accuracy', 'precision', 'recall']):
    ax[i].plot(history_dpnet.history[met])
    ax[i].plot(history_dpnet.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %% [markdown]
# ###### Predict on test set

# %%
loss, acc, prec, rec = dpnet.evaluate(test_batched)
print("Loss of the model is - " , loss)
print("Accuracy of the model is - " , acc*100 , "%")
print("Precision of the model is - " , prec)
print("Recall of the model is - " , rec)

# %% [markdown]
# ## Privacy

# %% [markdown]
# ### Compute epsilon

# %%
# computes epsilon for given hyperparameters
def compute_epsilon(n, batch_size, noise_multiplier, epochs, delta):
    if noise_multiplier == 0.0:
        return float('inf')
    sampling_probability = batch_size / n
    steps = int(math.ceil(epochs * n / batch_size))
    orders = [1 + x / 10. for x in range(1, 100)] + list(range(12, 64))
    rdp = compute_rdp(
        q = sampling_probability,
        noise_multiplier = noise_multiplier,
        steps = steps,
        orders = orders)
    return get_privacy_spent(orders, rdp, target_delta=delta)[0]

# %%
# delta rule of thumb: set to less than the inverse of the training data size
delta = 1 / (TRAIN_IMG_COUNT * 1.5)
eps = compute_epsilon(
    TRAIN_IMG_COUNT,
    BATCH_SIZE,
    NOISE_MULTIPLIER,
    EPOCHS, # early_stopping.stopped_epoch
    delta)
print('Delta = %.e, Epsilon = %.3f'%(delta, eps))

# %% [markdown]
# ### Attacks
